# %%
#%pip install beautifulsoup4
#%pip install pip-system-certs
#% -m pip install ipykernel -U --force-reinstall

# %%
import requests
from bs4 import BeautifulSoup as bs
import pandas as pd
import os
from langchain_community.graphs import Neo4jGraph
from PyPDF2 import PdfReader
import fitz
from langdetect import detect
import spacy
import re
from unidecode import unidecode
import time

# %% [markdown]
# Conectando ao Neo4j

# %%
from neo4j import GraphDatabase

# Neo4j variables
NEO4J_URL = os.getenv("NEO4J_URL")
NEO4J_USERNAME =os.getenv("NEO4J_USERNAME")
NEO4J_PASSWORD = os.getenv("NEO4J_PASSWORD")


graph = GraphDatabase.driver(NEO4J_URL, auth=(NEO4J_USERNAME, NEO4J_PASSWORD))

# %% [markdown]
# - Buscar os links para a tese no Neo4j
# - Buscar o link do PDF no repositório da universidade
# - Baixar o PDF
# - Extrair o texto do PDF

# %% [markdown]
# Buscar links para a tese no Neo4j

# %%
# Query to get theses and their repositories from the Neo4j database
# This query retrieves theses that are published by the State University of Rio de Janeiro (UERJ) and have not been processed yet.
query1 = """
MATCH (t:Thesis)-[:publisher]-(uni:University{uri:'tag:stardog:api:UERJ'})
WHERE NOT EXISTS {(t{processed:true})}
RETURN distinct(t["uri"]) as Thesis, t["repository"] as repository 
"""

# Alternative query to get theses that do not have excerpts and have been processed.
query2 = """ 
match (t:Thesis)-[:publisher]-(uni:University{uri:'tag:stardog:api:UERJ'})
where (not (t:Thesis)-[:BFO_0000050]-(:Exerpt)) and  exists {(t{processed:true})}
return distinct(t["uri"]) as Thesis, t["repository"] as repository
"""

# Query to retrive theses with few pages and their repositories.
query3 = """
MATCH (t:Thesis)-[:publisher]-(uni:University{uri:'tag:stardog:api:UERJ'})
Match (t:Thesis)-[:BFO_0000050]-(e:Exerpt)
RETURN count(e) as pages, t["uri"] as Thesis, t["repository"] as repository
 order by (pages) limit 40
"""

query4 = """
MATCH (t:Thesis)-[:publisher]-(uni:University{uri:'tag:stardog:api:UERJ'})
WHERE NOT EXISTS {(t{processed:true})}
RETURN distinct(t["uri"]) as Thesis, t["title"] as title 
"""

query5 = """
MATCH (t:Thesis {processed: true})-[:publisher]-(uni:University {uri: 'tag:stardog:api:UERJ'})
WHERE NOT (t)--(:Exerpt)
RETURN distinct(t["uri"]) as Thesis, t["title"] as title 
"""

graph = GraphDatabase.driver(NEO4J_URL, auth=(NEO4J_USERNAME, NEO4J_PASSWORD))
results = graph.execute_query(query4).records
graph.close()

#results = graph.query(query2)
# Convert the results to a DataFrame
#thesis_repository = pd.DataFrame(results, columns=["pages", "Thesis", "repository"])
thesis_repository = pd.DataFrame(results, columns=["Thesis", "title"])
thesis_repository = thesis_repository.reset_index(drop=True) 
thesis_repository
# Out:
#                                                 Thesis  \
# 0    tag:stardog:api:analise_do_movimento_de_partic...
# 1    tag:stardog:api:por_uma_etica_coletiva_negra_o...
# 2    tag:stardog:api:uma_integracao_para_o_capital_...
# 3    tag:stardog:api:o_processo_politico_de_constru...
# 4    tag:stardog:api:possiveis_genealogias_para_tre...
# ..                                                 ...
# 512  tag:stardog:api:ouro_negro_cafe_e_escravos_na_...
# 513  tag:stardog:api:representacao_politica_negra_e...
# 514  tag:stardog:api:educacao_dos_negros_em_santa_c...
# 515  tag:stardog:api:a_multimodalidade_no_livro_did...
# 516  tag:stardog:api:precipitacao_curricular_respon...
#
#                                                  title
# 0    Análise do movimento de partículas numa soluçã...
# 1    Por uma ética coletiva negra: os cursos prepar...
# 2    Uma integração para o capital: a IIRSA como pr...
# 3    O processo político de construção dos Planos M...
# 4    Possíveis genealogias para três tipos de artis...
# ..                                                 ...
# 512  Ouro negro: café e escravos na formação da cla...
# 513  Representação política negra e feminina: candi...
# 514  Educação dos negros em Santa Catarina: narrati...
# 515  A multimodalidade no livro didático de inglês ...
# 516  Precipitação curricular responsável: entre a e...
#
# [517 rows x 2 columns]

# %% [markdown]
# Criando as utils functions

# %%
# Funcao para coletar link do repositorio na página da BDTD

def get_repository_link(title):

    bdtd_url = 'https://bdtd.ibict.br/vufind/Search/Results?lookfor=' + title.replace(' ', '+') + '&type=Title' #&limit=1'
    #Fazer requisição e parsear o arquivo html
    try:
        f = requests.get(bdtd_url, verify=True).text#, verify=False) 
    except:
        print("Sleeping for 5 seconds before retrying... (get_repository_link)")
        time.sleep(5)
        try:
            f = requests.get(bdtd_url, verify=True).text#, verify=False) 
        except:
            print("Sleeping for 30 seconds before retrying... (get_repository_link)")
            time.sleep(30)
            f = requests.get(bdtd_url, verify=True).text#, verify=False)    
    soup = bs(f, "html.parser")

    #Coletando link para o repositório
    link_list = []
    for doc in soup.find_all('a', href=True):

        if doc['href'].startswith('http://www.bdtd.uerj.br/'):
            path = doc['href']
            path = path.replace('http://www.bdtd.uerj.br/', 'https://www.bdtd.uerj.br:8443/')
            link_list.append(path)
    if link_list != []:
        return list(set(link_list))[0]
    else:
        return None



# Funcao para coletar link do pdf

def get_pdf_link(url):
    
    headers = {
    'User-Agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/58.0.3029.110 Safari/537.3'
                }

    #Fazer requisição e parsear o arquivo html
    try:
        f = requests.get(url, headers=headers, verify=True).text#, verify=False) 
        
    except:
        print("Sleeping for 5 seconds before retrying... (get_pdf_link)")
        time.sleep(5)
        try:
            f = requests.get(url, headers=headers, verify=True).text#, verify=False) 
        except:
            print("Sleeping for 30 seconds before retrying... (get_pdf_link)")
            time.sleep(30)
            f = requests.get(url, headers=headers, verify=True).text#, verify=False)    
    soup = bs(f, "html.parser")
    
    #Coletando link para as teses
    link_list = []
    for doc in soup.find_all('a', href=True):
        if doc['href'].startswith('/bitstream/'):     # (doc['href'].endswith('.pdf')):# & doc['href'].startswith('/bitstream')):
            path = doc['href']
            prefix_uni = 'https://www.bdtd.uerj.br:8443'
            link = prefix_uni + path
            link_list.append(link)
    if link_list != []:
        return list(set(link_list))
    else:
        return None
    
    #return None

#fazer download do arquivo
def download_file(pdf_link, thesis_uri):

    headers = {
    'User-Agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/58.0.3029.110 Safari/537.3'
                }
    
    # NOTE the stream=True parameter below
    try:
        r = requests.get(pdf_link, headers=headers, verify=True, stream=True)
    except:
        print("Sleeping for 5 seconds before retrying... (download_file)")
        time.sleep(5)
        try:
            r = requests.get(pdf_link, headers=headers, verify=True, stream=True)
        except:
            print("Sleeping for 30 seconds before retrying... (download_file)")
            time.sleep(30)
            r = requests.get(pdf_link, headers=headers, verify=True, stream=True)
    # raise_for_status() is not needed with stream=True
    # r.raise_for_status()
    with open('tese UERJ.pdf', 'wb') as f:
        for chunk in r.iter_content(chunk_size=8192):
            f.write(chunk)
    return 

#Carregando os modelos SpaCy para inglês e português 
nlp_en = spacy.load("en_core_web_lg")
nlp_pt = spacy.load("pt_core_news_lg")

# Funcão que recebe uma string e a limpar para ficar no formato aceitável para uma URI
def process_uri(x):
    return (re.sub('[^a-zA-Z0-9_ ]', '',
            unidecode(x.strip())
                        .replace(" ", "_")
                        .replace("[","")
                        .replace("]","")
                        .replace("?","")
                        .replace("'","")
                        .lower()))


# Função para extrair texto de uma tese em PDF e identificar entidades
def extratc_text(tese_path):
    
    # Processando o arquivo em PDF
    try:
        reader = PdfReader(tese_path)
        number_of_pages = len(reader.pages)
    
        excerpt = {}

        extractor = 'PdfReader'

    except:
        reader = fitz.open(tese_path)
        number_of_pages = len(reader)
    
        excerpt = {}
        
        extractor = 'PyMuPDF'

    # Iterando por cada página
    for page_number in range(number_of_pages):

        # Verificando qual extrator de pdf foi utilizado    
        if extractor == 'PdfReader':

            # Extraindo o texto da página
            try:
                if page_number == 0:
                    try:
                        page_text = (reader.pages[page_number].extract_text() + '\n ' 
                                    + reader.pages[page_number+1].extract_text()[:400])
                    except:
                        page_text = reader.pages[page_number].extract_text()
                else:
                    
                    if page_number == number_of_pages -1:
                        try:
                            page_text = (reader.pages[page_number-1].extract_text()[-400:] + '\n ' 
                                        + reader.pages[page_number].extract_text())
                        except:
                            page_text = reader.pages[page_number].extract_text()
                    
                    else:
                        try:
                            page_text = (reader.pages[page_number-1].extract_text()[-400:] + '\n ' 
                                        + reader.pages[page_number].extract_text() + '\n ' 
                                        + reader.pages[page_number+1].extract_text()[:400])  
                        except:
                            page_text = reader.pages[page_number].extract_text()
            except:
                page_text = ''
            
        else:
                
            # Extraindo o texto da página
            try:
                if page_number == 0:
                    try:
                        page_text = (reader[page_number].get_text() + '\n ' 
                                    + reader[page_number+1].get_text()[:400])
                    except:
                        page_text = reader[page_number].get_text()
                else:
                    
                    if page_number == number_of_pages -1:
                        try:
                            page_text = (reader[page_number-1].get_text()[-400:] + '\n ' 
                                        + reader[page_number].get_text())
                        except:
                            page_text = reader[page_number].get_text()
                    
                    else:
                        try:
                            page_text = (reader[page_number-1].get_text()[-400:] + '\n ' 
                                        + reader[page_number].get_text() + '\n ' 
                                        + reader[page_number+1].get_text()[:400])  
                        except:
                            page_text = reader[page_number].get_text()

            except:
                page_text = ''

        # Limpando page text         
        page_text = page_text.replace("'", "").replace('"', '')
        # Verifica se o último caractere é uma barra invertida
        if page_text != '':
            if page_text[-1] == '\\': 
                page_text = page_text[:-2]
        page_text = re.sub(r"[\ud800-\udfff]", " ", page_text)
        page_text = page_text.encode('utf-8').decode('utf-8')
        
        
        # Detectando o idioma do texto
        try:
            lang = detect(page_text)
            
        except:
            lang = 'Não_detectado'
        
        
        # Extraindo as entidades
        page_extracted = False
        if lang == 'pt':
            doc = nlp_pt(page_text)
            page_extracted = True
        if lang == 'en':
            doc = nlp_en(page_text)
            page_extracted = True
        

        if page_extracted:

            persons = []
            gpes = []
            #orgs = []
            for ent in doc.ents:
                if ent.label_ == "PER": #"PERSON":
                    persons.append(process_uri(ent.text))
                if ent.label_ == "LOC": #"GPE":
                    gpes.append(process_uri(ent.text))
                #if ent.label_ == "ORG":
                #    orgs.append(process_uri(ent.text))
                    
            excerpt[page_number] = {'text': page_text, 
                                    'lang': lang, 
                                    'persons': list(set(persons)), 
                                    'gpes': list(set(gpes)),
                                #'orgs': list(set(orgs))
                                }

    return excerpt

# %% [markdown]
# Iterando por todas as URI para extrair o texto e gravar no grafo NEO4j

# %%
# Gravar hora de início do processamento
start_time = pd.Timestamp.now()
parcial_time = pd.Timestamp.now()

for i in range(0,len(thesis_repository)):

    #title ='The problem of identity as it relates to the american black\'s vision of Africa'
    title = thesis_repository['title'][i].replace("?","").replace('-', ' ').replace('&', ' ').replace('/', ' ').replace('\\', ' ')  
    repo = get_repository_link(title)

    # Coletando o link do PDF
    #url = thesis_repository['repository'][i]
    thesis_uri = thesis_repository['Thesis'][i][16:]
    pdf_link = get_pdf_link(repo) #url)
    if pdf_link is not None:
        # Itereando pelos links de PDF encontrados (em alguns casos há outros materiais além da tese)
        for pdf_num in range(len(pdf_link)):
            print(f"{i} - Downloading and extracting: {thesis_uri} from {pdf_link[pdf_num]}")
            download_file(pdf_link[pdf_num], thesis_uri)

            # Extraindo o texto e entidades
            tese_path = 'tese UERJ.pdf'
            excerpt = extratc_text(tese_path)

            excerpts = []
            persons = []
            gpes = []

            # Salvando as triplas em CSV
            for n in excerpt.keys():

                excerpt_uri = thesis_repository['Thesis'][i] + '_pdf_' + str(pdf_num) + '_p_' + str(n)
                excerpt_text = excerpt[n]['text']
                # Verifica se o último caractere é uma barra invertida
                #if excerpt_text[-1] == '\\': 
                #    excerpt_text = excerpt_text[:-1]
                

                excerpt_page = 'pdf_' + str(pdf_num) + '_p_' + str(n)
                excerpt_lang = excerpt[n]['lang']
                
                excerpts.append([thesis_repository['Thesis'][i], excerpt_uri, excerpt_text, excerpt_page, excerpt_lang])
                    
                #Criando as relações com as entidades
                for person in excerpt[n]['persons']:
                    persons.append([excerpt_uri, 'tag:stardog:api:' + person])
                
                for gpe in excerpt[n]['gpes']:
                    gpes.append([excerpt_uri, 'tag:stardog:api:' + gpe])
            
            # Salvando os dados em CSV no diretório de importação do Neo4j
            pd.DataFrame(excerpts).to_csv('C:\\Users\\facordei\\.Neo4jDesktop\\relate-data\\dbmss\\dbms-792eabfc-5517-4220-ab29-30ef6ec3236e\\import\\excerptsUERJ.csv', index=False, header=False)
            pd.DataFrame(persons).to_csv('C:\\Users\\facordei\\.Neo4jDesktop\\relate-data\\dbmss\\dbms-792eabfc-5517-4220-ab29-30ef6ec3236e\\import\\personsUERJ.csv', index=False, header=False)
            pd.DataFrame(gpes).to_csv('C:\\Users\\facordei\\.Neo4jDesktop\\relate-data\\dbmss\\dbms-792eabfc-5517-4220-ab29-30ef6ec3236e\\import\\gpesUERJ.csv', index=False, header=False)

            #Deletando o arquivo PDF após o processamento
            os.remove('tese UERJ.pdf')

            print(f"Loading triplas: {thesis_uri}")

            # Importanto os dados para o Neo4j
            #Excerpts
            query = """
            LOAD CSV FROM 'file:///excerptsUERJ.csv'
            AS row
            MATCH  (t:Thesis{uri: row[0]})
            MERGE  (e:Exerpt{
                    uri: row[1],
                    text: row[2],
                    page: row[3],
                    lang: row[4]
                    })-[r:BFO_0000050]-(t);
            """
            graph = GraphDatabase.driver(NEO4J_URL, auth=(NEO4J_USERNAME, NEO4J_PASSWORD))
            results = graph.execute_query(query)
            graph.close()

            #Persons
            query = """
            LOAD CSV FROM 'file:///personsUERJ.csv'
            AS row
            MATCH  (e:Exerpt{uri: row[0]})
            MERGE  (p:Person{uri: row[1]})
            MERGE  (e)-[r:mentions]-(p);
            """
            graph = GraphDatabase.driver(NEO4J_URL, auth=(NEO4J_USERNAME, NEO4J_PASSWORD))
            results = graph.execute_query(query)
            graph.close()

            #GPEs
            query = """
            LOAD CSV FROM 'file:///gpesUERJ.csv'
            AS row
            MATCH  (e:Exerpt{uri: row[0]})
            MERGE  (p:Place{uri: row[1]})
            MERGE  (e)-[r:mentions]-(p);
            """
            graph = GraphDatabase.driver(NEO4J_URL, auth=(NEO4J_USERNAME, NEO4J_PASSWORD))
            results = graph.execute_query(query)
            graph.close()

            # Removendo os arquivos CSV após a importação
            os.remove('C:\\Users\\facordei\\.Neo4jDesktop\\relate-data\\dbmss\\dbms-792eabfc-5517-4220-ab29-30ef6ec3236e\\import\\excerptsUERJ.csv')
            os.remove('C:\\Users\\facordei\\.Neo4jDesktop\\relate-data\\dbmss\\dbms-792eabfc-5517-4220-ab29-30ef6ec3236e\\import\\personsUERJ.csv')
            os.remove('C:\\Users\\facordei\\.Neo4jDesktop\\relate-data\\dbmss\\dbms-792eabfc-5517-4220-ab29-30ef6ec3236e\\import\\gpesUERJ.csv')

            print(f"Total time: {pd.Timestamp.now() - start_time}")
            print(f"Partial time: {pd.Timestamp.now() - parcial_time}")
            # Atualizando a hora parcial
            parcial_time = pd.Timestamp.now()
    else:
        print(f"No PDF link found for {thesis_uri}")

    # gravando no grafo que a tese foi processada
    query = """
    MATCH  (t:Thesis{uri: \'""" + thesis_repository['Thesis'][i] +  """\'})
    SET t.processed = true
    SET t.repository = \'""" + str(repo) +  """\'
    """
    graph = GraphDatabase.driver(NEO4J_URL, auth=(NEO4J_USERNAME, NEO4J_PASSWORD))
    results = graph.execute_query(query)
    graph.close()
    #break
# Out:
# 0 - Downloading and extracting: analise_do_movimento_de_particulas_numa_solucao_de_buraco_negro_regular from https://www.bdtd.uerj.br:8443/bitstream/1/12959/1/katharine%20ivette.pdf
# Loading triplas: analise_do_movimento_de_particulas_numa_solucao_de_buraco_negro_regular
# Total time: 0 days 00:00:17.564101
# Partial time: 0 days 00:00:17.564596
# 1 - Downloading and extracting: por_uma_etica_coletiva_negra_os_cursos_preparatorios_para_posgraduacao_e_tensionamento_do_dispositivo_meritocratico_na_universidade from https://www.bdtd.uerj.br:8443/bitstream/1/20710/2/Tese%20-%20Renata%20Nascimento%20da%20Silva%20-%202023%20-%20Completa.pdf
# Loading triplas: por_uma_etica_coletiva_negra_os_cursos_preparatorios_para_posgraduacao_e_tensionamento_do_dispositivo_meritocratico_na_universidade
# Total time: 0 days 00:01:17.859908
# Partial time: 0 days 00:01:00.294808
# 2 - Downloading and extracting: uma_integracao_para_o_capital_a_iirsa_como_projeto_de_expansao_do_agronegocio_e_das_grandes_empreiteiras_brasileiras_20002014 from https://www.bdtd.uerj.br:8443/bitstream/1/20731/2/Tese%20-%20Larissa%20Martins%20Monteiro%20Barros%20-%202023%20-%20Completa.pdf
# Loading triplas: uma_integracao_para_o_capital_a_iirsa_como_projeto_de_expansao_do_agronegocio_e_das_grandes_empreiteiras_brasileiras_20002014
# Total time: 0 days 00:02:20.440410
# Partial time: 0 days 00:01:02.581502
# 3 - Downloading and extracting: o_processo_politico_de_construcao_dos_planos_municipais_de_educacao_no_territorio_de_identidade_do_sudoeste_baiano from https://www.bdtd.uerj.br:8443/bitstream/1/20717/2/Tese%20-%20Jo%c3%a3o%20Paulo%20Lopes%20dos%20Santos%20-%202023%20-%20Completa.pdf
# Loading triplas: o_processo_politico_de_construcao_dos_planos_municipais_de_educacao_no_territorio_de_identidade_do_sudoeste_baiano
# Total time: 0 days 00:03:09.644173
# Partial time: 0 days 00:00:49.202763
# 4 - Downloading and extracting: possiveis_genealogias_para_tres_tipos_de_artista_xamanicomessianico_artesaotrabalhador_e_pacientearteterapeutico from https://www.bdtd.uerj.br:8443/bitstream/1/18212/2/Dissertacao%20-%20Andr%c3%a9%20Fernandes%20Leite%20da%20Luz%20-%202021%20-%20Completa_.pdf
# Loading triplas: possiveis_genealogias_para_tres_tipos_de_artista_xamanicomessianico_artesaotrabalhador_e_pacientearteterapeutico
# Total time: 0 days 00:03:37.657345
# Partial time: 0 days 00:00:28.013172
# 5 - Downloading and extracting: enteogenos_na_america_latina_experiencias_de_realidade_expandida from https://www.bdtd.uerj.br:8443/bitstream/1/6946/1/Sebastian%20Torterola%20Antelo%20Dissertacao.pdf
# Loading triplas: enteogenos_na_america_latina_experiencias_de_realidade_expandida
# Total time: 0 days 00:03:53.427655
# Partial time: 0 days 00:00:15.770310
# 6 - Downloading and extracting: producao_curricular_de_itaborairj_discursos_e_significacoes from https://www.bdtd.uerj.br:8443/bitstream/1/18138/5/Disserta%c3%a7%c3%a3o%20-%20Gisele%20Pimentel%20da%20Silva%20Salgueiro%20-%202022%20-%20Completa.pdf
# Loading triplas: producao_curricular_de_itaborairj_discursos_e_significacoes
# Total time: 0 days 00:04:16.913217
# Partial time: 0 days 00:00:23.485562
# 7 - Downloading and extracting: espectros_da_differance_na_corporeidade_desconstrucao_da_arquitetura_e_cultura_corporal_afromaranhense_a_partir_de_jacques_derrida from https://www.bdtd.uerj.br:8443/bitstream/1/20079/2/Tese%20-%20Diogo%20Silva%20Corr%c3%aaa%20-%202022%20-%20Completa.pdf
# Loading triplas: espectros_da_differance_na_corporeidade_desconstrucao_da_arquitetura_e_cultura_corporal_afromaranhense_a_partir_de_jacques_derrida
# Total time: 0 days 00:05:04.421484
# Partial time: 0 days 00:00:47.508267
# 8 - Downloading and extracting: avaliacao_da_contaminacao_de_camaroes_por_hpas_na_baia_de_guanabara from https://www.bdtd.uerj.br:8443/bitstream/1/20070/2/Disserta%c3%a7%c3%a3o%20-%20Jo%c3%a3o%20Pedro%20Marvila%20Padilha%20Pitta%20-%202023%20-%20Completo.pdf
# Loading triplas: avaliacao_da_contaminacao_de_camaroes_por_hpas_na_baia_de_guanabara
# Total time: 0 days 00:05:24.468554
# Partial time: 0 days 00:00:20.047070
# 9 - Downloading and extracting: o_fio_ancestral_tecendo_narrativas_escreviventes from https://www.bdtd.uerj.br:8443/bitstream/1/19767/2/Disserta%c3%a7%c3%a3o%20-%20Tatiana%20Vasconcelos%20Cordeiro%20-%20Completa%20-%202022.pdf
# Loading triplas: o_fio_ancestral_tecendo_narrativas_escreviventes
# Total time: 0 days 00:05:55.180111
# Partial time: 0 days 00:00:30.711557
# 10 - Downloading and extracting: burocracia_e_acoes_afirmativas_a_implementacao_da_lei_ndeg1271112_em_cinco_universidades_federais from https://www.bdtd.uerj.br:8443/bitstream/1/19968/2/Tese%20-%20Luma%20Don%c3%a9%20Miranda%20-%202022%20-%20Completa.pdf
# Loading triplas: burocracia_e_acoes_afirmativas_a_implementacao_da_lei_ndeg1271112_em_cinco_universidades_federais
# Total time: 0 days 00:06:44.886549
# Partial time: 0 days 00:00:49.706438
# 11 - Downloading and extracting: autoria_e_producao_de_sentidos_na_escola_a_partir_da_perspectiva_discursiva_de_ensino_de_lingua from https://www.bdtd.uerj.br:8443/bitstream/1/20234/2/Disserta%c3%a7%c3%a3o%20-%20Andr%c3%a9a%20Costa%20Alegria%20-%202023%20-%20Completa.pdf
# Loading triplas: autoria_e_producao_de_sentidos_na_escola_a_partir_da_perspectiva_discursiva_de_ensino_de_lingua
# Total time: 0 days 00:07:11.538421
# Partial time: 0 days 00:00:26.651872
# 12 - Downloading and extracting: trajetoria_desenvolvimento_e_realizacao_profissional_na_area_de_saude_atravessamentos_de_genero_e_raca from https://www.bdtd.uerj.br:8443/bitstream/1/20182/2/Disserta%c3%a7%c3%a3o%20-%20Marcia%20Nana%20de%20Castro%20-%202023%20-%20Completa.pdf
# Loading triplas: trajetoria_desenvolvimento_e_realizacao_profissional_na_area_de_saude_atravessamentos_de_genero_e_raca
# Total time: 0 days 00:07:35.915863
# Partial time: 0 days 00:00:24.377442
# 13 - Downloading and extracting: o_discurso_sobre_o_indigena_e_sua_cultura_nas_producoes_escritas_de_alunos_do_ensino_fundamental from https://www.bdtd.uerj.br:8443/bitstream/1/20215/2/Disserta%c3%a7%c3%a3o%20-%20Jo%c3%a3o%20Gabriel%20de%20Vasconcelos%20Nascimento%20-%202023%20-%20Completa.pdf
# Loading triplas: o_discurso_sobre_o_indigena_e_sua_cultura_nas_producoes_escritas_de_alunos_do_ensino_fundamental
# Total time: 0 days 00:07:55.849063
# Partial time: 0 days 00:00:19.933200
# 14 - Downloading and extracting: aldeia_marakana_rexiste_um_espaco_intercultural_na_cidade_do_rio_de_janeiro from https://www.bdtd.uerj.br:8443/bitstream/1/20394/2/Disserta%c3%a7%c3%a3o%20-%20Erlan%20Raposo%20-%202023%20-%20Completa.pdf
# Loading triplas: aldeia_marakana_rexiste_um_espaco_intercultural_na_cidade_do_rio_de_janeiro
# Total time: 0 days 00:08:39.053150
# Partial time: 0 days 00:00:43.204087
# 15 - Downloading and extracting: antiincrustantes_a_base_de_cobre_revisao_da_literatura_e_analise_bibliometrica from https://www.bdtd.uerj.br:8443/bitstream/1/20429/2/Disserta%c3%a7%c3%a3o%20-%20Gustavo%20Marceno%20de%20Oliveira%20-%202022%20-%20Completa.pdf
# Loading triplas: antiincrustantes_a_base_de_cobre_revisao_da_literatura_e_analise_bibliometrica
# Total time: 0 days 00:09:00.197361
# Partial time: 0 days 00:00:21.144211
# 16 - Downloading and extracting: estruturacao_genica_e_ancestralidade_da_populacao_brasileira_estudo_da_populacao_nativa_da_ilha_de_marajo_com_o_emprego_de_marcadores_de_dna from https://www.bdtd.uerj.br:8443/bitstream/1/20349/2/Tese%20-%20Silvia%20de%20Oliveira%20Loiola%20Martins%20-%20Completa%20-%202022.pdf
# Loading triplas: estruturacao_genica_e_ancestralidade_da_populacao_brasileira_estudo_da_populacao_nativa_da_ilha_de_marajo_com_o_emprego_de_marcadores_de_dna
# Total time: 0 days 00:10:15.287397
# Partial time: 0 days 00:01:15.090036
# 17 - Downloading and extracting: os_neabis_como_espacos_de_problematizacao_e_aprendizagem_dos_processos_historicos_e_culturais_dos_povos_africanos_e_afrobrasileiros_vivencias_na_educacao_basica from https://www.bdtd.uerj.br:8443/bitstream/1/17924/2/Disserta%c3%a7%c3%a3o%20-%20Carla%20Cristina%20Goulart%20Farias%20-%202022%20-%20Completa.pdf
# Loading triplas: os_neabis_como_espacos_de_problematizacao_e_aprendizagem_dos_processos_historicos_e_culturais_dos_povos_africanos_e_afrobrasileiros_vivencias_na_educacao_basica
# Total time: 0 days 00:10:41.090750
# Partial time: 0 days 00:00:25.803353
# 18 - Downloading and extracting: multiplas_conexoes_a_presenca_intermidiatica_do_cordel_no_romance_de_dom_pantero_de_ariano_suassuna from https://www.bdtd.uerj.br:8443/bitstream/1/18297/2/Tese%20-%20Rosana%20da%20Silva%20Malafaia%20-%202022%20-%20Completa.pdf
# Loading triplas: multiplas_conexoes_a_presenca_intermidiatica_do_cordel_no_romance_de_dom_pantero_de_ariano_suassuna
# Total time: 0 days 00:11:19.894342
# Partial time: 0 days 00:00:38.803592
# 19 - Downloading and extracting: filtros_adaptativos_no_dominio_da_frequencia_para_correcao_de_previsao_climatica_da_temperatura_da_superficie_do_mar_global from https://www.bdtd.uerj.br:8443/bitstream/1/20173/2/Disserta%c3%a7%c3%a3o%20-%20Hugo%20Hinostroza%20Farf%c3%a1n%20-%202023%20-%20Completo.pdf
# Loading triplas: filtros_adaptativos_no_dominio_da_frequencia_para_correcao_de_previsao_climatica_da_temperatura_da_superficie_do_mar_global
# Total time: 0 days 00:11:40.903502
# Partial time: 0 days 00:00:21.009160
# 20 - Downloading and extracting: filogeografia_da_baleiabicudadecuvier_ziphius_cavirostris_odontoceti_ziphiidae from https://www.bdtd.uerj.br:8443/bitstream/1/20379/2/Disserta%c3%a7%c3%a3o%20-%20Anna%20Luiza%20dos%20SantosDonato%20-%202022%20-%20Completa.pdf
# Loading triplas: filogeografia_da_baleiabicudadecuvier_ziphius_cavirostris_odontoceti_ziphiidae
# Total time: 0 days 00:12:01.698832
# Partial time: 0 days 00:00:20.795330
# 21 - Downloading and extracting: anjos_arcabuzeiros_uma_tematica_andina from https://www.bdtd.uerj.br:8443/bitstream/1/20334/2/Dissertacao%20-%20Andre%20Luis%20da%20Rocha%20Perrett%20-%202023%20-%20Completo.pdf
# Loading triplas: anjos_arcabuzeiros_uma_tematica_andina
# Total time: 0 days 00:12:24.118473
# Partial time: 0 days 00:00:22.420641
# 22 - Downloading and extracting: autorias_indigenas_nos_livros_didaticos_do_pnld_culturas_ausencias_e_desafios from https://www.bdtd.uerj.br:8443/bitstream/1/18757/2/Disserta%c3%a7%c3%a3o%20-%20Juliana%20Rios%20Luiz%20-%202022%20-%20Completa.pdf
# Loading triplas: autorias_indigenas_nos_livros_didaticos_do_pnld_culturas_ausencias_e_desafios
# Total time: 0 days 00:12:39.813077
# Partial time: 0 days 00:00:15.693604
# 23 - Downloading and extracting: as_violacoes_de_direitos_dos_povos_indigenas_matogrossenses_o_caso_cintalarga_1963__1975 from https://www.bdtd.uerj.br:8443/bitstream/1/21059/2/Dissertacao%20-%20Milena%20Valle%20Rodrigues%20-%202023%20-%20Completa.pdf
# Loading triplas: as_violacoes_de_direitos_dos_povos_indigenas_matogrossenses_o_caso_cintalarga_1963__1975
# Total time: 0 days 00:13:00.148060
# Partial time: 0 days 00:00:20.334983
# 24 - Downloading and extracting: a_identidade_indigena_o_letramento_e_as_tecnologias_hipertextuais_no_referencial_curricular_nacional_para_a_educacao_indigena_rcnei from https://www.bdtd.uerj.br:8443/bitstream/1/18142/5/Tese%20-%20Angela%20Maria%20dos%20Santos%20Rufino%20-%202022%20-%20Completa.pdf
# Loading triplas: a_identidade_indigena_o_letramento_e_as_tecnologias_hipertextuais_no_referencial_curricular_nacional_para_a_educacao_indigena_rcnei
# Total time: 0 days 00:13:29.990747
# Partial time: 0 days 00:00:29.842687
# 25 - Downloading and extracting: as_margens_no_centro_podcast_trajetorias_perifericas_memorias_contrahegemonicas from https://www.bdtd.uerj.br:8443/bitstream/1/19879/2/Disserta%c3%a7%c3%a3o%20Pablo%20Andrade%20Afonso%20-%202022%20-%20Completa.pdf
# Loading triplas: as_margens_no_centro_podcast_trajetorias_perifericas_memorias_contrahegemonicas
# Total time: 0 days 00:13:58.404155
# Partial time: 0 days 00:00:28.413408
# 26 - Downloading and extracting: a_incidencia_da_cosmovisao_indigena_na_politica_externa_de_meio_ambiente_boliviana_a_internacionalizacao_dos_direitos_da_mae_terra_durante_os_dois_primeiros_mandatos_de_evo_morales_20062015 from https://www.bdtd.uerj.br:8443/bitstream/1/20086/2/Disserta%c3%a7%c3%a3o%20-%20Ana%20L%c3%bacia%20de%20Lacerda%20Gon%c3%a7alves%20-%202022%20-%20completa.pdf
# Loading triplas: a_incidencia_da_cosmovisao_indigena_na_politica_externa_de_meio_ambiente_boliviana_a_internacionalizacao_dos_direitos_da_mae_terra_durante_os_dois_primeiros_mandatos_de_evo_morales_20062015
# Total time: 0 days 00:14:27.999073
# Partial time: 0 days 00:00:29.594918
# 27 - Downloading and extracting: narrativas_e_olhares_sobre_culturas_indigenas_nas_aulas_de_artes_visuais from https://www.bdtd.uerj.br:8443/bitstream/1/18817/2/Disserta%c3%a7%c3%a3o%20-%20Adriana%20Cardoso%20Linhares%20-%202022%20-%20Completo.pdf
# Loading triplas: narrativas_e_olhares_sobre_culturas_indigenas_nas_aulas_de_artes_visuais
# Total time: 0 days 00:14:57.766707
# Partial time: 0 days 00:00:29.767634
# 28 - Downloading and extracting: do_territorio_ao_corpo_e_do_corpo_ao_territorio_o_corpo_como_escala_antiextrativismo_e_o_caso_de_berta_caceres from https://www.bdtd.uerj.br:8443/bitstream/1/19989/2/Disserta%c3%a7%c3%a3o%20-%20Vit%c3%b3ria%20Gonzalez%20Rodriguez%20-%202021%20-%20Completa.pdf
# Loading triplas: do_territorio_ao_corpo_e_do_corpo_ao_territorio_o_corpo_como_escala_antiextrativismo_e_o_caso_de_berta_caceres
# Total time: 0 days 00:15:31.862731
# Partial time: 0 days 00:00:34.096024
# 29 - Downloading and extracting: encontros_e_desencontros_na_india_do_seculo_xvi_15021599_a_redescoberta_dos_cristaos_de_sao_tome_pelos_portugueses_e_a_tentativa_de_latinizacao_do_rito_siromalabar_ate_ao_sinodo_de_diamper from https://www.bdtd.uerj.br:8443/bitstream/1/16349/2/Disserta%c3%a7%c3%a3o%20-%20%20Odimar%20Gomes%20Junior%20-%202021%20-%20Completa.pdf
# Loading triplas: encontros_e_desencontros_na_india_do_seculo_xvi_15021599_a_redescoberta_dos_cristaos_de_sao_tome_pelos_portugueses_e_a_tentativa_de_latinizacao_do_rito_siromalabar_ate_ao_sinodo_de_diamper
# Total time: 0 days 00:16:11.719359
# Partial time: 0 days 00:00:39.856628
# 30 - Downloading and extracting: naturezas_e_culturas_em_contextos_xakriaba_mg_um_estudo_com_educadores_indigenas from https://www.bdtd.uerj.br:8443/bitstream/1/20803/2/Tese%20-%20%20Adriana%20Maria%20Loureiro%20-%202021%20-%20Completa.pdf
# Loading triplas: naturezas_e_culturas_em_contextos_xakriaba_mg_um_estudo_com_educadores_indigenas
# Total time: 0 days 00:17:05.735074
# Partial time: 0 days 00:00:54.015715
# 31 - Downloading and extracting: um_retrato_historico_da_adocao_do_sistema_numerico_indoarabico_pela_europa_ocidental_e_o_papel_do_liber_abaci from https://www.bdtd.uerj.br:8443/bitstream/1/20134/2/Disserta%c3%a7%c3%a3o%20-%20Raquel%20Gomes%20Rosa%20de%20Mendon%c3%a7a%20-%202021%20-%20Completa.pdf.pdf
# Loading triplas: um_retrato_historico_da_adocao_do_sistema_numerico_indoarabico_pela_europa_ocidental_e_o_papel_do_liber_abaci
# Total time: 0 days 00:17:45.514829
# Partial time: 0 days 00:00:39.780763
# 32 - Downloading and extracting: temejakrekate_gnosecidio_resistencia_e_transcolonialidade_dos_saberes_tradicionais_no_vale_do_tocantinsaraguaia from https://www.bdtd.uerj.br:8443/bitstream/1/17506/5/Tese%20-%20Ronnielle%20de%20Azevedo-Lopes%20-%202021%20-%20Completa.pdf
# Loading triplas: temejakrekate_gnosecidio_resistencia_e_transcolonialidade_dos_saberes_tradicionais_no_vale_do_tocantinsaraguaia
# Total time: 0 days 00:19:37.123339
# Partial time: 0 days 00:01:51.607502
# 33 - Downloading and extracting: mulheres_indigenas_da_amazonia_e_politica_analises_a_partir_de_2018 from https://www.bdtd.uerj.br:8443/bitstream/1/18245/2/Disserta%c3%a7%c3%a3o%20-%20Viviane%20Heringer%20Tavares%20-%202021%20-%20Completa.pdf
# Loading triplas: mulheres_indigenas_da_amazonia_e_politica_analises_a_partir_de_2018
# Total time: 0 days 00:20:04.146979
# Partial time: 0 days 00:00:27.023640
# 34 - Downloading and extracting: lutando_por_novos_espacos_construindo_novos_saberes_uma_analise_da_politica_de_cotas_raciais_no_brasil_20132017 from https://www.bdtd.uerj.br:8443/bitstream/1/16344/2/Disserta%c3%a7%c3%a3o%20-%20Adilson%20Geroncio%20da%20Silva%20-%202020%20-%20Completa.pdf
# Loading triplas: lutando_por_novos_espacos_construindo_novos_saberes_uma_analise_da_politica_de_cotas_raciais_no_brasil_20132017
# Total time: 0 days 00:20:48.121913
# Partial time: 0 days 00:00:43.973934
# 35 - Downloading and extracting: e_se_eu_nao_existo_por_que_cobras_de_mim_a_dupla_marginalidade_das_pessoas_privadas_de_liberdade_sem_documentacao_civil_no_estado_do_rio_de_janeiro from https://www.bdtd.uerj.br:8443/bitstream/1/17228/5/Disserta%c3%a7%c3%a3o%20-%20Let%c3%adcia%20Valverde%20Chahaira%20-%202020%20-%20Completa.pdf
# Loading triplas: e_se_eu_nao_existo_por_que_cobras_de_mim_a_dupla_marginalidade_das_pessoas_privadas_de_liberdade_sem_documentacao_civil_no_estado_do_rio_de_janeiro
# Total time: 0 days 00:21:10.944010
# Partial time: 0 days 00:00:22.822097
# 36 - Downloading and extracting: casa_do_indio_uma_narrativa_sobre_o_controle_psicossocial_de_indigenas_na_ditadura_empresarial_militar from https://www.bdtd.uerj.br:8443/bitstream/1/19720/2/Tese%20-%20Andr%c3%a9%20Lu%c3%ads%20de%20Oliveira%20de%20Sant%27anna%20-%202022%20-%20Completa.pdf
# Loading triplas: casa_do_indio_uma_narrativa_sobre_o_controle_psicossocial_de_indigenas_na_ditadura_empresarial_militar
# Total time: 0 days 00:21:40.984280
# Partial time: 0 days 00:00:30.039751
# 37 - Downloading and extracting: reflections_on_coloniality_diasporas_and_cosmopolitanisms_in_kiran_desais_the_inheritance_of_loss from https://www.bdtd.uerj.br:8443/bitstream/1/16795/2/Dissertacao%20-%20Marcelli%20Claudinni%20Teixeira%20Osorio%20-%202020%20-%20Completa.pdf
# Loading triplas: reflections_on_coloniality_diasporas_and_cosmopolitanisms_in_kiran_desais_the_inheritance_of_loss
# Total time: 0 days 00:22:02.657126
# Partial time: 0 days 00:00:21.672846
# 38 - Downloading and extracting: influencia_de_variaveis_fisicoquimicas_de_biomassas_lignocelulosicas_e_de_processo_pirolitico_no_rendimento_de_biocarvao_e_potencial_de_aplicacao_no_sequestro_de_carbono from https://www.bdtd.uerj.br:8443/bitstream/1/17683/3/Tese%20-%20Renato%20Rocha%20Batista%20-%202021%20-%20Parcial.pdf
# Loading triplas: influencia_de_variaveis_fisicoquimicas_de_biomassas_lignocelulosicas_e_de_processo_pirolitico_no_rendimento_de_biocarvao_e_potencial_de_aplicacao_no_sequestro_de_carbono
# Total time: 0 days 00:22:44.659376
# Partial time: 0 days 00:00:42.002250
# 38 - Downloading and extracting: influencia_de_variaveis_fisicoquimicas_de_biomassas_lignocelulosicas_e_de_processo_pirolitico_no_rendimento_de_biocarvao_e_potencial_de_aplicacao_no_sequestro_de_carbono from https://www.bdtd.uerj.br:8443/bitstream/1/17683/2/Tese%20-%20Renato%20Rocha%20Batista%20-%202021%20-%20Completo.pdf
# Loading triplas: influencia_de_variaveis_fisicoquimicas_de_biomassas_lignocelulosicas_e_de_processo_pirolitico_no_rendimento_de_biocarvao_e_potencial_de_aplicacao_no_sequestro_de_carbono
# Total time: 0 days 00:22:45.666620
# Partial time: 0 days 00:00:01.006245
# 39 - Downloading and extracting: ruptura_historica_e_abordagem_criativa_uma_cartografia_de_identidades_nativas from https://www.bdtd.uerj.br:8443/bitstream/1/16753/2/Tese%20-%20Fernanda%20Vieira%20de%20Sant%20Anna%20-%202021%20-%20Completa.pdf
# Loading triplas: ruptura_historica_e_abordagem_criativa_uma_cartografia_de_identidades_nativas
# Total time: 0 days 00:23:43.369385
# Partial time: 0 days 00:00:57.702765
# 40 - Downloading and extracting: incantatrix_tropical_bruxaria_e_resistencia_feminina_no_brasil_colonial from https://www.bdtd.uerj.br:8443/bitstream/1/17632/5/Tese%20-%20Maria%20Cl%c3%a1udia%20Novaes%20Messias%20-%202021%20-%20Completa.pdf
# Loading triplas: incantatrix_tropical_bruxaria_e_resistencia_feminina_no_brasil_colonial
# Total time: 0 days 00:24:55.662596
# Partial time: 0 days 00:01:12.293211
# 41 - Downloading and extracting: narrativas_biograficas_em_cordel_a_intergenericidade_nas_aulas_de_lingua_portuguesa from https://www.bdtd.uerj.br:8443/bitstream/1/17182/2/Disserta%c3%a7%c3%a3o%20-%20T%c3%a2nia%20Regina%20dos%20Santos%20Fernandes%20-%202021%20-%20Completa.pdf
# Loading triplas: narrativas_biograficas_em_cordel_a_intergenericidade_nas_aulas_de_lingua_portuguesa
# Total time: 0 days 00:25:21.473689
# Partial time: 0 days 00:00:25.811093
# 42 - Downloading and extracting: a_roda_da_eternidade_o_elogio_da_morte_e_outros_discursos_sobre_finitude_na_oratoria_de_antonio_vieira from https://www.bdtd.uerj.br:8443/bitstream/1/16730/2/Tese%20-%20Felipe%20Lima%20da%20Silva%20-%202021%20-%20Completa.pdf
# Loading triplas: a_roda_da_eternidade_o_elogio_da_morte_e_outros_discursos_sobre_finitude_na_oratoria_de_antonio_vieira
# Total time: 0 days 00:26:06.728322
# Partial time: 0 days 00:00:45.254633
# 43 - Downloading and extracting: a_origem_do_r_caipira_no_portugues_do_brasil from https://www.bdtd.uerj.br:8443/bitstream/1/19001/2/Disserta%c3%a7%c3%a3o%20-%20Elizabeth%20Aparecida%20Hautz%20-%202021%20-%20Completa.pdf
# Loading triplas: a_origem_do_r_caipira_no_portugues_do_brasil
# Total time: 0 days 00:26:27.199646
# Partial time: 0 days 00:00:20.471324
# 44 - Downloading and extracting: isso_vai_transformar_o_rio_reflexoes_sobre_o_processo_de_criacao_do_museu_de_arte_do_rio__mar from https://www.bdtd.uerj.br:8443/bitstream/1/7427/1/Luiz%20Carlos%20Silva%20Guimaraes_Dissertacao.pdf
# Loading triplas: isso_vai_transformar_o_rio_reflexoes_sobre_o_processo_de_criacao_do_museu_de_arte_do_rio__mar
# Total time: 0 days 00:27:04.907234
# Partial time: 0 days 00:00:37.708555
# 45 - Downloading and extracting: raposa_serra_do_sol_vinculo_e_pertencimento from https://www.bdtd.uerj.br:8443/bitstream/1/18278/2/Tese%20-%20Bruno%20Pacheco%20de%20Oliveira%20-%202019%20-%20Completa.pdf
# Loading triplas: raposa_serra_do_sol_vinculo_e_pertencimento
# Total time: 0 days 00:27:38.462386
# Partial time: 0 days 00:00:33.554185
# 46 - Downloading and extracting: ancestralidade_genomica_matrilinear_de_individuos_das_regioes_centrooeste_norte_e_nordeste_do_brasil from https://www.bdtd.uerj.br:8443/bitstream/1/16124/1/Tatiana%20Lucia%20Santos%20Nogueira%20Tese%20completa.pdf
# Loading triplas: ancestralidade_genomica_matrilinear_de_individuos_das_regioes_centrooeste_norte_e_nordeste_do_brasil
# Total time: 0 days 00:28:03.297982
# Partial time: 0 days 00:00:24.835596
# 47 - Downloading and extracting: as_duras_penas_o_indio_na_literatura_e_a_literatura_indigena from https://www.bdtd.uerj.br:8443/bitstream/1/16785/2/Tese%20-%20Livia%20Penedo%20Jacob%20-%202020%20-%20Completo.pdf
# Loading triplas: as_duras_penas_o_indio_na_literatura_e_a_literatura_indigena
# Total time: 0 days 00:28:55.176825
# Partial time: 0 days 00:00:51.878843
# 48 - Downloading and extracting: todo_dia_e_dia_de_indio_que_indio from https://www.bdtd.uerj.br:8443/bitstream/1/19007/2/Disserta%c3%a7%c3%a3o%20-%20Monique%20Magalh%c3%a3es%20Marins%20-%202020%20-%20Completa.pdf
# Loading triplas: todo_dia_e_dia_de_indio_que_indio
# Total time: 0 days 00:29:17.266592
# Partial time: 0 days 00:00:22.089767
# 49 - Downloading and extracting: educacao_permanente_em_saude_por_teleducacao_o_caso_do_programa_telessaude_brasil_redes_sob_a_perspectiva_dos_usuarios from https://www.bdtd.uerj.br:8443/bitstream/1/4502/1/Tese%20Pedro%20Maximo%20completa.pdf
# Loading triplas: educacao_permanente_em_saude_por_teleducacao_o_caso_do_programa_telessaude_brasil_redes_sob_a_perspectiva_dos_usuarios
# Total time: 0 days 00:29:45.774835
# Partial time: 0 days 00:00:28.508243
# 50 - Downloading and extracting: nao_porque_ele_quis_mas_pela_nossa_luta_conversando_aprendendo_e_fazendo_historias_com_professores_indigenas from https://www.bdtd.uerj.br:8443/bitstream/1/17269/5/Tese%20-%20Leonardo%20Ferreira%20Peixoto%20-%202020%20-%20Completa.pdf
# Loading triplas: nao_porque_ele_quis_mas_pela_nossa_luta_conversando_aprendendo_e_fazendo_historias_com_professores_indigenas
# Total time: 0 days 00:30:10.555918
# Partial time: 0 days 00:00:24.781083
# 51 - Downloading and extracting: quem_sao_os_indigenas_presentes_nas_politicas_curriculares_um_estudo_da_lei_no_1164508 from https://www.bdtd.uerj.br:8443/bitstream/1/10064/1/Dissertacao%20Maria%20Carolina%20Neves%20Lopes.pdf
# Loading triplas: quem_sao_os_indigenas_presentes_nas_politicas_curriculares_um_estudo_da_lei_no_1164508
# Total time: 0 days 00:30:22.883050
# Partial time: 0 days 00:00:12.328143
# 52 - Downloading and extracting: paisagens_e_fluxos_curriculares_pataxo_processos_de_hibridizacao_e_biopolitica from https://www.bdtd.uerj.br:8443/bitstream/1/10304/1/Tese_Paulo%20de%20Tassio%20Borges%20da%20Silva.pdf
# Loading triplas: paisagens_e_fluxos_curriculares_pataxo_processos_de_hibridizacao_e_biopolitica
# Total time: 0 days 00:30:59.108528
# Partial time: 0 days 00:00:36.224467
# 53 - Downloading and extracting: a_recepcao_da_obra_de_graciliano_ramos_no_brasil_e_nos_eua_da_critica_inaugural_nos_jornais_aos_estudos_academicos from https://www.bdtd.uerj.br:8443/bitstream/1/5957/1/Izaura%20Vieira%20Mariano%20de%20Sousa_Tese.pdf
# Loading triplas: a_recepcao_da_obra_de_graciliano_ramos_no_brasil_e_nos_eua_da_critica_inaugural_nos_jornais_aos_estudos_academicos
# Total time: 0 days 00:31:31.718635
# Partial time: 0 days 00:00:32.610107
# 54 - Downloading and extracting: da_arqueologia_para_a_historia_o_lugar_dos_indios_no_municipio_de_araruama from https://www.bdtd.uerj.br:8443/bitstream/1/13557/1/Marlon%20Barcelos%20Ferreira.pdf
# Loading triplas: da_arqueologia_para_a_historia_o_lugar_dos_indios_no_municipio_de_araruama
# Total time: 0 days 00:32:04.087537
# Partial time: 0 days 00:00:32.368902
# 55 - Downloading and extracting: a_jurisdicao_indigena_originaria_campesina_e_a_marka_quila_quila_um_estudo_de_caso_sobre_a_luta_pela_defesa_do_seu_territorio_e_o_reconhecimento_de_sua_autonomia_cultural_e_politica from https://www.bdtd.uerj.br:8443/bitstream/1/17510/2/Tese%20-%20Adriano%20Corr%c3%aaa%20de%20Sousa%20-%202019%20-%20Completa.pdf
# Loading triplas: a_jurisdicao_indigena_originaria_campesina_e_a_marka_quila_quila_um_estudo_de_caso_sobre_a_luta_pela_defesa_do_seu_territorio_e_o_reconhecimento_de_sua_autonomia_cultural_e_politica
# Total time: 0 days 00:32:56.155139
# Partial time: 0 days 00:00:52.068123
# 56 - Downloading and extracting: identidade_experiencia_urbana_e_agencias_cotidianas_trajetorias_de_quatro_mulheres_indigenas_na_cidade_do_rio_de_janeiro from https://www.bdtd.uerj.br:8443/bitstream/1/16380/2/Dissertacao%20-%20Luiza%20Freire%20Nasciutti%20-%202019%20-%20Completa.pdf
# Loading triplas: identidade_experiencia_urbana_e_agencias_cotidianas_trajetorias_de_quatro_mulheres_indigenas_na_cidade_do_rio_de_janeiro
# Total time: 0 days 00:33:42.763921
# Partial time: 0 days 00:00:46.608261
# 57 - Downloading and extracting: figuracoes_primitivistas_transitos_do_exotico_entre_museus_cinema_e_zoologicos_humanos from https://www.bdtd.uerj.br:8443/bitstream/1/17708/4/Tese%20-%20Mariana%20Cavalcante%20Vieira%20-%202019%20-%20Completa.pdf
# Loading triplas: figuracoes_primitivistas_transitos_do_exotico_entre_museus_cinema_e_zoologicos_humanos
# Total time: 0 days 00:35:22.945282
# Partial time: 0 days 00:01:40.181361
# 58 - Downloading and extracting: movimentos_sociais_suas_demandas_e_articulacao_politica_nas_politicas_de_curriculo_promovidas_pela_secadmec_brasil_20032010 from https://www.bdtd.uerj.br:8443/bitstream/1/16551/5/Tese%20-%20Cristiane%20Gon%c3%a7alves%20de%20Souza%20-%202019%20-%20Completa.pdf
# Loading triplas: movimentos_sociais_suas_demandas_e_articulacao_politica_nas_politicas_de_curriculo_promovidas_pela_secadmec_brasil_20032010
# Total time: 0 days 00:35:51.196294
# Partial time: 0 days 00:00:28.251012
# 59 - Downloading and extracting: ancestralidade_materna_em_populacoes_da_america_do_sul_contrastando_dados_geneticos_e_historicos from https://www.bdtd.uerj.br:8443/bitstream/1/16115/1/Filipa%20Isabel%20Figueira%20Simao%20Tese%20completa.pdf
# Loading triplas: ancestralidade_materna_em_populacoes_da_america_do_sul_contrastando_dados_geneticos_e_historicos
# Total time: 0 days 00:36:19.499073
# Partial time: 0 days 00:00:28.302779
# 60 - Downloading and extracting: praticas_linguageiras_e_saberes_locais_o_movimento_linguisticodiscursivo_dos_pataxo_de_aldeia_velha_porto_seguro__ba from https://www.bdtd.uerj.br:8443/bitstream/1/16697/2/Tese%20-%20Keyla%20Silva%20Rabelo%20-%202020%20-%20Completa.pdf
# Loading triplas: praticas_linguageiras_e_saberes_locais_o_movimento_linguisticodiscursivo_dos_pataxo_de_aldeia_velha_porto_seguro__ba
# Total time: 0 days 00:37:10.703147
# Partial time: 0 days 00:00:51.204074
# 61 - Downloading and extracting: juventudes_indigenas_em_espacos_urbanos_amazonenses_narrativas_sateremawe from https://www.bdtd.uerj.br:8443/bitstream/1/10302/1/Tese_Marcos%20Andre%20Estacio.pdf
# Loading triplas: juventudes_indigenas_em_espacos_urbanos_amazonenses_narrativas_sateremawe
# Total time: 0 days 00:38:31.251756
# Partial time: 0 days 00:01:20.548609
# 62 - Downloading and extracting: direitos_territoriais_indigenas_uma_interpretacao_intercultural from https://www.bdtd.uerj.br:8443/bitstream/1/9812/1/Julio%20Jose%20Araujo%20Junior_Total.pdf
# Loading triplas: direitos_territoriais_indigenas_uma_interpretacao_intercultural
# Total time: 0 days 00:39:52.941652
# Partial time: 0 days 00:01:21.689896
# 63 - Downloading and extracting: o_comeco_do_fim_do_mundo_violencia_estrutural_contra_mulheres_no_contexto_da_hidreletrica_de_belo_monte from https://www.bdtd.uerj.br:8443/bitstream/1/17723/2/Tese%20-%20Milena%20Fernandes%20Barroso%20-%202018%20-%20Completa.pdf
# Loading triplas: o_comeco_do_fim_do_mundo_violencia_estrutural_contra_mulheres_no_contexto_da_hidreletrica_de_belo_monte
# Total time: 0 days 00:41:11.279303
# Partial time: 0 days 00:01:18.337651
# 64 - Downloading and extracting: tlacamictiliztli_os_rituais_sacrificiais_nahuas_e_sua_recepcao_no_universo_artistico_europeu_e_do_vicereino_da_nova_espanha from https://www.bdtd.uerj.br:8443/bitstream/1/7361/1/Rafael%20Augusto%20Castells%20de%20Andrade%20-%20Tese%20abr19.pdf
# Loading triplas: tlacamictiliztli_os_rituais_sacrificiais_nahuas_e_sua_recepcao_no_universo_artistico_europeu_e_do_vicereino_da_nova_espanha
# Total time: 0 days 00:42:02.524757
# Partial time: 0 days 00:00:51.245454
# 65 - Downloading and extracting: geracao_de_outros_romanticos_a_verificacao_do_anti_servico_de_protecao_aos_indios from https://www.bdtd.uerj.br:8443/bitstream/1/9392/1/Grazielle%20da%20Silveira%20Pereira%20%20%20Versao%20final%20%20%20%20PROTEGIDO.pdf
# Loading triplas: geracao_de_outros_romanticos_a_verificacao_do_anti_servico_de_protecao_aos_indios
# Total time: 0 days 00:42:29.727359
# Partial time: 0 days 00:00:27.202602
# 66 - Downloading and extracting: rastros_de_uma_campanha_de_alfabetizacao_uma_narracao_mexicana_impossivel from https://www.bdtd.uerj.br:8443/bitstream/1/10751/1/Disert_Dafne%20G%20Solis.pdf
# Loading triplas: rastros_de_uma_campanha_de_alfabetizacao_uma_narracao_mexicana_impossivel
# Total time: 0 days 00:42:53.232073
# Partial time: 0 days 00:00:23.503715
# 67 - Downloading and extracting: um_ser_tao_assombrado_manifestacoes_do_gotico_no_regionalismo_brasileiro_do_romantismo_ao_modernismo from https://www.bdtd.uerj.br:8443/bitstream/1/6183/1/Fabianna%20Simao%20Bellizzi%20Carneiro%20Tese.pdf
# Loading triplas: um_ser_tao_assombrado_manifestacoes_do_gotico_no_regionalismo_brasileiro_do_romantismo_ao_modernismo
# Total time: 0 days 00:43:23.001584
# Partial time: 0 days 00:00:29.769511
# 68 - Downloading and extracting: cade_o_indio_que_vivia_aqui_os_puri_a_ocupacao_dos_sertoes_de_campo_alegre_da_paraiba_nova_e_o_processo_de_invisibilidade_indigena_seculos_xviii_e_xix from https://www.bdtd.uerj.br:8443/bitstream/1/17653/2/Tese%20-%20Enio%20Sebasti%c3%a3o%20Cardoso%20de%20Oliveira%20-%202018%20-%20Completa.pdf
# Loading triplas: cade_o_indio_que_vivia_aqui_os_puri_a_ocupacao_dos_sertoes_de_campo_alegre_da_paraiba_nova_e_o_processo_de_invisibilidade_indigena_seculos_xviii_e_xix
# Total time: 0 days 00:44:50.137920
# Partial time: 0 days 00:01:27.136336
# 69 - Downloading and extracting: a_historia_ambiental_e_a_producao_de_territorialidades from https://www.bdtd.uerj.br:8443/bitstream/1/14239/1/Tese_%20FelipeRobledo_PPGMAl_versaofinal.pdf
# Loading triplas: a_historia_ambiental_e_a_producao_de_territorialidades
# Total time: 0 days 00:45:23.022669
# Partial time: 0 days 00:00:32.884749
# 70 - Downloading and extracting: febronio_indio_do_brasil_na_imprensa_carioca_1919_1939 from https://www.bdtd.uerj.br:8443/bitstream/1/15221/1/Dissert_Hugo%20de%20Nilson%20Damasceno.pdf
# Loading triplas: febronio_indio_do_brasil_na_imprensa_carioca_1919_1939
# Total time: 0 days 00:45:45.723927
# Partial time: 0 days 00:00:22.701258
# 71 - Downloading and extracting: a_pena_em_riste_erudicao_e_polemica_na_obra_de_francisco_adolfo_de_varnhagen_18381858 from https://www.bdtd.uerj.br:8443/bitstream/1/18261/2/Tese%20-%20Victor%20Hugo%20Baptista%20Neves%20-%202018%20-%20Completa.pdf
# Loading triplas: a_pena_em_riste_erudicao_e_polemica_na_obra_de_francisco_adolfo_de_varnhagen_18381858
# Total time: 0 days 00:46:40.669653
# Partial time: 0 days 00:00:54.945726
# 72 - Downloading and extracting: o_bandeirismo_nao_e_apenas_um_tema_do_passado_bandeirantes_entradas_e_bandeiras_na_construcao_historiografica_no_curso_de_bandeirologia_1946 from https://www.bdtd.uerj.br:8443/bitstream/1/13048/1/Veronica%20Rocha%20da%20Silva.pdf
# Loading triplas: o_bandeirismo_nao_e_apenas_um_tema_do_passado_bandeirantes_entradas_e_bandeiras_na_construcao_historiografica_no_curso_de_bandeirologia_1946
# Total time: 0 days 00:47:19.024155
# Partial time: 0 days 00:00:38.354502
# 73 - Downloading and extracting: fatores_contextuais_e_individuais_associados_com_a_utilizacao_dos_servicos_de_saude_bucal_por_adultos_no_brasil from https://www.bdtd.uerj.br:8443/bitstream/1/4807/4/Tese%20-%20Fernando%20Jos%c3%a9%20Herkrath%20-%202018%20-%20Completa.pdf
# Loading triplas: fatores_contextuais_e_individuais_associados_com_a_utilizacao_dos_servicos_de_saude_bucal_por_adultos_no_brasil
# Total time: 0 days 00:47:57.605165
# Partial time: 0 days 00:00:38.581010
# 74 - Downloading and extracting: prevalencia_e_fatores_associados_as_condicoes_musculoesqueleticas_em_adultos_brasileiros_pesquisa_nacional_de_saude from https://www.bdtd.uerj.br:8443/bitstream/1/4384/1/dissertacao%20Maria%20Alonso.pdf
# Loading triplas: prevalencia_e_fatores_associados_as_condicoes_musculoesqueleticas_em_adultos_brasileiros_pesquisa_nacional_de_saude
# Total time: 0 days 00:48:14.724627
# Partial time: 0 days 00:00:17.119462
# 75 - Downloading and extracting: quando_a_terra_e_dinheiro_a_natureza_e_territorio_uma_investigacao_historicogeografica_de_povos_indigenas_no_medio_xingu_19501980 from https://www.bdtd.uerj.br:8443/bitstream/1/13259/1/Dissertacao%20Geografia%20Nubia%20Vieira%20Dissertacao%20completa.pdf
# Loading triplas: quando_a_terra_e_dinheiro_a_natureza_e_territorio_uma_investigacao_historicogeografica_de_povos_indigenas_no_medio_xingu_19501980
# Total time: 0 days 00:48:46.601206
# Partial time: 0 days 00:00:31.876579
# 76 - Downloading and extracting: a_escultura_e_seu_oficio_no_brasil_do_segundo_reinado_18401889 from https://www.bdtd.uerj.br:8443/bitstream/1/7393/1/Alberto%20M%20Chillon_Tese%20Pre-textuais%20-%20Cap%202.pdf
# Loading triplas: a_escultura_e_seu_oficio_no_brasil_do_segundo_reinado_18401889
# Total time: 0 days 00:49:25.698877
# Partial time: 0 days 00:00:39.098659
# 76 - Downloading and extracting: a_escultura_e_seu_oficio_no_brasil_do_segundo_reinado_18401889 from https://www.bdtd.uerj.br:8443/bitstream/1/7393/2/Alberto%20M%20Chillon_Tese%20Cap%203%20-%20Apend.pdf
# Loading triplas: a_escultura_e_seu_oficio_no_brasil_do_segundo_reinado_18401889
# Total time: 0 days 00:50:08.836832
# Partial time: 0 days 00:00:43.136967
# 77 - Downloading and extracting: a_influencia_negativa_da_imposicao_do_portugues_num_contexto_multilingue_e_multicultural_bantu_caso_do_ensino_fundamental_em_mocambique from https://www.bdtd.uerj.br:8443/bitstream/1/10747/1/Dissert_Marcelino%20H%20Velasco.pdf
# Loading triplas: a_influencia_negativa_da_imposicao_do_portugues_num_contexto_multilingue_e_multicultural_bantu_caso_do_ensino_fundamental_em_mocambique
# Total time: 0 days 00:50:33.706375
# Partial time: 0 days 00:00:24.869543
# 78 - Downloading and extracting: pensamento_social_justica_e_cotas_um_estudo_de_representacoes_sociais_com_universitarios from https://www.bdtd.uerj.br:8443/bitstream/1/15395/1/Dissert_Thamiris%20Marques%20da%20Silva.pdf
# Loading triplas: pensamento_social_justica_e_cotas_um_estudo_de_representacoes_sociais_com_universitarios
# Total time: 0 days 00:50:57.439586
# Partial time: 0 days 00:00:23.733211
# 79 - Downloading and extracting: acoes_afirmativas_de_reserva_de_vagas_para_indigenas_no_ensino_medio_tecnico_profissionalizante_no_ifmt_impactos_e_possibilidades_de_ressignificacao from https://www.bdtd.uerj.br:8443/bitstream/1/9969/1/Jane%20Santos.pdf
# Loading triplas: acoes_afirmativas_de_reserva_de_vagas_para_indigenas_no_ensino_medio_tecnico_profissionalizante_no_ifmt_impactos_e_possibilidades_de_ressignificacao
# Total time: 0 days 00:51:35.123592
# Partial time: 0 days 00:00:37.685006
# 80 - Downloading and extracting: anjos_de_fuziluma_etnografia_das_relacoes_entre_igreja_e_trafico_na_cidade_de_deus from https://www.bdtd.uerj.br:8443/bitstream/1/15519/1/tese%20Diogo%20Silva%20Correa.pdf
# Loading triplas: anjos_de_fuziluma_etnografia_das_relacoes_entre_igreja_e_trafico_na_cidade_de_deus
# Total time: 0 days 00:54:00.058105
# Partial time: 0 days 00:02:24.933513
