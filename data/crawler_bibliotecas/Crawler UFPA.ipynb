# %%
#%pip install beautifulsoup4
#%pip install pip-system-certs
#% -m pip install ipykernel -U --force-reinstall

# %%
import requests
from bs4 import BeautifulSoup as bs
import pandas as pd
import os
from langchain_community.graphs import Neo4jGraph
from PyPDF2 import PdfReader
import fitz
from langdetect import detect
import spacy
import re
from unidecode import unidecode
import time

# %% [markdown]
# Conectando ao Neo4j

# %%
from neo4j import GraphDatabase

# Neo4j variables
NEO4J_URL = os.getenv("NEO4J_URL")
NEO4J_USERNAME =os.getenv("NEO4J_USERNAME")
NEO4J_PASSWORD = os.getenv("NEO4J_PASSWORD")


graph = GraphDatabase.driver(NEO4J_URL, auth=(NEO4J_USERNAME, NEO4J_PASSWORD))

# %% [markdown]
# - Buscar os links para a tese no Neo4j
# - Buscar o link do PDF no repositório da universidade
# - Baixar o PDF
# - Extrair o texto do PDF

# %% [markdown]
# Buscar links para a tese no Neo4j

# %%
# Query to get theses and their repositories from the Neo4j database
# This query retrieves theses that are published by the Federal University of Pará (UFPA) and have not been processed yet.
query1 = """
MATCH (t:Thesis)-[:publisher]-(uni:University{uri:'tag:stardog:api:UFPA'})
WHERE NOT EXISTS {(t{processed:true})}
RETURN distinct(t["uri"]) as Thesis, t["repository"] as repository 
"""

# Alternative query to get theses that do not have excerpts and have been processed.
query2 = """ 
match (t:Thesis)-[:publisher]-(uni:University{uri:'tag:stardog:api:UFPA'})
where (not (t:Thesis)-[:BFO_0000050]-(:Exerpt)) and  exists {(t{processed:true})}
return distinct(t["uri"]) as Thesis, t["repository"] as repository
"""

# Query to retrive theses with few pages and their repositories.
query3 = """
MATCH (t:Thesis)-[:publisher]-(uni:University{uri:'tag:stardog:api:UFPA'})
Match (t:Thesis)-[:BFO_0000050]-(e:Exerpt)
RETURN count(e) as pages, t["uri"] as Thesis, t["repository"] as repository
 order by (pages) limit 40
"""

query4 = """
MATCH (t:Thesis)-[:publisher]-(uni:University{uri:'tag:stardog:api:UFPA'})
WHERE NOT EXISTS {(t{processed:true})}
RETURN distinct(t["uri"]) as Thesis, t["title"] as title 
"""

query5 = """
MATCH (t:Thesis {processed: true})-[:publisher]-(uni:University {uri: 'tag:stardog:api:UFPA'})
WHERE NOT (t)--(:Exerpt)
RETURN distinct(t["uri"]) as Thesis, t["title"] as title 
"""

graph = GraphDatabase.driver(NEO4J_URL, auth=(NEO4J_USERNAME, NEO4J_PASSWORD))
results = graph.execute_query(query1).records
graph.close()

#results = graph.query(query2)
# Convert the results to a DataFrame
#thesis_repository = pd.DataFrame(results, columns=["pages", "Thesis", "repository"])
thesis_repository = pd.DataFrame(results, columns=["Thesis", "repository"])
thesis_repository = thesis_repository.reset_index(drop=True) 
thesis_repository
# Out:
#                                                 Thesis  \
# 0    tag:stardog:api:juventude_do_campo_e_quilombol...
# 1    tag:stardog:api:o_territorio_quilombola_de_ara...
# 2    tag:stardog:api:saberes_e_praticas_tradicionai...
# 3    tag:stardog:api:direitos_educacionais_quilombo...
# 4    tag:stardog:api:exposicao_ao_mercurio_e_desenv...
# ..                                                 ...
# 122  tag:stardog:api:a_senhora_do_reino_encantado_d...
# 123  tag:stardog:api:vivencias_negras_amazonicas_in...
# 124  tag:stardog:api:nos_sertoes_da_provincia_do_gr...
# 125  tag:stardog:api:formacao_de_enfermeiras_e_enfe...
# 126  tag:stardog:api:fora_dos_padroes_estetica_negr...
#
#                                             repository
# 0    http://repositorio.ufpa.br/jspui/handle/2011/6180
# 1    http://repositorio.ufpa.br/jspui/handle/2011/9406
# 2    http://repositorio.ufpa.br:8080/jspui/handle/2...
# 3    https://repositorio.ufpa.br/jspui/handle/2011/...
# 4    http://repositorio.ufpa.br/jspui/handle/2011/9090
# ..                                                 ...
# 122  https://repositorio.ufpa.br/jspui/handle/2011/...
# 123  https://repositorio.ufpa.br/jspui/handle/2011/...
# 124  https://repositorio.ufpa.br/jspui/handle/2011/...
# 125  https://repositorio.ufpa.br/jspui/handle/2011/...
# 126  https://repositorio.ufpa.br/jspui/handle/2011/...
#
# [127 rows x 2 columns]

# %% [markdown]
# Criando as utils functions

# %%
# Funcao para coletar link do repositorio na página da BDTD

#def get_repository_link(title):

#    bdtd_url = 'https://bdtd.ibict.br/vufind/Search/Results?lookfor=' + title.replace(' ', '+') + '&type=Title' #&limit=1'
   #Fazer requisição e parsear o arquivo html
#    try:
#        f = requests.get(bdtd_url, verify=True).text#, verify=False) 
#    except:
#        print("Sleeping for 5 seconds before retrying... (get_repository_link)")
#        time.sleep(5)
#        try:
#            f = requests.get(bdtd_url, verify=True).text#, verify=False) 
#        except:
#            print("Sleeping for 30 seconds before retrying... (get_repository_link)")
#            time.sleep(30)
#            f = requests.get(bdtd_url, verify=True).text#, verify=False)    
#    soup = bs(f, "html.parser")

    #Coletando link para o repositório
#    link_list = []
#    for doc in soup.find_all('a', href=True):
#        if (doc['href'].startswith('https://app.uff.br/') |
#            doc['href'].startswith('http://app.uff.br/')):
#            path = doc['href']
#            link_list.append(path)
#    if link_list != []:
#        return list(set(link_list))[0]
#    else:
#        return None



# Funcao para coletar link do pdf

def get_pdf_link(url):
    
    url = url.replace('http:', 'https:').replace(':8080', '')
    headers = {
    'User-Agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/58.0.3029.110 Safari/537.3'
                }

    #Fazer requisição e parsear o arquivo html
    try:
        f = requests.get(url, headers=headers, verify=True).text#, verify=False) 
        
    except:
        print("Sleeping for 5 seconds before retrying... (get_pdf_link)")
        time.sleep(5)
        try:
            f = requests.get(url, headers=headers, verify=True).text#, verify=False) 
        except:
            print("Sleeping for 30 seconds before retrying... (get_pdf_link)")
            time.sleep(30)
            f = requests.get(url, headers=headers, verify=True).text#, verify=False)    
    soup = bs(f, "html.parser")
    
    #Coletando link para as teses
    link_list = []
    for doc in soup.find_all('a', href=True):
        if doc['href'].startswith('/bitstreams'):     # (doc['href'].endswith('.pdf')):# & doc['href'].startswith('/bitstream')):
            path = doc['href']
            prefix_uni = 'https://repositorio.ufpa.br/server/api/core'
            link = prefix_uni + path.replace('download', 'content')
            link_list.append(link)
    if link_list != []:
        return list(set(link_list))
    else:
        return None
    

#fazer download do arquivo
def download_file(pdf_link, thesis_uri):

    headers = {
    'User-Agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/58.0.3029.110 Safari/537.3'
                }
    
    # NOTE the stream=True parameter below
    try:
        r = requests.get(pdf_link, headers=headers, verify=True, stream=True)
    except:
        print("Sleeping for 5 seconds before retrying... (download_file)")
        time.sleep(5)
        try:
            r = requests.get(pdf_link, headers=headers, verify=True, stream=True)
        except:
            print("Sleeping for 30 seconds before retrying... (download_file)")
            time.sleep(30)
            r = requests.get(pdf_link, headers=headers, verify=True, stream=True)
    # raise_for_status() is not needed with stream=True
    # r.raise_for_status()
    with open('tese UFPA.pdf', 'wb') as f:
        for chunk in r.iter_content(chunk_size=8192):
            f.write(chunk)
    return 

#Carregando os modelos SpaCy para inglês e português 
nlp_en = spacy.load("en_core_web_lg")
nlp_pt = spacy.load("pt_core_news_lg")

# Funcão que recebe uma string e a limpar para ficar no formato aceitável para uma URI
def process_uri(x):
    return (re.sub('[^a-zA-Z0-9_ ]', '',
            unidecode(x.strip())
                        .replace(" ", "_")
                        .replace("[","")
                        .replace("]","")
                        .replace("?","")
                        .replace("'","")
                        .lower()))


# Função para extrair texto de uma tese em PDF e identificar entidades
def extratc_text(tese_path):
    
    # Processando o arquivo em PDF
    try:
        reader = PdfReader(tese_path)
        number_of_pages = len(reader.pages)
    
        excerpt = {}

        extractor = 'PdfReader'

    except:
        reader = fitz.open(tese_path)
        number_of_pages = len(reader)
    
        excerpt = {}
        
        extractor = 'PyMuPDF'

    # Iterando por cada página
    for page_number in range(number_of_pages):

        # Verificando qual extrator de pdf foi utilizado    
        if extractor == 'PdfReader':

            # Extraindo o texto da página
            try:
                if page_number == 0:
                    try:
                        page_text = (reader.pages[page_number].extract_text() + '\n ' 
                                    + reader.pages[page_number+1].extract_text()[:400])
                    except:
                        page_text = reader.pages[page_number].extract_text()
                else:
                    
                    if page_number == number_of_pages -1:
                        try:
                            page_text = (reader.pages[page_number-1].extract_text()[-400:] + '\n ' 
                                        + reader.pages[page_number].extract_text())
                        except:
                            page_text = reader.pages[page_number].extract_text()
                    
                    else:
                        try:
                            page_text = (reader.pages[page_number-1].extract_text()[-400:] + '\n ' 
                                        + reader.pages[page_number].extract_text() + '\n ' 
                                        + reader.pages[page_number+1].extract_text()[:400])  
                        except:
                            page_text = reader.pages[page_number].extract_text()
            except:
                page_text = ''
            
        else:
                
            # Extraindo o texto da página
            try:
                if page_number == 0:
                    try:
                        page_text = (reader[page_number].get_text() + '\n ' 
                                    + reader[page_number+1].get_text()[:400])
                    except:
                        page_text = reader[page_number].get_text()
                else:
                    
                    if page_number == number_of_pages -1:
                        try:
                            page_text = (reader[page_number-1].get_text()[-400:] + '\n ' 
                                        + reader[page_number].get_text())
                        except:
                            page_text = reader[page_number].get_text()
                    
                    else:
                        try:
                            page_text = (reader[page_number-1].get_text()[-400:] + '\n ' 
                                        + reader[page_number].get_text() + '\n ' 
                                        + reader[page_number+1].get_text()[:400])  
                        except:
                            page_text = reader[page_number].get_text()

            except:
                page_text = ''

        # Limpando page text         
        page_text = page_text.replace("'", "").replace('"', '')
        # Verifica se o último caractere é uma barra invertida
        if page_text != '':
            if page_text[-1] == '\\': 
                page_text = page_text[:-2]
        page_text = re.sub(r"[\ud800-\udfff]", " ", page_text)
        page_text = page_text.encode('utf-8').decode('utf-8')
        
        
        # Detectando o idioma do texto
        try:
            lang = detect(page_text)
            
        except:
            lang = 'Não_detectado'
        
        
        # Extraindo as entidades
        page_extracted = False
        if lang == 'pt':
            doc = nlp_pt(page_text)
            page_extracted = True
        if lang == 'en':
            doc = nlp_en(page_text)
            page_extracted = True
        

        if page_extracted:

            persons = []
            gpes = []
            #orgs = []
            for ent in doc.ents:
                if ent.label_ == "PER": #"PERSON":
                    persons.append(process_uri(ent.text))
                if ent.label_ == "LOC": #"GPE":
                    gpes.append(process_uri(ent.text))
                #if ent.label_ == "ORG":
                #    orgs.append(process_uri(ent.text))
                    
            excerpt[page_number] = {'text': page_text, 
                                    'lang': lang, 
                                    'persons': list(set(persons)), 
                                    'gpes': list(set(gpes)),
                                #'orgs': list(set(orgs))
                                }

    return excerpt

# %% [markdown]
# Iterando por todas as URI para extrair o texto e gravar no grafo NEO4j

# %%
# Gravar hora de início do processamento
start_time = pd.Timestamp.now()
parcial_time = pd.Timestamp.now()

for i in range(0,len(thesis_repository)):

    #title ='The problem of identity as it relates to the american black\'s vision of Africa'
    #title = thesis_repository['title'][i].replace("?","").replace('-', ' ').replace('&', ' ').replace('/', ' ').replace('\\', ' ')  
    #repo = get_repository_link(title)
    # Coletando o link do PDF
    repo = thesis_repository['repository'][i]
    
    if repo is None:
        print(f"No repository link found for title: {title}")
        pass
    
    else:
        thesis_uri = thesis_repository['Thesis'][i][16:]
        pdf_link = get_pdf_link(repo)
        if pdf_link is not None:
            # Itereando pelos links de PDF encontrados (em alguns casos há outros materiais além da tese)
            for pdf_num in range(len(pdf_link)):
                print(f"{i} - Downloading and extracting: {thesis_uri} from {pdf_link[pdf_num]}")
                download_file(pdf_link[pdf_num], thesis_uri)

                # Extraindo o texto e entidades
                tese_path = 'tese UFPA.pdf'
                excerpt = extratc_text(tese_path)

                excerpts = []
                persons = []
                gpes = []

                # Salvando as triplas em CSV
                for n in excerpt.keys():

                    excerpt_uri = thesis_repository['Thesis'][i] + '_pdf_' + str(pdf_num) + '_p_' + str(n)
                    excerpt_text = excerpt[n]['text']
                    # Verifica se o último caractere é uma barra invertida
                    #if excerpt_text[-1] == '\\': 
                    #    excerpt_text = excerpt_text[:-1]
                    

                    excerpt_page = 'pdf_' + str(pdf_num) + '_p_' + str(n)
                    excerpt_lang = excerpt[n]['lang']
                    
                    excerpts.append([thesis_repository['Thesis'][i], excerpt_uri, excerpt_text, excerpt_page, excerpt_lang])
                        
                    #Criando as relações com as entidades
                    for person in excerpt[n]['persons']:
                        persons.append([excerpt_uri, 'tag:stardog:api:' + person])
                    
                    for gpe in excerpt[n]['gpes']:
                        gpes.append([excerpt_uri, 'tag:stardog:api:' + gpe])
                
                # Salvando os dados em CSV no diretório de importação do Neo4j
                pd.DataFrame(excerpts).to_csv('C:\\Users\\facordei\\.Neo4jDesktop\\relate-data\\dbmss\\dbms-792eabfc-5517-4220-ab29-30ef6ec3236e\\import\\excerptsUFPA.csv', index=False, header=False)
                pd.DataFrame(persons).to_csv('C:\\Users\\facordei\\.Neo4jDesktop\\relate-data\\dbmss\\dbms-792eabfc-5517-4220-ab29-30ef6ec3236e\\import\\personsUFPA.csv', index=False, header=False)
                pd.DataFrame(gpes).to_csv('C:\\Users\\facordei\\.Neo4jDesktop\\relate-data\\dbmss\\dbms-792eabfc-5517-4220-ab29-30ef6ec3236e\\import\\gpesUFPA.csv', index=False, header=False)

                #Deletando o arquivo PDF após o processamento
                os.remove('tese UFPA.pdf')

                print(f"Loading triplas: {thesis_uri}")

                # Importanto os dados para o Neo4j
                #Excerpts
                query = """
                LOAD CSV FROM 'file:///excerptsUFPA.csv'
                AS row
                MATCH  (t:Thesis{uri: row[0]})
                MERGE  (e:Exerpt{
                        uri: row[1],
                        text: row[2],
                        page: row[3],
                        lang: row[4]
                        })-[r:BFO_0000050]-(t);
                """
                graph = GraphDatabase.driver(NEO4J_URL, auth=(NEO4J_USERNAME, NEO4J_PASSWORD))
                results = graph.execute_query(query)
                graph.close()

                #Persons
                query = """
                LOAD CSV FROM 'file:///personsUFPA.csv'
                AS row
                MATCH  (e:Exerpt{uri: row[0]})
                MERGE  (p:Person{uri: row[1]})
                MERGE  (e)-[r:mentions]-(p);
                """
                graph = GraphDatabase.driver(NEO4J_URL, auth=(NEO4J_USERNAME, NEO4J_PASSWORD))
                results = graph.execute_query(query)
                graph.close()

                #GPEs
                query = """
                LOAD CSV FROM 'file:///gpesUFPA.csv'
                AS row
                MATCH  (e:Exerpt{uri: row[0]})
                MERGE  (p:Place{uri: row[1]})
                MERGE  (e)-[r:mentions]-(p);
                """
                graph = GraphDatabase.driver(NEO4J_URL, auth=(NEO4J_USERNAME, NEO4J_PASSWORD))
                results = graph.execute_query(query)
                graph.close()

                # Removendo os arquivos CSV após a importação
                os.remove('C:\\Users\\facordei\\.Neo4jDesktop\\relate-data\\dbmss\\dbms-792eabfc-5517-4220-ab29-30ef6ec3236e\\import\\excerptsUFPA.csv')
                os.remove('C:\\Users\\facordei\\.Neo4jDesktop\\relate-data\\dbmss\\dbms-792eabfc-5517-4220-ab29-30ef6ec3236e\\import\\personsUFPA.csv')
                os.remove('C:\\Users\\facordei\\.Neo4jDesktop\\relate-data\\dbmss\\dbms-792eabfc-5517-4220-ab29-30ef6ec3236e\\import\\gpesUFPA.csv')

                print(f"Total time: {pd.Timestamp.now() - start_time}")
                print(f"Partial time: {pd.Timestamp.now() - parcial_time}")
                # Atualizando a hora parcial
                parcial_time = pd.Timestamp.now()
        else:
            print(f"No PDF link found for {thesis_uri}")

        # gravando no grafo que a tese foi processada
        query = """
        MATCH  (t:Thesis{uri: \'""" + thesis_repository['Thesis'][i] +  """\'})
        SET t.processed = true
        """
        #SET t.repository = \'""" + str(repo) +  """\'
        
        graph = GraphDatabase.driver(NEO4J_URL, auth=(NEO4J_USERNAME, NEO4J_PASSWORD))
        results = graph.execute_query(query)
        graph.close()
        #break
# Out:
# 0 - Downloading and extracting: juventude_do_campo_e_quilombola_educacao_e_identidade_cultural_na_comunidade_quilombola_de_itaboca__inhangapi__pa from https://repositorio.ufpa.br/server/api/core/bitstreams/c4a4d773-be24-44bc-aca8-3b4917c0748f/content
# Loading triplas: juventude_do_campo_e_quilombola_educacao_e_identidade_cultural_na_comunidade_quilombola_de_itaboca__inhangapi__pa
# Total time: 0 days 00:00:25.419933
# Partial time: 0 days 00:00:25.419933
# 1 - Downloading and extracting: o_territorio_quilombola_de_araquembaua_baiaopa from https://repositorio.ufpa.br/server/api/core/bitstreams/cf55ba29-eac8-464a-b065-c84b2deed10e/content
# Loading triplas: o_territorio_quilombola_de_araquembaua_baiaopa
# Total time: 0 days 00:01:09.190300
# Partial time: 0 days 00:00:43.770367
# 2 - Downloading and extracting: saberes_e_praticas_tradicionais_sobre_recursos_faunisticos_e_cultura_alimentar_na_comunidade_quilombola_do_jacarequara_municipio_de_santa_luzia_do_para_amazonia_oriental from https://repositorio.ufpa.br/server/api/core/bitstreams/8049ac1e-26e2-465c-8275-92421d81d95e/content
# Loading triplas: saberes_e_praticas_tradicionais_sobre_recursos_faunisticos_e_cultura_alimentar_na_comunidade_quilombola_do_jacarequara_municipio_de_santa_luzia_do_para_amazonia_oriental
# Total time: 0 days 00:02:25.753021
# Partial time: 0 days 00:01:16.563720
# 3 - Downloading and extracting: direitos_educacionais_quilombolas_e_os_desafios_para_efetivacao_na_comunidade_quilombola_de_inhanhum_municipio_de_santa_maria_da_boa_vista_pernambuco from https://repositorio.ufpa.br/server/api/core/bitstreams/c2d736ba-a7fb-462f-be86-c721d16cd453/content
# Loading triplas: direitos_educacionais_quilombolas_e_os_desafios_para_efetivacao_na_comunidade_quilombola_de_inhanhum_municipio_de_santa_maria_da_boa_vista_pernambuco
# Total time: 0 days 00:04:08.320505
# Partial time: 0 days 00:01:42.566485
# 4 - Downloading and extracting: exposicao_ao_mercurio_e_desenvolvimento_motor_de_criancas_quilombolas_na_regiao_do_baixo_amazonas from https://repositorio.ufpa.br/server/api/core/bitstreams/41e218b9-3447-49f9-b713-80f0fca28a25/content
# Loading triplas: exposicao_ao_mercurio_e_desenvolvimento_motor_de_criancas_quilombolas_na_regiao_do_baixo_amazonas
# Total time: 0 days 00:05:39.835953
# Partial time: 0 days 00:01:31.515448
# 5 - Downloading and extracting: educacao_escolar_e_identidade_quilombola_um_enfoque_na_comunidade_nossa_senhora_do_perpetuo_socorro_municipio_de_abaetetuba_estado_do_para from https://repositorio.ufpa.br/server/api/core/bitstreams/2bc52c97-a032-40e7-a91a-80c891dd90ec/content
# Loading triplas: educacao_escolar_e_identidade_quilombola_um_enfoque_na_comunidade_nossa_senhora_do_perpetuo_socorro_municipio_de_abaetetuba_estado_do_para
# Total time: 0 days 00:06:44.192824
# Partial time: 0 days 00:01:04.359532
# 6 - Downloading and extracting: mulheres_quilombolas_e_uso_de_plantas_medicinais_praticas_de_cura_em_santa_rita_de_barreirapa from https://repositorio.ufpa.br/server/api/core/bitstreams/0c2b1b17-88b9-4804-85a1-9e922f0ee2ad/content
# Loading triplas: mulheres_quilombolas_e_uso_de_plantas_medicinais_praticas_de_cura_em_santa_rita_de_barreirapa
# Total time: 0 days 00:08:36.873411
# Partial time: 0 days 00:01:52.677926
# 7 - Downloading and extracting: territorio_e_politicas_de_acao_afirmativa_para_remanescentes_quilombolas_na_amazonia_programa_raizes_e_para_quilombola_nas_comunidades_de_itacoamiri_e_guajaramiri from https://repositorio.ufpa.br/server/api/core/bitstreams/d2a995b8-e485-40dd-b0aa-b0c00193c146/content
# Loading triplas: territorio_e_politicas_de_acao_afirmativa_para_remanescentes_quilombolas_na_amazonia_programa_raizes_e_para_quilombola_nas_comunidades_de_itacoamiri_e_guajaramiri
# Total time: 0 days 00:10:20.434873
# Partial time: 0 days 00:01:43.563455
# 8 - Downloading and extracting: indigenas_e_quilombolas_icamiabas_em_situacao_de_violencia_rompendo_fronteiras_em_busca_de_direitos from https://repositorio.ufpa.br/server/api/core/bitstreams/07107bc2-52b6-4402-9d83-712c3ffabcf7/content
# Loading triplas: indigenas_e_quilombolas_icamiabas_em_situacao_de_violencia_rompendo_fronteiras_em_busca_de_direitos
# Total time: 0 days 00:12:18.118467
# Partial time: 0 days 00:01:57.681601
# 9 - Downloading and extracting: entre_quilombos_circuitos_de_festas_de_santo_e_a_construcao_de_aliancas_politicas_entre_as_comunidades_quilombolas_de_salvaterra__marajo__para from https://repositorio.ufpa.br/server/api/core/bitstreams/79f3df78-baae-4814-8992-6ef8f33a31d2/content
# Loading triplas: entre_quilombos_circuitos_de_festas_de_santo_e_a_construcao_de_aliancas_politicas_entre_as_comunidades_quilombolas_de_salvaterra__marajo__para
# Total time: 0 days 00:14:20.313180
# Partial time: 0 days 00:02:02.195715
# 10 - Downloading and extracting: agro_nao_e_tudo_a_expansao_da_monocultura_da_soja_sobre_os_territorios_quilombolas_na_amazonia_oriental from https://repositorio.ufpa.br/server/api/core/bitstreams/8027c058-e8e2-413b-aaae-dd6a3f584a68/content
# Loading triplas: agro_nao_e_tudo_a_expansao_da_monocultura_da_soja_sobre_os_territorios_quilombolas_na_amazonia_oriental
# Total time: 0 days 00:17:10.300451
# Partial time: 0 days 00:02:49.986269
# 11 - Downloading and extracting: economia_madeireira_dificuldades_de_regulacao_e_efeitos_sobre_quilombolas_no_arquipelago_do_marajo from https://repositorio.ufpa.br/server/api/core/bitstreams/419d72e1-b60e-4b93-878f-c2652bea8b16/content
# Loading triplas: economia_madeireira_dificuldades_de_regulacao_e_efeitos_sobre_quilombolas_no_arquipelago_do_marajo
# Total time: 0 days 00:18:39.151604
# Partial time: 0 days 00:01:28.852154
# No PDF link found for quilombo_de_sao_pedro_dos_bois_memoria_biocultural_subvertida_nas_logicas_de_ocupacoes_recentes_do_amapa
# 13 - Downloading and extracting: pobres_como_nos_quilombolas_de_rosario_e_uso_comum_no_rio_camara_municipios_de_salvaterra_e_cachoeira_do_araripa from https://repositorio.ufpa.br/server/api/core/bitstreams/6e3a341b-ebd9-4b2d-870d-45c220ed2f55/content
# Loading triplas: pobres_como_nos_quilombolas_de_rosario_e_uso_comum_no_rio_camara_municipios_de_salvaterra_e_cachoeira_do_araripa
# Total time: 0 days 00:20:37.504294
# Partial time: 0 days 00:01:58.352688
# 14 - Downloading and extracting: nosso_canto_e_aqui_quilombolas_de_santa_maria_do_traquateua_frente_a_interesses_do_poder_privado_em_jambuacupara from https://repositorio.ufpa.br/server/api/core/bitstreams/63a1ba9a-93ea-49f5-a8a1-2f797d1dbb1f/content
# Loading triplas: nosso_canto_e_aqui_quilombolas_de_santa_maria_do_traquateua_frente_a_interesses_do_poder_privado_em_jambuacupara
# Total time: 0 days 00:22:31.142075
# Partial time: 0 days 00:01:53.644158
# 15 - Downloading and extracting: a_natureza_juridica_da_reserva_legal_e_sua_aplicabilidade_em_areas_habitadas_por_populacoes_tradicionais from https://repositorio.ufpa.br/server/api/core/bitstreams/52b4fff2-1359-4828-ac95-582ed19237f6/content
# Loading triplas: a_natureza_juridica_da_reserva_legal_e_sua_aplicabilidade_em_areas_habitadas_por_populacoes_tradicionais
# Total time: 0 days 00:23:17.909232
# Partial time: 0 days 00:00:46.759781
# 16 - Downloading and extracting: processos_identitarios_e_suas_vicissitudes_em_uma_comunidade_quilombola from https://repositorio.ufpa.br/server/api/core/bitstreams/0d303f77-98f1-408f-9019-ca8039f7595f/content
# Loading triplas: processos_identitarios_e_suas_vicissitudes_em_uma_comunidade_quilombola
# Total time: 0 days 00:25:45.177721
# Partial time: 0 days 00:02:27.268489
# 17 - Downloading and extracting: cultivando_autonomia_analise_da_socioeconomia_e_agrobiodiversidade_no_quilombo_de_providencia_salvaterra_ilha_do_marajopa from https://repositorio.ufpa.br/server/api/core/bitstreams/2d0f61e5-e33f-4cf6-8abd-ccf2fc09e490/content
# Loading triplas: cultivando_autonomia_analise_da_socioeconomia_e_agrobiodiversidade_no_quilombo_de_providencia_salvaterra_ilha_do_marajopa
# Total time: 0 days 00:27:12.654600
# Partial time: 0 days 00:01:27.478887
# 18 - Downloading and extracting: a_morosidade_do_processo_de_titulacao_como_ameaca_as_comunidades_quilombolas_do_marajo_a_analise_da_acao_de_antagonistas_no_municipio_de_salvaterra from https://repositorio.ufpa.br/server/api/core/bitstreams/7185b990-a450-474d-a92d-9a13f668f1d5/content
# Loading triplas: a_morosidade_do_processo_de_titulacao_como_ameaca_as_comunidades_quilombolas_do_marajo_a_analise_da_acao_de_antagonistas_no_municipio_de_salvaterra
# Total time: 0 days 00:28:23.692453
# Partial time: 0 days 00:01:11.036842
# 19 - Downloading and extracting: a_sobreposicao_do_planejamento_urbano_no_territorio_da_comunidade_quilombola_do_abacatal_pa_a_luta_pela_garantia_da_sustentabilidade_da_vida from https://repositorio.ufpa.br/server/api/core/bitstreams/2c3c70ea-0264-4469-b22f-a72c55b7adb3/content
# Loading triplas: a_sobreposicao_do_planejamento_urbano_no_territorio_da_comunidade_quilombola_do_abacatal_pa_a_luta_pela_garantia_da_sustentabilidade_da_vida
# Total time: 0 days 00:30:23.317411
# Partial time: 0 days 00:01:59.623961
# 20 - Downloading and extracting: nem_parece_que_tem_quilombola_aqui_in_visibilidade_da_identidade_quilombola_no_processo_formativo_da_cfr_do_territorio_quilombola_de_jambuacu_pe_sergio_tonetto from https://repositorio.ufpa.br/server/api/core/bitstreams/3d28bf99-d285-49b2-9cd4-13458eb6ea50/content
# Loading triplas: nem_parece_que_tem_quilombola_aqui_in_visibilidade_da_identidade_quilombola_no_processo_formativo_da_cfr_do_territorio_quilombola_de_jambuacu_pe_sergio_tonetto
# Total time: 0 days 00:31:45.410258
# Partial time: 0 days 00:01:22.091846
# 21 - Downloading and extracting: territorialidades_especificas_em_barcarena_confrontadas_com_projetos_de_desenvolvimento from https://repositorio.ufpa.br/server/api/core/bitstreams/2debcd96-2f51-4381-b02d-47085dd1ef07/content
# Loading triplas: territorialidades_especificas_em_barcarena_confrontadas_com_projetos_de_desenvolvimento
# Total time: 0 days 00:35:24.988452
# Partial time: 0 days 00:03:39.578194
# 22 - Downloading and extracting: avaliacao_epidemiologica_clinica_e_molecular_de_enteropatogenos_causadores_de_diarreia_aguda_em_criancas_e_adultos_residentes_na_comunidade_quilombola_do_abacatal_ananindeua_para from https://repositorio.ufpa.br/server/api/core/bitstreams/cc0d4d74-446c-429f-87c2-f4f76677eef2/content
# Loading triplas: avaliacao_epidemiologica_clinica_e_molecular_de_enteropatogenos_causadores_de_diarreia_aguda_em_criancas_e_adultos_residentes_na_comunidade_quilombola_do_abacatal_ananindeua_para
# Total time: 0 days 00:36:43.951659
# Partial time: 0 days 00:01:18.964211
# 23 - Downloading and extracting: conhecimento_etnobotanico_de_moradores_da_comunidade_quilombola_itaboca_municipio_de_inhangapi_estado_do_para from https://repositorio.ufpa.br/server/api/core/bitstreams/40f2e17b-8a68-4e20-9143-28f1b56cd5f1/content
# Loading triplas: conhecimento_etnobotanico_de_moradores_da_comunidade_quilombola_itaboca_municipio_de_inhangapi_estado_do_para
# Total time: 0 days 00:37:26.844206
# Partial time: 0 days 00:00:42.892590
# 24 - Downloading and extracting: estudo_comparativo_entre_reatores_uasb_e_tanque_septico_em_escala_unifamiliar_no_tratamento_de_esgoto_de_comunidade_quilombola_amazonica from https://repositorio.ufpa.br/server/api/core/bitstreams/706c90cb-45f0-4973-987b-de7091836b52/content
# Loading triplas: estudo_comparativo_entre_reatores_uasb_e_tanque_septico_em_escala_unifamiliar_no_tratamento_de_esgoto_de_comunidade_quilombola_amazonica
# Total time: 0 days 00:38:59.631961
# Partial time: 0 days 00:01:32.786708
# No PDF link found for os_tambores_da_africa_reverberam_aqui_o_projeto_batuque_como_pratica_decolonial_na_comunidade_quilombola_de_sao_pedro_dos_boisap
# No PDF link found for cultura_territorialidade_e_desenvolvimento_local_o_caso_da_apa_do_rio_curiau_no_amapa
# No PDF link found for prevalencia_da_infeccao_pelo_virus_linfotropico_de_celulas_t_humanas_em_mulheres_de_comunidades_remanescentes_de_quilombos_de_santarem_para
# No PDF link found for cadastro_ambiental_rural_em_terras_de_uso_comum_desafios_e_aprendizagens_da_elaboracao_coletiva_a_partir_do_territorio_quilombola_do_jambuacu_moju__pa
# No PDF link found for minha_viola_e_de_buriti_uma_etnomusicologia_aplicadaparticipativaengajada_sobre_a_musicalidade_no_quilombo_mumbuca_no_jalapao_to
# No PDF link found for conflito_socioambiental_e_gestao_de_recursos_naturais_em_territorios_quilombolas_marajoaras_o_caso_da_comunidade_deus_me_ajude_salvaterra_marajopa
# No PDF link found for uma_camera_para_os_quilombolas_representacoes_imageticas_de_si_e_da_cultura_negra_em_ourempa
# No PDF link found for planejamento_energetico_para_pequenas_comunidades_da_amazonia_um_estudo_de_caso_da_comunidade_quilombola_de_genipauba__abaetetuba__para
# No PDF link found for memorias_e_saberes_quilombolas_acerca_dos_sistemas_alimentares_em_contexto_de_expropriacao_territorial_do_quilombo_da_bocaina_porto_estrela_mato_grosso
# No PDF link found for do_quilombo_a_universidade_trajetorias_relatos_representacoes_e_desafios_de_estudantes_quilombolas_da_universidade_federal_do_paracampus_belem_quanto_a_permanencia
# No PDF link found for igarapemiri_a_passagem_da_escravidao_ao_trabalho_livre_numa_regiao_de_engenhos_graopara_18431888
# No PDF link found for contabilizando_os_custos_do_trabalho_escravo_em_empresas_e_fazendas
# No PDF link found for a_critica_da_modernidade_em_nietzsche_o_ultimo_homem_e_o_tipo_escravo
# No PDF link found for trabalho_escravo_e_aliciamento_proposta_para_a_regularizacao_da_relacao_juridica_de_emprego
# No PDF link found for liberdade_sem_sustos_nem_inquietacoes_significados_e_sentidos_do_fundo_de_emancipacao_no_graopara_18711888
# No PDF link found for o_carater_educativo_do_cdvdhcb_no_enfrentamento_ao_trabalho_escravo
# No PDF link found for escravidao_negra_em_belem_mercado_trabalho_e_liberdade_18101850
# No PDF link found for escravos_selvagens_e_loucos_estudos_sobre_figuras_da_animalidade_no_pensamento_de_nietzsche_e_foucault
# No PDF link found for em_outras_margens_do_atlantico_trafico_negreiro_para_o_estado_do_maranhao_e_graopara_17071750
# No PDF link found for pesquisa_de_rotavirus_e_endoparasitos_em_animais_na_comunidade_quilombola_do_abacatal_municipio_de_ananindeua_para
# No PDF link found for trabalho_em_condicoes_analogas_ao_de_escravo_uma_analise_a_partir_da_jurisprudencia_do_trf_3a_da_regiao
# No PDF link found for saberes_ribeirinhos_quilombolas_e_sua_relacao_com_a_educacao_de_jovens_e_adultos_da_comunidade_de_sao_joao_do_medio_itacuruca_abaetetubapa
# No PDF link found for territorio_quilombola_do_curiau_e_area_de_protecao_ambiental_do_rio_curiau_interpretacoes_dos_conflitos_socioambientais_pela_economia_ecologica
# No PDF link found for etnomatematica_quilombola_as_relacoes_dos_saberes_da_matematica_dialogica_com_as_praticas_socioculturais_dos_remanescentes_de_quilombo_do_molaitapocupa
# No PDF link found for do_tempo_dos_pretos_dantes_aos_povos_do_aproaga_patrimonio_arqueologico_e_territorialidade_quilombola_no_vale_do_rio_capim_pa
# No PDF link found for exploracao_madeireira_e_trabalho_analogo_ao_de_escravo_no_estado_do_para_o_caso_do_arquipelago_do_marajo
# No PDF link found for direitos_humanos_trafico_de_pessoas_e_exploracao_sexual_de_mulheres_em_belemparabrasil
# No PDF link found for aspectos_estruturais_da_inspecao_do_trabalho_no_brasil_e_o_combate_a_escravidao_contemporanea_uma_analise_do_trabalho_escravo_na_construcao_civil_no_estado_do_para
# No PDF link found for os_conceitos_de_trabalho_escravo_contemporaneo_na_jurisprudencia_brasileira_e_na_corte_interamericana_de_direitos_humanos_a_busca_da_maior_protecao_ao_trabalhador
# No PDF link found for trabalho_escravo_urbano_na_construcao_civil_condicoes_degradantes_e_a_experiencia_do_operariado_vinculado_ao_sindicato_dos_trabalhadores_da_industria_da_construcao_civil_e_em_frentes_de_obras_em_belem_do_para
# No PDF link found for uso_dos_recursos_alimentares_por_populacoes_quilombolas_da_amazonia_brasileira
# No PDF link found for revitalizacao_e_potencializacao_da_atividade_piscicola_na_comunidade_remanescentes_de_quilombo_de_itacoamiri_municipio_de_acara__pa
# No PDF link found for em_nome_de_deus_amem_mulheres_escravos_familias_e_herancas_atraves_dos_testamentos_em_belem_do_graopara_na_primeira_metade_do_seculo_xix
# No PDF link found for o_trabalho_escravo_contemporaneo_como_fator_de_descumprimento_da_funcao_social_da_propriedade_rural
# No PDF link found for territorialidade_e_uso_comum_entre_os_quilombolas_de_santa_rita_da_barreira_em_contradicao_com_politicas_de_etnodesenvolvimento
# No PDF link found for territorio_de_pesca_no_estuario_marajoara_comunidades_quilombolas_aguas_de_trabalho_e_conflito_no_municipio_de_salvaterra_para
# No PDF link found for trabalho_escravo_contemporaneo_no_brasil_ambivalencias_e_ambiguidades_na_operacionalizacao_da_politica
# No PDF link found for intervencao_e_exploracao_de_recursos_naturais_em_comunidade_quilombola_o_caso_de_abacatal
# 63 - Downloading and extracting: seguranca_alimentar_em_comunidades_quilombolas_estudo_comparativo_de_santo_antonio_concordia_do_para_e_cacau_colares_para from https://repositorio.ufpa.br/server/api/core/bitstreams/1f55934a-0443-432d-842f-31d784bac89b/content
# Loading triplas: seguranca_alimentar_em_comunidades_quilombolas_estudo_comparativo_de_santo_antonio_concordia_do_para_e_cacau_colares_para
# Total time: 0 days 00:41:10.499911
# Partial time: 0 days 00:02:10.869966
# No PDF link found for impactos_socioterritoriais_e_identidade_quilombola_em_espaco_metropolitano_o_caso_da_comunidade_de_abacatal_para
# No PDF link found for analise_de_documentos_que_compoem_as_nocoes_acerca_das_praticas_de_exploracao_de_trabalhadores_rurais_um_estudo_genealogico
# No PDF link found for paleoambiente_e_quimioestratigrafia_da_formacao_serra_do_quilombo_neoproterozoico_da_faixa_paraguai_norte_regioes_de_caceres_e_nobres_mt
# No PDF link found for o_enfrentamento_ao_trabalho_escravo_na_amazonia_maranhense_uma_analise_da_atuacao_do_cdvdhcb_no_municipio_de_acailandiama
# No PDF link found for entre_costas_brasilicas_o_trafico_interno_de_escravos_em_direitura_a_amazonia_c1778c1830
# No PDF link found for odo_iya_da_espetacularidade_do_yle_ase_oba_okuta_ayra_yntyle_ao_corpocena
# No PDF link found for entrelaces_da_resistencia_comunicacao_e_praticas_emancipatorias_de_mulheres_negras_trancadeiras_da_amazonia
# No PDF link found for pombo_pato_galinha_bode_bichos_em_transito_estudo_etnografico_sobre_as_apropriacoes_de_animais_no_ile_ase_iya_ogunte__um_templo_de_candomble_na_amazonia
# No PDF link found for o_candomble_no_amapa_historia_memoria_imigracao_e_hibridismo_cultural
# No PDF link found for o_ensino_de_historia_e_as_mulheres_negras_contribuicoes_para_a_formacao_de_identidades_negras_no_ensino_fundamental
# No PDF link found for a_terra_da_liberdade_e_a_memoria_estudantil_ensino_de_historia_e_negritude_em_benevides__para
# No PDF link found for saberes_tradicionais_a_partir_do_jogo_de_buzios_no_candomble
# No PDF link found for marcha_virtual_das_mulheres_negras_amazonidas_dimensoes_interseccionais_na_comunicacao_ativista_em_tempos_de_pandemia
# No PDF link found for historias_de_brancos_memoria_historiografia_dos_indios_manao_do_rio_negro_seculo_xviiixx
# No PDF link found for relacoes_sociais_na_escola_representacoes_de_alunos_negros_sobre_as_relacoes_que_estabelecem_no_espaco_escolar
# No PDF link found for leis_mortes_e_fugas_o_processo_de_abolicao_da_escravidao_e_a_entrada_dos_imigrantes_no_piaui_1872__1887
# No PDF link found for um_estudo_sobre_intelectuais_negros_na_academia_entre_1970_e_1990_trajetoria_academica_de_florentina_da_silva_souza
# No PDF link found for o_campo_tem_cor_presencaausencia_do_negro_no_curriculo_da_educacao_do_campo_no_para
# No PDF link found for o_quadro_de_escrever_como_mediador_na_relacao_professoraluno_na_aula_de_matematica
# No PDF link found for secao_de_choque_de_absorcao_de_buracos_negros_de_schwarzschild_e_de_buracos_acusticos_canonicos
# No PDF link found for variacao_geografica_zonas_de_intergradacao_e_especiacao_no_complexo_icterus_cayanensischrysocephalus_aves__icteridae
# No PDF link found for comunidad_negra_de_itacoa_territorio_biodiversidad_y_organizacion_social_pilares_para_el_etnodesarrollo
# No PDF link found for a_maconaria_e_a_campanha_abolicionista_no_para18701888
# No PDF link found for o_racismo_na_trajetoria_escolar_e_profissional_de_professoras_universitarias
# No PDF link found for o_negro_na_literatura_sob_a_perspectiva_filosoficoliteraria_de_friedrich_nietzsche_e_bruno_de_menezes_civilizacao_religiao_e_corpo
# No PDF link found for familia_negra_como_resistencia_o_uso_de_fontes_em_sala_de_aula_para_um_ensino_de_historia_antirracista
# No PDF link found for a_hidra_e_os_pantanos_quilombos_e_mocambos_no_brasil_secs_xviixix
# No PDF link found for negro_e_ensino_medio_representacoes_de_professores_acerca_de_relacoes_raciais_no_curriculo
# No PDF link found for compartimentacao_morfotectonica_do_interfluvio_solimoesnegro
# No PDF link found for ingleses_pretos_barbadianos_negros_brasileiros_morenos_identidades_e_memorias_belem_seculos_xx_e_xxi
# No PDF link found for o_quadro_de_escrever_como_mediador_para_construcao_de_relacoes_de_autonomia_no_ambiente_de_sala_de_aula
# No PDF link found for despatologizacao_das_vivencias_trans_o_impacto_da_abolicao_do_diagnostico_de_genero_nos_direitos_das_pessoas_trans
# No PDF link found for o_movimento_negro_e_o_processo_de_elaboracao_das_diretrizes_curriculares_nacionais_para_a_educacao_das_relacoes_etnicoraciais
# 97 - Downloading and extracting: os_herdeiros_de_ananse_movimento_negro_acoes_afirmativas_cotas_para_negros_na_universidade from https://repositorio.ufpa.br/server/api/core/bitstreams/3c414889-a9ed-4b41-91e8-d0998639331c/content
# Loading triplas: os_herdeiros_de_ananse_movimento_negro_acoes_afirmativas_cotas_para_negros_na_universidade
# Total time: 0 days 00:45:31.828103
# Partial time: 0 days 00:04:21.328201
# 98 - Downloading and extracting: movimento_negro_em_belem__acao_coletiva_de_combate_ao_racismo_e_defesa_de_negras_e_negros from https://repositorio.ufpa.br/server/api/core/bitstreams/e046ba22-7510-4783-a850-f6ff922b0f5d/content
