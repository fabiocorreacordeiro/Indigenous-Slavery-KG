# %%
#%pip install beautifulsoup4
#%pip install pip-system-certs

# %%
import requests
from bs4 import BeautifulSoup as bs
import pandas as pd
import os
from langchain_community.graphs import Neo4jGraph
from PyPDF2 import PdfReader
from langdetect import detect
import spacy
import re
from unidecode import unidecode
import time

# %% [markdown]
# Conectando ao Neo4j

# %%
from neo4j import GraphDatabase

# Neo4j variables
NEO4J_URL = os.getenv("NEO4J_URL")
NEO4J_USERNAME =os.getenv("NEO4J_USERNAME")
NEO4J_PASSWORD = os.getenv("NEO4J_PASSWORD")


graph = GraphDatabase.driver(NEO4J_URL, auth=(NEO4J_USERNAME, NEO4J_PASSWORD))

# %% [markdown]
# - Buscar os links para a tese no Neo4j
# - Buscar o link do PDF no repositório da universidade
# - Baixar o PDF
# - Extrair o texto do PDF

# %% [markdown]
# Buscar links para a tese no Neo4j

# %%
# Query to get theses and their repositories from the Neo4j database
# This query retrieves theses that are published by the Campinas State University (UNICAMP) and have not been processed yet.
query1 = """
MATCH (t:Thesis)-[:publisher]-(uni:University{uri:'tag:stardog:api:UNICAMP'})
WHERE NOT EXISTS {(t{processed:true})}
RETURN distinct(t["uri"]) as Thesis, t["repository"] as repository 
"""

# Alternative query to get theses that do not have excerpts and have been processed.
query2 = """ 
match (t:Thesis)-[:publisher]-(uni:University{uri:'tag:stardog:api:UNICAMP'})
where (not (t:Thesis)-[:BFO_0000050]-(:Exerpt)) and  exists {(t{processed:true})}
return distinct(t["uri"]) as Thesis, t["repository"] as repository
"""

# Query to retrive theses with few pages and their repositories.
query3 = """
MATCH (t:Thesis)-[:publisher]-(uni:University{uri:'tag:stardog:api:UNICAMP'})
Match (t:Thesis)-[:BFO_0000050]-(e:Exerpt)
RETURN count(e) as pages, t["uri"] as Thesis, t["repository"] as repository
 order by (pages) limit 40
"""

graph = GraphDatabase.driver(NEO4J_URL, auth=(NEO4J_USERNAME, NEO4J_PASSWORD))
results = graph.execute_query(query1).records
graph.close()

#results = graph.query(query2)
# Convert the results to a DataFrame
#thesis_repository = pd.DataFrame(results, columns=["pages", "Thesis", "repository"])
thesis_repository = pd.DataFrame(results, columns=["Thesis", "repository"])
thesis_repository = thesis_repository.reset_index(drop=True) 
thesis_repository
# Out:
#                                                  Thesis  \
# 0     tag:stardog:api:os_sentidos_de_liberdade_dos_e...
# 1     tag:stardog:api:saude_indigena_institucional_p...
# 2     tag:stardog:api:os_nao_saberes_sobre_linguas_i...
# 3     tag:stardog:api:trancando_com_os_baniwa__por_u...
# 4     tag:stardog:api:terra_arrasada_e_acumulacao_po...
# ...                                                 ...
# 1044  tag:stardog:api:tecendo_lacos_e_ligando_pontos...
# 1045  tag:stardog:api:historias_de_brancos__memoria_...
# 1046  tag:stardog:api:poeticas_negras_em_movimento__...
# 1047  tag:stardog:api:comportamento_de_algumas_medid...
# 1048  tag:stardog:api:revista_estudos_afroasiaticos_...
#
#                                        repository
# 0                                            None
# 1       https://hdl.handle.net/20.500.12733/16274
# 2       https://hdl.handle.net/20.500.12733/19975
# 3       https://hdl.handle.net/20.500.12733/10530
# 4        https://hdl.handle.net/20.500.12733/9802
# ...                                           ...
# 1044       https://hdl.handle.net/20.500.12733/51
# 1045  https://hdl.handle.net/20.500.12733/1585937
# 1046     https://hdl.handle.net/20.500.12733/4981
# 1047  https://hdl.handle.net/20.500.12733/1576566
# 1048  https://hdl.handle.net/20.500.12733/1588385
#
# [1049 rows x 2 columns]

# %% [markdown]
# Criando as utils functions

# %%
# Funcao para coletar link do pdf

def get_pdf_link(url):
    
    #Fazer requisição e parsear o arquivo html
    if url == None:
        return None
    else:
        try:
            f = requests.get(url, verify=True).text#, verify=False) 
        except:
            print("Sleeping for 5 seconds before retrying...")
            time.sleep(5)
            try:
                f = requests.get(url, verify=True).text#, verify=False) 
            except:
                print("Sleeping for 30 seconds before retrying...")
                time.sleep(30)
                f = requests.get(url, verify=True).text#, verify=False)    
        soup = bs(f, "html.parser")
        
        #Coletando link para as teses
        link_list = []
        for doc in soup.find_all('a', href=True):
            if doc['href'].startswith('/Busca/Download'):     # (doc['href'].endswith('.pdf')):# & doc['href'].startswith('/bitstream')):
                path = doc['href']
                prefix_uni = 'https://repositorio.unicamp.br'
                link = prefix_uni + path
                link_list.append(link)
        if link_list != []:
            return list(set(link_list))
        else:
            return None
    
    #return None

#fazer download do arquivo
def download_file(pdf_link, thesis_uri):


    # NOTE the stream=True parameter below
    try:
        r = requests.get(pdf_link, verify=True, stream=True)
    except:
        print("Sleeping for 5 seconds before retrying...")
        time.sleep(5)
        try:
            r = requests.get(pdf_link, verify=True, stream=True)
        except:
            print("Sleeping for 30 seconds before retrying...")
            time.sleep(30)
            r = requests.get(pdf_link, verify=True, stream=True)
    # raise_for_status() is not needed with stream=True
    # r.raise_for_status()
    with open('tese UNICAMP.pdf', 'wb') as f:
        for chunk in r.iter_content(chunk_size=8192):
            f.write(chunk)
    return 

#Carregando os modelos SpaCy para inglês e português 
nlp_en = spacy.load("en_core_web_lg")
nlp_pt = spacy.load("pt_core_news_lg")

# Funcão que recebe uma string e a limpar para ficar no formato aceitável para uma URI
def process_uri(x):
    return (re.sub('[^a-zA-Z0-9_ ]', '',
            unidecode(x.strip())
                        .replace(" ", "_")
                        .replace("[","")
                        .replace("]","")
                        .replace("?","")
                        .replace("'","")
                        .lower()))


# Função para extrair texto de uma tese em PDF e identificar entidades
def extratc_text(tese_path):
    
    # Processando o arquivo em PDF
    try:
        reader = PdfReader(tese_path)
    except:
        print(f"Erro ao ler o arquivo {tese_path}. ")
        excerpt = {}
        return excerpt
    number_of_pages = len(reader.pages)
    excerpt = {}
    

    # Iterando por cada página
    for page_number in range(number_of_pages):
        
        
        
        # Extraindo o texto da página
        try:
            if page_number == 0:
                try:
                    page_text = (reader.pages[page_number].extract_text() + '\n ' 
                                + reader.pages[page_number+1].extract_text()[:400])
                except:
                    page_text = reader.pages[page_number].extract_text()
            else:
                
                if page_number == number_of_pages -1:
                    try:
                        page_text = (reader.pages[page_number-1].extract_text()[-400:] + '\n ' 
                                    + reader.pages[page_number].extract_text())
                    except:
                        page_text = reader.pages[page_number].extract_text()
                
                else:
                    try:
                        page_text = (reader.pages[page_number-1].extract_text()[-400:] + '\n ' 
                                    + reader.pages[page_number].extract_text() + '\n ' 
                                    + reader.pages[page_number+1].extract_text()[:400])  
                    except:
                        page_text = reader.pages[page_number].extract_text()
        except:
            page_text = ''
        
        # Limpando page text         
        page_text = page_text.replace("'", "").replace('"', '')
        # Verifica se o último caractere é uma barra invertida
        if page_text != '':
            if page_text[-1] == '\\': 
                page_text = page_text[:-1]
        page_text = re.sub(r"[\ud800-\udfff]", " ", page_text)
        page_text = page_text.encode('utf-8').decode('utf-8')
        
        
        # Detectando o idioma do texto
        try:
            lang = detect(page_text)
            
        except:
            lang = 'Não_detectado'
        
        
        # Extraindo as entidades
        page_extracted = False
        if lang == 'pt':
            doc = nlp_pt(page_text)
            page_extracted = True
        if lang == 'en':
            doc = nlp_en(page_text)
            page_extracted = True
        

        if page_extracted:

            persons = []
            gpes = []
            #orgs = []
            for ent in doc.ents:
                if ent.label_ == "PER": #"PERSON":
                    persons.append(process_uri(ent.text))
                if ent.label_ == "LOC": #"GPE":
                    gpes.append(process_uri(ent.text))
                #if ent.label_ == "ORG":
                #    orgs.append(process_uri(ent.text))
                    
            excerpt[page_number] = {'text': page_text, 
                                    'lang': lang, 
                                    'persons': list(set(persons)), 
                                    'gpes': list(set(gpes)),
                                #'orgs': list(set(orgs))
                                }

    return excerpt

# %% [markdown]
# Iterando por todas as URI para extrair o texto e gravar no grafo NEO4j

# %%
# Gravar hora de início do processamento
start_time = pd.Timestamp.now()
parcial_time = pd.Timestamp.now()

for i in range(0,len(thesis_repository)):

    # Coletando o link do PDF
    url = thesis_repository['repository'][i]
    thesis_uri = thesis_repository['Thesis'][i][16:]
    pdf_link = get_pdf_link(url)
    if pdf_link is not None:
        # Itereando pelos links de PDF encontrados (em alguns casos há outros materiais além da tese)
        for pdf_num in range(len(pdf_link)):
            print(f"{i} - Downloading and extracting: {thesis_uri} from {pdf_link[pdf_num]}")
            download_file(pdf_link[pdf_num], thesis_uri)

            # Extraindo o texto e entidades
            tese_path = 'tese UNICAMP.pdf'
            excerpt = extratc_text(tese_path)

            excerpts = []
            persons = []
            gpes = []

            # Salvando as triplas em CSV
            for n in excerpt.keys():

                excerpt_uri = thesis_repository['Thesis'][i] + '_pdf_' + str(pdf_num) + '_p_' + str(n)
                excerpt_text = excerpt[n]['text']
                # Verifica se o último caractere é uma barra invertida
                #if excerpt_text[-1] == '\\': 
                #    excerpt_text = excerpt_text[:-1]
                

                excerpt_page = 'pdf_' + str(pdf_num) + '_p_' + str(n)
                excerpt_lang = excerpt[n]['lang']
                
                excerpts.append([thesis_repository['Thesis'][i], excerpt_uri, excerpt_text, excerpt_page, excerpt_lang])
                    
                #Criando as relações com as entidades
                for person in excerpt[n]['persons']:
                    persons.append([excerpt_uri, 'tag:stardog:api:' + person])
                
                for gpe in excerpt[n]['gpes']:
                    gpes.append([excerpt_uri, 'tag:stardog:api:' + gpe])
            
            # Salvando os dados em CSV no diretório de importação do Neo4j
            pd.DataFrame(excerpts).to_csv('C:\\Users\\facordei\\.Neo4jDesktop\\relate-data\\dbmss\\dbms-792eabfc-5517-4220-ab29-30ef6ec3236e\\import\\excerptsUNICAMP.csv', index=False, header=False)
            pd.DataFrame(persons).to_csv('C:\\Users\\facordei\\.Neo4jDesktop\\relate-data\\dbmss\\dbms-792eabfc-5517-4220-ab29-30ef6ec3236e\\import\\personsUNICAMP.csv', index=False, header=False)
            pd.DataFrame(gpes).to_csv('C:\\Users\\facordei\\.Neo4jDesktop\\relate-data\\dbmss\\dbms-792eabfc-5517-4220-ab29-30ef6ec3236e\\import\\gpesUNICAMP.csv', index=False, header=False)

            #Deletando o arquivo PDF após o processamento
            os.remove('tese UNICAMP.pdf')

            print(f"Loading triplas: {thesis_uri}")

            # Importanto os dados para o Neo4j
            #Excerpts
            query = """
            LOAD CSV FROM 'file:///excerptsUNICAMP.csv'
            AS row
            MATCH  (t:Thesis{uri: row[0]})
            MERGE  (e:Exerpt{
                    uri: row[1],
                    text: row[2],
                    page: row[3],
                    lang: row[4]
                    })-[r:BFO_0000050]-(t);
            """
            graph = GraphDatabase.driver(NEO4J_URL, auth=(NEO4J_USERNAME, NEO4J_PASSWORD))
            results = graph.execute_query(query)
            graph.close()

            #Persons
            query = """
            LOAD CSV FROM 'file:///personsUNICAMP.csv'
            AS row
            MATCH  (e:Exerpt{uri: row[0]})
            MERGE  (p:Person{uri: row[1]})
            MERGE  (e)-[r:mentions]-(p);
            """
            graph = GraphDatabase.driver(NEO4J_URL, auth=(NEO4J_USERNAME, NEO4J_PASSWORD))
            results = graph.execute_query(query)
            graph.close()

            #GPEs
            query = """
            LOAD CSV FROM 'file:///gpesUNICAMP.csv'
            AS row
            MATCH  (e:Exerpt{uri: row[0]})
            MERGE  (p:Place{uri: row[1]})
            MERGE  (e)-[r:mentions]-(p);
            """
            graph = GraphDatabase.driver(NEO4J_URL, auth=(NEO4J_USERNAME, NEO4J_PASSWORD))
            results = graph.execute_query(query)
            graph.close()

            # Removendo os arquivos CSV após a importação
            os.remove('C:\\Users\\facordei\\.Neo4jDesktop\\relate-data\\dbmss\\dbms-792eabfc-5517-4220-ab29-30ef6ec3236e\\import\\excerptsUNICAMP.csv')
            os.remove('C:\\Users\\facordei\\.Neo4jDesktop\\relate-data\\dbmss\\dbms-792eabfc-5517-4220-ab29-30ef6ec3236e\\import\\personsUNICAMP.csv')
            os.remove('C:\\Users\\facordei\\.Neo4jDesktop\\relate-data\\dbmss\\dbms-792eabfc-5517-4220-ab29-30ef6ec3236e\\import\\gpesUNICAMP.csv')

            print(f"Total time: {pd.Timestamp.now() - start_time}")
            print(f"Partial time: {pd.Timestamp.now() - parcial_time}")
            # Atualizando a hora parcial
            parcial_time = pd.Timestamp.now()
    else:
        print(f"No PDF link found for {thesis_uri}")

    # gravando no grafo que a tese foi processada
    query = """
    MATCH  (t:Thesis{uri: \'""" + thesis_repository['Thesis'][i] +  """\'})
    SET t.processed = true
    """
    graph = GraphDatabase.driver(NEO4J_URL, auth=(NEO4J_USERNAME, NEO4J_PASSWORD))
    results = graph.execute_query(query)
    graph.close()
# Out:
# No PDF link found for os_sentidos_de_liberdade_dos_escravos_na_constituicao_do_sujeito_de_enunciacao_sustentada_pelo_instrumento_da_alforria
# 1 - Downloading and extracting: saude_indigena_institucional_programa_mais_medicos_e_cooperacao_cubana__a_atencao_diferenciada_a_partir_do_distrito_sanitario_indigena_amapa_e_norte_do_para from https://repositorio.unicamp.br/Busca/Download?codigoArquivo=592478&tipoMidia=0
# Loading triplas: saude_indigena_institucional_programa_mais_medicos_e_cooperacao_cubana__a_atencao_diferenciada_a_partir_do_distrito_sanitario_indigena_amapa_e_norte_do_para
# Total time: 0 days 00:01:15.027258
# Partial time: 0 days 00:01:15.028257
# 2 - Downloading and extracting: os_nao_saberes_sobre_linguas_indigenas_no_brasil__analise_da_serie_brasil_em_outras_linguas from https://repositorio.unicamp.br/Busca/Download?codigoArquivo=587578&tipoMidia=0
# Loading triplas: os_nao_saberes_sobre_linguas_indigenas_no_brasil__analise_da_serie_brasil_em_outras_linguas
# Total time: 0 days 00:01:43.821847
# Partial time: 0 days 00:00:28.793590
# 3 - Downloading and extracting: trancando_com_os_baniwa__por_uma_transformacao_de_nos_kariwa from https://repositorio.unicamp.br/Busca/Download?codigoArquivo=591412&tipoMidia=0
# Loading triplas: trancando_com_os_baniwa__por_uma_transformacao_de_nos_kariwa
# Total time: 0 days 00:02:27.145025
# Partial time: 0 days 00:00:43.323178
# 4 - Downloading and extracting: terra_arrasada_e_acumulacao_por_preservacao_da_natureza__um_estudo_sobre_a_modernizacao_capitalista_do_espaco_e_o_desenvolvimento_desigual_no_darienuraba_colombia from https://repositorio.unicamp.br/Busca/Download?codigoArquivo=556522&tipoMidia=0
# Loading triplas: terra_arrasada_e_acumulacao_por_preservacao_da_natureza__um_estudo_sobre_a_modernizacao_capitalista_do_espaco_e_o_desenvolvimento_desigual_no_darienuraba_colombia
# Total time: 0 days 00:03:35.641465
# Partial time: 0 days 00:01:08.496440
# 5 - Downloading and extracting: caminhando_para_aprender__caca_pessoa_e_movimento_nos_xikrin_do_bacaja from https://repositorio.unicamp.br/Busca/Download?codigoArquivo=589820&tipoMidia=0
# Loading triplas: caminhando_para_aprender__caca_pessoa_e_movimento_nos_xikrin_do_bacaja
# Total time: 0 days 00:04:59.718765
# Partial time: 0 days 00:01:24.078805
# 6 - Downloading and extracting: resistencia_etnica_e_resistencia_de_vida__contracondutas_revolucionarias_em_arte from https://repositorio.unicamp.br/Busca/Download?codigoArquivo=588428&tipoMidia=0
# Loading triplas: resistencia_etnica_e_resistencia_de_vida__contracondutas_revolucionarias_em_arte
# Total time: 0 days 00:05:57.512043
# Partial time: 0 days 00:00:57.791773
# 7 - Downloading and extracting: tecituras_de_fe__costuras_de_memorias_e_ancestralidade from https://repositorio.unicamp.br/Busca/Download?codigoArquivo=588894&tipoMidia=0
# Loading triplas: tecituras_de_fe__costuras_de_memorias_e_ancestralidade
# Total time: 0 days 00:06:24.702023
# Partial time: 0 days 00:00:27.189980
# 8 - Downloading and extracting: a_yoga_crista_de_padre_haroldo_rahm__ortopratica_e_corporeidade from https://repositorio.unicamp.br/Busca/Download?codigoArquivo=589645&tipoMidia=0
# Loading triplas: a_yoga_crista_de_padre_haroldo_rahm__ortopratica_e_corporeidade
# Total time: 0 days 00:06:48.211067
# Partial time: 0 days 00:00:23.509044
# 9 - Downloading and extracting: aplicacao_da_abordagem_lipidomica_no_estudo_do_tratamento_do_transtorno_da_depressao_maior_com_ayahuasca_em_pacientes_resistentes_a_antidepressivos_convencionais from https://repositorio.unicamp.br/Busca/Download?codigoArquivo=587171&tipoMidia=0
# Loading triplas: aplicacao_da_abordagem_lipidomica_no_estudo_do_tratamento_do_transtorno_da_depressao_maior_com_ayahuasca_em_pacientes_resistentes_a_antidepressivos_convencionais
# Total time: 0 days 00:07:19.325634
# Partial time: 0 days 00:00:31.114567
# 10 - Downloading and extracting: objetos_digitais_e_multiletramentos_para_o_ensino_de_linguas_na_educacao_de_indigenas_surdos__desafios_e_proposicoes from https://repositorio.unicamp.br/Busca/Download?codigoArquivo=591498&tipoMidia=0
# Loading triplas: objetos_digitais_e_multiletramentos_para_o_ensino_de_linguas_na_educacao_de_indigenas_surdos__desafios_e_proposicoes
# Total time: 0 days 00:07:48.737226
# Partial time: 0 days 00:00:29.411592
# 11 - Downloading and extracting: karaja_e_xavante__parentesco_macroje_ou_contato_linguistico from https://repositorio.unicamp.br/Busca/Download?codigoArquivo=494394&tipoMidia=0
# Loading triplas: karaja_e_xavante__parentesco_macroje_ou_contato_linguistico
# Total time: 0 days 00:08:05.870912
# Partial time: 0 days 00:00:17.133686
# 12 - Downloading and extracting: fotografias_festas_e_cultura_escolar_em_terras_da_amazonia_19601989 from https://repositorio.unicamp.br/Busca/Download?codigoArquivo=589384&tipoMidia=0
# Loading triplas: fotografias_festas_e_cultura_escolar_em_terras_da_amazonia_19601989
# Total time: 0 days 00:08:50.508805
# Partial time: 0 days 00:00:44.637893
# 13 - Downloading and extracting: instituto_baccarelli_e_o_canto_coral__ferramenta_para_formacao_e_transformacao_da_sociedade from https://repositorio.unicamp.br/Busca/Download?codigoArquivo=588792&tipoMidia=0
# Loading triplas: instituto_baccarelli_e_o_canto_coral__ferramenta_para_formacao_e_transformacao_da_sociedade
# Total time: 0 days 00:09:29.653057
# Partial time: 0 days 00:00:39.145253
# 14 - Downloading and extracting: historias_de_professoras_e_professores_da_transamazonica_e_xingu__interfaces_entre_memoria_e_formacao_docente from https://repositorio.unicamp.br/Busca/Download?codigoArquivo=588447&tipoMidia=0
# Loading triplas: historias_de_professoras_e_professores_da_transamazonica_e_xingu__interfaces_entre_memoria_e_formacao_docente
# Total time: 0 days 00:11:09.308213
# Partial time: 0 days 00:01:39.654155
# No PDF link found for a_influencia_dos_the_beatles_no_vegetarianismo__perspectivas_culturais_psicologicas_nutricionais_e_educacionais
# No PDF link found for ninguem_faz_a_reza_so__uma_etnografia_da_mobilidade_e_das_formas_de_cuidar_a_partir_das_mulheres_pankararu
# No PDF link found for disputas_pela_administracao_das_aldeias_indigenas_no_estado_do_maranhao_durante_a_uniao_iberica_16031647__a_questao_da_liberdade
# No PDF link found for contrastes_e_continuidades_em_uma_tradicao_amazonica__as_regioes_da_ayahuasca
# No PDF link found for a_pena_e_a_palavra__imagens_em_literaturas_indigenas
# No PDF link found for alteridade_em_a_queda_do_ceu_e_a_tarefa_de_escutar_as_palavras_de_um_xama_yanomami_em_desenhos_de_escrita
# No PDF link found for injectivity_of_biopolymers_solutions_through_porous_media__injetividade_de_solucoes_de_biopolimeros_atraves_de_meios_porosos
# No PDF link found for conhecimentos_indigenas_e_o_cultivo_de_generos_naturais_da_terra_no_estado_do_maranhao_e_graopara_16701757
# 23 - Downloading and extracting: vozes_ativistas_sobre_questoes_indigenas_em_plataformas_de_midia_social__potencialidades_revolucionarias from https://repositorio.unicamp.br/Busca/Download?codigoArquivo=587583&tipoMidia=0
# Loading triplas: vozes_ativistas_sobre_questoes_indigenas_em_plataformas_de_midia_social__potencialidades_revolucionarias
# Total time: 0 days 00:12:14.794567
# Partial time: 0 days 00:01:05.486354
# 24 - Downloading and extracting: imigracao_e_lutas_migrantes__redes_e_encruzilhadas_da_mobilizacao_por_direitos_e_contra_a_xenofobia_racializada_no_brasil_em_crise from https://repositorio.unicamp.br/Busca/Download?codigoArquivo=590877&tipoMidia=0
# Loading triplas: imigracao_e_lutas_migrantes__redes_e_encruzilhadas_da_mobilizacao_por_direitos_e_contra_a_xenofobia_racializada_no_brasil_em_crise
# Total time: 0 days 00:13:19.079144
# Partial time: 0 days 00:01:04.285577
# 25 - Downloading and extracting: auwe_uptabi_povo_do_sonho__nossas_historias_e_modos_de_educar from https://repositorio.unicamp.br/Busca/Download?codigoArquivo=590125&tipoMidia=0
# Loading triplas: auwe_uptabi_povo_do_sonho__nossas_historias_e_modos_de_educar
# Total time: 0 days 00:13:37.661790
# Partial time: 0 days 00:00:18.581646
# 26 - Downloading and extracting: sonhos_de_claudia_andujar__experimentalismo_e_cosmovisao_yanomami__dreams_by_claudia_andujar_experimentalism_and_yanomami_cosmovision from https://repositorio.unicamp.br/Busca/Download?codigoArquivo=588615&tipoMidia=0
# Loading triplas: sonhos_de_claudia_andujar__experimentalismo_e_cosmovisao_yanomami__dreams_by_claudia_andujar_experimentalism_and_yanomami_cosmovision
# Total time: 0 days 00:14:38.302368
# Partial time: 0 days 00:01:00.640578
# 27 - Downloading and extracting: as_visualidades_na_fabulacao_de_macunaima from https://repositorio.unicamp.br/Busca/Download?codigoArquivo=584439&tipoMidia=0
# Loading triplas: as_visualidades_na_fabulacao_de_macunaima
# Total time: 0 days 00:15:04.044655
# Partial time: 0 days 00:00:25.742287
# 28 - Downloading and extracting: manchando__o_que_fazer_com_a_menstruacao_estrategias_e_experimentos_para_vazar_questoes_feministas_atraves_das_tecnociencias from https://repositorio.unicamp.br/Busca/Download?codigoArquivo=573543&tipoMidia=0
# Loading triplas: manchando__o_que_fazer_com_a_menstruacao_estrategias_e_experimentos_para_vazar_questoes_feministas_atraves_das_tecnociencias
# Total time: 0 days 00:17:01.082924
# Partial time: 0 days 00:01:57.039280
# No PDF link found for guerreiros_do_alfabeto_estelar__iniciacao_em_performance_e_xamantismo_na_criacao_do_espetaculo_ka_de_renato_cohen
# 30 - Downloading and extracting: estudo_morfologico_em_linguas_arawak__uma_abordagem_tipologica from https://repositorio.unicamp.br/Busca/Download?codigoArquivo=587785&tipoMidia=0
# Loading triplas: estudo_morfologico_em_linguas_arawak__uma_abordagem_tipologica
# Total time: 0 days 00:18:41.547467
# Partial time: 0 days 00:01:40.463532
# 31 - Downloading and extracting: transitos_atravessamentos_e_trajetorias__bharatanatyam_interculturalidade_e_criacao_em_danca__transits_crossings_and_trajectories_bharatanatyam_interculturalism_and_dance_creation from https://repositorio.unicamp.br/Busca/Download?codigoArquivo=589605&tipoMidia=0
# Loading triplas: transitos_atravessamentos_e_trajetorias__bharatanatyam_interculturalidade_e_criacao_em_danca__transits_crossings_and_trajectories_bharatanatyam_interculturalism_and_dance_creation
# Total time: 0 days 00:19:03.225321
# Partial time: 0 days 00:00:21.677854
# 32 - Downloading and extracting: sistemas_agroflorestais_em_franjas_urbanas from https://repositorio.unicamp.br/Busca/Download?codigoArquivo=585876&tipoMidia=0
# Loading triplas: sistemas_agroflorestais_em_franjas_urbanas
# Total time: 0 days 00:19:49.505368
# Partial time: 0 days 00:00:46.280047
# 33 - Downloading and extracting: naturalizacao_do_ser_humano_e_humanizacao_da_natureza__uma_colcha_composta_por_muitos_retalhos from https://repositorio.unicamp.br/Busca/Download?codigoArquivo=591082&tipoMidia=0
# Loading triplas: naturalizacao_do_ser_humano_e_humanizacao_da_natureza__uma_colcha_composta_por_muitos_retalhos
# Total time: 0 days 00:20:21.604238
# Partial time: 0 days 00:00:32.098870
# 34 - Downloading and extracting: abordagens_omicas_na_analise_de_amostras_com_conhecimento_tradicional_associado__ayahuasca_e_folhas_de_psychotria_viridis_ruiz__pav from https://repositorio.unicamp.br/Busca/Download?codigoArquivo=586878&tipoMidia=0
# Loading triplas: abordagens_omicas_na_analise_de_amostras_com_conhecimento_tradicional_associado__ayahuasca_e_folhas_de_psychotria_viridis_ruiz__pav
# Total time: 0 days 00:21:04.647488
# Partial time: 0 days 00:00:43.044250
# 35 - Downloading and extracting: autoria_emergente_contemporanea_e_escrita_do_corpo__um_estudo_aplicado_a_romances_decoloniais_escritos_por_mulheres from https://repositorio.unicamp.br/Busca/Download?codigoArquivo=587650&tipoMidia=0
# Loading triplas: autoria_emergente_contemporanea_e_escrita_do_corpo__um_estudo_aplicado_a_romances_decoloniais_escritos_por_mulheres
# Total time: 0 days 00:21:31.140409
# Partial time: 0 days 00:00:26.493018
# 36 - Downloading and extracting: a_revolucao_na_india__o_movimento_naxalita_suas_estrategias_taticas_e_conexoes_internacionais from https://repositorio.unicamp.br/Busca/Download?codigoArquivo=570896&tipoMidia=0
# Loading triplas: a_revolucao_na_india__o_movimento_naxalita_suas_estrategias_taticas_e_conexoes_internacionais
# Total time: 0 days 00:22:49.169137
# Partial time: 0 days 00:01:18.027631
# 37 - Downloading and extracting: entre_rios_peixes_e_conhecimentos_em_praticas_de_ciencia_cidada_na_amazonia from https://repositorio.unicamp.br/Busca/Download?codigoArquivo=587557&tipoMidia=0
# Loading triplas: entre_rios_peixes_e_conhecimentos_em_praticas_de_ciencia_cidada_na_amazonia
# Total time: 0 days 00:23:23.128757
# Partial time: 0 days 00:00:33.959620
# 38 - Downloading and extracting: identidade_indigena_e_resistencia_politica_em_poemas_de_marcia_kambeba from https://repositorio.unicamp.br/Busca/Download?codigoArquivo=587892&tipoMidia=0
# Loading triplas: identidade_indigena_e_resistencia_politica_em_poemas_de_marcia_kambeba
# Total time: 0 days 00:23:40.924982
# Partial time: 0 days 00:00:17.796225
# 39 - Downloading and extracting: os_sentidos_de_ser_brasileiro_para_indigenas_terena from https://repositorio.unicamp.br/Busca/Download?codigoArquivo=587349&tipoMidia=0
# Loading triplas: os_sentidos_de_ser_brasileiro_para_indigenas_terena
# Total time: 0 days 00:24:11.771686
# Partial time: 0 days 00:00:30.846704
# 40 - Downloading and extracting: sobre_letras_e_leis__indianismo_e_justica_em_bernardo_guimaraes from https://repositorio.unicamp.br/Busca/Download?codigoArquivo=557842&tipoMidia=0
# Loading triplas: sobre_letras_e_leis__indianismo_e_justica_em_bernardo_guimaraes
# Total time: 0 days 00:24:58.240096
# Partial time: 0 days 00:00:46.469407
# 41 - Downloading and extracting: a_construcao_politica_da_categoria_infanticidio_indigena_e_o_mapeamento_de_seus_atores_sociais_no_brasil from https://repositorio.unicamp.br/Busca/Download?codigoArquivo=548649&tipoMidia=0
# Loading triplas: a_construcao_politica_da_categoria_infanticidio_indigena_e_o_mapeamento_de_seus_atores_sociais_no_brasil
# Total time: 0 days 00:25:38.496631
# Partial time: 0 days 00:00:40.256554
# 42 - Downloading and extracting: uma_historia_em_pedacos__invisibilidade_e_estereotipo_imagetico_da_tematica_indigena_em_livros_didaticos_20082017 from https://repositorio.unicamp.br/Busca/Download?codigoArquivo=588107&tipoMidia=0
# Loading triplas: uma_historia_em_pedacos__invisibilidade_e_estereotipo_imagetico_da_tematica_indigena_em_livros_didaticos_20082017
# Total time: 0 days 00:26:23.164771
# Partial time: 0 days 00:00:44.667124
# 43 - Downloading and extracting: paramo_merideno_agrobiodiversidad_y_produccion_de_conocimiento_asociado_a_semillas_de_papa__paramo_meridenho_agrobiodiversidade_e_producao_de_conhecimento_associado_a_sementes_de_batata from https://repositorio.unicamp.br/Busca/Download?codigoArquivo=589318&tipoMidia=0
# Loading triplas: paramo_merideno_agrobiodiversidad_y_produccion_de_conocimiento_asociado_a_semillas_de_papa__paramo_meridenho_agrobiodiversidade_e_producao_de_conhecimento_associado_a_sementes_de_batata
# Total time: 0 days 00:26:40.392818
# Partial time: 0 days 00:00:17.228047
# 44 - Downloading and extracting: o_grafismo_da_invencao_e_a_invencao_do_grafismo_ou_ensaio_para_uma_proposta_indisciplinar from https://repositorio.unicamp.br/Busca/Download?codigoArquivo=584825&tipoMidia=0
# Loading triplas: o_grafismo_da_invencao_e_a_invencao_do_grafismo_ou_ensaio_para_uma_proposta_indisciplinar
# Total time: 0 days 00:26:56.720760
# Partial time: 0 days 00:00:16.327942
# 45 - Downloading and extracting: uma_floresta_de_universos_alem__a_decolonialidade_e_a_etnossintaxe_como_dever_para_com_as_linguas_indigenas from https://repositorio.unicamp.br/Busca/Download?codigoArquivo=587816&tipoMidia=0
# Loading triplas: uma_floresta_de_universos_alem__a_decolonialidade_e_a_etnossintaxe_como_dever_para_com_as_linguas_indigenas
# Total time: 0 days 00:27:24.078250
# Partial time: 0 days 00:00:27.357490
# 46 - Downloading and extracting: paracimadaterra_em_massekury__a_linguagem_mitica_dos_jamamadi_do_alto_purus from https://repositorio.unicamp.br/Busca/Download?codigoArquivo=593044&tipoMidia=0
# Loading triplas: paracimadaterra_em_massekury__a_linguagem_mitica_dos_jamamadi_do_alto_purus
# Total time: 0 days 00:28:46.888618
# Partial time: 0 days 00:01:22.810368
# 47 - Downloading and extracting: caleidoscopio_missionario__aliancas_interesses_e_conflitos_entre_a_atuacao_de_agencias_missionarias_evangelicas_e_os_povos_indigenas_do_vale_do_javariam from https://repositorio.unicamp.br/Busca/Download?codigoArquivo=589330&tipoMidia=0
# Loading triplas: caleidoscopio_missionario__aliancas_interesses_e_conflitos_entre_a_atuacao_de_agencias_missionarias_evangelicas_e_os_povos_indigenas_do_vale_do_javariam
# Total time: 0 days 00:29:25.462091
# Partial time: 0 days 00:00:38.573473
# 48 - Downloading and extracting: estudos_das_categorias_nominais_em_enawene_nawe_aruak__uma_analise_preliminar from https://repositorio.unicamp.br/Busca/Download?codigoArquivo=587851&tipoMidia=0
# Loading triplas: estudos_das_categorias_nominais_em_enawene_nawe_aruak__uma_analise_preliminar
# Total time: 0 days 00:29:45.152331
# Partial time: 0 days 00:00:19.690240
# 49 - Downloading and extracting: bocuya_mara__processos_inventivos_entre_desenho_escrita_por_meio_dos_saberes_karirixoco from https://repositorio.unicamp.br/Busca/Download?codigoArquivo=588687&tipoMidia=0
# Loading triplas: bocuya_mara__processos_inventivos_entre_desenho_escrita_por_meio_dos_saberes_karirixoco
# Total time: 0 days 00:30:27.273473
# Partial time: 0 days 00:00:42.121142
# 50 - Downloading and extracting: os_lugares_da_marinhagem__trabalho_e_associativismo_em_manaus_19051919 from https://repositorio.unicamp.br/Busca/Download?codigoArquivo=590792&tipoMidia=0
# Loading triplas: os_lugares_da_marinhagem__trabalho_e_associativismo_em_manaus_19051919
# Total time: 0 days 00:31:38.983762
# Partial time: 0 days 00:01:11.710289
# 51 - Downloading and extracting: estudo_comparativo_das_mudancas_causadas_pela_experiencia_bilingue_na_estrutura_e_funcao_cerebral_de_idosos_saudaveis_e_idosos_com_doenca_de_alzheimer_via_revisao_sistematica from https://repositorio.unicamp.br/Busca/Download?codigoArquivo=585376&tipoMidia=0
# Loading triplas: estudo_comparativo_das_mudancas_causadas_pela_experiencia_bilingue_na_estrutura_e_funcao_cerebral_de_idosos_saudaveis_e_idosos_com_doenca_de_alzheimer_via_revisao_sistematica
# Total time: 0 days 00:31:51.634032
# Partial time: 0 days 00:00:12.650270
# 52 - Downloading and extracting: rastro_de_onca_no_romance_da_pedra_do_reino__a_mitificacao_de_uma_simbolica_perspectivista from https://repositorio.unicamp.br/Busca/Download?codigoArquivo=587834&tipoMidia=0
# Loading triplas: rastro_de_onca_no_romance_da_pedra_do_reino__a_mitificacao_de_uma_simbolica_perspectivista
# Total time: 0 days 00:33:01.742357
# Partial time: 0 days 00:01:10.108325
# 53 - Downloading and extracting: mbry_ro_sahoro__descricao_e_analise_linguistica_de_um_genero_de_fala_do_povo_khisetje from https://repositorio.unicamp.br/Busca/Download?codigoArquivo=591448&tipoMidia=0
# Loading triplas: mbry_ro_sahoro__descricao_e_analise_linguistica_de_um_genero_de_fala_do_povo_khisetje
# Total time: 0 days 00:33:39.131280
# Partial time: 0 days 00:00:37.388923
# 54 - Downloading and extracting: crise_ambiental_literaturamundial_e_o_paradigma_do_indico_em_joao_paulo_borges_coelho from https://repositorio.unicamp.br/Busca/Download?codigoArquivo=591501&tipoMidia=0
# Loading triplas: crise_ambiental_literaturamundial_e_o_paradigma_do_indico_em_joao_paulo_borges_coelho
# Total time: 0 days 00:35:44.671418
# Partial time: 0 days 00:02:05.540138
# 55 - Downloading and extracting: corpos_transitorios__a_utopia_brasil_e_o_discurso_indigenista_de_darcy_ribeiro from https://repositorio.unicamp.br/Busca/Download?codigoArquivo=590781&tipoMidia=0
# Loading triplas: corpos_transitorios__a_utopia_brasil_e_o_discurso_indigenista_de_darcy_ribeiro
# Total time: 0 days 00:39:00.639354
# Partial time: 0 days 00:03:15.967936
# 56 - Downloading and extracting: avanco_da_urbanizacao_e_das_praticas_capitalistas_na_amazonia_setentrional_e_o_caso_da_cidade_de_pacaraima_sobre_a_terra_indigena_sao_marcos__rr from https://repositorio.unicamp.br/Busca/Download?codigoArquivo=589788&tipoMidia=0
# Loading triplas: avanco_da_urbanizacao_e_das_praticas_capitalistas_na_amazonia_setentrional_e_o_caso_da_cidade_de_pacaraima_sobre_a_terra_indigena_sao_marcos__rr
# Total time: 0 days 00:42:16.688701
# Partial time: 0 days 00:03:16.049349
# 57 - Downloading and extracting: a_influencia_do_substrato_ito_nas_propriedades_eletronicas_e_opticas_de_monocamadas_de_wse2 from https://repositorio.unicamp.br/Busca/Download?codigoArquivo=590493&tipoMidia=0
# Loading triplas: a_influencia_do_substrato_ito_nas_propriedades_eletronicas_e_opticas_de_monocamadas_de_wse2
# Total time: 0 days 00:43:32.137579
# Partial time: 0 days 00:01:15.448899
# 58 - Downloading and extracting: pontes_de_papel__intelectuais_projetos_revolucionarios_e_concepcoes_americanistas_nos_cuadernos_americanos_19421959 from https://repositorio.unicamp.br/Busca/Download?codigoArquivo=590876&tipoMidia=0
# Loading triplas: pontes_de_papel__intelectuais_projetos_revolucionarios_e_concepcoes_americanistas_nos_cuadernos_americanos_19421959
# Total time: 0 days 00:45:04.966622
# Partial time: 0 days 00:01:32.828020
# No PDF link found for meliponicultores_do_rio_urubu__analise_da_dinamica_e_sustentabilidade_da_producao_de_mel_de_abelhas_indigenas_sem_ferrao_no_municipio_de_boa_vista_do_ramosam
# No PDF link found for sao_paulo_e_mumbai__crescimento_populacional_e_planejamento_urbano_em_megacidades_do_sul_global
# No PDF link found for arte_eletronica_indigena_interacoes_posdigitais__poeticas_multiculturais
# No PDF link found for floresta_de_gigantes__atores_e_estrategias_em_arenas_do_maior_bloco_de_areas_protegidas_da_amazonia
# No PDF link found for a_reinscricao_de_uma_lingua_destituida__o_nheengatu_no_baixo_tapajos
# No PDF link found for a_literatura_nativa_e_o_ensino_das_relacoes_etnicoraciais_nos_anos_iniciais_do_ensino_fundamental
# No PDF link found for kuzagwe__fazeres_e_saberes_de_mulheres_indigenas_tentehar_em_grajauma
# 66 - Downloading and extracting: uso_ritual_da_ayahuasca_durante_o_tratamento_de_doencas_fisicas_graves__um_estudo_qualitativo from https://repositorio.unicamp.br/Busca/Download?codigoArquivo=449804&tipoMidia=0
# Loading triplas: uso_ritual_da_ayahuasca_durante_o_tratamento_de_doencas_fisicas_graves__um_estudo_qualitativo
# Total time: 0 days 00:47:51.964803
# Partial time: 0 days 00:02:46.996666
# 67 - Downloading and extracting: saberes_acumulados_entre_grafismo_trancados_e_tramas__uma_analise_da_colecao_de_etnologia_do_museu_universitario_da_puccampinas from https://repositorio.unicamp.br/Busca/Download?codigoArquivo=492527&tipoMidia=0
# Loading triplas: saberes_acumulados_entre_grafismo_trancados_e_tramas__uma_analise_da_colecao_de_etnologia_do_museu_universitario_da_puccampinas
# Total time: 0 days 00:49:59.876393
# Partial time: 0 days 00:02:07.911607
# 68 - Downloading and extracting: rios_de_conhecimentos__os_povos_das_conquistas_e_as_expedicoes_cientificas_na_amazonia_e_na_africa_oriental_portuguesa_17801798 from https://repositorio.unicamp.br/Busca/Download?codigoArquivo=494999&tipoMidia=0
# Loading triplas: rios_de_conhecimentos__os_povos_das_conquistas_e_as_expedicoes_cientificas_na_amazonia_e_na_africa_oriental_portuguesa_17801798
# Total time: 0 days 00:52:42.346416
# Partial time: 0 days 00:02:42.470021
# 69 - Downloading and extracting: causos_do_sub_desenvolvimento__a_instalacao_do_presal_no_litoral_norte_paulista_e_a_resistencia_dos_povos_tradicionais from https://repositorio.unicamp.br/Busca/Download?codigoArquivo=548600&tipoMidia=0
# Loading triplas: causos_do_sub_desenvolvimento__a_instalacao_do_presal_no_litoral_norte_paulista_e_a_resistencia_dos_povos_tradicionais
# Total time: 0 days 00:55:11.606097
# Partial time: 0 days 00:02:29.259666
# 70 - Downloading and extracting: fonologia_e_morfossintaxe_da_lingua_mehinaku_arawak from https://repositorio.unicamp.br/Busca/Download?codigoArquivo=491608&tipoMidia=0
# Loading triplas: fonologia_e_morfossintaxe_da_lingua_mehinaku_arawak
# Total time: 0 days 01:00:46.289048
# Partial time: 0 days 00:05:34.683079
# 71 - Downloading and extracting: o_bordar_das_presencas_femininas_no_teatro_paraguaio_contado_ao_meu_filho from https://repositorio.unicamp.br/Busca/Download?codigoArquivo=588911&tipoMidia=0
# Loading triplas: o_bordar_das_presencas_femininas_no_teatro_paraguaio_contado_ao_meu_filho
# Total time: 0 days 01:02:59.640284
# Partial time: 0 days 00:02:13.350108
# 72 - Downloading and extracting: corpografias_originarias__processo_de_imersao_poetica_intercultural from https://repositorio.unicamp.br/Busca/Download?codigoArquivo=456794&tipoMidia=0
# Loading triplas: corpografias_originarias__processo_de_imersao_poetica_intercultural
# Total time: 0 days 01:03:59.622756
# Partial time: 0 days 00:00:59.982472
# 73 - Downloading and extracting: coletoras_de_sementes_e_semeadoras_de_florestas__o_protagonismo_das_mulheres_na_rede_de_sementes_do_xingu from https://repositorio.unicamp.br/Busca/Download?codigoArquivo=493508&tipoMidia=0
# Loading triplas: coletoras_de_sementes_e_semeadoras_de_florestas__o_protagonismo_das_mulheres_na_rede_de_sementes_do_xingu
# Total time: 0 days 01:04:27.714209
# Partial time: 0 days 00:00:28.091453
# 74 - Downloading and extracting: vidas_em_suspenso__imagens_e_narrativas_de_bento_rodrigues_mg_depois_do_rompimento_da_barragem_de_fundao from https://repositorio.unicamp.br/Busca/Download?codigoArquivo=497610&tipoMidia=0
# Loading triplas: vidas_em_suspenso__imagens_e_narrativas_de_bento_rodrigues_mg_depois_do_rompimento_da_barragem_de_fundao
# Total time: 0 days 01:14:53.943886
# Partial time: 0 days 00:10:26.229677
# 75 - Downloading and extracting: ortografia_e_norma__os_efeitos_das_reformas_ortograficas_em_alguns_toponimos_brasileiros from https://repositorio.unicamp.br/Busca/Download?codigoArquivo=491617&tipoMidia=0
# Loading triplas: ortografia_e_norma__os_efeitos_das_reformas_ortograficas_em_alguns_toponimos_brasileiros
# Total time: 0 days 01:36:33.119227
# Partial time: 0 days 00:21:39.175341
# 76 - Downloading and extracting: politicas_do_primitivismo_na_america_latina__raca_nacao_e_utopia_em_amauta_e_na_revista_de_antropofagia from https://repositorio.unicamp.br/Busca/Download?codigoArquivo=587519&tipoMidia=0
# Loading triplas: politicas_do_primitivismo_na_america_latina__raca_nacao_e_utopia_em_amauta_e_na_revista_de_antropofagia
# Total time: 0 days 01:38:18.943545
# Partial time: 0 days 00:01:45.824318
# 77 - Downloading and extracting: avaliacao_emergetica_e_indicadores_socioambientais_de_brasil_estados_unidos_e_mexico_nas_ultimas_sete_decadas from https://repositorio.unicamp.br/Busca/Download?codigoArquivo=462325&tipoMidia=0
# Loading triplas: avaliacao_emergetica_e_indicadores_socioambientais_de_brasil_estados_unidos_e_mexico_nas_ultimas_sete_decadas
# Total time: 0 days 01:39:41.204619
# Partial time: 0 days 00:01:22.261597
# 78 - Downloading and extracting: entre_experimentalismo_e_mercado__uma_analise_do_disco_joia_de_caetano_veloso from https://repositorio.unicamp.br/Busca/Download?codigoArquivo=483558&tipoMidia=0
# Loading triplas: entre_experimentalismo_e_mercado__uma_analise_do_disco_joia_de_caetano_veloso
# Total time: 0 days 01:42:03.880855
# Partial time: 0 days 00:02:22.675713
# 79 - Downloading and extracting: os_sentidos_do_museu_florestal_octavio_vecchi from https://repositorio.unicamp.br/Busca/Download?codigoArquivo=493620&tipoMidia=0
# Loading triplas: os_sentidos_do_museu_florestal_octavio_vecchi
# Total time: 0 days 01:44:06.092874
# Partial time: 0 days 00:02:02.212019
# 80 - Downloading and extracting: revolucao_ordem_e_progresso__ruptura_e_permanencia_na_cultura_politica_do_mexico_revolucionario_1867__1940 from https://repositorio.unicamp.br/Busca/Download?codigoArquivo=496266&tipoMidia=0
# Loading triplas: revolucao_ordem_e_progresso__ruptura_e_permanencia_na_cultura_politica_do_mexico_revolucionario_1867__1940
# Total time: 0 days 01:46:35.863689
# Partial time: 0 days 00:02:29.769815
# 81 - Downloading and extracting: caracterizacao_de_diferentes_oleos_de_copaiba_e_avaliacao_da_propriedade_cicatrizante from https://repositorio.unicamp.br/Busca/Download?codigoArquivo=456352&tipoMidia=0
# Loading triplas: caracterizacao_de_diferentes_oleos_de_copaiba_e_avaliacao_da_propriedade_cicatrizante
# Total time: 0 days 01:47:22.602597
# Partial time: 0 days 00:00:46.738908
# 82 - Downloading and extracting: a_ruina_a_espreita__leituras_do_romance_de_30 from https://repositorio.unicamp.br/Busca/Download?codigoArquivo=587792&tipoMidia=0
# Loading triplas: a_ruina_a_espreita__leituras_do_romance_de_30
# Total time: 0 days 01:49:08.468489
# Partial time: 0 days 00:01:45.865892
# 83 - Downloading and extracting: forjando_maquina_grande_nos_sertoes_do_atlantico__dimensoes_centroafricanas_na_historia_da_exploracao_das_minas_de_ipanema_e_na_instalacao_de_uma_real_fabrica_de_ferro_no_morro_do_aracoiaba_15971810 from https://repositorio.unicamp.br/Busca/Download?codigoArquivo=495702&tipoMidia=0
# Loading triplas: forjando_maquina_grande_nos_sertoes_do_atlantico__dimensoes_centroafricanas_na_historia_da_exploracao_das_minas_de_ipanema_e_na_instalacao_de_uma_real_fabrica_de_ferro_no_morro_do_aracoiaba_15971810
# Total time: 0 days 01:51:42.596530
# Partial time: 0 days 00:02:34.128041
# 84 - Downloading and extracting: nau_etu__criancas_kalapalo_entre_a_aldeia_e_a_cidade from https://repositorio.unicamp.br/Busca/Download?codigoArquivo=592564&tipoMidia=0
# Loading triplas: nau_etu__criancas_kalapalo_entre_a_aldeia_e_a_cidade
# Total time: 0 days 01:53:56.221239
# Partial time: 0 days 00:02:13.624709
# 85 - Downloading and extracting: analise_de_atividades_de_geoturismo_do_proposto_geoparque_do_corumbatai from https://repositorio.unicamp.br/Busca/Download?codigoArquivo=502460&tipoMidia=0
# Loading triplas: analise_de_atividades_de_geoturismo_do_proposto_geoparque_do_corumbatai
# Total time: 0 days 01:55:23.088783
# Partial time: 0 days 00:01:26.867544
# 86 - Downloading and extracting: a_tematica_indigena_na_escola__possibilidades_e_desafios_entre_a_pratica_e_a_teoria from https://repositorio.unicamp.br/Busca/Download?codigoArquivo=591440&tipoMidia=0
# Loading triplas: a_tematica_indigena_na_escola__possibilidades_e_desafios_entre_a_pratica_e_a_teoria
# Total time: 0 days 01:56:25.720644
# Partial time: 0 days 00:01:02.632856
# 87 - Downloading and extracting: comportamento_glicemico_de_adultos_jovens_diante_da_insercao_de_semente_de_chia_em_alimento_de_alto_consumo_no_brasil_tapioca from https://repositorio.unicamp.br/Busca/Download?codigoArquivo=477266&tipoMidia=0
# Loading triplas: comportamento_glicemico_de_adultos_jovens_diante_da_insercao_de_semente_de_chia_em_alimento_de_alto_consumo_no_brasil_tapioca
# Total time: 0 days 01:56:56.540499
# Partial time: 0 days 00:00:30.818860
# 88 - Downloading and extracting: la_nocion_mapuche_de_che_persona__a_nocao_mapuche_de_che_pessoa from https://repositorio.unicamp.br/Busca/Download?codigoArquivo=496727&tipoMidia=0
# Loading triplas: la_nocion_mapuche_de_che_persona__a_nocao_mapuche_de_che_pessoa
# Total time: 0 days 01:58:26.378854
# Partial time: 0 days 00:01:29.838355
# 89 - Downloading and extracting: aplicacoes_de_nanofios_semicondutores_para_a_investigacao_do_efeito_da_nacetilcisteina_na_bacteria_xylella_fastidiosa from https://repositorio.unicamp.br/Busca/Download?codigoArquivo=498916&tipoMidia=0
# Loading triplas: aplicacoes_de_nanofios_semicondutores_para_a_investigacao_do_efeito_da_nacetilcisteina_na_bacteria_xylella_fastidiosa
# Total time: 0 days 01:59:29.032831
# Partial time: 0 days 00:01:02.652977
# 90 - Downloading and extracting: criterios_autoctones_como_subsidios_para_a_revisao_da_escala_de_proficiencia_utilizada_no_contexto_aeronautico from https://repositorio.unicamp.br/Busca/Download?codigoArquivo=493648&tipoMidia=0
# Loading triplas: criterios_autoctones_como_subsidios_para_a_revisao_da_escala_de_proficiencia_utilizada_no_contexto_aeronautico
# Total time: 0 days 02:01:24.844593
# Partial time: 0 days 00:01:55.811762
# 91 - Downloading and extracting: autonomia_zapatista__elementos_de_uma_experiencia_de_educacao_antihegemonica from https://repositorio.unicamp.br/Busca/Download?codigoArquivo=460492&tipoMidia=0
# Loading triplas: autonomia_zapatista__elementos_de_uma_experiencia_de_educacao_antihegemonica
# Total time: 0 days 02:02:57.189381
# Partial time: 0 days 00:01:32.344788
# 92 - Downloading and extracting: por_um_lugar_de_vida__os_kiriri_do_rio_verde_caldasmg from https://repositorio.unicamp.br/Busca/Download?codigoArquivo=495919&tipoMidia=0
# Loading triplas: por_um_lugar_de_vida__os_kiriri_do_rio_verde_caldasmg
# Total time: 0 days 02:03:33.718151
# Partial time: 0 days 00:00:36.529770
# 93 - Downloading and extracting: a_tecnologia_como_vetor_e_bussola_no_processo_de_desenvolvimento_chines from https://repositorio.unicamp.br/Busca/Download?codigoArquivo=490109&tipoMidia=0
# Loading triplas: a_tecnologia_como_vetor_e_bussola_no_processo_de_desenvolvimento_chines
# Total time: 0 days 02:04:29.042846
# Partial time: 0 days 00:00:55.323695
# 94 - Downloading and extracting: por_uma_ciencia_popular_da_vida__educacao_do_campo_agroecologia_e_tradicao_biocultural from https://repositorio.unicamp.br/Busca/Download?codigoArquivo=499694&tipoMidia=0
# Loading triplas: por_uma_ciencia_popular_da_vida__educacao_do_campo_agroecologia_e_tradicao_biocultural
# Total time: 0 days 02:05:25.389608
# Partial time: 0 days 00:00:56.348782
# 95 - Downloading and extracting: aportes_al_tratamiento_de_los_conocimientos_tradicionales_y_el_desarrollo_cientifico_y_tecnologico_en_cuba__contribuicoes_ao_tratamento_do_conhecimento_tradicional_e_desenvolvimento_cientifico_e_tecnologico_em_cuba from https://repositorio.unicamp.br/Busca/Download?codigoArquivo=501737&tipoMidia=0
# Loading triplas: aportes_al_tratamiento_de_los_conocimientos_tradicionales_y_el_desarrollo_cientifico_y_tecnologico_en_cuba__contribuicoes_ao_tratamento_do_conhecimento_tradicional_e_desenvolvimento_cientifico_e_tecnologico_em_cuba
# Total time: 0 days 02:05:55.557101
# Partial time: 0 days 00:00:30.170514
# 96 - Downloading and extracting: origem_e_presente_de_praticas_politicas_das_populacoes_indigenas_do_baixo_oiapoque from https://repositorio.unicamp.br/Busca/Download?codigoArquivo=497317&tipoMidia=0
# Loading triplas: origem_e_presente_de_praticas_politicas_das_populacoes_indigenas_do_baixo_oiapoque
# Total time: 0 days 02:07:09.946578
# Partial time: 0 days 00:01:14.385373
# 97 - Downloading and extracting: a_comissao_parlamentar_de_inquerito_da_funai_e_do_incra_e_direitos_territoriais_indigenas_tradicionais_e_camponeses_em_questao from https://repositorio.unicamp.br/Busca/Download?codigoArquivo=498681&tipoMidia=0
# Loading triplas: a_comissao_parlamentar_de_inquerito_da_funai_e_do_incra_e_direitos_territoriais_indigenas_tradicionais_e_camponeses_em_questao
# Total time: 0 days 02:15:57.482129
# Partial time: 0 days 00:08:47.534614
# 98 - Downloading and extracting: o_sentido_geografico_da_identidade__metafenomenologia_da_alteridade_payaya__the_geographical_sense_of_identity_metaphenomenology_of_the_payayas_alterity from https://repositorio.unicamp.br/Busca/Download?codigoArquivo=502250&tipoMidia=0
# Loading triplas: o_sentido_geografico_da_identidade__metafenomenologia_da_alteridade_payaya__the_geographical_sense_of_identity_metaphenomenology_of_the_payayas_alterity
# Total time: 0 days 02:18:20.668150
# Partial time: 0 days 00:02:23.186021
# 99 - Downloading and extracting: sensorialidades_antropofagicas__saberes_do_sul_na_danca_contemporanea from https://repositorio.unicamp.br/Busca/Download?codigoArquivo=482979&tipoMidia=0
# Loading triplas: sensorialidades_antropofagicas__saberes_do_sul_na_danca_contemporanea
# Total time: 0 days 02:22:54.396195
# Partial time: 0 days 00:04:33.728045
# 100 - Downloading and extracting: de_picadas_lotes_cutioes_e_precisao__sociabilidade_e_modos_de_habitar_no_projeto_de_assentamento_ajarani_rr from https://repositorio.unicamp.br/Busca/Download?codigoArquivo=498182&tipoMidia=0
# Loading triplas: de_picadas_lotes_cutioes_e_precisao__sociabilidade_e_modos_de_habitar_no_projeto_de_assentamento_ajarani_rr
# Total time: 0 days 02:24:10.785232
# Partial time: 0 days 00:01:16.389555
# 101 - Downloading and extracting: fabricacao_e_caracterizacao_de_transistores_hbt_vertical_mosfet_jnt_e_tfet_baseados_em_substratos_iiiv_com_passivacao_por_nitreto_de_silicio from https://repositorio.unicamp.br/Busca/Download?codigoArquivo=466246&tipoMidia=0
# Loading triplas: fabricacao_e_caracterizacao_de_transistores_hbt_vertical_mosfet_jnt_e_tfet_baseados_em_substratos_iiiv_com_passivacao_por_nitreto_de_silicio
# Total time: 0 days 02:25:46.521163
# Partial time: 0 days 00:01:35.735413
# 102 - Downloading and extracting: sobreposicoes_em_areas_protegidas__unidades_de_conservacao_e_terras_indigenas_no_entorno_de_santarempa from https://repositorio.unicamp.br/Busca/Download?codigoArquivo=449167&tipoMidia=0
# Loading triplas: sobreposicoes_em_areas_protegidas__unidades_de_conservacao_e_terras_indigenas_no_entorno_de_santarempa
# Total time: 0 days 02:26:32.623115
# Partial time: 0 days 00:00:46.102465
# 103 - Downloading and extracting: faz_tempo_que_disseram_que_nao_era_mais_para_pegar_menino_nos_matos__narrativas_de_partos_entre_indigenas_tapeba_e_tremembe_no_ceara from https://repositorio.unicamp.br/Busca/Download?codigoArquivo=495549&tipoMidia=0
# Loading triplas: faz_tempo_que_disseram_que_nao_era_mais_para_pegar_menino_nos_matos__narrativas_de_partos_entre_indigenas_tapeba_e_tremembe_no_ceara
# Total time: 0 days 02:30:07.075483
# Partial time: 0 days 00:03:34.460397
# 104 - Downloading and extracting: a_viagem_como_producao_da_diferenca__deslocamento_e_territorialidade_entre_o_povo_wauja_alto_xingu from https://repositorio.unicamp.br/Busca/Download?codigoArquivo=498773&tipoMidia=0
# Loading triplas: a_viagem_como_producao_da_diferenca__deslocamento_e_territorialidade_entre_o_povo_wauja_alto_xingu
# Total time: 0 days 02:32:04.108419
# Partial time: 0 days 00:01:57.027003
# 105 - Downloading and extracting: epistemologias_manchadas__mesticagem_e_sujeitos_politicos_da_descolonizacao_na_bolivia_andina from https://repositorio.unicamp.br/Busca/Download?codigoArquivo=495001&tipoMidia=0
# Loading triplas: epistemologias_manchadas__mesticagem_e_sujeitos_politicos_da_descolonizacao_na_bolivia_andina
# Total time: 0 days 02:33:39.553563
# Partial time: 0 days 00:01:35.442535
# 106 - Downloading and extracting: a_epigrafia_e_os_maya__uma_analise_historiografica_do_processo_de_construcao_da_imagem_de_um_povo_a_partir_de_sua_escrita from https://repositorio.unicamp.br/Busca/Download?codigoArquivo=498077&tipoMidia=0
# Loading triplas: a_epigrafia_e_os_maya__uma_analise_historiografica_do_processo_de_construcao_da_imagem_de_um_povo_a_partir_de_sua_escrita
# Total time: 0 days 02:35:09.510383
# Partial time: 0 days 00:01:29.955744
# 107 - Downloading and extracting: antropometria_dentaria_em_brasileiros_no_processo_de_identificacao_humana____dental_anthropometry_in_brazilians_in_the_process_of_human_identification from https://repositorio.unicamp.br/Busca/Download?codigoArquivo=478628&tipoMidia=0
# Loading triplas: antropometria_dentaria_em_brasileiros_no_processo_de_identificacao_humana____dental_anthropometry_in_brazilians_in_the_process_of_human_identification
# Total time: 0 days 02:35:25.605429
# Partial time: 0 days 00:00:16.097582
# 108 - Downloading and extracting: vea_los_campesinos_aqui_estamos__etnografia_de_la_reaparicion_del_campesinado_como_sujeto_politico_en_los_andes_narinenses_colombianos__olha_so_os_camponeses_aqui_estamos_etnografia_do_reaparecimento_do_campesinato_como_sujeito_politico_nos_andes_narinenses_colombianos from https://repositorio.unicamp.br/Busca/Download?codigoArquivo=497683&tipoMidia=0
# Loading triplas: vea_los_campesinos_aqui_estamos__etnografia_de_la_reaparicion_del_campesinado_como_sujeto_politico_en_los_andes_narinenses_colombianos__olha_so_os_camponeses_aqui_estamos_etnografia_do_reaparecimento_do_campesinato_como_sujeito_politico_nos_andes_narinenses_colombianos
# Total time: 0 days 02:36:39.950523
# Partial time: 0 days 00:01:14.341554
# 109 - Downloading and extracting: educacao_superior_brasileira_no_inicio_do_seculo_xxi__inclusao_interrompida from https://repositorio.unicamp.br/Busca/Download?codigoArquivo=491030&tipoMidia=0
# Loading triplas: educacao_superior_brasileira_no_inicio_do_seculo_xxi__inclusao_interrompida
# Total time: 0 days 02:37:45.506658
# Partial time: 0 days 00:01:05.556135
# 110 - Downloading and extracting: de_terras_indigenas_a_princesa_da_serra_fluminense__o_processo_de_realizacao_da_propriedade_cafeeira_em_valenca_provincia_do_rio_de_janeiro_seculo_xix from https://repositorio.unicamp.br/Busca/Download?codigoArquivo=494572&tipoMidia=0
# Loading triplas: de_terras_indigenas_a_princesa_da_serra_fluminense__o_processo_de_realizacao_da_propriedade_cafeeira_em_valenca_provincia_do_rio_de_janeiro_seculo_xix
# Total time: 0 days 02:38:39.119339
# Partial time: 0 days 00:00:53.612681
# 111 - Downloading and extracting: palhacoa_como_ser_do_contrario_e_provocadora_do_riso__uma_trajetoria_em_formacao__clown_comme_etre_du_contraire_et_provocateur_du_rire__une_trajectoire_en_formation from https://repositorio.unicamp.br/Busca/Download?codigoArquivo=483531&tipoMidia=0
# Loading triplas: palhacoa_como_ser_do_contrario_e_provocadora_do_riso__uma_trajetoria_em_formacao__clown_comme_etre_du_contraire_et_provocateur_du_rire__une_trajectoire_en_formation
# Total time: 0 days 02:39:33.581690
# Partial time: 0 days 00:00:54.462351
# 112 - Downloading and extracting: as_terras_do_grande_espirito__politicas_indigenistas_nos_estados_unidos_do_seculo_xix from https://repositorio.unicamp.br/Busca/Download?codigoArquivo=494591&tipoMidia=0
# Loading triplas: as_terras_do_grande_espirito__politicas_indigenistas_nos_estados_unidos_do_seculo_xix
# Total time: 0 days 02:41:28.702554
# Partial time: 0 days 00:01:55.120864
# 113 - Downloading and extracting: a_construcao_dos_relatos_de_pacificacao_chichimeca__uma_analise_a_partir_da_informacion_de_oficio_de_luis_de_carvajal_1587 from https://repositorio.unicamp.br/Busca/Download?codigoArquivo=497177&tipoMidia=0
# Loading triplas: a_construcao_dos_relatos_de_pacificacao_chichimeca__uma_analise_a_partir_da_informacion_de_oficio_de_luis_de_carvajal_1587
# Total time: 0 days 02:41:54.470618
# Partial time: 0 days 00:00:25.770071
# 114 - Downloading and extracting: impacto_e_eficiencia_da_alimentacao_escolar_na_melhoria_da_seguranca_alimentar_e_nutricional from https://repositorio.unicamp.br/Busca/Download?codigoArquivo=449073&tipoMidia=0
# Loading triplas: impacto_e_eficiencia_da_alimentacao_escolar_na_melhoria_da_seguranca_alimentar_e_nutricional
# Total time: 0 days 02:42:26.315900
# Partial time: 0 days 00:00:31.843275
# 115 - Downloading and extracting: soldagem_branda_de_silicio_com_invar_utilizando_ligas_de_estanho_para_aplicacao_em_instrumentacao_optica from https://repositorio.unicamp.br/Busca/Download?codigoArquivo=472193&tipoMidia=0
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[10], line 15
#      13 for pdf_num in range(len(pdf_link)):
#      14     print(f"{i} - Downloading and extracting: {thesis_uri} from {pdf_link[pdf_num]}")
# ---> 15     download_file(pdf_link[pdf_num], thesis_uri)
#      17     # Extraindo o texto e entidades
#      18     tese_path = 'tese UNICAMP.pdf'
#
# Cell In[9], line 56, in download_file(pdf_link, thesis_uri)
#      53 # raise_for_status() is not needed with stream=True
#      54 # r.raise_for_status()
#      55 with open('tese UNICAMP.pdf', 'wb') as f:
# ---> 56     for chunk in r.iter_content(chunk_size=8192):
#      57         f.write(chunk)
#      58 return
#
# File c:\Users\facordei\OneDrive - Capgemini\Documents\GitHub\Indigenous-Slavery-KG\.venv-IndigSlave\Lib\site-packages\requests\models.py:820, in Response.iter_content.<locals>.generate()
#     818 if hasattr(self.raw, "stream"):
#     819     try:
# --> 820         yield from self.raw.stream(chunk_size, decode_content=True)
#     821     except ProtocolError as e:
#     822         raise ChunkedEncodingError(e)
#
# File c:\Users\facordei\OneDrive - Capgemini\Documents\GitHub\Indigenous-Slavery-KG\.venv-IndigSlave\Lib\site-packages\urllib3\response.py:628, in HTTPResponse.stream(self, amt, decode_content)
#     626 else:
#     627     while not is_fp_closed(self._fp):
# --> 628         data = self.read(amt=amt, decode_content=decode_content)
#     630         if data:
#     631             yield data
#
# File c:\Users\facordei\OneDrive - Capgemini\Documents\GitHub\Indigenous-Slavery-KG\.venv-IndigSlave\Lib\site-packages\urllib3\response.py:567, in HTTPResponse.read(self, amt, decode_content, cache_content)
#     564 fp_closed = getattr(self._fp, "closed", False)
#     566 with self._error_catcher():
# --> 567     data = self._fp_read(amt) if not fp_closed else b""
#     568     if amt is None:
#     569         flush_decoder = True
#
# File c:\Users\facordei\OneDrive - Capgemini\Documents\GitHub\Indigenous-Slavery-KG\.venv-IndigSlave\Lib\site-packages\urllib3\response.py:533, in HTTPResponse._fp_read(self, amt)
#     530     return buffer.getvalue()
#     531 else:
#     532     # StringIO doesn't like amt=None
# --> 533     return self._fp.read(amt) if amt is not None else self._fp.read()
#
# File C:\Program Files\WindowsApps\PythonSoftwareFoundation.Python.3.11_3.11.2544.0_x64__qbz5n2kfra8p0\Lib\http\client.py:473, in HTTPResponse.read(self, amt)
#     470 if self.length is not None and amt > self.length:
#     471     # clip the read to the "end of response"
#     472     amt = self.length
# --> 473 s = self.fp.read(amt)
#     474 if not s and amt:
#     475     # Ideally, we would raise IncompleteRead if the content-length
#     476     # wasn't satisfied, but it might break compatibility.
#     477     self._close_conn()
#
# File C:\Program Files\WindowsApps\PythonSoftwareFoundation.Python.3.11_3.11.2544.0_x64__qbz5n2kfra8p0\Lib\socket.py:706, in SocketIO.readinto(self, b)
#     704 while True:
#     705     try:
# --> 706         return self._sock.recv_into(b)
#     707     except timeout:
#     708         self._timeout_occurred = True
#
# File C:\Program Files\WindowsApps\PythonSoftwareFoundation.Python.3.11_3.11.2544.0_x64__qbz5n2kfra8p0\Lib\ssl.py:1314, in SSLSocket.recv_into(self, buffer, nbytes, flags)
#    1310     if flags != 0:
#    1311         raise ValueError(
#    1312           "non-zero flags not allowed in calls to recv_into() on %s" %
#    1313           self.__class__)
# -> 1314     return self.read(nbytes, buffer)
#    1315 else:
#    1316     return super().recv_into(buffer, nbytes, flags)
#
# File C:\Program Files\WindowsApps\PythonSoftwareFoundation.Python.3.11_3.11.2544.0_x64__qbz5n2kfra8p0\Lib\ssl.py:1166, in SSLSocket.read(self, len, buffer)
#    1164 try:
#    1165     if buffer is not None:
# -> 1166         return self._sslobj.read(len, buffer)
#    1167     else:
#    1168         return self._sslobj.read(len)
#
# KeyboardInterrupt:
