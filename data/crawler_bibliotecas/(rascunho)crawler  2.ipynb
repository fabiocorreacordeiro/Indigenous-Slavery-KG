# %%
#%pip install beautifulsoup4
#%pip install pip-system-certs

# %%
import requests
from bs4 import BeautifulSoup as bs
import pandas as pd
import json
import stardog
import os
import io
from langchain_community.graphs import Neo4jGraph
from PyPDF2 import PdfReader
from langdetect import detect
import spacy
import re
from unidecode import unidecode

# %%
from neo4j import GraphDatabase

# Neo4j variables
NEO4J_URL = os.getenv("NEO4J_URL")
NEO4J_USERNAME =os.getenv("NEO4J_USERNAME")
NEO4J_PASSWORD = os.getenv("NEO4J_PASSWORD")


graph = GraphDatabase.driver(NEO4J_URL, auth=(NEO4J_USERNAME, NEO4J_PASSWORD))

# %% [markdown]
# - Buscar os links para a tese no Neo4j
# - Buscar o link do PDF no repositório da universidade
# - Baixar o PDF
# - Extrair o texto do PDF

# %% [markdown]
# Buscar links para a tese no Neo4j

# %% [markdown]
# Conectando ao Neo4j

# %%
# Neo4j variables
#NEO4J_URL = os.getenv("NEO4J_URL")
#NEO4J_USERNAME =os.getenv("NEO4J_USERNAME")
#NEO4J_PASSWORD = os.getenv("NEO4J_PASSWORD")

#Connecting to the graph
#graph = Neo4jGraph(
#    url=NEO4J_URL,
#    username=NEO4J_USERNAME,
#    password=NEO4J_PASSWORD
#)

# %%
#Cypher query to get all theses from USP
query1 = """
MATCH (t:Thesis)-[:publisher]-(uni:University{uri:'tag:stardog:api:USP'})
Match (e:Exerpt)
RETURN distinct(t["uri"]) as Thesis, t["repository"] as repository 
"""

query2 = """
MATCH (t:Thesis)-[:publisher]-(uni:University{uri:'tag:stardog:api:USP'})
WHERE NOT EXISTS {(:Exerpt)--(t)}
RETURN distinct(t["uri"]) as Thesis, t["repository"] as repository 
"""

graph = GraphDatabase.driver(NEO4J_URL, auth=(NEO4J_USERNAME, NEO4J_PASSWORD))
results = graph.execute_query(query2).records
graph.close()

#results = graph.query(query2)
# Convert the results to a DataFrame
thesis_repository = pd.DataFrame(results, columns=["Thesis", "repository"])
thesis_repository = thesis_repository[200:300].reset_index(drop=True) 
thesis_repository
# Out:
#                                                Thesis  \
# 0   tag:stardog:api:a_floresta_em_rede_a_informaca...
# 1   tag:stardog:api:as_possibilidades_educacionais...
# 2   tag:stardog:api:a_instituicao_do_nome_analise_...
# 3   tag:stardog:api:vigilancia_epidemiologica_da_d...
# 4   tag:stardog:api:circular_e_preciso_a_expansao_...
# ..                                                ...
# 95  tag:stardog:api:fonologia_e_morfossintaxe_da_l...
# 96  tag:stardog:api:os_indios_em_raizes_do_brasil_...
# 97  tag:stardog:api:entre_liberdade_e_cultura_mult...
# 98  tag:stardog:api:estudo_da_biodegradacao_bacter...
# 99  tag:stardog:api:a_economia_zapatista_retratos_...
#
#                                            repository
# 0   https://www.teses.usp.br/teses/disponiveis/27/...
# 1   https://www.teses.usp.br/teses/disponiveis/103...
# 2   https://www.teses.usp.br/teses/disponiveis/8/8...
# 3   https://www.teses.usp.br/teses/disponiveis/6/6...
# 4   https://www.teses.usp.br/teses/disponiveis/8/8...
# ..                                                ...
# 95  https://www.teses.usp.br/teses/disponiveis/8/8...
# 96  http://www.teses.usp.br/teses/disponiveis/8/81...
# 97  https://www.teses.usp.br/teses/disponiveis/2/2...
# 98  http://www.teses.usp.br/teses/disponiveis/97/9...
# 99  http://www.teses.usp.br/teses/disponiveis/8/81...
#
# [100 rows x 2 columns]

# %% [markdown]
# Criando as utils functions

# %%
# Funcao para coletar link do pdf

def get_pdf_link(url):
    
    #Fazer requisição e parsear o arquivo html
    f = requests.get(url, verify=True).text#, verify=False) 
    soup = bs(f, "html.parser")
    
    #Coletando link para as teses
    for doc in soup.find_all('a', href=True):
        if doc['href'].endswith('.pdf'):
            path = doc['href']
            prefix_uni = 'https://www.teses.usp.br'
            link = prefix_uni + path

            return link
    
    return None

#fazer download do arquivo
def download_file(pdf_link, thesis_uri):
    # NOTE the stream=True parameter below
    r = requests.get(pdf_link, verify=True, stream=True)
    # raise_for_status() is not needed with stream=True
    # r.raise_for_status()
    with open('tese2.pdf', 'wb') as f:
        for chunk in r.iter_content(chunk_size=8192):
            f.write(chunk)
    return 

#Carregando os modelos SpaCy para inglês e português 
nlp_en = spacy.load("en_core_web_lg")
nlp_pt = spacy.load("pt_core_news_lg")

# Funcão que recebe uma string e a limpar para ficar no formato aceitável para uma URI
def process_uri(x):
    return (re.sub('[^a-zA-Z0-9_ ]', '',
            unidecode(x.strip())
                        .replace(" ", "_")
                        .replace("[","")
                        .replace("]","")
                        .replace("?","")
                        .replace("'","")
                        .lower()))


# Função para extrair texto de uma tese em PDF e identificar entidades
def extratc_text(tese_path):
    
    # Processando o arquivo em PDF
    reader = PdfReader(tese_path)
    number_of_pages = len(reader.pages)
    excerpt = {}
    

    # Iterando por cada página
    for page_number in range(number_of_pages):
        
        
        # Extraindo o texto da página
        if page_number == 0:
            page_text = (reader.pages[page_number].extract_text() + '\n ' 
                        + reader.pages[page_number+1].extract_text()[:400])
        else:
            
            if page_number == number_of_pages -1:
                page_text = (reader.pages[page_number-1].extract_text()[-400:] + '\n ' 
                            + reader.pages[page_number].extract_text())
            
            else:
                page_text = (reader.pages[page_number-1].extract_text()[-400:] + '\n ' 
                            + reader.pages[page_number].extract_text() + '\n ' 
                            + reader.pages[page_number+1].extract_text()[:400])  
      
        # Detectando o idioma do texto
        try:
            lang = detect(page_text)
            
        except:
            lang = 'Não_detectado'
        
        # Extraindo as entidades
        page_extracted = False
        if lang == 'pt':
            doc = nlp_pt(page_text)
            page_extracted = True
        if lang == 'en':
            doc = nlp_en(page_text)
            page_extracted = True
        
        if page_extracted:

            persons = []
            gpes = []
            #orgs = []
            for ent in doc.ents:
                if ent.label_ == "PER": #"PERSON":
                    persons.append(process_uri(ent.text))
                if ent.label_ == "LOC": #"GPE":
                    gpes.append(process_uri(ent.text))
                #if ent.label_ == "ORG":
                #    orgs.append(process_uri(ent.text))
                    
            excerpt[page_number] = {'text': page_text, 
                                    'lang': lang, 
                                    'persons': list(set(persons)), 
                                    'gpes': list(set(gpes)),
                                #'orgs': list(set(orgs))
                                }

    return excerpt

# %% [markdown]
# Iterando por todas as URI para extrair o texto e gravar no grafo NEO4j

# %%
# Gravar hora de início do processamento
start_time = pd.Timestamp.now()
parcial_time = pd.Timestamp.now()

for i in range(0,len(thesis_repository)):

    # Coletando o link do PDF
    url = thesis_repository['repository'][i]
    thesis_uri = thesis_repository['Thesis'][i][16:]
    pdf_link = get_pdf_link(url)
    if pdf_link is not None:
        print(f"{i} - Downloading and extracting: {thesis_uri} from {pdf_link}")
        # Download do arquivo PDF
        # Verificando se o arquivo já existe e removendo se necessário
        #if os.path.exists('tese.pdf'):
        #   os.remove('tese.pdf')
        download_file(pdf_link, thesis_uri)
        
        # Extraindo o texto e entidades
        tese_path = 'tese2.pdf'
        excerpt = extratc_text(tese_path)
        print(f"Extracted {thesis_uri}")
        
        # Salvando o triplas no grafo Neo4j
        for n in excerpt.keys():
     
            excerpt_uri = thesis_repository['Thesis'][i] + '_p_' + str(n)
            excerpt_text = excerpt[n]['text']
            if "'" in excerpt_text:
                excerpt_text = excerpt_text.replace("'", "")

            excerpt_page = n
            excerpt_lang = excerpt[n]['lang']
            #criando o dicionário para a inserção no grafo
            excerpt_dict = """{
                uri: \'""" + excerpt_uri +"""\',
                text: \'""" + excerpt_text + """\',
                page: \'""" + str(excerpt_page) + """\',
                lang: \'""" + excerpt_lang + """\'
                }"""
            
            #Criando a query para inserir o nó Exerpt

            query = """
            MATCH  (t:Thesis{uri: \'""" + thesis_repository['Thesis'][i] +  """\'})
            MERGE  (e:Exerpt""" + str(excerpt_dict) + """)-[r:BFO_0000050]-(t);

            """
            
            graph = GraphDatabase.driver(NEO4J_URL, auth=(NEO4J_USERNAME, NEO4J_PASSWORD))
            results = graph.execute_query(query)
            graph.close()
            #results = graph.query(query)
                
            #Criando as relações com as entidades
            for person in excerpt[n]['persons']:
                query = """
                MATCH  (e:Exerpt{uri: '""" + excerpt_uri + """'})
                MERGE  (p:Person{uri: \'tag:stardog:api:""" + person + """\'})
                MERGE  (e)-[r:mentions]-(p);

                """
                graph = GraphDatabase.driver(NEO4J_URL, auth=(NEO4J_USERNAME, NEO4J_PASSWORD))
                results = graph.execute_query(query)
                graph.close()
            #results = graph.query(query)

            for gpe in excerpt[n]['gpes']:
                query = """
                MATCH  (e:Exerpt{uri: '""" + excerpt_uri + """'})
                MERGE  (p:Place{uri: \'tag:stardog:api:""" + gpe + """\'})
                MERGE  (e)-[r:mentions]-(p);

                """
                graph = GraphDatabase.driver(NEO4J_URL, auth=(NEO4J_USERNAME, NEO4J_PASSWORD))
                results = graph.execute_query(query)
                graph.close()
                #results = graph.query(query)

        #graph = GraphDatabase.driver(NEO4J_URL, auth=(NEO4J_USERNAME, NEO4J_PASSWORD))
        #results = graph.execute_query("""CALL apoc.cypher.runMany(' """ + query[:-1] + """ ', {})""")  # Remove the last semicolon
        #results = graph.execute_query(query)
        #graph.close()

        print(f"Processed and added to graph: {thesis_uri}")
        #Deletando o arquivo PDF após o processamento
        os.remove('tese2.pdf')
        print(f"Total time: {pd.Timestamp.now() - start_time}")
        print(f"Partial time: {pd.Timestamp.now() - parcial_time}")
        # Atualizando a hora parcial
        parcial_time = pd.Timestamp.now()
    else:
        print(f"No PDF link found for {thesis_uri}")
# Out:
# 0 - Downloading and extracting: a_floresta_em_rede_a_informacao_como_instrumento_de_mediacao_e_resistencia_cultural from https://www.teses.usp.br/teses/disponiveis/27/27151/tde-04052022-115403/publico/WalaceSoaresdeOliveiracorrigida.pdf
# Extracted a_floresta_em_rede_a_informacao_como_instrumento_de_mediacao_e_resistencia_cultural
# Processed and added to graph: a_floresta_em_rede_a_informacao_como_instrumento_de_mediacao_e_resistencia_cultural
# Total time: 0 days 00:02:37.223397
# Partial time: 0 days 00:02:37.223397
# 1 - Downloading and extracting: as_possibilidades_educacionais_dos_acervos_digitais_indigenas_estudo_de_caso_a_partir_de_projetos_glamwiki from https://www.teses.usp.br/teses/disponiveis/103/103131/tde-06022023-171051/publico/LucianaConradoMartinORIGINAL.pdf
# Extracted as_possibilidades_educacionais_dos_acervos_digitais_indigenas_estudo_de_caso_a_partir_de_projetos_glamwiki
# Processed and added to graph: as_possibilidades_educacionais_dos_acervos_digitais_indigenas_estudo_de_caso_a_partir_de_projetos_glamwiki
# Total time: 0 days 00:03:40.120497
# Partial time: 0 days 00:01:02.896117
# 2 - Downloading and extracting: a_instituicao_do_nome_analise_historiografica_da_producao_ficcional_de_graciliano_ramos from https://www.teses.usp.br/teses/disponiveis/8/8149/tde-15062021-115644/publico/2020_EdilsonDiasDeMoura_VOrig.pdf
# Extracted a_instituicao_do_nome_analise_historiografica_da_producao_ficcional_de_graciliano_ramos
# Processed and added to graph: a_instituicao_do_nome_analise_historiografica_da_producao_ficcional_de_graciliano_ramos
# Total time: 0 days 00:13:37.935434
# Partial time: 0 days 00:09:57.814937
# 3 - Downloading and extracting: vigilancia_epidemiologica_da_desnutricao_infantil_na_regiao_norte_brasileira_de_2008_a_2017 from https://www.teses.usp.br/teses/disponiveis/6/6138/tde-29092020-231129/publico/CorreaEM_DR_R.pdf
# Extracted vigilancia_epidemiologica_da_desnutricao_infantil_na_regiao_norte_brasileira_de_2008_a_2017
# Processed and added to graph: vigilancia_epidemiologica_da_desnutricao_infantil_na_regiao_norte_brasileira_de_2008_a_2017
# Total time: 0 days 00:16:12.148282
# Partial time: 0 days 00:02:34.212848
# 4 - Downloading and extracting: circular_e_preciso_a_expansao_capitalista_no_entorno_do_rio_amazonas_do_desencontro_ao_encontro_territorial_no_baixo_amazonas_paraense from https://www.teses.usp.br/teses/disponiveis/8/8136/tde-11112021-192842/publico/2021_GilberValerioCordovil_VCorr.pdf
# Extracted circular_e_preciso_a_expansao_capitalista_no_entorno_do_rio_amazonas_do_desencontro_ao_encontro_territorial_no_baixo_amazonas_paraense
# Processed and added to graph: circular_e_preciso_a_expansao_capitalista_no_entorno_do_rio_amazonas_do_desencontro_ao_encontro_territorial_no_baixo_amazonas_paraense
# Total time: 0 days 00:22:26.959061
# Partial time: 0 days 00:06:14.810779
# 5 - Downloading and extracting: nocoes_de_bem_viver_latinoamericanas_na_perspectiva_da_psicologia_uma_revisao_de_escopo from https://www.teses.usp.br/teses/disponiveis/47/47134/tde-21012021-004617/publico/siqueira_corrigida.pdf
# Extracted nocoes_de_bem_viver_latinoamericanas_na_perspectiva_da_psicologia_uma_revisao_de_escopo
# Processed and added to graph: nocoes_de_bem_viver_latinoamericanas_na_perspectiva_da_psicologia_uma_revisao_de_escopo
# Total time: 0 days 00:25:22.213017
# Partial time: 0 days 00:02:55.253956
# 6 - Downloading and extracting: millennialscale_variability_in_eastern_south_american_climate_and_western_south_atlantic_circulation_during_the_last_70000_years from https://www.teses.usp.br/teses/disponiveis/100/100136/tde-19062020-163854/publico/MariliaCampos_TeseDoutorado_corrigida.pdf
# Extracted millennialscale_variability_in_eastern_south_american_climate_and_western_south_atlantic_circulation_during_the_last_70000_years
# Processed and added to graph: millennialscale_variability_in_eastern_south_american_climate_and_western_south_atlantic_circulation_during_the_last_70000_years
# Total time: 0 days 00:26:27.650766
# Partial time: 0 days 00:01:05.437749
# 7 - Downloading and extracting: boe_joruduwa_boe_ero__a_educacao_bororo_e_o_bakaru from https://www.teses.usp.br/teses/disponiveis/8/8161/tde-23052022-161322/publico/2021_LauroLopesLeandroParikoEkureu_VOrig.pdf
# Extracted boe_joruduwa_boe_ero__a_educacao_bororo_e_o_bakaru
# Processed and added to graph: boe_joruduwa_boe_ero__a_educacao_bororo_e_o_bakaru
# Total time: 0 days 00:30:32.203244
# Partial time: 0 days 00:04:04.552478
# 8 - Downloading and extracting: mediacao_de_conflitos_em_casos_de_discriminacao_reconhecendo_as_diferencas_e_promovendo_os_direitos_das_minorias from https://www.teses.usp.br/teses/disponiveis/2/2140/tde-08052021-002123/publico/10238630_Dissertacao_Corrigida.pdf
# Extracted mediacao_de_conflitos_em_casos_de_discriminacao_reconhecendo_as_diferencas_e_promovendo_os_direitos_das_minorias
# Processed and added to graph: mediacao_de_conflitos_em_casos_de_discriminacao_reconhecendo_as_diferencas_e_promovendo_os_direitos_das_minorias
# Total time: 0 days 00:35:39.079462
# Partial time: 0 days 00:05:06.876218
# 9 - Downloading and extracting: musica_educacion_y_descolonizacion_el_modelo_educativo_sociocomunitario_productivo_del_estado_plurinacional_de_bolivia_en_el_contexto_de_las_culturas_populares_de_america_latina_y_el_caribe from https://www.teses.usp.br/teses/disponiveis/84/84131/tde-04082021-192439/publico/2021_FelixCenevivaEid_VCorr.pdf
# Extracted musica_educacion_y_descolonizacion_el_modelo_educativo_sociocomunitario_productivo_del_estado_plurinacional_de_bolivia_en_el_contexto_de_las_culturas_populares_de_america_latina_y_el_caribe
# Processed and added to graph: musica_educacion_y_descolonizacion_el_modelo_educativo_sociocomunitario_productivo_del_estado_plurinacional_de_bolivia_en_el_contexto_de_las_culturas_populares_de_america_latina_y_el_caribe
# Total time: 0 days 00:36:39.476624
# Partial time: 0 days 00:01:00.397162
# 10 - Downloading and extracting: encontros_zoe_nas_guianas from https://www.teses.usp.br/teses/disponiveis/8/8134/tde-08012021-235604/publico/2020_FabioAugustoNogueiraRibeiro_VCorr.pdf
# Extracted encontros_zoe_nas_guianas
# Processed and added to graph: encontros_zoe_nas_guianas
# Total time: 0 days 00:50:30.608700
# Partial time: 0 days 00:13:51.133094
# 11 - Downloading and extracting: o_som_que_da_no_pife_trajetoria_e_resistencia_da_banda_cabacal_dos_irmaos_aniceto from https://www.teses.usp.br/teses/disponiveis/27/27157/tde-28092023-154306/publico/MuriloGasparMendesCorrigida.pdf
# Extracted o_som_que_da_no_pife_trajetoria_e_resistencia_da_banda_cabacal_dos_irmaos_aniceto
# Processed and added to graph: o_som_que_da_no_pife_trajetoria_e_resistencia_da_banda_cabacal_dos_irmaos_aniceto
# Total time: 0 days 00:56:18.527307
# Partial time: 0 days 00:05:47.917589
# 12 - Downloading and extracting: territorialidades_em_tensao_processos_e_disputas_por_territorializacao_na_amazonia from https://www.teses.usp.br/teses/disponiveis/8/8136/tde-24082021-212031/publico/2021_EneiasBarbosaGuedes_VCorr.pdf
# Extracted territorialidades_em_tensao_processos_e_disputas_por_territorializacao_na_amazonia
# Processed and added to graph: territorialidades_em_tensao_processos_e_disputas_por_territorializacao_na_amazonia
# Total time: 0 days 01:05:46.372673
# Partial time: 0 days 00:09:27.845366
# 13 - Downloading and extracting: revisao_taxonomica_de_synodus_scopoli_1777_synodontidae_aulopiformes_teleostei_do_atlantico_sul_ocidental from https://www.teses.usp.br/teses/disponiveis/21/21134/tde-30112021-152908/publico/Dissertacao_Fernandes_Nathalie_Original.pdf
# Extracted revisao_taxonomica_de_synodus_scopoli_1777_synodontidae_aulopiformes_teleostei_do_atlantico_sul_ocidental
# Processed and added to graph: revisao_taxonomica_de_synodus_scopoli_1777_synodontidae_aulopiformes_teleostei_do_atlantico_sul_ocidental
# Total time: 0 days 01:08:46.204189
# Partial time: 0 days 00:02:59.831516
# 14 - Downloading and extracting: analise_de_redes_aplicada_a_fatores_relacionados_a_saude_bucal_de_populacoes_indigenas from https://www.teses.usp.br/teses/disponiveis/23/23158/tde-10112021-124506/publico/GustavoHermesSoaresVersaoOriginal.pdf
# Extracted analise_de_redes_aplicada_a_fatores_relacionados_a_saude_bucal_de_populacoes_indigenas
# Processed and added to graph: analise_de_redes_aplicada_a_fatores_relacionados_a_saude_bucal_de_populacoes_indigenas
# Total time: 0 days 01:11:27.662174
# Partial time: 0 days 00:02:41.457985
# 15 - Downloading and extracting: complexos_de_galioiii_e_indioiii_com_ligantes_hidrazonas_derivados_da_isoniazida_investigacao_estrutural_ensaios_de_interacao_com_biomoleculas_e_avaliacao_das_atividades_anticancer_e_antimycobacterium_tuberculosis from https://www.teses.usp.br/teses/disponiveis/75/75135/tde-24012022-095506/publico/RenanCamurcaFernandesLeitaorevisada.pdf
# Extracted complexos_de_galioiii_e_indioiii_com_ligantes_hidrazonas_derivados_da_isoniazida_investigacao_estrutural_ensaios_de_interacao_com_biomoleculas_e_avaliacao_das_atividades_anticancer_e_antimycobacterium_tuberculosis
# Processed and added to graph: complexos_de_galioiii_e_indioiii_com_ligantes_hidrazonas_derivados_da_isoniazida_investigacao_estrutural_ensaios_de_interacao_com_biomoleculas_e_avaliacao_das_atividades_anticancer_e_antimycobacterium_tuberculosis
# Total time: 0 days 01:14:44.150907
# Partial time: 0 days 00:03:16.489680
# 16 - Downloading and extracting: environmental_management_strategies_for_pest_control_in_strawberry_crop from https://www.teses.usp.br/teses/disponiveis/11/11146/tde-13122021-174103/publico/Fernanda_de_Cassia_Neves_Esteca.pdf
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[13], line 17
#      12 print(f"{i} - Downloading and extracting: {thesis_uri} from {pdf_link}")
#      13 # Download do arquivo PDF
#      14 # Verificando se o arquivo já existe e removendo se necessário
#      15 #if os.path.exists('tese.pdf'):
#      16 #   os.remove('tese.pdf')
# ---> 17 download_file(pdf_link, thesis_uri)
#      19 # Extraindo o texto e entidades
#      20 tese_path = 'tese2.pdf'
#
# Cell In[12], line 23, in download_file(pdf_link, thesis_uri)
#      21 def download_file(pdf_link, thesis_uri):
#      22     # NOTE the stream=True parameter below
# ---> 23     r = requests.get(pdf_link, verify=True, stream=True)
#      24     # raise_for_status() is not needed with stream=True
#      25     # r.raise_for_status()
#      26     with open('tese2.pdf', 'wb') as f:
#
# File c:\Users\facordei\OneDrive - Capgemini\Documents\GitHub\Indigenous-Slavery-KG\.venv-IndigSlave\Lib\site-packages\requests\api.py:73, in get(url, params, **kwargs)
#      62 def get(url, params=None, **kwargs):
#      63     r"""Sends a GET request.
#      64
#      65     :param url: URL for the new :class:`Request` object.
#    (...)
#      70     :rtype: requests.Response
#      71     """
# ---> 73     return request("get", url, params=params, **kwargs)
#
# File c:\Users\facordei\OneDrive - Capgemini\Documents\GitHub\Indigenous-Slavery-KG\.venv-IndigSlave\Lib\site-packages\requests\api.py:59, in request(method, url, **kwargs)
#      55 # By using the 'with' statement we are sure the session is closed, thus we
#      56 # avoid leaving sockets open which can trigger a ResourceWarning in some
#      57 # cases, and look like a memory leak in others.
#      58 with sessions.Session() as session:
# ---> 59     return session.request(method=method, url=url, **kwargs)
#
# File c:\Users\facordei\OneDrive - Capgemini\Documents\GitHub\Indigenous-Slavery-KG\.venv-IndigSlave\Lib\site-packages\requests\sessions.py:589, in Session.request(self, method, url, params, data, headers, cookies, files, auth, timeout, allow_redirects, proxies, hooks, stream, verify, cert, json)
#     584 send_kwargs = {
#     585     "timeout": timeout,
#     586     "allow_redirects": allow_redirects,
#     587 }
#     588 send_kwargs.update(settings)
# --> 589 resp = self.send(prep, **send_kwargs)
#     591 return resp
#
# File c:\Users\facordei\OneDrive - Capgemini\Documents\GitHub\Indigenous-Slavery-KG\.venv-IndigSlave\Lib\site-packages\requests\sessions.py:703, in Session.send(self, request, **kwargs)
#     700 start = preferred_clock()
#     702 # Send the request
# --> 703 r = adapter.send(request, **kwargs)
#     705 # Total elapsed time of the request (approximately)
#     706 elapsed = preferred_clock() - start
#
# File c:\Users\facordei\OneDrive - Capgemini\Documents\GitHub\Indigenous-Slavery-KG\.venv-IndigSlave\Lib\site-packages\requests\adapters.py:667, in HTTPAdapter.send(self, request, stream, timeout, verify, cert, proxies)
#     664     timeout = TimeoutSauce(connect=timeout, read=timeout)
#     666 try:
# --> 667     resp = conn.urlopen(
#     668         method=request.method,
#     669         url=url,
#     670         body=request.body,
#     671         headers=request.headers,
#     672         redirect=False,
#     673         assert_same_host=False,
#     674         preload_content=False,
#     675         decode_content=False,
#     676         retries=self.max_retries,
#     677         timeout=timeout,
#     678         chunked=chunked,
#     679     )
#     681 except (ProtocolError, OSError) as err:
#     682     raise ConnectionError(err, request=request)
#
# File c:\Users\facordei\OneDrive - Capgemini\Documents\GitHub\Indigenous-Slavery-KG\.venv-IndigSlave\Lib\site-packages\urllib3\connectionpool.py:716, in HTTPConnectionPool.urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, **response_kw)
#     713     self._prepare_proxy(conn)
#     715 # Make the request on the httplib connection object.
# --> 716 httplib_response = self._make_request(
#     717     conn,
#     718     method,
#     719     url,
#     720     timeout=timeout_obj,
#     721     body=body,
#     722     headers=headers,
#     723     chunked=chunked,
#     724 )
#     726 # If we're going to release the connection in ``finally:``, then
#     727 # the response doesn't need to know about the connection. Otherwise
#     728 # it will also try to release it and we'll have a double-release
#     729 # mess.
#     730 response_conn = conn if not release_conn else None
#
# File c:\Users\facordei\OneDrive - Capgemini\Documents\GitHub\Indigenous-Slavery-KG\.venv-IndigSlave\Lib\site-packages\urllib3\connectionpool.py:468, in HTTPConnectionPool._make_request(self, conn, method, url, timeout, chunked, **httplib_request_kw)
#     463             httplib_response = conn.getresponse()
#     464         except BaseException as e:
#     465             # Remove the TypeError from the exception chain in
#     466             # Python 3 (including for exceptions like SystemExit).
#     467             # Otherwise it looks like a bug in the code.
# --> 468             six.raise_from(e, None)
#     469 except (SocketTimeout, BaseSSLError, SocketError) as e:
#     470     self._raise_timeout(err=e, url=url, timeout_value=read_timeout)
#
# File <string>:3, in raise_from(value, from_value)
#
# File c:\Users\facordei\OneDrive - Capgemini\Documents\GitHub\Indigenous-Slavery-KG\.venv-IndigSlave\Lib\site-packages\urllib3\connectionpool.py:463, in HTTPConnectionPool._make_request(self, conn, method, url, timeout, chunked, **httplib_request_kw)
#     460 except TypeError:
#     461     # Python 3
#     462     try:
# --> 463         httplib_response = conn.getresponse()
#     464     except BaseException as e:
#     465         # Remove the TypeError from the exception chain in
#     466         # Python 3 (including for exceptions like SystemExit).
#     467         # Otherwise it looks like a bug in the code.
#     468         six.raise_from(e, None)
#
# File C:\Program Files\WindowsApps\PythonSoftwareFoundation.Python.3.11_3.11.2544.0_x64__qbz5n2kfra8p0\Lib\http\client.py:1395, in HTTPConnection.getresponse(self)
#    1393 try:
#    1394     try:
# -> 1395         response.begin()
#    1396     except ConnectionError:
#    1397         self.close()
#
# File C:\Program Files\WindowsApps\PythonSoftwareFoundation.Python.3.11_3.11.2544.0_x64__qbz5n2kfra8p0\Lib\http\client.py:325, in HTTPResponse.begin(self)
#     323 # read until we get a non-100 response
#     324 while True:
# --> 325     version, status, reason = self._read_status()
#     326     if status != CONTINUE:
#     327         break
#
# File C:\Program Files\WindowsApps\PythonSoftwareFoundation.Python.3.11_3.11.2544.0_x64__qbz5n2kfra8p0\Lib\http\client.py:286, in HTTPResponse._read_status(self)
#     285 def _read_status(self):
# --> 286     line = str(self.fp.readline(_MAXLINE + 1), "iso-8859-1")
#     287     if len(line) > _MAXLINE:
#     288         raise LineTooLong("status line")
#
# File C:\Program Files\WindowsApps\PythonSoftwareFoundation.Python.3.11_3.11.2544.0_x64__qbz5n2kfra8p0\Lib\socket.py:706, in SocketIO.readinto(self, b)
#     704 while True:
#     705     try:
# --> 706         return self._sock.recv_into(b)
#     707     except timeout:
#     708         self._timeout_occurred = True
#
# File C:\Program Files\WindowsApps\PythonSoftwareFoundation.Python.3.11_3.11.2544.0_x64__qbz5n2kfra8p0\Lib\ssl.py:1314, in SSLSocket.recv_into(self, buffer, nbytes, flags)
#    1310     if flags != 0:
#    1311         raise ValueError(
#    1312           "non-zero flags not allowed in calls to recv_into() on %s" %
#    1313           self.__class__)
# -> 1314     return self.read(nbytes, buffer)
#    1315 else:
#    1316     return super().recv_into(buffer, nbytes, flags)
#
# File C:\Program Files\WindowsApps\PythonSoftwareFoundation.Python.3.11_3.11.2544.0_x64__qbz5n2kfra8p0\Lib\ssl.py:1166, in SSLSocket.read(self, len, buffer)
#    1164 try:
#    1165     if buffer is not None:
# -> 1166         return self._sslobj.read(len, buffer)
#    1167     else:
#    1168         return self._sslobj.read(len)
#
# KeyboardInterrupt:

# %%
### Ajustar o codigo cypher para inserir todas as triplas de uma vez só vez

# %%
print(query)
# Out:
#
#             MATCH  (t:Thesis{uri: 'tag:stardog:api:analise_da_ancestralidades_genetica_da_populacao_de_sao_paulo'})
#             MERGE  (e:Exerpt{
#                 uri: 'tag:stardog:api:analise_da_ancestralidades_genetica_da_populacao_de_sao_paulo_p_0',
#                 text: 'UNIVERSIDADE DE SÃO PAULO
# INSTITUTO DE BIOCIÊNCIAS
# PROGRAMA INTERUNIDADES DE PÓS -GRADUAÇÃO EM BIOINFORMÁTICA
# RAP
# HAEL BRUNO AMEMIYA
# A
# nálise da ancestralidade genética da população de São Paulo
# S
# ão Paulo
# 2024
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#  ',
#                 page: '0',
#                 lang: 'pt'
#                 })-[r:BFO_0000050]-(t);
#
#
#                 MATCH  (e:Exerpt{uri: 'tag:stardog:api:analise_da_ancestralidades_genetica_da_populacao_de_sao_paulo_p_0'})
#                 MERGE  (p:Person{uri: 'tag:stardog:api:hael'})
#                 MERGE  (e)-[r:mentions]-(p);
#
#                 MATCH  (e:Exerpt{uri: 'tag:stardog:api:analise_da_ancestralidades_genetica_da_populacao_de_sao_paulo_p_0'})
#                 MERGE  (p:Place{uri: 'tag:stardog:api:instituto_de_biociencias'})
#                 MERGE  (e)-[r:mentions]-(p);
#
#                 MATCH  (e:Exerpt{uri: 'tag:stardog:api:analise_da_ancestralidades_genetica_da_populacao_de_sao_paulo_p_0'})
#                 MERGE  (p:Place{uri: 'tag:stardog:api:universidade_de_sao_paulo'})
#                 MERGE  (e)-[r:mentions]-(p);
#
#                 MATCH  (e:Exerpt{uri: 'tag:stardog:api:analise_da_ancestralidades_genetica_da_populacao_de_sao_paulo_p_0'})
#                 MERGE  (p:Place{uri: 'tag:stardog:api:de_sao_paulo'})
#                 MERGE  (e)-[r:mentions]-(p);
#
#             MATCH  (t:Thesis{uri: 'tag:stardog:api:analise_da_ancestralidades_genetica_da_populacao_de_sao_paulo'})
#             MERGE  (e:Exerpt{
#                 uri: 'tag:stardog:api:analise_da_ancestralidades_genetica_da_populacao_de_sao_paulo_p_1',
#                 text: 'UNIVERSIDADE DE SÃO PAULO
# INSTITUTO DE BIOCIÊNCIAS
# PROGRAMA INTERUNIDADES DE PÓS -GRADUAÇÃO EM BIOINFORMÁTICA
# RAP
# HAEL BRUNO AMEMIYA
# A
# nálise da ancestralidade genética da população de São Paulo
# S
# ão Paulo
# 2024
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#  Raphael Bruno Amemiya
#
#
#
#
#
# Análise d a ancestralidade genética da população de São Paulo
#
#
#
# Versão Corrigida
#
#
#
# Dissertação de Mestrado apresentada ao Programa
# Interunidades  de Pós -Graduação em Bionformática da
# Universidade de São Paulo para obtenção do título de
# Mestre em Ciências.
#
# Área de Concentração: Bioinformática
# Orientador: Prof. Dr. Sergio Russo Matioli
#
#
# ',
#                 page: '1',
#                 lang: 'pt'
#                 })-[r:BFO_0000050]-(t);
#
#
#                 MATCH  (e:Exerpt{uri: 'tag:stardog:api:analise_da_ancestralidades_genetica_da_populacao_de_sao_paulo_p_1'})
#                 MERGE  (p:Person{uri: 'tag:stardog:api:hael'})
#                 MERGE  (e)-[r:mentions]-(p);
#
#                 MATCH  (e:Exerpt{uri: 'tag:stardog:api:analise_da_ancestralidades_genetica_da_populacao_de_sao_paulo_p_1'})
#                 MERGE  (p:Person{uri: 'tag:stardog:api:dr_sergio_russo_matioli'})
#                 MERGE  (e)-[r:mentions]-(p);
#
#                 MATCH  (e:Exerpt{uri: 'tag:stardog:api:analise_da_ancestralidades_genetica_da_populacao_de_sao_paulo_p_1'})
#                 MERGE  (p:Person{uri: 'tag:stardog:api:raphael_bruno_amemiya________analise_d'})
#                 MERGE  (e)-[r:mentions]-(p);
#
#                 MATCH  (e:Exerpt{uri: 'tag:stardog:api:analise_da_ancestralidades_genetica_da_populacao_de_sao_paulo_p_1'})
#                 MERGE  (p:Place{uri: 'tag:stardog:api:instituto_de_biociencias'})
#                 MERGE  (e)-[r:mentions]-(p);
#
#                 MATCH  (e:Exerpt{uri: 'tag:stardog:api:analise_da_ancestralidades_genetica_da_populacao_de_sao_paulo_p_1'})
#                 MERGE  (p:Place{uri: 'tag:stardog:api:universidade_de_sao_paulo'})
#                 MERGE  (e)-[r:mentions]-(p);
#
#                 MATCH  (e:Exerpt{uri: 'tag:stardog:api:analise_da_ancestralidades_genetica_da_populacao_de_sao_paulo_p_1'})
#                 MERGE  (p:Place{uri: 'tag:stardog:api:area_de_concentracao'})
#                 MERGE  (e)-[r:mentions]-(p);
#
#                 MATCH  (e:Exerpt{uri: 'tag:stardog:api:analise_da_ancestralidades_genetica_da_populacao_de_sao_paulo_p_1'})
#                 MERGE  (p:Place{uri: 'tag:stardog:api:bionformatica_da_universidade_de_sao_paulo'})
#                 MERGE  (e)-[r:mentions]-(p);
#
#                 MATCH  (e:Exerpt{uri: 'tag:stardog:api:analise_da_ancestralidades_genetica_da_populacao_de_sao_paulo_p_1'})
#                 MERGE  (p:Place{uri: 'tag:stardog:api:de_sao_paulo'})
#                 MERGE  (e)-[r:mentions]-(p);
#
#             MATCH  (t:Thesis{uri: 'tag:stardog:api:analise_da_ancestralidades_genetica_da_populacao_de_sao_paulo'})
#             MERGE  (e:Exerpt{
#                 uri: 'tag:stardog:api:analise_da_ancestralidades_genetica_da_populacao_de_sao_paulo_p_2',
#                 text: '
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#  Raphael Bruno Amemiya
#
#
#
#
#
# Análise d a ancestralidade genética da população de São Paulo
#
#
#
# Versão Corrigida
#
#
#
# Dissertação de Mestrado apresentada ao Programa
# Interunidades  de Pós -Graduação em Bionformática da
# Universidade de São Paulo para obtenção do título de
# Mestre em Ciências.
#
# Área de Concentração: Bioinformática
# Orientador: Prof. Dr. Sergio Russo Matioli
#
#
#
#
#
#
#
#
#
#
#
#
# São Paulo
# 2024
#  Autorizo a reprodução e divulgação total ou parcial deste trabalho, por qualquer meio
# convencional ou eletronico, para fins de estudo e pesquisa, desde que citada a fonte.
# Ficha Catalográfica elaborada eletronicamente pelo autor, utilizando o
# programa desenvolvido pela Seção Técnica de Informática do ICMC/USP e
# adaptado para a Divisão de Biblioteca e Documentação do Conjunto das Químicas da USP
# A4',
#                 page: '2',
#                 lang: 'pt'
#                 })-[r:BFO_0000050]-(t);
#
#
#                 MATCH  (e:Exerpt{uri: 'tag:stardog:api:analise_da_ancestralidades_genetica_da_populacao_de_sao_paulo_p_2'})
#                 MERGE  (p:Person{uri: 'tag:stardog:api:dr_sergio_russo_matioli'})
#                 MERGE  (e)-[r:mentions]-(p);
#
#                 MATCH  (e:Exerpt{uri: 'tag:stardog:api:analise_da_ancestralidades_genetica_da_populacao_de_sao_paulo_p_2'})
#                 MERGE  (p:Person{uri: 'tag:stardog:api:raphael_bruno_amemiya________analise_d'})
#                 MERGE  (e)-[r:mentions]-(p);
#
#                 MATCH  (e:Exerpt{uri: 'tag:stardog:api:analise_da_ancestralidades_genetica_da_populacao_de_sao_paulo_p_2'})
#                 MERGE  (p:Place{uri: 'tag:stardog:api:area_de_concentracao'})
#                 MERGE  (e)-[r:mentions]-(p);
#
#                 MATCH  (e:Exerpt{uri: 'tag:stardog:api:analise_da_ancestralidades_genetica_da_populacao_de_sao_paulo_p_2'})
#                 MERGE  (p:Place{uri: 'tag:stardog:api:bionformatica_da_universidade_de_sao_paulo'})
#                 MERGE  (e)-[r:mentions]-(p);
#
#                 MATCH  (e:Exerpt{uri: 'tag:stardog:api:analise_da_ancestralidades_genetica_da_populacao_de_sao_paulo_p_2'})
#                 MERGE  (p:Place{uri: 'tag:stardog:api:de_sao_paulo'})
#                 MERGE  (e)-[r:mentions]-(p);
#
#                 MATCH  (e:Exerpt{uri: 'tag:stardog:api:analise_da_ancestralidades_genetica_da_populacao_de_sao_paulo_p_2'})
#                 MERGE  (p:Place{uri: 'tag:stardog:api:usp'})
#                 MERGE  (e)-[r:mentions]-(p);
#
#                 MATCH  (e:Exerpt{uri: 'tag:stardog:api:analise_da_ancestralidades_genetica_da_populacao_de_sao_paulo_p_2'})
#                 MERGE  (p:Place{uri: 'tag:stardog:api:sao_paulo'})
#                 MERGE  (e)-[r:mentions]-(p);
#
#             MATCH  (t:Thesis{uri: 'tag:stardog:api:analise_da_ancestralidades_genetica_da_populacao_de_sao_paulo'})
#             MERGE  (e:Exerpt{
#                 uri: 'tag:stardog:api:analise_da_ancestralidades_genetica_da_populacao_de_sao_paulo_p_3',
#                 text: 'ise d a ancestralidade genética da população de São Paulo
#
#
#
# Versão Corrigida
#
#
#
# Dissertação de Mestrado apresentada ao Programa
# Interunidades  de Pós -Graduação em Bionformática da
# Universidade de São Paulo para obtenção do título de
# Mestre em Ciências.
#
# Área de Concentração: Bioinformática
# Orientador: Prof. Dr. Sergio Russo Matioli
#
#
#
#
#
#
#
#
#
#
#
#
# São Paulo
# 2024
#  Autorizo a reprodução e divulgação total ou parcial deste trabalho, por qualquer meio
# convencional ou eletronico, para fins de estudo e pesquisa, desde que citada a fonte.
# Ficha Catalográfica elaborada eletronicamente pelo autor, utilizando o
# programa desenvolvido pela Seção Técnica de Informática do ICMC/USP e
# adaptado para a Divisão de Biblioteca e Documentação do Conjunto das Químicas da USP
# A498aAmemiya, Raphael Bruno
#    Análise da ancestralidade genética da população
# de São Paulo / Raphael Bruno Amemiya. - São Paulo,
# 2024.
#    83 p.
# Dissertação (mestrado) - Programa Interunidades de
# Pós-Graduação em Bioinformática - USP, .
#    Orientador: Matioli, Sergio Russo
# 1. Ancestralidade. 2. Genética. 3.
# Bioinformática. 4. Aprendizado de máquina. 5.
# Ciência de dados. I. T. II. Matioli, Sergio Russo,
# orientador.
#  Nome: AMEMIYA, Raphael Bruno
# Título: Análise da ancestralidade genética da população de São Paulo
# Dissertação de Mestrado apresentada ao Programa Interunidades de Pós -Graduação
# em Bionformática da Universidade de São Paulo para obtenção do título de Mestre em
# Ciências .
#
# Aprovado em:  11 de junho de 2024
#  Banca Examinadora
# Profa. Dra. Julia Maria Pavan Soler
# Instituição  IME - USP ',
#                 page: '3',
#                 lang: 'pt'
#                 })-[r:BFO_0000050]-(t);
#
#
#                 MATCH  (e:Exerpt{uri: 'tag:stardog:api:analise_da_ancestralidades_genetica_da_populacao_de_sao_paulo_p_3'})
#                 MERGE  (p:Person{uri: 'tag:stardog:api:julia_maria_pavan_soler'})
#                 MERGE  (e)-[r:mentions]-(p);
#
#                 MATCH  (e:Exerpt{uri: 'tag:stardog:api:analise_da_ancestralidades_genetica_da_populacao_de_sao_paulo_p_3'})
#                 MERGE  (p:Person{uri: 'tag:stardog:api:dra'})
#                 MERGE  (e)-[r:mentions]-(p);
#
#                 MATCH  (e:Exerpt{uri: 'tag:stardog:api:analise_da_ancestralidades_genetica_da_populacao_de_sao_paulo_p_3'})
#                 MERGE  (p:Person{uri: 'tag:stardog:api:dr_sergio_russo_matioli'})
#                 MERGE  (e)-[r:mentions]-(p);
#
#                 MATCH  (e:Exerpt{uri: 'tag:stardog:api:analise_da_ancestralidades_genetica_da_populacao_de_sao_paulo_p_3'})
#                 MERGE  (p:Person{uri: 'tag:stardog:api:raphael_bruno_amemiya'})
#                 MERGE  (e)-[r:mentions]-(p);
#
#                 MATCH  (e:Exerpt{uri: 'tag:stardog:api:analise_da_ancestralidades_genetica_da_populacao_de_sao_paulo_p_3'})
#                 MERGE  (p:Person{uri: 'tag:stardog:api:sergio_russo'})
#                 MERGE  (e)-[r:mentions]-(p);
#
#                 MATCH  (e:Exerpt{uri: 'tag:stardog:api:analise_da_ancestralidades_genetica_da_populacao_de_sao_paulo_p_3'})
#                 MERGE  (p:Person{uri: 'tag:stardog:api:i_t_ii'})
#                 MERGE  (e)-[r:mentions]-(p);
#
#                 MATCH  (e:Exerpt{uri: 'tag:stardog:api:analise_da_ancestralidades_genetica_da_populacao_de_sao_paulo_p_3'})
#                 MERGE  (p:Person{uri: 'tag:stardog:api:amemiya'})
#                 MERGE  (e)-[r:mentions]-(p);
#
#                 MATCH  (e:Exerpt{uri: 'tag:stardog:api:analise_da_ancestralidades_genetica_da_populacao_de_sao_paulo_p_3'})
#                 MERGE  (p:Person{uri: 'tag:stardog:api:raphael_bruno'})
#                 MERGE  (e)-[r:mentions]-(p);
#
#                 MATCH  (e:Exerpt{uri: 'tag:stardog:api:analise_da_ancestralidades_genetica_da_populacao_de_sao_paulo_p_3'})
#                 MERGE  (p:Person{uri: 'tag:stardog:api:matioli'})
#                 MERGE  (e)-[r:mentions]-(p);
#
#                 MATCH  (e:Exerpt{uri: 'tag:stardog:api:analise_da_ancestralidades_genetica_da_populacao_de_sao_paulo_p_3'})
#                 MERGE  (p:Place{uri: 'tag:stardog:api:ime'})
#                 MERGE  (e)-[r:mentions]-(p);
#
#                 MATCH  (e:Exerpt{uri: 'tag:stardog:api:analise_da_ancestralidades_genetica_da_populacao_de_sao_paulo_p_3'})
#                 MERGE  (p:Place{uri: 'tag:stardog:api:area_de_concentracao'})
#                 MERGE  (e)-[r:mentions]-(p);
#
#                 MATCH  (e:Exerpt{uri: 'tag:stardog:api:analise_da_ancestralidades_genetica_da_populacao_de_sao_paulo_p_3'})
#                 MERGE  (p:Place{uri: 'tag:stardog:api:bionformatica_da_universidade_de_sao_paulo'})
#                 MERGE  (e)-[r:mentions]-(p);
#
#                 MATCH  (e:Exerpt{uri: 'tag:stardog:api:analise_da_ancestralidades_genetica_da_populacao_de_sao_paulo_p_3'})
#                 MERGE  (p:Place{uri: 'tag:stardog:api:de_sao_paulo'})
#                 MERGE  (e)-[r:mentions]-(p);
#
#                 MATCH  (e:Exerpt{uri: 'tag:stardog:api:analise_da_ancestralidades_genetica_da_populacao_de_sao_paulo_p_3'})
#                 MERGE  (p:Place{uri: 'tag:stardog:api:usp'})
#                 MERGE  (e)-[r:mentions]-(p);
#
#                 MATCH  (e:Exerpt{uri: 'tag:stardog:api:analise_da_ancestralidades_genetica_da_populacao_de_sao_paulo_p_3'})
#                 MERGE  (p:Place{uri: 'tag:stardog:api:sao_paulo'})
#                 MERGE  (e)-[r:mentions]-(p);
#
#             MATCH  (t:Thesis{uri: 'tag:stardog:api:analise_da_ancestralidades_genetica_da_populacao_de_sao_paulo'})
#             MERGE  (e:Exerpt{
#                 uri: 'tag:stardog:api:analise_da_ancestralidades_genetica_da_populacao_de_sao_paulo_p_4',
#                 text: 'hael Bruno
#    Análise da ancestralidade genética da população
# de São Paulo / Raphael Bruno Amemiya. - São Paulo,
# 2024.
#    83 p.
# Dissertação (mestrado) - Programa Interunidades de
# Pós-Graduação em Bioinformática - USP, .
#    Orientador: Matioli, Sergio Russo
# 1. Ancestralidade. 2. Genética. 3.
# Bioinformática. 4. Aprendizado de máquina. 5.
# Ciência de dados. I. T. II. Matioli, Sergio Russo,
# orientador.
#  Nome: AMEMIYA, Raphael Bruno
# Título: Análise da ancestralidade genética da população de São Paulo
# Dissertação de Mestrado apresentada ao Programa Interunidades de Pós -Graduação
# em Bionformática da Universidade de São Paulo para obtenção do título de Mestre em
# Ciências .
#
# Aprovado em:  11 de junho de 2024
#  Banca Examinadora
# Profa. Dra. Julia Maria Pavan Soler
# Instituição  IME - USP
# Julgamento  A
#
# Profa. Dra. Regina Celia Mingroni Netto
# Instituição  IB - USP
# Julgamento  A
#
# Profa. Dra. Síntia Iole Nogueira Belangero
# Instituição  UNIFESP(FM)
# Julgamento  A
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#  ',
#                 page: '4',
#                 lang: 'pt'
#                 })-[r:BFO_0000050]-(t);
#
#
#                 MATCH  (e:Exerpt{uri: 'tag:stardog:api:analise_da_ancestralidades_genetica_da_populacao_de_sao_paulo_p_4'})
#                 MERGE  (p:Person{uri: 'tag:stardog:api:julia_maria_pavan_soler'})
#                 MERGE  (e)-[r:mentions]-(p);
#
#                 MATCH  (e:Exerpt{uri: 'tag:stardog:api:analise_da_ancestralidades_genetica_da_populacao_de_sao_paulo_p_4'})
#                 MERGE  (p:Person{uri: 'tag:stardog:api:dra'})
#                 MERGE  (e)-[r:mentions]-(p);
#
#                 MATCH  (e:Exerpt{uri: 'tag:stardog:api:analise_da_ancestralidades_genetica_da_populacao_de_sao_paulo_p_4'})
#                 MERGE  (p:Person{uri: 'tag:stardog:api:hael_bruno___analise'})
#                 MERGE  (e)-[r:mentions]-(p);
#
#                 MATCH  (e:Exerpt{uri: 'tag:stardog:api:analise_da_ancestralidades_genetica_da_populacao_de_sao_paulo_p_4'})
#                 MERGE  (p:Person{uri: 'tag:stardog:api:regina_celia_mingroni_netto'})
#                 MERGE  (e)-[r:mentions]-(p);
#
#                 MATCH  (e:Exerpt{uri: 'tag:stardog:api:analise_da_ancestralidades_genetica_da_populacao_de_sao_paulo_p_4'})
#                 MERGE  (p:Person{uri: 'tag:stardog:api:raphael_bruno_amemiya'})
#                 MERGE  (e)-[r:mentions]-(p);
#
#                 MATCH  (e:Exerpt{uri: 'tag:stardog:api:analise_da_ancestralidades_genetica_da_populacao_de_sao_paulo_p_4'})
#                 MERGE  (p:Person{uri: 'tag:stardog:api:sergio_russo'})
#                 MERGE  (e)-[r:mentions]-(p);
#
#                 MATCH  (e:Exerpt{uri: 'tag:stardog:api:analise_da_ancestralidades_genetica_da_populacao_de_sao_paulo_p_4'})
#                 MERGE  (p:Person{uri: 'tag:stardog:api:i_t_ii'})
#                 MERGE  (e)-[r:mentions]-(p);
#
#                 MATCH  (e:Exerpt{uri: 'tag:stardog:api:analise_da_ancestralidades_genetica_da_populacao_de_sao_paulo_p_4'})
#                 MERGE  (p:Person{uri: 'tag:stardog:api:sintia_iole_nogueira_belangero'})
#                 MERGE  (e)-[r:mentions]-(p);
#
#                 MATCH  (e:Exerpt{uri: 'tag:stardog:api:analise_da_ancestralidades_genetica_da_populacao_de_sao_paulo_p_4'})
#                 MERGE  (p:Person{uri: 'tag:stardog:api:amemiya'})
#                 MERGE  (e)-[r:mentions]-(p);
#
#                 MATCH  (e:Exerpt{uri: 'tag:stardog:api:analise_da_ancestralidades_genetica_da_populacao_de_sao_paulo_p_4'})
#                 MERGE  (p:Person{uri: 'tag:stardog:api:raphael_bruno'})
#                 MERGE  (e)-[r:mentions]-(p);
#
#                 MATCH  (e:Exerpt{uri: 'tag:stardog:api:analise_da_ancestralidades_genetica_da_populacao_de_sao_paulo_p_4'})
#                 MERGE  (p:Person{uri: 'tag:stardog:api:matioli'})
#                 MERGE  (e)-[r:mentions]-(p);
#
#                 MATCH  (e:Exerpt{uri: 'tag:stardog:api:analise_da_ancestralidades_genetica_da_populacao_de_sao_paulo_p_4'})
#                 MERGE  (p:Place{uri: 'tag:stardog:api:ime'})
#                 MERGE  (e)-[r:mentions]-(p);
#
#                 MATCH  (e:Exerpt{uri: 'tag:stardog:api:analise_da_ancestralidades_genetica_da_populacao_de_sao_paulo_p_4'})
#                 MERGE  (p:Place{uri: 'tag:stardog:api:bionformatica_da_universidade_de_sao_paulo'})
#                 MERGE  (e)-[r:mentions]-(p);
#
#                 MATCH  (e:Exerpt{uri: 'tag:stardog:api:analise_da_ancestralidades_genetica_da_populacao_de_sao_paulo_p_4'})
#                 MERGE  (p:Place{uri: 'tag:stardog:api:unifespfm'})
#                 MERGE  (e)-[r:mentions]-(p);
#
#                 MATCH  (e:Exerpt{uri: 'tag:stardog:api:analise_da_ancestralidades_genetica_da_populacao_de_sao_paulo_p_4'})
#                 MERGE  (p:Place{uri: 'tag:stardog:api:de_sao_paulo'})
#                 MERGE  (e)-[r:mentions]-(p);
#
#                 MATCH  (e:Exerpt{uri: 'tag:stardog:api:analise_da_ancestralidades_genetica_da_populacao_de_sao_paulo_p_4'})
#                 MERGE  (p:Place{uri: 'tag:stardog:api:usp_julgamento'})
#                 MERGE  (e)-[r:mentions]-(p);
#
#                 MATCH  (e:Exerpt{uri: 'tag:stardog:api:analise_da_ancestralidades_genetica_da_populacao_de_sao_paulo_p_4'})
#                 MERGE  (p:Place{uri: 'tag:stardog:api:usp'})
#                 MERGE  (e)-[r:mentions]-(p);
#
#                 MATCH  (e:Exerpt{uri: 'tag:stardog:api:analise_da_ancestralidades_genetica_da_populacao_de_sao_paulo_p_4'})
#                 MERGE  (p:Place{uri: 'tag:stardog:api:sao_paulo'})
#                 MERGE  (e)-[r:mentions]-(p);
#
#             MATCH  (t:Thesis{uri: 'tag:stardog:api:analise_da_ancestralidades_genetica_da_populacao_de_sao_paulo'})
#             MERGE  (e:Exerpt{
#                 uri: 'tag:stardog:api:analise_da_ancestralidades_genetica_da_populacao_de_sao_paulo_p_5',
#                 text: 'ara obtenção do título de Mestre em
# Ciências .
#
# Aprovado em:  11 de junho de 2024
#  Banca Examinadora
# Profa. Dra. Julia Maria Pavan Soler
# Instituição  IME - USP
# Julgamento  A
#
# Profa. Dra. Regina Celia Mingroni Netto
# Instituição  IB - USP
# Julgamento  A
#
# Profa. Dra. Síntia Iole Nogueira Belangero
# Instituição  UNIFESP(FM)
# Julgamento  A
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#  AGRADECIMENTOS
#
# À minha mãe , Cleusa de Sousa Amemiya, por todo apoio e incentivo aos
# meus estudos. Seu exemplo de perseverança e dedicação foi essencial para que eu
# acreditasse no meu potencial e continuasse avanç ando em  minha jornada
# acadêmica.
#
# Ao Prof. Dr. S ergio Russo Matioli, por me aceitar como alun o e pela confiança
# no projeto de pesquisa .
#
# Ao André Chinchio, Ricardo di La',
#                 page: '5',
#                 lang: 'pt'
#                 })-[r:BFO_0000050]-(t);
#
#
#                 MATCH  (e:Exerpt{uri: 'tag:stardog:api:analise_da_ancestralidades_genetica_da_populacao_de_sao_paulo_p_5'})
#                 MERGE  (p:Person{uri: 'tag:stardog:api:julia_maria_pavan_soler'})
#                 MERGE  (e)-[r:mentions]-(p);
#
#                 MATCH  (e:Exerpt{uri: 'tag:stardog:api:analise_da_ancestralidades_genetica_da_populacao_de_sao_paulo_p_5'})
#                 MERGE  (p:Person{uri: 'tag:stardog:api:dra'})
#                 MERGE  (e)-[r:mentions]-(p);
#
#                 MATCH  (e:Exerpt{uri: 'tag:stardog:api:analise_da_ancestralidades_genetica_da_populacao_de_sao_paulo_p_5'})
#                 MERGE  (p:Person{uri: 'tag:stardog:api:regina_celia_mingroni_netto'})
#                 MERGE  (e)-[r:mentions]-(p);
#
#                 MATCH  (e:Exerpt{uri: 'tag:stardog:api:analise_da_ancestralidades_genetica_da_populacao_de_sao_paulo_p_5'})
#                 MERGE  (p:Person{uri: 'tag:stardog:api:prof'})
#                 MERGE  (e)-[r:mentions]-(p);
#
#                 MATCH  (e:Exerpt{uri: 'tag:stardog:api:analise_da_ancestralidades_genetica_da_populacao_de_sao_paulo_p_5'})
#                 MERGE  (p:Person{uri: 'tag:stardog:api:cleusa_de_sousa_amemiya'})
#                 MERGE  (e)-[r:mentions]-(p);
#
#                 MATCH  (e:Exerpt{uri: 'tag:stardog:api:analise_da_ancestralidades_genetica_da_populacao_de_sao_paulo_p_5'})
#                 MERGE  (p:Person{uri: 'tag:stardog:api:sintia_iole_nogueira_belangero'})
#                 MERGE  (e)-[r:mentions]-(p);
#
#                 MATCH  (e:Exerpt{uri: 'tag:stardog:api:analise_da_ancestralidades_genetica_da_populacao_de_sao_paulo_p_5'})
#                 MERGE  (p:Person{uri: 'tag:stardog:api:avanc'})
#                 MERGE  (e)-[r:mentions]-(p);
#
#                 MATCH  (e:Exerpt{uri: 'tag:stardog:api:analise_da_ancestralidades_genetica_da_populacao_de_sao_paulo_p_5'})
#                 MERGE  (p:Person{uri: 'tag:stardog:api:dr_s_ergio_russo_matioli'})
#                 MERGE  (e)-[r:mentions]-(p);
#
#                 MATCH  (e:Exerpt{uri: 'tag:stardog:api:analise_da_ancestralidades_genetica_da_populacao_de_sao_paulo_p_5'})
#                 MERGE  (p:Person{uri: 'tag:stardog:api:ricardo_di_la'})
#                 MERGE  (e)-[r:mentions]-(p);
#
#                 MATCH  (e:Exerpt{uri: 'tag:stardog:api:analise_da_ancestralidades_genetica_da_populacao_de_sao_paulo_p_5'})
#                 MERGE  (p:Person{uri: 'tag:stardog:api:andre_chinchio'})
#                 MERGE  (e)-[r:mentions]-(p);
#
#                 MATCH  (e:Exerpt{uri: 'tag:stardog:api:analise_da_ancestralidades_genetica_da_populacao_de_sao_paulo_p_5'})
#                 MERGE  (p:Place{uri: 'tag:stardog:api:unifespfm'})
#                 MERGE  (e)-[r:mentions]-(p);
#
#                 MATCH  (e:Exerpt{uri: 'tag:stardog:api:analise_da_ancestralidades_genetica_da_populacao_de_sao_paulo_p_5'})
#                 MERGE  (p:Place{uri: 'tag:stardog:api:julgamento'})
#                 MERGE  (e)-[r:mentions]-(p);
#
#                 MATCH  (e:Exerpt{uri: 'tag:stardog:api:analise_da_ancestralidades_genetica_da_populacao_de_sao_paulo_p_5'})
#                 MERGE  (p:Place{uri: 'tag:stardog:api:usp_julgamento'})
#                 MERGE  (e)-[r:mentions]-(p);
#
#                 MATCH  (e:Exerpt{uri: 'tag:stardog:api:analise_da_ancestralidades_genetica_da_populacao_de_sao_paulo_p_5'})
#                 MERGE  (p:Place{uri: 'tag:stardog:api:ime'})
#                 MERGE  (e)-[r:mentions]-(p);
#
#             MATCH  (t:Thesis{uri: 'tag:stardog:api:analise_da_ancestralidades_genetica_da_populacao_de_sao_paulo'})
#             MERGE  (e:Exerpt{
#                 uri: 'tag:stardog:api:analise_da_ancestralidades_genetica_da_populacao_de_sao_paulo_p_6',
#                 text: '
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#  AGRADECIMENTOS
#
# À minha mãe , Cleusa de Sousa Amemiya, por todo apoio e incentivo aos
# meus estudos. Seu exemplo de perseverança e dedicação foi essencial para que eu
# acreditasse no meu potencial e continuasse avanç ando em  minha jornada
# acadêmica.
#
# Ao Prof. Dr. S ergio Russo Matioli, por me aceitar como alun o e pela confiança
# no projeto de pesquisa .
#
# Ao André Chinchio, Ricardo di Lazzaro Filho e toda a equipe Genera com
# quem tive oportunidade de trabalhar  e aprender sobre pesquisa e inovação.
#
# À Universidade de São Paulo, por todo conhecimento que recebi , o qual foi
# fundament al para o meu crescimento professional  e para o desenvolvimento deste
# projeto.
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#                          ',
#                 page: '6',
#                 lang: 'pt'
#                 })-[r:BFO_0000050]-(t);
#
#
#                 MATCH  (e:Exerpt{uri: 'tag:stardog:api:analise_da_ancestralidades_genetica_da_populacao_de_sao_paulo_p_6'})
#                 MERGE  (p:Person{uri: 'tag:stardog:api:ricardo_di_lazzaro_filho'})
#                 MERGE  (e)-[r:mentions]-(p);
#
#                 MATCH  (e:Exerpt{uri: 'tag:stardog:api:analise_da_ancestralidades_genetica_da_populacao_de_sao_paulo_p_6'})
#                 MERGE  (p:Person{uri: 'tag:stardog:api:prof'})
#                 MERGE  (e)-[r:mentions]-(p);
#
#                 MATCH  (e:Exerpt{uri: 'tag:stardog:api:analise_da_ancestralidades_genetica_da_populacao_de_sao_paulo_p_6'})
#                 MERGE  (p:Person{uri: 'tag:stardog:api:cleusa_de_sousa_amemiya'})
#                 MERGE  (e)-[r:mentions]-(p);
#
#                 MATCH  (e:Exerpt{uri: 'tag:stardog:api:analise_da_ancestralidades_genetica_da_populacao_de_sao_paulo_p_6'})
#                 MERGE  (p:Person{uri: 'tag:stardog:api:dr_s_ergio_russo_matioli'})
#                 MERGE  (e)-[r:mentions]-(p);
#
#                 MATCH  (e:Exerpt{uri: 'tag:stardog:api:analise_da_ancestralidades_genetica_da_populacao_de_sao_paulo_p_6'})
#                 MERGE  (p:Person{uri: 'tag:stardog:api:avanc'})
#                 MERGE  (e)-[r:mentions]-(p);
#
#                 MATCH  (e:Exerpt{uri: 'tag:stardog:api:analise_da_ancestralidades_genetica_da_populacao_de_sao_paulo_p_6'})
#                 MERGE  (p:Person{uri: 'tag:stardog:api:andre_chinchio'})
#                 MERGE  (e)-[r:mentions]-(p);
#
#                 MATCH  (e:Exerpt{uri: 'tag:stardog:api:analise_da_ancestralidades_genetica_da_populacao_de_sao_paulo_p_6'})
#                 MERGE  (p:Place{uri: 'tag:stardog:api:genera'})
#                 MERGE  (e)-[r:mentions]-(p);
#
#                 MATCH  (e:Exerpt{uri: 'tag:stardog:api:analise_da_ancestralidades_genetica_da_populacao_de_sao_paulo_p_6'})
#                 MERGE  (p:Place{uri: 'tag:stardog:api:universidade_de_sao_paulo'})
#                 MERGE  (e)-[r:mentions]-(p);
#
#             MATCH  (t:Thesis{uri: 'tag:stardog:api:analise_da_ancestralidades_genetica_da_populacao_de_sao_paulo'})
#             MERGE  (e:Exerpt{
#                 uri: 'tag:stardog:api:analise_da_ancestralidades_genetica_da_populacao_de_sao_paulo_p_7',
#                 text: 'iança
# no projeto de pesquisa .
#
# Ao André Chinchio, Ricardo di Lazzaro Filho e toda a equipe Genera com
# quem tive oportunidade de trabalhar  e aprender sobre pesquisa e inovação.
#
# À Universidade de São Paulo, por todo conhecimento que recebi , o qual foi
# fundament al para o meu crescimento professional  e para o desenvolvimento deste
# projeto.
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#  RESUMO
#
# AMEMIYA, R. B. Análise da ancestralidade genética da população de São Paulo .
# 2024. Dissertação (Mestrado)  – Programa Interunidades de Pós -Graduação em
# Bioinformática , Universidade de São Paulo, São Paulo, 2024.
#
# Os avanços da Biotecnologia  possibilitaram  a análise de  milhares de marcadores
# genéticos, fornecendo  informações  importantes sobre  ancestralidade e saúde. No
# co',
#                 page: '7',
#                 lang: 'pt'
#                 })-[r:BFO_0000050]-(t);
#
#
#                 MATCH  (e:Exerpt{uri: 'tag:stardog:api:analise_da_ancestralidades_genetica_da_populacao_de_sao_paulo_p_7'})
#                 MERGE  (p:Person{uri: 'tag:stardog:api:r_b_analise'})
#                 MERGE  (e)-[r:mentions]-(p);
#
#                 MATCH  (e:Exerpt{uri: 'tag:stardog:api:analise_da_ancestralidades_genetica_da_populacao_de_sao_paulo_p_7'})
#                 MERGE  (p:Person{uri: 'tag:stardog:api:andre_chinchio'})
#                 MERGE  (e)-[r:mentions]-(p);
#
#                 MATCH  (e:Exerpt{uri: 'tag:stardog:api:analise_da_ancestralidades_genetica_da_populacao_de_sao_paulo_p_7'})
#                 MERGE  (p:Person{uri: 'tag:stardog:api:ricardo_di_lazzaro_filho'})
#                 MERGE  (e)-[r:mentions]-(p);
#
#                 MATCH  (e:Exerpt{uri: 'tag:stardog:api:analise_da_ancestralidades_genetica_da_populacao_de_sao_paulo_p_7'})
#                 MERGE  (p:Place{uri: 'tag:stardog:api:genera'})
#                 MERGE  (e)-[r:mentions]-(p);
#
#                 MATCH  (e:Exerpt{uri: 'tag:stardog:api:analise_da_ancestralidades_genetica_da_populacao_de_sao_paulo_p_7'})
#                 MERGE  (p:Place{uri: 'tag:stardog:api:ianca'})
#                 MERGE  (e)-[r:mentions]-(p);
#
#                 MATCH  (e:Exerpt{uri: 'tag:stardog:api:analise_da_ancestralidades_genetica_da_populacao_de_sao_paulo_p_7'})
#                 MERGE  (p:Place{uri: 'tag:stardog:api:universidade_de_sao_paulo'})
#                 MERGE  (e)-[r:mentions]-(p);
#
#                 MATCH  (e:Exerpt{uri: 'tag:stardog:api:analise_da_ancestralidades_genetica_da_populacao_de_sao_paulo_p_7'})
#                 MERGE  (p:Place{uri: 'tag:stardog:api:de_sao_paulo'})
#                 MERGE  (e)-[r:mentions]-(p);
#
#                 MATCH  (e:Exerpt{uri: 'tag:stardog:api:analise_da_ancestralidades_genetica_da_populacao_de_sao_paulo_p_7'})
#                 MERGE  (p:Place{uri: 'tag:stardog:api:bioinformatica'})
#                 MERGE  (e)-[r:mentions]-(p);
#
#                 MATCH  (e:Exerpt{uri: 'tag:stardog:api:analise_da_ancestralidades_genetica_da_populacao_de_sao_paulo_p_7'})
#                 MERGE  (p:Place{uri: 'tag:stardog:api:mestrado'})
#                 MERGE  (e)-[r:mentions]-(p);
#
#                 MATCH  (e:Exerpt{uri: 'tag:stardog:api:analise_da_ancestralidades_genetica_da_populacao_de_sao_paulo_p_7'})
#                 MERGE  (p:Place{uri: 'tag:stardog:api:sao_paulo'})
#                 MERGE  (e)-[r:mentions]-(p);
#
#             MATCH  (t:Thesis{uri: 'tag:stardog:api:analise_da_ancestralidades_genetica_da_populacao_de_sao_paulo'})
#             MERGE  (e:Exerpt{
#                 uri: 'tag:stardog:api:analise_da_ancestralidades_genetica_da_populacao_de_sao_paulo_p_8',
#                 text: '
#
#
#
#
#  RESUMO
#
# AMEMIYA, R. B. Análise da ancestralidade genética da população de São Paulo .
# 2024. Dissertação (Mestrado)  – Programa Interunidades de Pós -Graduação em
# Bioinformática , Universidade de São Paulo, São Paulo, 2024.
#
# Os avanços da Biotecnologia  possibilitaram  a análise de  milhares de marcadores
# genéticos, fornecendo  informações  importantes sobre  ancestralidade e saúde. No
# contexto da ancestralidade genética, testes de DNA são importantes para identificar
# as origens de uma população e proporcionar  aos indivíduos um maior conhecimento
# sobre seus antepassados. O Brasil é reconhecido por sua vasta diversidade étnica,
# com contribuições europeias, africanas, indígenas, asiáticas, entre outras . Essa
# diversidade étnica apresenta desafios na inferência da ancestralidade . Neste
# contexto,  a aplicação de técnicas de bioinformática é importante para a análise de
# dados genéticos e  a elaboração de modelos para inferir  a ancestralidade.  Tendo isso
# em mente, o objetivo deste projeto foi analisar a ancestralidade global de indivíduos
# da população de São Paulo  utilizando técnicas de aprendizado de máquina . Para
# esta finalidade,  buscou -se bancos genéticos públicos contendo dados de diferentes
# populações . Os dados foram processados e estruturados para serem aplicados em
# modelos não supervisionados e supervisionados . Neste projeto,  foram
# implementados  modelos supervisionados em Python com base na Estimativa de
# Máxima Verossimilhança.  Os modelos criados também foram combinados usando
# abordagens de  previsão em conjunto, que combina m os resultados de diferentes
# modelos. A capacidade dos modelos em inferir a ancestralidade de 23 grupos
# populacionais foi avaliada com validação cruzada estratificada  e amostras
# simuladas . A raiz do erro quadrático médio ( RMSE ) foi calculada  entre as
# proporções  inferidas  e esperada s de  ancestralidade  com amostras simuladas. O
# modelo com menor  valor médio de RM SE teve uma média de precisão e
# sensibilidade na validação de 96,0% e 94,3%, respectivamente.  Este modelo foi
# usado para inferir a ancestralidade de 411 indivíduos de São Paulo. Con siderando
# apenas os grupos continentais com maiores proporções , foi inferida,  em média
# 77,5%  de ancestralidade europeia, 10,3%  africana,  7,4%  nativ a americana  e 4,1%
# de leste asiática. As análises realizadas  neste projeto exemplificam a eficácia da
# combinação de mais de um modelo na inferência de ancestralidade genética , assim
# como o uso de técnicas de aprendizado de máquina como ferramenta para
# compreender a diversidade de populações complexas , como a de São Paulo.
#  Palavras -chave:  Ancestralidade. Aprendizado de máquina.  Bioinformática . Genética.
#
#
#
#
#
#
#
#
#
#
#                          ',
#                 page: '8',
#                 lang: 'pt'
#                 })-[r:BFO_0000050]-(t);
#
#
#                 MATCH  (e:Exerpt{uri: 'tag:stardog:api:analise_da_ancestralidades_genetica_da_populacao_de_sao_paulo_p_8'})
#                 MERGE  (p:Person{uri: 'tag:stardog:api:r_b_analise'})
#                 MERGE  (e)-[r:mentions]-(p);
#
#                 MATCH  (e:Exerpt{uri: 'tag:stardog:api:analise_da_ancestralidades_genetica_da_populacao_de_sao_paulo_p_8'})
#                 MERGE  (p:Person{uri: 'tag:stardog:api:nativ'})
#                 MERGE  (e)-[r:mentions]-(p);
#
#                 MATCH  (e:Exerpt{uri: 'tag:stardog:api:analise_da_ancestralidades_genetica_da_populacao_de_sao_paulo_p_8'})
#                 MERGE  (p:Place{uri: 'tag:stardog:api:estimativa_de_maxima_verossimilhanca'})
#                 MERGE  (e)-[r:mentions]-(p);
#
#                 MATCH  (e:Exerpt{uri: 'tag:stardog:api:analise_da_ancestralidades_genetica_da_populacao_de_sao_paulo_p_8'})
#                 MERGE  (p:Place{uri: 'tag:stardog:api:universidade_de_sao_paulo'})
#                 MERGE  (e)-[r:mentions]-(p);
#
#                 MATCH  (e:Exerpt{uri: 'tag:stardog:api:analise_da_ancestralidades_genetica_da_populacao_de_sao_paulo_p_8'})
#                 MERGE  (p:Place{uri: 'tag:stardog:api:rm_se'})
#                 MERGE  (e)-[r:mentions]-(p);
#
#                 MATCH  (e:Exerpt{uri: 'tag:stardog:api:analise_da_ancestralidades_genetica_da_populacao_de_sao_paulo_p_8'})
#                 MERGE  (p:Place{uri: 'tag:stardog:api:de_sao_paulo'})
#                 MERGE  (e)-[r:mentions]-(p);
#
#                 MATCH  (e:Exerpt{uri: 'tag:stardog:api:analise_da_ancestralidades_genetica_da_populacao_de_sao_paulo_p_8'})
#                 MERGE  (p:Place{uri: 'tag:stardog:api:bioinformatica'})
#                 MERGE  (e)-[r:mentions]-(p);
#
#                 MATCH  (e:Exerpt{uri: 'tag:stardog:api:analise_da_ancestralidades_genetica_da_populacao_de_sao_paulo_p_8'})
#                 MERGE  (p:Place{uri: 'tag:stardog:api:mestrado'})
#                 MERGE  (e)-[r:mentions]-(p);
#
#                 MATCH  (e:Exerpt{uri: 'tag:stardog:api:analise_da_ancestralidades_genetica_da_populacao_de_sao_paulo_p_8'})
#                 MERGE  (p:Place{uri: 'tag:stardog:api:brasil'})
#                 MERGE  (e)-[r:mentions]-(p);
#
#                 MATCH  (e:Exerpt{uri: 'tag:stardog:api:analise_da_ancestralidades_genetica_da_populacao_de_sao_paulo_p_8'})
#                 MERGE  (p:Place{uri: 'tag:stardog:api:sao_paulo'})
#                 MERGE  (e)-[r:mentions]-(p);
#
#             MATCH  (t:Thesis{uri: 'tag:stardog:api:analise_da_ancestralidades_genetica_da_populacao_de_sao_paulo'})
#             MERGE  (e:Exerpt{
#                 uri: 'tag:stardog:api:analise_da_ancestralidades_genetica_da_populacao_de_sao_paulo_p_9',
#                 text: '. As análises realizadas  neste projeto exemplificam a eficácia da
# combinação de mais de um modelo na inferência de ancestralidade genética , assim
# como o uso de técnicas de aprendizado de máquina como ferramenta para
# compreender a diversidade de populações complexas , como a de São Paulo.
#  Palavras -chave:  Ancestralidade. Aprendizado de máquina.  Bioinformática . Genética.
#
#
#
#
#
#
#
#
#
#
#
#  ABSTRACT
#
# AMEMIYA, R. B. Genetic ancestry analysis of the population of São Paulo . 2024.
# Dissertação (Mestrado) – Programa Interunidades de Pós -Graduação em
# Bioinformática , Universidade de São Paulo, São Paulo, 2024.
#
# Advances in biotechnology  have enabled the analysis o f thousands of genetic
# markers , providing important information about ancestry  and health . In the context of
# ge',
#                 page: '9',
#                 lang: 'pt'
#                 })-[r:BFO_0000050]-(t);
#
#
#                 MATCH  (e:Exerpt{uri: 'tag:stardog:api:analise_da_ancestralidades_genetica_da_populacao_de_sao_paulo_p_9'})
#                 MERGE  (p:Person{uri: 'tag:stardog:api:r_b_genetic'})
#                 MERGE  (e)-[r:mentions]-(p);
#
#                 MATCH  (e:Exerpt{uri: 'tag:stardog:api:analise_da_ancestralidades_genetica_da_populacao_de_sao_paulo_p_9'})
#                 MERGE  (p:Place{uri: 'tag:stardog:api:universidade_de_sao_paulo'})
#                 MERGE  (e)-[r:mentions]-(p);
#
#                 MATCH  (e:Exerpt{uri: 'tag:stardog:api:analise_da_ancestralidades_genetica_da_populacao_de_sao_paulo_p_9'})
#                 MERGE  (p:Place{uri: 'tag:stardog:api:dissertacao'})
#                 MERGE  (e)-[r:mentions]-(p);
#
#                 MATCH  (e:Exerpt{uri: 'tag:stardog:api:analise_da_ancestralidades_genetica_da_populacao_de_sao_paulo_p_9'})
#                 MERGE  (p:Place{uri: 'tag:stardog:api:de_sao_paulo'})
#                 MERGE  (e)-[r:mentions]-(p);
#
#                 MATCH  (e:Exerpt{uri: 'tag:stardog:api:analise_da_ancestralidades_genetica_da_populacao_de_sao_paulo_p_9'})
#                 MERGE  (p:Place{uri: 'tag:stardog:api:bioinformatica'})
#                 MERGE  (e)-[r:mentions]-(p);
#
#                 MATCH  (e:Exerpt{uri: 'tag:stardog:api:analise_da_ancestralidades_genetica_da_populacao_de_sao_paulo_p_9'})
#                 MERGE  (p:Place{uri: 'tag:stardog:api:mestrado'})
#                 MERGE  (e)-[r:mentions]-(p);
#
#                 MATCH  (e:Exerpt{uri: 'tag:stardog:api:analise_da_ancestralidades_genetica_da_populacao_de_sao_paulo_p_9'})
#                 MERGE  (p:Place{uri: 'tag:stardog:api:sao_paulo'})
#                 MERGE  (e)-[r:mentions]-(p);
#
#             MATCH  (t:Thesis{uri: 'tag:stardog:api:analise_da_ancestralidades_genetica_da_populacao_de_sao_paulo'})
#             MERGE  (e:Exerpt{
#                 uri: 'tag:stardog:api:analise_da_ancestralidades_genetica_da_populacao_de_sao_paulo_p_10',
#                 text: '
#
#
#
#
#  ABSTRACT
#
# AMEMIYA, R. B. Genetic ancestry analysis of the population of São Paulo . 2024.
# Dissertação (Mestrado) – Programa Interunidades de Pós -Graduação em
# Bioinformática , Universidade de São Paulo, São Paulo, 2024.
#
# Advances in biotechnology  have enabled the analysis o f thousands of genetic
# markers , providing important information about ancestry  and health . In the context of
# genetic ancestry, DNA tests  are important f or identifying the origins of a population
# and providing  individuals with better  knowledge about their ancestors. Brazil is known
# for its vast ethnic diversity,  with contributions  from European,  African, Native
# American,  Asian , and other populations.  This ethnic diversity represents  a challenge
# in inferring ancestry. In this context, the development and application of
# bioinformatics techniques are important for genetic data analysis and the
# development of models to infer ancestry . With th ese in mind, the goal of this p roject
# was t o analy ze the genetic ancestry of individuals from the São Paulo population
# using machine learning models. For this purpose, public genetic databases with
# diverse populations were selected . The data were processed and structured to be
# applied with unsupervised and supervised models. In this project , supervised models
# were implemented in Python based on Maximum Likelihood Estimation.  The
# developed model s were also combined into ensemble model s. The ability of the
# model to infer  the ancestry of 23 population groups w as evaluated using stratified
# cross validation , and simulated samples . The root mean squared error (RMSE) was
# calculated between the predicted and expected proportions of ancestry using the
# simulated samples. The model with the lowest value of mean RMSE had an average
# precision,  and sensitivity  of 96.0% and 94 .3%, respectively. This model was used to
# infer ancestry of 411 individuals from São Paulo. Considering only continental groups
# with the highest proportions, it was inferred an average of  77.5% for European
# ancestry, 10.3% for African ancestry , 7.4% for Native American  ancestry and 4. 1%
# for East Asian  ancestry . The analys es conducted in this project exemplif y the
# effectiveness  of the combination of model s in inferring genetic ancestry , as well as
# the use of machine learning models as a tool to better comprehend the diversity of
# complex population, such as the population of São Paulo.
#
# Keywords : Ancestry . Machine learning. Bioinformatics . Genetic s.
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#   ',
#                 page: '10',
#                 lang: 'en'
#                 })-[r:BFO_0000050]-(t);
#
#
#             MATCH  (t:Thesis{uri: 'tag:stardog:api:analise_da_ancestralidades_genetica_da_populacao_de_sao_paulo'})
#             MERGE  (e:Exerpt{
#                 uri: 'tag:stardog:api:analise_da_ancestralidades_genetica_da_populacao_de_sao_paulo_p_11',
#                 text: 'r East Asian  ancestry . The analys es conducted in this project exemplif y the
# effectiveness  of the combination of model s in inferring genetic ancestry , as well as
# the use of machine learning models as a tool to better comprehend the diversity of
# complex population, such as the population of São Paulo.
#
# Keywords : Ancestry . Machine learning. Bioinformatics . Genetic s.
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#  LISTA DE SIGLAS
#
# DTC direct -to-consumer
# STRs  Short Tandem Repeats
# SNPs  Single Nucleotide Polymorphism
# AIMs  Ancestry Informative Markers
# HGDP  Human Genome Diversity Project
# 1kGP  1000 Genomes Project
# AISNPs  Ancestry Informative SNPs
# PCA Principal Component Analysis
# MDS  Multidimensional Scaling
# HMM  Hidden Markov Model
# GWAS  Genome Wide Association Study
# MLE Maximum L',
#                 page: '11',
#                 lang: 'en'
#                 })-[r:BFO_0000050]-(t);
#
#
#             MATCH  (t:Thesis{uri: 'tag:stardog:api:analise_da_ancestralidades_genetica_da_populacao_de_sao_paulo'})
#             MERGE  (e:Exerpt{
#                 uri: 'tag:stardog:api:analise_da_ancestralidades_genetica_da_populacao_de_sao_paulo_p_12',
#                 text: '
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#  LISTA DE SIGLAS
#
# DTC direct -to-consumer
# STRs  Short Tandem Repeats
# SNPs  Single Nucleotide Polymorphism
# AIMs  Ancestry Informative Markers
# HGDP  Human Genome Diversity Project
# 1kGP  1000 Genomes Project
# AISNPs  Ancestry Informative SNPs
# PCA Principal Component Analysis
# MDS  Multidimensional Scaling
# HMM  Hidden Markov Model
# GWAS  Genome Wide Association Study
# MLE Maximum Likelihood Estimation
# TCLE  Termo de Consentimento Livre e Esclarecido
# gnomAD  Genome Aggregation Database
# KRGP  Korean Reference Genome Database
# VCF Variant Call Format
# USP Universidade de São Paulo
# GSA  Global Screening Arrays
# MAF  Minor Allele Frequency
# HWE  Hardy -Weinberg Equilibrium
# PC Principal Component
# LCN Local Classifier per Node
# LCPN  Local Classifier per Parent Node
# LCL Local Classifier per Level
# RMSE  Root Mean Squared Error
# SABE  Saúde, Bem -estar e Envelhecimento
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#  ',
#                 page: '12',
#                 lang: 'en'
#                 })-[r:BFO_0000050]-(t);
#
#
#             MATCH  (t:Thesis{uri: 'tag:stardog:api:analise_da_ancestralidades_genetica_da_populacao_de_sao_paulo'})
#             MERGE  (e:Exerpt{
#                 uri: 'tag:stardog:api:analise_da_ancestralidades_genetica_da_populacao_de_sao_paulo_p_13',
#                 text: 'ference Genome Database
# VCF Variant Call Format
# USP Universidade de São Paulo
# GSA  Global Screening Arrays
# MAF  Minor Allele Frequency
# HWE  Hardy -Weinberg Equilibrium
# PC Principal Component
# LCN Local Classifier per Node
# LCPN  Local Classifier per Parent Node
# LCL Local Classifier per Level
# RMSE  Root Mean Squared Error
# SABE  Saúde, Bem -estar e Envelhecimento
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#  SUMÁRIO
# 1 INTRODUÇÃO  ................................................................................................................. 15
# 1.1 Justificativa  .................................................................................................................. 19
# ...
#  WATHEN, Michael J. et al. LEI: a novel allele frequency -based feature selection
# method for multi -ancestry admixed populations. Scientific reports, v. 9, n. 1, p. 11103,
# 2019.
#  WOLLSTEIN, Andreas; LAO, Oscar. Detecting individual ancestry in the human genome. Investigative genetics, v. 6, p. 1- 12, 2015.
#
# YUAN, Kai et al. Models, methods and tools for ancestry inference and admixture analysis. Quantitative Biology, v. 5, n. 3, p. 236- 250, 2017.
#  ZHAO, Shilin et al. Strategies for processing and quality control of Illumina genotyping arrays. Briefings in bioinformatics, v. 19, n. 5, p. 765- 775, 2018.
#  ZHENG, Xiuwen et al. A high -performance computing toolset for relatedness and
# principal component analysis of SNP data. Bioinformatics, v. 28, n. 24, p. 3326- 3328,
# 2012.
#
#
#
#
#
#
#
#
#
#
#
#
#  73
#
# APÊNDICE
#
# APÊNDICE A – PCA do conjunto de referência, PC1 x PC3
#
#
#
# APÊNDICE B – PCA do conjunto de referência, PC2 x PC3
#
# ',
#                 page: '73',
#                 lang: 'en'
#                 })-[r:BFO_0000050]-(t);
#
#
#             MATCH  (t:Thesis{uri: 'tag:stardog:api:analise_da_ancestralidades_genetica_da_populacao_de_sao_paulo'})
#             MERGE  (e:Exerpt{
#                 uri: 'tag:stardog:api:analise_da_ancestralidades_genetica_da_populacao_de_sao_paulo_p_74',
#                 text: 'gy, v. 5, n. 3, p. 236- 250, 2017.
#  ZHAO, Shilin et al. Strategies for processing and quality control of Illumina genotyping arrays. Briefings in bioinformatics, v. 19, n. 5, p. 765- 775, 2018.
#  ZHENG, Xiuwen et al. A high -performance computing toolset for relatedness and
# principal component analysis of SNP data. Bioinformatics, v. 28, n. 24, p. 3326- 3328,
# 2012.
#
#
#
#
#
#
#
#
#
#
#
#
#  73
#
# APÊNDICE
#
# APÊNDICE A – PCA do conjunto de referência, PC1 x PC3
#
#
#
# APÊNDICE B – PCA do conjunto de referência, PC2 x PC3
#
#
#  74
#
# APÊNDICE C –  PCA do conjunto de referência (África)
#
#
# APÊNDICE D –  PCA do conjunto de referência (Europa)
#
# ',
#                 page: '74',
#                 lang: 'en'
#                 })-[r:BFO_0000050]-(t);
#
#
#                 MATCH  (e:Exerpt{uri: 'tag:stardog:api:analise_da_ancestralidades_genetica_da_populacao_de_sao_paulo_p_74'})
#                 MERGE  (p:Place{uri: 'tag:stardog:api:europa'})
#                 MERGE  (e)-[r:mentions]-(p);
#
#             MATCH  (t:Thesis{uri: 'tag:stardog:api:analise_da_ancestralidades_genetica_da_populacao_de_sao_paulo'})
#             MERGE  (e:Exerpt{
#                 uri: 'tag:stardog:api:analise_da_ancestralidades_genetica_da_populacao_de_sao_paulo_p_75',
#                 text: '73
#
# APÊNDICE
#
# APÊNDICE A – PCA do conjunto de referência, PC1 x PC3
#
#
#
# APÊNDICE B – PCA do conjunto de referência, PC2 x PC3
#
#
#  74
#
# APÊNDICE C –  PCA do conjunto de referência (África)
#
#
# APÊNDICE D –  PCA do conjunto de referência (Europa)
#
#
#  75
#
# APÊNDICE E – PCA do conjunto de referência ( Nativo s Americanos )
#
#
# APÊNDICE F – PCA do conjunto de referência ( Ásia)
#
#
#
# ',
#                 page: '75',
#                 lang: 'pt'
#                 })-[r:BFO_0000050]-(t);
#
#
#                 MATCH  (e:Exerpt{uri: 'tag:stardog:api:analise_da_ancestralidades_genetica_da_populacao_de_sao_paulo_p_75'})
#                 MERGE  (p:Place{uri: 'tag:stardog:api:pc2'})
#                 MERGE  (e)-[r:mentions]-(p);
#
#                 MATCH  (e:Exerpt{uri: 'tag:stardog:api:analise_da_ancestralidades_genetica_da_populacao_de_sao_paulo_p_75'})
#                 MERGE  (p:Place{uri: 'tag:stardog:api:pc3'})
#                 MERGE  (e)-[r:mentions]-(p);
#
#                 MATCH  (e:Exerpt{uri: 'tag:stardog:api:analise_da_ancestralidades_genetica_da_populacao_de_sao_paulo_p_75'})
#                 MERGE  (p:Place{uri: 'tag:stardog:api:africa'})
#                 MERGE  (e)-[r:mentions]-(p);
#
#                 MATCH  (e:Exerpt{uri: 'tag:stardog:api:analise_da_ancestralidades_genetica_da_populacao_de_sao_paulo_p_75'})
#                 MERGE  (p:Place{uri: 'tag:stardog:api:americanos'})
#                 MERGE  (e)-[r:mentions]-(p);
#
#                 MATCH  (e:Exerpt{uri: 'tag:stardog:api:analise_da_ancestralidades_genetica_da_populacao_de_sao_paulo_p_75'})
#                 MERGE  (p:Place{uri: 'tag:stardog:api:pc1_x_pc3'})
#                 MERGE  (e)-[r:mentions]-(p);
#
#                 MATCH  (e:Exerpt{uri: 'tag:stardog:api:analise_da_ancestralidades_genetica_da_populacao_de_sao_paulo_p_75'})
#                 MERGE  (p:Place{uri: 'tag:stardog:api:asia'})
#                 MERGE  (e)-[r:mentions]-(p);
#
#                 MATCH  (e:Exerpt{uri: 'tag:stardog:api:analise_da_ancestralidades_genetica_da_populacao_de_sao_paulo_p_75'})
#                 MERGE  (p:Place{uri: 'tag:stardog:api:nativo'})
#                 MERGE  (e)-[r:mentions]-(p);
#
#                 MATCH  (e:Exerpt{uri: 'tag:stardog:api:analise_da_ancestralidades_genetica_da_populacao_de_sao_paulo_p_75'})
#                 MERGE  (p:Place{uri: 'tag:stardog:api:europa'})
#                 MERGE  (e)-[r:mentions]-(p);
#
#             MATCH  (t:Thesis{uri: 'tag:stardog:api:analise_da_ancestralidades_genetica_da_populacao_de_sao_paulo'})
#             MERGE  (e:Exerpt{
#                 uri: 'tag:stardog:api:analise_da_ancestralidades_genetica_da_populacao_de_sao_paulo_p_76',
#                 text: '74
#
# APÊNDICE C –  PCA do conjunto de referência (África)
#
#
# APÊNDICE D –  PCA do conjunto de referência (Europa)
#
#
#  75
#
# APÊNDICE E – PCA do conjunto de referência ( Nativo s Americanos )
#
#
# APÊNDICE F – PCA do conjunto de referência ( Ásia)
#
#
#
#
#  76
#
# APÊNDICE G – Admixture com todos os grupos populacionais
#
#
#
#
#
#
#
#
#
#
#
# ',
#                 page: '76',
#                 lang: 'pt'
#                 })-[r:BFO_0000050]-(t);
#
#
#                 MATCH  (e:Exerpt{uri: 'tag:stardog:api:analise_da_ancestralidades_genetica_da_populacao_de_sao_paulo_p_76'})
#                 MERGE  (p:Place{uri: 'tag:stardog:api:africa'})
#                 MERGE  (e)-[r:mentions]-(p);
#
#                 MATCH  (e:Exerpt{uri: 'tag:stardog:api:analise_da_ancestralidades_genetica_da_populacao_de_sao_paulo_p_76'})
#                 MERGE  (p:Place{uri: 'tag:stardog:api:americanos'})
#                 MERGE  (e)-[r:mentions]-(p);
#
#                 MATCH  (e:Exerpt{uri: 'tag:stardog:api:analise_da_ancestralidades_genetica_da_populacao_de_sao_paulo_p_76'})
#                 MERGE  (p:Place{uri: 'tag:stardog:api:asia'})
#                 MERGE  (e)-[r:mentions]-(p);
#
#                 MATCH  (e:Exerpt{uri: 'tag:stardog:api:analise_da_ancestralidades_genetica_da_populacao_de_sao_paulo_p_76'})
#                 MERGE  (p:Place{uri: 'tag:stardog:api:nativo'})
#                 MERGE  (e)-[r:mentions]-(p);
#
#                 MATCH  (e:Exerpt{uri: 'tag:stardog:api:analise_da_ancestralidades_genetica_da_populacao_de_sao_paulo_p_76'})
#                 MERGE  (p:Place{uri: 'tag:stardog:api:europa'})
#                 MERGE  (e)-[r:mentions]-(p);
#
#             MATCH  (t:Thesis{uri: 'tag:stardog:api:analise_da_ancestralidades_genetica_da_populacao_de_sao_paulo'})
#             MERGE  (e:Exerpt{
#                 uri: 'tag:stardog:api:analise_da_ancestralidades_genetica_da_populacao_de_sao_paulo_p_77',
#                 text: '75
#
# APÊNDICE E – PCA do conjunto de referência ( Nativo s Americanos )
#
#
# APÊNDICE F – PCA do conjunto de referência ( Ásia)
#
#
#
#
#  76
#
# APÊNDICE G – Admixture com todos os grupos populacionais
#
#
#
#
#
#
#
#
#
#
#
#
#  77
#
# APÊNDICE H – Admixture com os grupos da África
#
#
#
#
#
#
#
#
#
#
#
#
# ',
#                 page: '77',
#                 lang: 'pt'
#                 })-[r:BFO_0000050]-(t);
#
#
#                 MATCH  (e:Exerpt{uri: 'tag:stardog:api:analise_da_ancestralidades_genetica_da_populacao_de_sao_paulo_p_77'})
#                 MERGE  (p:Place{uri: 'tag:stardog:api:asia'})
#                 MERGE  (e)-[r:mentions]-(p);
#
#                 MATCH  (e:Exerpt{uri: 'tag:stardog:api:analise_da_ancestralidades_genetica_da_populacao_de_sao_paulo_p_77'})
#                 MERGE  (p:Place{uri: 'tag:stardog:api:africa'})
#                 MERGE  (e)-[r:mentions]-(p);
#
#                 MATCH  (e:Exerpt{uri: 'tag:stardog:api:analise_da_ancestralidades_genetica_da_populacao_de_sao_paulo_p_77'})
#                 MERGE  (p:Place{uri: 'tag:stardog:api:americanos'})
#                 MERGE  (e)-[r:mentions]-(p);
#
#                 MATCH  (e:Exerpt{uri: 'tag:stardog:api:analise_da_ancestralidades_genetica_da_populacao_de_sao_paulo_p_77'})
#                 MERGE  (p:Place{uri: 'tag:stardog:api:nativo'})
#                 MERGE  (e)-[r:mentions]-(p);
#
#             MATCH  (t:Thesis{uri: 'tag:stardog:api:analise_da_ancestralidades_genetica_da_populacao_de_sao_paulo'})
#             MERGE  (e:Exerpt{
#                 uri: 'tag:stardog:api:analise_da_ancestralidades_genetica_da_populacao_de_sao_paulo_p_78',
#                 text: '76
#
# APÊNDICE G – Admixture com todos os grupos populacionais
#
#
#
#
#
#
#
#
#
#
#
#
#  77
#
# APÊNDICE H – Admixture com os grupos da África
#
#
#
#
#
#
#
#
#
#
#
#
#
#  78
#
# APÊNDICE I – Admixture com os grupos  Nativo Americanos
#
#
#
#
#
#
#
#
#
#
#
#
# ',
#                 page: '78',
#                 lang: 'pt'
#                 })-[r:BFO_0000050]-(t);
#
#
#                 MATCH  (e:Exerpt{uri: 'tag:stardog:api:analise_da_ancestralidades_genetica_da_populacao_de_sao_paulo_p_78'})
#                 MERGE  (p:Place{uri: 'tag:stardog:api:africa'})
#                 MERGE  (e)-[r:mentions]-(p);
#
#                 MATCH  (e:Exerpt{uri: 'tag:stardog:api:analise_da_ancestralidades_genetica_da_populacao_de_sao_paulo_p_78'})
#                 MERGE  (p:Place{uri: 'tag:stardog:api:nativo_americanos'})
#                 MERGE  (e)-[r:mentions]-(p);
#
#             MATCH  (t:Thesis{uri: 'tag:stardog:api:analise_da_ancestralidades_genetica_da_populacao_de_sao_paulo'})
#             MERGE  (e:Exerpt{
#                 uri: 'tag:stardog:api:analise_da_ancestralidades_genetica_da_populacao_de_sao_paulo_p_79',
#                 text: '77
#
# APÊNDICE H – Admixture com os grupos da África
#
#
#
#
#
#
#
#
#
#
#
#
#
#  78
#
# APÊNDICE I – Admixture com os grupos  Nativo Americanos
#
#
#
#
#
#
#
#
#
#
#
#
#
#  79
#
# APÊNDICE J – Admixture com os grupos da Ásia
#
#
#
#
#
#
#
#
#
#
#
#
# ',
#                 page: '79',
#                 lang: 'pt'
#                 })-[r:BFO_0000050]-(t);
#
#
#                 MATCH  (e:Exerpt{uri: 'tag:stardog:api:analise_da_ancestralidades_genetica_da_populacao_de_sao_paulo_p_79'})
#                 MERGE  (p:Place{uri: 'tag:stardog:api:africa'})
#                 MERGE  (e)-[r:mentions]-(p);
#
#                 MATCH  (e:Exerpt{uri: 'tag:stardog:api:analise_da_ancestralidades_genetica_da_populacao_de_sao_paulo_p_79'})
#                 MERGE  (p:Place{uri: 'tag:stardog:api:nativo_americanos'})
#                 MERGE  (e)-[r:mentions]-(p);
#
#                 MATCH  (e:Exerpt{uri: 'tag:stardog:api:analise_da_ancestralidades_genetica_da_populacao_de_sao_paulo_p_79'})
#                 MERGE  (p:Place{uri: 'tag:stardog:api:asia'})
#                 MERGE  (e)-[r:mentions]-(p);
#
#             MATCH  (t:Thesis{uri: 'tag:stardog:api:analise_da_ancestralidades_genetica_da_populacao_de_sao_paulo'})
#             MERGE  (e:Exerpt{
#                 uri: 'tag:stardog:api:analise_da_ancestralidades_genetica_da_populacao_de_sao_paulo_p_80',
#                 text: '78
#
# APÊNDICE I – Admixture com os grupos  Nativo Americanos
#
#
#
#
#
#
#
#
#
#
#
#
#
#  79
#
# APÊNDICE J – Admixture com os grupos da Ásia
#
#
#
#
#
#
#
#
#
#
#
#
#
#  80
#
# APÊNDICE L – Admixture com os grupos da Europa
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# ',
#                 page: '80',
#                 lang: 'pt'
#                 })-[r:BFO_0000050]-(t);
#
#
#                 MATCH  (e:Exerpt{uri: 'tag:stardog:api:analise_da_ancestralidades_genetica_da_populacao_de_sao_paulo_p_80'})
#                 MERGE  (p:Place{uri: 'tag:stardog:api:europa'})
#                 MERGE  (e)-[r:mentions]-(p);
#
#                 MATCH  (e:Exerpt{uri: 'tag:stardog:api:analise_da_ancestralidades_genetica_da_populacao_de_sao_paulo_p_80'})
#                 MERGE  (p:Place{uri: 'tag:stardog:api:nativo_americanos'})
#                 MERGE  (e)-[r:mentions]-(p);
#
#                 MATCH  (e:Exerpt{uri: 'tag:stardog:api:analise_da_ancestralidades_genetica_da_populacao_de_sao_paulo_p_80'})
#                 MERGE  (p:Place{uri: 'tag:stardog:api:asia'})
#                 MERGE  (e)-[r:mentions]-(p);
#
#             MATCH  (t:Thesis{uri: 'tag:stardog:api:analise_da_ancestralidades_genetica_da_populacao_de_sao_paulo'})
#             MERGE  (e:Exerpt{
#                 uri: 'tag:stardog:api:analise_da_ancestralidades_genetica_da_populacao_de_sao_paulo_p_81',
#                 text: '79
#
# APÊNDICE J – Admixture com os grupos da Ásia
#
#
#
#
#
#
#
#
#
#
#
#
#
#  80
#
# APÊNDICE L – Admixture com os grupos da Europa
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#  81
#
# APÊNDICE M – RMSE dos m odelos supervisionados
# (continua)
# Modelos  RMSE (std)
# 1 VotingClassifier: RegMLEMix (λ=0) e RegMLEMix (λ=200)  0,040  (0,003)
# 2 VotingClassifier: RegMLEMix (λ=0) e RegMLEMix (λ=300)  0,04 1 (0,003)
# 3 HierarchicalLocalClassifier:
# N1 - RegMLEMix (λ=0)
# N2 - VotingClassifier: RegMLEMix (λ=0) e RegMLEMix (λ=200)
# N3 - VotingClassifier: RegMLEMix  (λ=0) e RegML',
#                 page: '81',
#                 lang: 'pt'
#                 })-[r:BFO_0000050]-(t);
#
#
#                 MATCH  (e:Exerpt{uri: 'tag:stardog:api:analise_da_ancestralidades_genetica_da_populacao_de_sao_paulo_p_81'})
#                 MERGE  (p:Person{uri: 'tag:stardog:api:regmlemix'})
#                 MERGE  (e)-[r:mentions]-(p);
#
#                 MATCH  (e:Exerpt{uri: 'tag:stardog:api:analise_da_ancestralidades_genetica_da_populacao_de_sao_paulo_p_81'})
#                 MERGE  (p:Person{uri: 'tag:stardog:api:hierarchicallocalclassifier'})
#                 MERGE  (e)-[r:mentions]-(p);
#
#                 MATCH  (e:Exerpt{uri: 'tag:stardog:api:analise_da_ancestralidades_genetica_da_populacao_de_sao_paulo_p_81'})
#                 MERGE  (p:Place{uri: 'tag:stardog:api:n1'})
#                 MERGE  (e)-[r:mentions]-(p);
#
#                 MATCH  (e:Exerpt{uri: 'tag:stardog:api:analise_da_ancestralidades_genetica_da_populacao_de_sao_paulo_p_81'})
#                 MERGE  (p:Place{uri: 'tag:stardog:api:regml'})
#                 MERGE  (e)-[r:mentions]-(p);
#
#                 MATCH  (e:Exerpt{uri: 'tag:stardog:api:analise_da_ancestralidades_genetica_da_populacao_de_sao_paulo_p_81'})
#                 MERGE  (p:Place{uri: 'tag:stardog:api:regmlemix'})
#                 MERGE  (e)-[r:mentions]-(p);
#
#                 MATCH  (e:Exerpt{uri: 'tag:stardog:api:analise_da_ancestralidades_genetica_da_populacao_de_sao_paulo_p_81'})
#                 MERGE  (p:Place{uri: 'tag:stardog:api:asia'})
#                 MERGE  (e)-[r:mentions]-(p);
#
#                 MATCH  (e:Exerpt{uri: 'tag:stardog:api:analise_da_ancestralidades_genetica_da_populacao_de_sao_paulo_p_81'})
#                 MERGE  (p:Place{uri: 'tag:stardog:api:europa'})
#                 MERGE  (e)-[r:mentions]-(p);
#
#                 MATCH  (e:Exerpt{uri: 'tag:stardog:api:analise_da_ancestralidades_genetica_da_populacao_de_sao_paulo_p_81'})
#                 MERGE  (p:Place{uri: 'tag:stardog:api:n2__votingclassifier'})
#                 MERGE  (e)-[r:mentions]-(p);

# %% [markdown]
# Extrair texto do PDF

# %%
excerpt = extratc_text(thesis_uri + '.pdf')

# %%
thesis_repository['Thesis'][i]
# Out:
# 'tag:stardog:api:o_jeito_yanomami_de_pendurar_redes'

# %% [markdown]
# Adicionar excerpt no Grafo Neo4j

# %%
#Cypher query 
for n in range(len(excerpt)):
     
    excerpt_uri = thesis_repository['Thesis'][i] + '_p_' + str(n)
    excerpt_text = excerpt[n]['text']
    excerpt_page = n
    excerpt_lang = excerpt[n]['lang']
    #criando o dicionário para a inserção no grafo
    excerpt_dict = """{
        uri: '""" + excerpt_uri +"""',
        text: '""" + excerpt_text + """',
        page: '""" + str(excerpt_page) + """',
        lang: '""" + excerpt_lang + """'
    }"""
    
    #Criando a query para inserir o nó Exerpt
    query = """
    MATCH  (t:Thesis{uri: '""" + thesis_repository['Thesis'][i] +  """'})
    MERGE  (e:Exerpt""" + str(excerpt_dict) + """)-[r:BFO_0000050]-(t)

    """

    results = graph.query(query)
        
    #Criando as relações com as entidades
    for person in excerpt[n]['persons']:
        query = """
        MATCH  (e:Exerpt{uri: '""" + excerpt_uri + """'})
        MERGE  (p:Person{uri: 'tag:stardog:api:""" + person + """'})
        MERGE  (e)-[r:mentions]-(p)
        """
        results = graph.query(query)

    for gpe in excerpt[n]['gpes']:
        query = """
        MATCH  (e:Exerpt{uri: '""" + excerpt_uri + """'})
        MERGE  (p:Place{uri: 'tag:stardog:api:""" + gpe + """'})
        MERGE  (e)-[r:mentions]-(p)
        """
        results = graph.query(query)

# %%
os.remove(thesis_uri + '.pdf')

# %%
query = """
        MATCH  (e:Exerpt{uri: '""" + excerpt_uri + """'})
        MERGE  (p:Person{uri: 'tag:stardog:api:""" + excerpt[263]['persons'][0] + """'})
        MERGE  (e)-[r:mentions]-(p)
        """
print (query)
# Out:
#         MATCH  (e:Exerpt{uri: 'tag:stardog:api:o_jeito_yanomami_de_pendurar_redes_p_263'})
#         MERGE  (p:Person{uri: 'tag:stardog:api:wilbert'})
#         MERGE  (e)-[r:mentions]-(p)

# %%
print(query)
# Out:
# MERGE  (e:Exerpt{
#     uri: 'tag:stardog:api:revisao_narrativa_para_subsidiar_o_entendimento_do_panorama_da_cobertura_vacinal_em_criancas_menores_de_um_ano_de_idade_no_contexto_brasileiro_p_0',
#     text: '
#  UNIVERSIDADE DE SÃO PAULO
# FACULDADE DE MEDICINA
#
#
#
#
#
# SILVANETE MENDES MONTAGNINI
#
#
#
#
# REVISÃO NARRATIVA PAR A SUBSIDIAR O ENTEND IMENTO DO PANORAMA
# DA COBERTURA VACINAL  EM CRIANÇAS MENORES  DE UM ANO DE IDADE ,
# NO CONTEXTO BRASILEI RO
#
#
#
#
#
#
#
#
# São Paulo
# 2024
#
#  SILVANETE MENDES MONTAGNINI
#
#
#
#
#
# REVISÃO NARRATIVA PAR A SUBSIDIAR O ENTEND IMENTO DO PANORAMA
# DA COBERTURA VACINAL  EM CRIANÇAS MENORES  DE UM ANO DE IDADE ,
# NO CONTEXTO BRASILEI RO
#
#
#
# Versão corrigida
# Resolução CoPGr 6018/11, de 01 de novembro de 2011 .
# A versão or iginal está disponível na Biblioteca FMUSP.
#
#
#
# Dissertação apresentada à Faculdade de
# Medicina da Universid',
#     page: '0',
#     lang: 'pt'
# })-[r:BFO_0000050]-(t:Thesis{uri: 'tag:stardog:api:revisao_narrativa_para_subsidiar_o_entendimento_do_panorama_da_cobertura_vacinal_em_criancas_menores_de_um_ano_de_idade_no_contexto_brasileiro'})

# %%
excerpt[60]
# Out:
# {'text': '59 \n de ESAVIS vem se estabelecendo e ganhando maior dimensão, mas a autonomia na \nprodução de vacinas ainda é menor, em comparação à Índia . Fabricantes de países de \nbaixo e médio nível socioeconômico têm um papel cada vez maior no fornecimento de \nvacinas, e sua a entrada no mercado estimula quedas de preço das principais vacinas .  \n 60 \n 6. DISCUSSÃO  \n \nPelo exposto depreen de-se que, apesar do sucesso dos programas de vacinação, já \nhavia sinais de preocupação em relação à manutenção das conquistas obtidas. A queda \ndas coberturas vacinais vinha ocorrendo principalmente a partir de 2016.  \nA vacinação se caracteriza por interdep endência de responsabilidades individuais, \ncoletivas e institucionais. Esta dissertação priorizou a investigação sobre as \nresponsabilidades institucionais na queda das coberturas vacinais.  \nNesta revisão narrativa sobre a interrelação entre a cobertura vaci nal no Brasil e \noutros indicadores de qualidade do SUS foram encontrados dados que corroboram a \nqueda das coberturas vacinais, e dados que mostram fragilidades do SUS, no mesmo \nperíodo.  \nA cobertura vacinal registrada pelo antigo sistema API poderia estar s uperestimada. \nOs registros eram de doses aplicadas, e não de pessoas imunizadas, nominal, como passou \na ser feito a partir do SIPNI. Algumas vezes a cobertura ultrapassava a população alvo. \nMas as dificuldades na implantação dos novos sistemas de informaçã o nominais podem \nter contribuído para subregistro de doses de vacinas aplicadas. Entretanto, os dados do \ninquérito de cobertura vacinal conduzido por Barata e colaboradores  (2023) , baseado em \ndados da carteira vacinal das crianças investigadas, detectou qu eda da cobertura  vacinal, \ne queda progressiva  da cobertura de todas as vacinas que necessitam de mais de uma dose \npara completar o esquema de vacinação . Outros fatores estão influenciando a queda das \ncoberturas vacinais. Entretanto são evidentes os problem as dos sistemas de informação. \nSistemas complexos, com m últiplas entradas ; relatórios de doses aplicadas  inadequados, \nlevando a d ificuldade de acesso aos dados  e demora na consolidação dos dados das \ndiversas fontes ; perda de dados . Salienta -se que registro s inadequados podem levar a \ninterpretações errôneas do problema . \nSato e colaboradores (2023), em artigo em que analisaram a Cobertura Vacinal \n(CV), a homogeneidade das CV e os casos  de sarampo no Brasil de 2011 a 2021,  referem \nque, a partir de 2015, observ a-se queda progressiva  das CV e da homogeneidade, \nacentuando -se após 2020 em todas as regiões, particularmente  Norte e Nordeste. \nAglomerados de baixa CV foram  associados a piores indicadores d e desenvolvimento  \nhumano, desigualdade social e menor  acesso à E stratégia de Saúde da Família . Até 2014, \ntodas as regi ões brasileiras apresentavam  CV de primeira dose da vacina sarampo ( D1) \n 61 \n acima de 95%. A  partir de 2015, as coberturas começaram a cair  e, ap ós 2016, nenhuma \nregião atingiu CV acima  de 95%.  Os autores co mentam que, n o Brasil, as ações verticais \ndo PNI na década de 1980 contribu íram para diminuir o gradiente  social da CV e garantir \no acesso universal à vacinação no país. Os primeiros inquéritos nacionais  de CV \napontavam piores coberturas em  segmentos',
#  'lang': 'pt',
#  'persons': ['ap_os_2016', 'sato', 'barata'],
#  'gpes': ['nordeste',
#   'sus',
#   'brasil',
#   'pni',
#   'esavis',
#   'd1',
#   'saude_da_familia',
#   'india',
#   'cv',
#   'norte']}

# %%
def extratc_text_NER(tese_uri, tese_path):

    triplas = """ """

    # Processando o arquivo em PDF
    reader = PdfReader(tese_path)
    number_of_pages = len(reader.pages)

    # Iterando por cada página
    for page_number in range(number_of_pages):
        

        # Extraindo o texto da página
        if page_number == 0:
            page_text = (reader.pages[page_number].extract_text() + '\n ' 
                        + reader.pages[page_number+1].extract_text()[:400])
        else:
            
            if page_number == number_of_pages -1:
                page_text = (reader.pages[page_number-1].extract_text()[-400:] + '\n ' 
                            + reader.pages[page_number].extract_text())
            
            else:
                page_text = (reader.pages[page_number-1].extract_text()[-400:] + '\n ' 
                            + reader.pages[page_number].extract_text() + '\n ' 
                            + reader.pages[page_number+1].extract_text()[:400])  

        # Detectando o idioma do texto
        try:
            lang = detect(page_text)
        except:
            lang = None

        # Extraindo as entidades
        if lang == 'pt':
            doc = nlp_pt(page_text)
        if lang == 'en':
            doc = nlp_en(page_text)

        persons = []
        gpes = []
        #orgs = []
        for ent in doc.ents:
            if ent.label_ == "PER": #"PERSON":
                persons.append(process_uri(ent.text))
            if ent.label_ == "LOC": #"GPE":
                gpes.append(process_uri(ent.text))
            #if ent.label_ == "ORG":
            #    orgs.append(process_uri(ent.text))


            
        tripla = """
        stardog:""" + tese_uri + "__page_" + str(page_number + 1) + """ rdf:type bibo:Excerpt.
        stardog:""" + tese_uri +  """ <http://purl.obolibrary.org/obo/BFO_0000051> stardog:""" + tese_uri + "__page_" + str(page_number + 1 ) + """.
        stardog:""" + tese_uri + "__page_" + str(page_number + 1 ) + """ bibo:pages '""" + str(page_number + 1) +  """'. 
        """
        if lang == 'pt':
            tripla = tripla + "stardog:" + tese_uri + "__page_" + str(page_number + 1 ) + " <http://purl.org/dc/terms/description> '" + page_text.replace("'","").replace(u'\\', u' ') +  "'@pt."
        if lang == 'en':
            tripla = tripla + "stardog:" + tese_uri + "__page_" + str(page_number + 1 ) + " <http://purl.org/dc/terms/description> '" + page_text.replace("'","").replace(u'\\', u' ') +  "'@en."
        
        #print(set(persons), set(gpes))
        for per in set(persons):  
            tripla = tripla + """
            stardog:""" + per + """ rdf:type foaf:Person.
            stardog:""" + tese_uri + "__page_" + str(page_number + 1) + """ <https://schema.org/mentions> stardog:""" + per + """. 
            """

        for gpe in set(gpes): 
            tripla = tripla + """
            stardog:""" + gpe + """ rdf:type <https://schema.org/Place>.
            stardog:""" + tese_uri + "__page_" + str(page_number + 1) + """ <https://schema.org/mentions> stardog:""" + gpe + """. 
            """

        triplas = triplas + " " + tripla

    add_triplas_to_stardog(prefixos, triplas)
    return

# %%
#!python -m spacy download pt_core_news_lg
#!python -m spacy download en_core_web_lg
#%pip install -U scikit-learn

# %%
import os
import io
import stardog
import pandas as pd
import spacy
from spacy import displacy
from sklearn.cluster import DBSCAN
import numpy as np
import requests
from unidecode import unidecode
import re
import json
from langdetect import detect

# %% [markdown]
# ### Specify Stardog connection details
