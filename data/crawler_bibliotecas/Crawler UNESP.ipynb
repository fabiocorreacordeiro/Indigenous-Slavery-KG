# %%
#%pip install beautifulsoup4
#%pip install pip-system-certs

# %%
import requests
from bs4 import BeautifulSoup as bs
import pandas as pd
import os
from langchain_community.graphs import Neo4jGraph
from PyPDF2 import PdfReader
from langdetect import detect
import spacy
import re
from unidecode import unidecode
import time

# %% [markdown]
# Conectando ao Neo4j

# %%
from neo4j import GraphDatabase

# Neo4j variables
NEO4J_URL = os.getenv("NEO4J_URL")
NEO4J_USERNAME =os.getenv("NEO4J_USERNAME")
NEO4J_PASSWORD = os.getenv("NEO4J_PASSWORD")


graph = GraphDatabase.driver(NEO4J_URL, auth=(NEO4J_USERNAME, NEO4J_PASSWORD))

# %% [markdown]
# - Buscar os links para a tese no Neo4j
# - Buscar o link do PDF no repositório da universidade
# - Baixar o PDF
# - Extrair o texto do PDF

# %% [markdown]
# Buscar links para a tese no Neo4j

# %%
# Query to get theses and their repositories from the Neo4j database
# This query retrieves theses that are published by the Paulista Federal University (UNESP) and have not been processed yet.
query1 = """
MATCH (t:Thesis)-[:publisher]-(uni:University{uri:'tag:stardog:api:UNESP'})
WHERE NOT EXISTS {(t{processed:true})}
RETURN distinct(t["uri"]) as Thesis, t["repository"] as repository 
"""

# Alternative query to get theses that do not have excerpts and have been processed.
query2 = """ 
match (t:Thesis)-[:publisher]-(uni:University{uri:'tag:stardog:api:UNESP'})
where (not (t:Thesis)-[:BFO_0000050]-(:Exerpt)) and  exists {(t{processed:true})}
return distinct(t["uri"]) as Thesis, t["repository"] as repository
"""

# Query to retrive theses with few pages and their repositories.
query3 = """
MATCH (t:Thesis)-[:publisher]-(uni:University{uri:'tag:stardog:api:UNESP'})
Match (t:Thesis)-[:BFO_0000050]-(e:Exerpt)
RETURN count(e) as pages, t["uri"] as Thesis, t["repository"] as repository
 order by (pages) limit 40
"""

query4 = """
MATCH (t:Thesis)-[:publisher]-(uni:University{uri:'tag:stardog:api:UNESP'})
WHERE NOT EXISTS {(t{processed:true})}
RETURN distinct(t["uri"]) as Thesis, t["title"] as title 
"""

query5 = """
MATCH (t:Thesis {processed: true})-[:publisher]-(uni:University {uri: 'tag:stardog:api:UNESP'})
WHERE NOT (t)--(:Exerpt)
RETURN distinct(t["uri"]) as Thesis, t["title"] as title 
"""

graph = GraphDatabase.driver(NEO4J_URL, auth=(NEO4J_USERNAME, NEO4J_PASSWORD))
results = graph.execute_query(query4).records
graph.close()

#results = graph.query(query2)
# Convert the results to a DataFrame
#thesis_repository = pd.DataFrame(results, columns=["pages", "Thesis", "repository"])
thesis_repository = pd.DataFrame(results, columns=["Thesis", "title"])
thesis_repository = thesis_repository.reset_index(drop=True)  #[7:]
thesis_repository
# Out:
#                                                 Thesis  \
# 0    tag:stardog:api:grandes_objetos_na_amazonia_da...
# 1    tag:stardog:api:a_juventude_e_trabalho_no_camp...
# 2    tag:stardog:api:paisagem_e_territorio_de_resis...
# 3    tag:stardog:api:ensino_de_historia_e_cultura_i...
# 4    tag:stardog:api:prospeccao_de_plantas_aromatic...
# ..                                                 ...
# 566  tag:stardog:api:antiracismo_em_marilia_trajeto...
# 567  tag:stardog:api:primeiro_como_tragedia_segundo...
# 568  tag:stardog:api:posabolicao_e_a_luta_pela_cida...
# 569  tag:stardog:api:adolescentes_negros_entre_a_in...
# 570  tag:stardog:api:analise_de_sistemas_de_cogerac...
#
#                                                  title
# 0    Grandes objetos na Amazônia: das velhas lógica...
# 1    A juventude e trabalho no campo: desafios e pe...
# 2    Paisagem e território de resistência: as frent...
# 3    Ensino de história e cultura indígena: os disc...
# 4    Prospecção de plantas aromáticas e condimentar...
# ..                                                 ...
# 566  Anti-racismo em Marília: trajetórias e perspec...
# 567  Primeiro como tragédia, segundo como farsa: es...
# 568  Pós-Abolição e a luta pela cidadania negra na ...
# 569  Adolescentes negros: entre a inclusão e a resi...
# 570  Análise de sistemas de cogeração com gaseifica...
#
# [571 rows x 2 columns]

# %% [markdown]
# Criando as utils functions

# %%
# Funcao para coletar link do repositorio na página da BDTD

def get_repository_link(title):

    bdtd_url = 'https://bdtd.ibict.br/vufind/Search/Results?lookfor=' + title.replace(' ', '+') + '&type=Title' #&limit=1'
    #Fazer requisição e parsear o arquivo html
    try:
        f = requests.get(bdtd_url, verify=True).text#, verify=False) 
    except:
        print("Sleeping for 5 seconds before retrying... (get_repository_link)")
        time.sleep(5)
        try:
            f = requests.get(bdtd_url, verify=True).text#, verify=False) 
        except:
            print("Sleeping for 30 seconds before retrying... (get_repository_link)")
            time.sleep(30)
            f = requests.get(bdtd_url, verify=True).text#, verify=False)    
    soup = bs(f, "html.parser")

    #Coletando link para o repositório
    link_list = []
    for doc in soup.find_all('a', href=True):

        if (doc['href'].startswith('http://hdl.handle.net') |
            doc['href'].startswith('https://hdl.handle.net')):
            path = doc['href']
            link_list.append(path)
    if link_list != []:
        return list(set(link_list))[0]
    else:
        return None



# Funcao para coletar link do pdf

def get_pdf_link(url):
    
    #Fazer requisição e parsear o arquivo html
    try:
        f = requests.get(url, verify=True).text#, verify=False) 
    except:
        print("Sleeping for 5 seconds before retrying... (get_pdf_link)")
        time.sleep(5)
        try:
            f = requests.get(url, verify=True).text#, verify=False) 
        except:
            print("Sleeping for 30 seconds before retrying... (get_pdf_link)")
            time.sleep(30)
            f = requests.get(url, verify=True).text#, verify=False)    
    soup = bs(f, "html.parser")
    
    #Coletando link para as teses
    link_list = []
    for doc in soup.find_all('a', href=True):
        if doc['href'].startswith('/bitstream'):     # (doc['href'].endswith('.pdf')):# & doc['href'].startswith('/bitstream')):
            path = doc['href']
            prefix_uni = 'https://repositorio.unesp.br/server/api/core'
            link = prefix_uni + path
            link = link.replace('/download', '/content')
            link_list.append(link)
    if link_list != []:
        return list(set(link_list))
    else:
        return None
    


#fazer download do arquivo
def download_file(pdf_link, thesis_uri):


    # NOTE the stream=True parameter below
    try:
        r = requests.get(pdf_link, verify=True, stream=True)
    except:
        print("Sleeping for 5 seconds before retrying... (download_file)")
        time.sleep(5)
        try:
            r = requests.get(pdf_link, verify=True, stream=True)
        except:
            print("Sleeping for 30 seconds before retrying... (download_file)")
            time.sleep(30)
            r = requests.get(pdf_link, verify=True, stream=True)
    # raise_for_status() is not needed with stream=True
    # r.raise_for_status()
    with open('tese UNESP.pdf', 'wb') as f:
        for chunk in r.iter_content(chunk_size=8192):
            f.write(chunk)
    return 

#Carregando os modelos SpaCy para inglês e português 
nlp_en = spacy.load("en_core_web_lg")
nlp_pt = spacy.load("pt_core_news_lg")

# Funcão que recebe uma string e a limpar para ficar no formato aceitável para uma URI
def process_uri(x):
    return (re.sub('[^a-zA-Z0-9_ ]', '',
            unidecode(x.strip())
                        .replace(" ", "_")
                        .replace("[","")
                        .replace("]","")
                        .replace("?","")
                        .replace("'","")
                        .lower()))


# Função para extrair texto de uma tese em PDF e identificar entidades
def extratc_text(tese_path):
    
    # Processando o arquivo em PDF
    try:
        reader = PdfReader(tese_path)
    except:
        print(f"Erro ao ler o arquivo {tese_path}. ")
        excerpt = {}
        return excerpt
    number_of_pages = len(reader.pages)
    excerpt = {}
    

    # Iterando por cada página
    for page_number in range(number_of_pages):
        
        
        
        # Extraindo o texto da página
        try:
            if page_number == 0:
                try:
                    page_text = (reader.pages[page_number].extract_text() + '\n ' 
                                + reader.pages[page_number+1].extract_text()[:400])
                except:
                    page_text = reader.pages[page_number].extract_text()
            else:
                
                if page_number == number_of_pages -1:
                    try:
                        page_text = (reader.pages[page_number-1].extract_text()[-400:] + '\n ' 
                                    + reader.pages[page_number].extract_text())
                    except:
                        page_text = reader.pages[page_number].extract_text()
                
                else:
                    try:
                        page_text = (reader.pages[page_number-1].extract_text()[-400:] + '\n ' 
                                    + reader.pages[page_number].extract_text() + '\n ' 
                                    + reader.pages[page_number+1].extract_text()[:400])  
                    except:
                        page_text = reader.pages[page_number].extract_text()
        except:
            page_text = ''
        
        # Limpando page text         
        page_text = page_text.replace("'", "").replace('"', '')
        # Verifica se o último caractere é uma barra invertida
        if page_text != '':
            if page_text[-1] == '\\': 
                page_text = page_text[:-2]
        page_text = re.sub(r"[\ud800-\udfff]", " ", page_text)
        page_text = page_text.encode('utf-8').decode('utf-8')
        
        
        # Detectando o idioma do texto
        try:
            lang = detect(page_text)
            
        except:
            lang = 'Não_detectado'
        
        
        # Extraindo as entidades
        page_extracted = False
        if lang == 'pt':
            doc = nlp_pt(page_text)
            page_extracted = True
        if lang == 'en':
            doc = nlp_en(page_text)
            page_extracted = True
        

        if page_extracted:

            persons = []
            gpes = []
            #orgs = []
            for ent in doc.ents:
                if ent.label_ == "PER": #"PERSON":
                    persons.append(process_uri(ent.text))
                if ent.label_ == "LOC": #"GPE":
                    gpes.append(process_uri(ent.text))
                #if ent.label_ == "ORG":
                #    orgs.append(process_uri(ent.text))
                    
            excerpt[page_number] = {'text': page_text, 
                                    'lang': lang, 
                                    'persons': list(set(persons)), 
                                    'gpes': list(set(gpes)),
                                #'orgs': list(set(orgs))
                                }

    return excerpt

# %% [markdown]
# Iterando por todas as URI para extrair o texto e gravar no grafo NEO4j

# %%
# Gravar hora de início do processamento
start_time = pd.Timestamp.now()
parcial_time = pd.Timestamp.now()

for i in range(0,len(thesis_repository)):

    title = thesis_repository['title'][i].replace("?","").replace('-', ' ').replace('&', ' ')  
    repo = get_repository_link(title)

    # Coletando o link do PDF
    #url = thesis_repository['repository'][i]
    thesis_uri = thesis_repository['Thesis'][i][16:]
    pdf_link = get_pdf_link(repo)
    if pdf_link is not None:
        # Itereando pelos links de PDF encontrados (em alguns casos há outros materiais além da tese)
        for pdf_num in range(len(pdf_link)):
            print(f"{i} - Downloading and extracting: {thesis_uri} from {pdf_link[pdf_num]}")
            download_file(pdf_link[pdf_num], thesis_uri)

            # Extraindo o texto e entidades
            tese_path = 'tese UNESP.pdf'
            excerpt = extratc_text(tese_path)

            excerpts = []
            persons = []
            gpes = []

            # Salvando as triplas em CSV
            for n in excerpt.keys():

                excerpt_uri = thesis_repository['Thesis'][i] + '_pdf_' + str(pdf_num) + '_p_' + str(n)
                excerpt_text = excerpt[n]['text']
                # Verifica se o último caractere é uma barra invertida
                #if excerpt_text[-1] == '\\': 
                #    excerpt_text = excerpt_text[:-1]
                

                excerpt_page = 'pdf_' + str(pdf_num) + '_p_' + str(n)
                excerpt_lang = excerpt[n]['lang']
                
                excerpts.append([thesis_repository['Thesis'][i], excerpt_uri, excerpt_text, excerpt_page, excerpt_lang])
                    
                #Criando as relações com as entidades
                for person in excerpt[n]['persons']:
                    persons.append([excerpt_uri, 'tag:stardog:api:' + person])
                
                for gpe in excerpt[n]['gpes']:
                    gpes.append([excerpt_uri, 'tag:stardog:api:' + gpe])
            
            # Salvando os dados em CSV no diretório de importação do Neo4j
            pd.DataFrame(excerpts).to_csv('C:\\Users\\facordei\\.Neo4jDesktop\\relate-data\\dbmss\\dbms-792eabfc-5517-4220-ab29-30ef6ec3236e\\import\\excerptsUNESP.csv', index=False, header=False)
            pd.DataFrame(persons).to_csv('C:\\Users\\facordei\\.Neo4jDesktop\\relate-data\\dbmss\\dbms-792eabfc-5517-4220-ab29-30ef6ec3236e\\import\\personsUNESP.csv', index=False, header=False)
            pd.DataFrame(gpes).to_csv('C:\\Users\\facordei\\.Neo4jDesktop\\relate-data\\dbmss\\dbms-792eabfc-5517-4220-ab29-30ef6ec3236e\\import\\gpesUNESP.csv', index=False, header=False)

            #Deletando o arquivo PDF após o processamento
            os.remove('tese UNESP.pdf')

            print(f"Loading triplas: {thesis_uri}")

            # Importanto os dados para o Neo4j
            #Excerpts
            query = """
            LOAD CSV FROM 'file:///excerptsUNESP.csv'
            AS row
            MATCH  (t:Thesis{uri: row[0]})
            MERGE  (e:Exerpt{
                    uri: row[1],
                    text: row[2],
                    page: row[3],
                    lang: row[4]
                    })-[r:BFO_0000050]-(t);
            """
            graph = GraphDatabase.driver(NEO4J_URL, auth=(NEO4J_USERNAME, NEO4J_PASSWORD))
            results = graph.execute_query(query)
            graph.close()

            #Persons
            query = """
            LOAD CSV FROM 'file:///personsUNESP.csv'
            AS row
            MATCH  (e:Exerpt{uri: row[0]})
            MERGE  (p:Person{uri: row[1]})
            MERGE  (e)-[r:mentions]-(p);
            """
            graph = GraphDatabase.driver(NEO4J_URL, auth=(NEO4J_USERNAME, NEO4J_PASSWORD))
            results = graph.execute_query(query)
            graph.close()

            #GPEs
            query = """
            LOAD CSV FROM 'file:///gpesUNESP.csv'
            AS row
            MATCH  (e:Exerpt{uri: row[0]})
            MERGE  (p:Place{uri: row[1]})
            MERGE  (e)-[r:mentions]-(p);
            """
            graph = GraphDatabase.driver(NEO4J_URL, auth=(NEO4J_USERNAME, NEO4J_PASSWORD))
            results = graph.execute_query(query)
            graph.close()

            # Removendo os arquivos CSV após a importação
            os.remove('C:\\Users\\facordei\\.Neo4jDesktop\\relate-data\\dbmss\\dbms-792eabfc-5517-4220-ab29-30ef6ec3236e\\import\\excerptsUNESP.csv')
            os.remove('C:\\Users\\facordei\\.Neo4jDesktop\\relate-data\\dbmss\\dbms-792eabfc-5517-4220-ab29-30ef6ec3236e\\import\\personsUNESP.csv')
            os.remove('C:\\Users\\facordei\\.Neo4jDesktop\\relate-data\\dbmss\\dbms-792eabfc-5517-4220-ab29-30ef6ec3236e\\import\\gpesUNESP.csv')

            print(f"Total time: {pd.Timestamp.now() - start_time}")
            print(f"Partial time: {pd.Timestamp.now() - parcial_time}")
            # Atualizando a hora parcial
            parcial_time = pd.Timestamp.now()
    else:
        print(f"No PDF link found for {thesis_uri}")

    # gravando no grafo que a tese foi processada
    query = """
    MATCH  (t:Thesis{uri: \'""" + thesis_repository['Thesis'][i] +  """\'})
    SET t.processed = true
    SET t.repository = \'""" + str(repo) +  """\'
    """
    graph = GraphDatabase.driver(NEO4J_URL, auth=(NEO4J_USERNAME, NEO4J_PASSWORD))
    results = graph.execute_query(query)
    graph.close()
# Out:
# 0 - Downloading and extracting: grandes_objetos_na_amazonia_das_velhas_logicas_hegemonicas_as_novas_centralidades_insurgentes_os_impactos_da_hidreletrica_de_belo_monte_as_escalas_da_vida from https://repositorio.unesp.br/server/api/core/bitstreams/2ab6f135-e6df-4120-9fa9-c2a50a756d01/content
# Loading triplas: grandes_objetos_na_amazonia_das_velhas_logicas_hegemonicas_as_novas_centralidades_insurgentes_os_impactos_da_hidreletrica_de_belo_monte_as_escalas_da_vida
# Total time: 0 days 00:01:22.299648
# Partial time: 0 days 00:01:22.299648
# 1 - Downloading and extracting: a_juventude_e_trabalho_no_campo_desafios_e_perspectivas_de_jovens_assentados_em_areas_de_reforma_agraria_no_municipio_acailandiamaranhao from https://repositorio.unesp.br/server/api/core/bitstreams/16015e71-a98e-42a2-958e-35cf21693409/content
# Loading triplas: a_juventude_e_trabalho_no_campo_desafios_e_perspectivas_de_jovens_assentados_em_areas_de_reforma_agraria_no_municipio_acailandiamaranhao
# Total time: 0 days 00:02:25.605675
# Partial time: 0 days 00:01:03.306027
# 2 - Downloading and extracting: paisagem_e_territorio_de_resistencia_as_frentes_de_expansao_economica_e_a_cultura_xavante from https://repositorio.unesp.br/server/api/core/bitstreams/b24c8315-da2a-4b7d-bc28-114fdc2477e2/content
# Loading triplas: paisagem_e_territorio_de_resistencia_as_frentes_de_expansao_economica_e_a_cultura_xavante
# Total time: 0 days 00:02:57.335287
# Partial time: 0 days 00:00:31.729612
# 3 - Downloading and extracting: ensino_de_historia_e_cultura_indigena_os_discursos_do_curriculo_sao_paulo_faz_escola_20142017_e_dos_docentes_de_historia from https://repositorio.unesp.br/server/api/core/bitstreams/3daeec31-dd27-4801-8abc-049a85557178/content
# Loading triplas: ensino_de_historia_e_cultura_indigena_os_discursos_do_curriculo_sao_paulo_faz_escola_20142017_e_dos_docentes_de_historia
# Total time: 0 days 00:03:51.235161
# Partial time: 0 days 00:00:53.899874
# 4 - Downloading and extracting: prospeccao_de_plantas_aromaticas_e_condimentares_no_brasil from https://repositorio.unesp.br/server/api/core/bitstreams/cba2dd5e-1409-4629-b76c-2bd95a3e94dd/content
# Loading triplas: prospeccao_de_plantas_aromaticas_e_condimentares_no_brasil
# Total time: 0 days 00:04:56.352648
# Partial time: 0 days 00:01:05.117487
# 5 - Downloading and extracting: analise_de_transcriptomas_de_moscabranca_bemisia_tabaci_e_diversidade_genetica_em_cloroplasto_de_mandiocas_manihot_esculenta_infectadas_com_virus from https://repositorio.unesp.br/server/api/core/bitstreams/4f14773d-f239-4792-bfbd-c02d6b612dc8/content
# Loading triplas: analise_de_transcriptomas_de_moscabranca_bemisia_tabaci_e_diversidade_genetica_em_cloroplasto_de_mandiocas_manihot_esculenta_infectadas_com_virus
# Total time: 0 days 00:05:37.932848
# Partial time: 0 days 00:00:41.580200
# 6 - Downloading and extracting: ceramica_dos_surui_de_rondonia_e_dos_asurini_do_xingu_visoes_diferenciadas_de_povos_indigenas_da_amazonia from https://repositorio.unesp.br/server/api/core/bitstreams/b8cf3d38-adff-41aa-95d9-a412953edbe2/content
# Loading triplas: ceramica_dos_surui_de_rondonia_e_dos_asurini_do_xingu_visoes_diferenciadas_de_povos_indigenas_da_amazonia
# Total time: 0 days 00:06:34.405139
# Partial time: 0 days 00:00:56.472291
# 7 - Downloading and extracting: entre_lisboa_e_recife_ganhos_e_recompensas_no_brasil_holandes_16361654 from https://repositorio.unesp.br/server/api/core/bitstreams/b34db3ac-332f-42b9-a332-8690c618c311/content
# Loading triplas: entre_lisboa_e_recife_ganhos_e_recompensas_no_brasil_holandes_16361654
# Total time: 0 days 00:07:21.241376
# Partial time: 0 days 00:00:46.836237
# 8 - Downloading and extracting: praticas_espaciais_saude_e_complexo_de_catalina_caminho_do_desenvolvimento_no_brasil_e_na_colombia from https://repositorio.unesp.br/server/api/core/bitstreams/52683de5-5ba6-47b7-9b50-2277963e121e/content
# Loading triplas: praticas_espaciais_saude_e_complexo_de_catalina_caminho_do_desenvolvimento_no_brasil_e_na_colombia
# Total time: 0 days 00:07:49.490723
# Partial time: 0 days 00:00:28.249347
# 9 - Downloading and extracting: fatores_associados_a_plaquetopenia_em_pacientes_com_dengue_estudo_de_casocontrole from https://repositorio.unesp.br/server/api/core/bitstreams/318dac11-3dc4-4b26-a0b0-74fd9e04922f/content
# Loading triplas: fatores_associados_a_plaquetopenia_em_pacientes_com_dengue_estudo_de_casocontrole
# Total time: 0 days 00:08:09.082867
# Partial time: 0 days 00:00:19.592144
# 9 - Downloading and extracting: fatores_associados_a_plaquetopenia_em_pacientes_com_dengue_estudo_de_casocontrole from https://repositorio.unesp.br/server/api/core/bitstreams/61ff2aa2-c044-4d28-a142-3984422a15e1/content
# Loading triplas: fatores_associados_a_plaquetopenia_em_pacientes_com_dengue_estudo_de_casocontrole
# Total time: 0 days 00:08:16.016576
# Partial time: 0 days 00:00:06.933709
# 10 - Downloading and extracting: indigenas_cosmovisao_e_ensino_superior_algumas_tensoes from https://repositorio.unesp.br/server/api/core/bitstreams/13ba693d-ed32-402d-b3d0-4a3ef800820d/content
# Loading triplas: indigenas_cosmovisao_e_ensino_superior_algumas_tensoes
# Total time: 0 days 00:12:00.028099
# Partial time: 0 days 00:03:44.012523
# 11 - Downloading and extracting: de_selvagens_bugres_a_caboclos_fanaticos_as_representacoes_no_diario_da_tarde_durante_o_contestado_19121916 from https://repositorio.unesp.br/server/api/core/bitstreams/c9eea65d-ea48-409c-a179-dfb9a1893898/content
# Loading triplas: de_selvagens_bugres_a_caboclos_fanaticos_as_representacoes_no_diario_da_tarde_durante_o_contestado_19121916
# Total time: 0 days 00:12:35.046364
# Partial time: 0 days 00:00:35.017265
# 12 - Downloading and extracting: o_retorno_ao_territorio_a_partir_da_cidade_sistemas_territoriais_urbanoribeirinhos_em_parintins_am from https://repositorio.unesp.br/server/api/core/bitstreams/2533a65e-0ac5-4c1a-9ba5-75e4df27976a/content
# Loading triplas: o_retorno_ao_territorio_a_partir_da_cidade_sistemas_territoriais_urbanoribeirinhos_em_parintins_am
# Total time: 0 days 00:13:27.119018
# Partial time: 0 days 00:00:52.072654
# 13 - Downloading and extracting: efeito_do_biocarvao_e_adubacao_fosfatada_no_desenvolvimento_de_castanheira_do_brasil_em_latossolo_amarelo_da_amazonia_central from https://repositorio.unesp.br/server/api/core/bitstreams/c8c46142-faa0-4088-b9ce-55e72cdab29b/content
# Loading triplas: efeito_do_biocarvao_e_adubacao_fosfatada_no_desenvolvimento_de_castanheira_do_brasil_em_latossolo_amarelo_da_amazonia_central
# Total time: 0 days 00:13:56.912196
# Partial time: 0 days 00:00:29.793178
# 14 - Downloading and extracting: bebidas_e_bebedores_no_norte_do_brasil_a_epoca_da_conquista_holandesa_16241654 from https://repositorio.unesp.br/server/api/core/bitstreams/1aba2f2d-1796-4b53-99de-be22a4399c02/content
# Loading triplas: bebidas_e_bebedores_no_norte_do_brasil_a_epoca_da_conquista_holandesa_16241654
# Total time: 0 days 00:14:36.507882
# Partial time: 0 days 00:00:39.595686
# 14 - Downloading and extracting: bebidas_e_bebedores_no_norte_do_brasil_a_epoca_da_conquista_holandesa_16241654 from https://repositorio.unesp.br/server/api/core/bitstreams/fe2c6a6b-31c7-45d3-88f3-d22c1f1ef233/content
# Loading triplas: bebidas_e_bebedores_no_norte_do_brasil_a_epoca_da_conquista_holandesa_16241654
# Total time: 0 days 00:14:43.835444
# Partial time: 0 days 00:00:07.327562
# 15 - Downloading and extracting: terra_ou_morte_trajetoria_intelectual_e_revolucionaria_de_hugo_blanco_19581972 from https://repositorio.unesp.br/server/api/core/bitstreams/9a4bbd06-ca5e-4d4f-8b38-860e19c3d848/content
# Loading triplas: terra_ou_morte_trajetoria_intelectual_e_revolucionaria_de_hugo_blanco_19581972
# Total time: 0 days 00:15:19.640909
# Partial time: 0 days 00:00:35.805465
# 16 - Downloading and extracting: das_consonancias_e_dissonancias_um_paradoxo_o_universo_romanticocristao_de_chateaubriand from https://repositorio.unesp.br/server/api/core/bitstreams/b8ed2e71-1d12-44be-82a2-46ae4805ffde/content
# Loading triplas: das_consonancias_e_dissonancias_um_paradoxo_o_universo_romanticocristao_de_chateaubriand
# Total time: 0 days 00:16:26.191920
# Partial time: 0 days 00:01:06.551011
# 16 - Downloading and extracting: das_consonancias_e_dissonancias_um_paradoxo_o_universo_romanticocristao_de_chateaubriand from https://repositorio.unesp.br/server/api/core/bitstreams/b603bd3a-1c1e-48b5-bc98-ee3f25161116/content
# Loading triplas: das_consonancias_e_dissonancias_um_paradoxo_o_universo_romanticocristao_de_chateaubriand
# Total time: 0 days 00:16:33.760711
# Partial time: 0 days 00:00:07.568791
# 17 - Downloading and extracting: heterotopias_no_pais_do_milagre_os_corpos_indigenas_e_as_historias_filmadas from https://repositorio.unesp.br/server/api/core/bitstreams/70bce588-3afc-4371-9258-978a90d3029a/content
# Loading triplas: heterotopias_no_pais_do_milagre_os_corpos_indigenas_e_as_historias_filmadas
# Total time: 0 days 00:17:08.151316
# Partial time: 0 days 00:00:34.391591
# 18 - Downloading and extracting: estudo_fonetico_e_fonologico_da_lingua_yuhup from https://repositorio.unesp.br/server/api/core/bitstreams/b6334ad7-7077-47ec-a134-8ce1310cdbf9/content
# Loading triplas: estudo_fonetico_e_fonologico_da_lingua_yuhup
# Total time: 0 days 00:17:32.976954
# Partial time: 0 days 00:00:24.825646
# 19 - Downloading and extracting: os_principios_eticos_do_yoga_e_sua_pratica_pedagogica__estudo_das_repercussoes_midiaticas_a_partir_da_revista_guia_de_yoga from https://repositorio.unesp.br/server/api/core/bitstreams/aae21c3f-a661-4de5-8230-aead1ef58976/content
# Loading triplas: os_principios_eticos_do_yoga_e_sua_pratica_pedagogica__estudo_das_repercussoes_midiaticas_a_partir_da_revista_guia_de_yoga
# Total time: 0 days 00:17:57.140391
# Partial time: 0 days 00:00:24.162443
# 20 - Downloading and extracting: patrimonio_cultural_e_ambiental_especulacao_imobiliaria_e_formas_de_resistencia_o_caso_de_cotia_e_itapevi from https://repositorio.unesp.br/server/api/core/bitstreams/27cad8a2-9a70-4237-932f-605d05f8e278/content
# Loading triplas: patrimonio_cultural_e_ambiental_especulacao_imobiliaria_e_formas_de_resistencia_o_caso_de_cotia_e_itapevi
# Total time: 0 days 00:19:05.025813
# Partial time: 0 days 00:01:07.885422
# 20 - Downloading and extracting: patrimonio_cultural_e_ambiental_especulacao_imobiliaria_e_formas_de_resistencia_o_caso_de_cotia_e_itapevi from https://repositorio.unesp.br/server/api/core/bitstreams/9c2acf2c-aac5-4792-8bbc-6195dcbdaeca/content
# Loading triplas: patrimonio_cultural_e_ambiental_especulacao_imobiliaria_e_formas_de_resistencia_o_caso_de_cotia_e_itapevi
# Total time: 0 days 00:19:21.097498
# Partial time: 0 days 00:00:16.071685
# 21 - Downloading and extracting: ceramica_em_rede_caminhos_saberes_e_transformacoes_dos_andes_a_amazonia_shipiboconibo from https://repositorio.unesp.br/server/api/core/bitstreams/c5099cb8-1e80-482b-909e-a3520e1be19a/content
# Loading triplas: ceramica_em_rede_caminhos_saberes_e_transformacoes_dos_andes_a_amazonia_shipiboconibo
# Total time: 0 days 00:20:31.525010
# Partial time: 0 days 00:01:10.427512
# 22 - Downloading and extracting: bioimperialismo_e_direito_de_propriedade_intelectual_disputas_pelo_acesso_ao_cupuacu_e_ao_conhecimento_tradicional from https://repositorio.unesp.br/server/api/core/bitstreams/ddefaf4d-e60f-4a82-8988-977c7e90f90c/content
# Loading triplas: bioimperialismo_e_direito_de_propriedade_intelectual_disputas_pelo_acesso_ao_cupuacu_e_ao_conhecimento_tradicional
# Total time: 0 days 00:21:12.998994
# Partial time: 0 days 00:00:41.474983
# 23 - Downloading and extracting: a_trajetoria_literaria_e_a_relacao_com_a_intelectualidade_em_jose_maria_arguedas_19341969 from https://repositorio.unesp.br/server/api/core/bitstreams/d3d6faaa-cc82-4a92-98c2-0b7eccc942d2/content
# Loading triplas: a_trajetoria_literaria_e_a_relacao_com_a_intelectualidade_em_jose_maria_arguedas_19341969
# Total time: 0 days 00:21:56.790889
# Partial time: 0 days 00:00:43.790896
# 24 - Downloading and extracting: o_processo_de_criacao_da_palavra_no_espetaculo_recusa_interlingua_e_interculturalidade from https://repositorio.unesp.br/server/api/core/bitstreams/d7b3f9ad-611a-43a1-bad3-e190e2b99d30/content
# Loading triplas: o_processo_de_criacao_da_palavra_no_espetaculo_recusa_interlingua_e_interculturalidade
# Total time: 0 days 00:22:45.716679
# Partial time: 0 days 00:00:48.925790
# 25 - Downloading and extracting: etnobotanica_de_plantas_alimenticias_em_comunidades_indigenas_multietnicas_do_baixo_rio_uaupes__amazonas from https://repositorio.unesp.br/server/api/core/bitstreams/9f91f585-820a-4161-9c25-e88dc266d055/content
# Loading triplas: etnobotanica_de_plantas_alimenticias_em_comunidades_indigenas_multietnicas_do_baixo_rio_uaupes__amazonas
# Total time: 0 days 00:23:03.676667
# Partial time: 0 days 00:00:17.959988
# 25 - Downloading and extracting: etnobotanica_de_plantas_alimenticias_em_comunidades_indigenas_multietnicas_do_baixo_rio_uaupes__amazonas from https://repositorio.unesp.br/server/api/core/bitstreams/0dca4e65-2138-4c21-8f59-8a3697b55ea4/content
# Loading triplas: etnobotanica_de_plantas_alimenticias_em_comunidades_indigenas_multietnicas_do_baixo_rio_uaupes__amazonas
# Total time: 0 days 00:23:40.223144
# Partial time: 0 days 00:00:36.546477
# 26 - Downloading and extracting: por_uma_rebeldia_mundial_formacao_e_acao_territorial_da_via_campesina_no_brasil from https://repositorio.unesp.br/server/api/core/bitstreams/6290de13-53c0-4c3b-8b79-c355ddb62b83/content
# Loading triplas: por_uma_rebeldia_mundial_formacao_e_acao_territorial_da_via_campesina_no_brasil
# Total time: 0 days 00:25:01.468296
# Partial time: 0 days 00:01:21.245152
# 27 - Downloading and extracting: unati_yapey_aspectos_da_vida_terena_em_arariba from https://repositorio.unesp.br/server/api/core/bitstreams/52758e94-e00e-4168-8f92-391707ebb1f4/content
# Loading triplas: unati_yapey_aspectos_da_vida_terena_em_arariba
# Total time: 0 days 00:25:41.609078
# Partial time: 0 days 00:00:40.140782
# 28 - Downloading and extracting: formas_de_fosforo_substancias_humicas_e_nitrogenio_inorganico_em_areas_da_amazonia_ocidental from https://repositorio.unesp.br/server/api/core/bitstreams/e316bdb1-8d7e-4063-bbbc-975e6d67f16b/content
# Loading triplas: formas_de_fosforo_substancias_humicas_e_nitrogenio_inorganico_em_areas_da_amazonia_ocidental
# Total time: 0 days 00:26:08.122175
# Partial time: 0 days 00:00:26.513097
# 29 - Downloading and extracting: producao_de_sensor_polimerico_reforcado_com_nanotubos_de_carbono from https://repositorio.unesp.br/server/api/core/bitstreams/1b12e679-7fe1-4e94-b771-efbf0be94383/content
# Loading triplas: producao_de_sensor_polimerico_reforcado_com_nanotubos_de_carbono
# Total time: 0 days 00:26:40.069249
# Partial time: 0 days 00:00:31.947074
# 30 - Downloading and extracting: carreamento_nasaloral_de_staphylococcus_aureus_em_populacoes_indigenas_do_norte_e_sudeste_do_brasil_resistencia_antimicrobiana_virulencia_fatores_de_risco_e_epidemiologia_molecular from https://repositorio.unesp.br/server/api/core/bitstreams/6e07eaa6-3c64-4033-9ec7-1501d423586c/content
# Loading triplas: carreamento_nasaloral_de_staphylococcus_aureus_em_populacoes_indigenas_do_norte_e_sudeste_do_brasil_resistencia_antimicrobiana_virulencia_fatores_de_risco_e_epidemiologia_molecular
# Total time: 0 days 00:26:59.434443
# Partial time: 0 days 00:00:19.365194
# 30 - Downloading and extracting: carreamento_nasaloral_de_staphylococcus_aureus_em_populacoes_indigenas_do_norte_e_sudeste_do_brasil_resistencia_antimicrobiana_virulencia_fatores_de_risco_e_epidemiologia_molecular from https://repositorio.unesp.br/server/api/core/bitstreams/edbe4fd2-4a90-4b38-88a1-61e34f0fea7b/content
# Loading triplas: carreamento_nasaloral_de_staphylococcus_aureus_em_populacoes_indigenas_do_norte_e_sudeste_do_brasil_resistencia_antimicrobiana_virulencia_fatores_de_risco_e_epidemiologia_molecular
# Total time: 0 days 00:27:20.796007
# Partial time: 0 days 00:00:21.361564
# 31 - Downloading and extracting: desenvolvimento_de_um_composito_contendo_polimero_condutor_pedotpss_e_material_ormosil_gptms_com_aplicacao_na_fabricacao_de_dispositivos_eletroluminescentes from https://repositorio.unesp.br/server/api/core/bitstreams/e9df5971-7276-45b5-89b8-4c8b476bc0d1/content
# Loading triplas: desenvolvimento_de_um_composito_contendo_polimero_condutor_pedotpss_e_material_ormosil_gptms_com_aplicacao_na_fabricacao_de_dispositivos_eletroluminescentes
# Total time: 0 days 00:28:00.307312
# Partial time: 0 days 00:00:39.511305
# 32 - Downloading and extracting: monitoramento_de_danos_estruturais_utilizando_sensores_de_nanocompositos from https://repositorio.unesp.br/server/api/core/bitstreams/3e2e505c-472e-4618-90e0-04a66401ab19/content
# Loading triplas: monitoramento_de_danos_estruturais_utilizando_sensores_de_nanocompositos
# Total time: 0 days 00:28:40.067691
# Partial time: 0 days 00:00:39.760379
# 33 - Downloading and extracting: territorializacao_da_monocultura_de_eucalipto_e_os_impactos_sobre_a_estrutura_agraria_no_norte_do_espirito_santo from https://repositorio.unesp.br/server/api/core/bitstreams/69e7e8ec-89d6-47fd-ab43-f10baa2128e0/content
# Loading triplas: territorializacao_da_monocultura_de_eucalipto_e_os_impactos_sobre_a_estrutura_agraria_no_norte_do_espirito_santo
# Total time: 0 days 00:29:28.526762
# Partial time: 0 days 00:00:48.459071
# 34 - Downloading and extracting: tematica_indigena_nas_obras_de_heitor_villalobos_manducarara from https://repositorio.unesp.br/server/api/core/bitstreams/457bf69f-397b-4c9e-ad80-5565df5c11ab/content
# Loading triplas: tematica_indigena_nas_obras_de_heitor_villalobos_manducarara
# Total time: 0 days 00:30:05.158876
# Partial time: 0 days 00:00:36.632114
# 35 - Downloading and extracting: o_estado_plurinacional_na_bolivia_democratizacao_e_estabilidade_das_instituicoes_politicas from https://repositorio.unesp.br/server/api/core/bitstreams/5df6dd4e-0d1a-4fc4-b985-aadc42a15c56/content
# Loading triplas: o_estado_plurinacional_na_bolivia_democratizacao_e_estabilidade_das_instituicoes_politicas
# Total time: 0 days 00:30:36.391910
# Partial time: 0 days 00:00:31.233034
# 36 - Downloading and extracting: a_linguagem_politica_do_bom_governo_nas_leis_novas_francisco_de_vitoria_e_o_tomismo_espanhol_14931543 from https://repositorio.unesp.br/server/api/core/bitstreams/043c4667-92ae-477a-8e32-0aba25436766/content
# Loading triplas: a_linguagem_politica_do_bom_governo_nas_leis_novas_francisco_de_vitoria_e_o_tomismo_espanhol_14931543
# Total time: 0 days 00:31:11.018450
# Partial time: 0 days 00:00:34.626540
# 37 - Downloading and extracting: agroindustria_canavieira_no_interior_de_sao_paulo_o_caso_de_lencois_paulista from https://repositorio.unesp.br/server/api/core/bitstreams/b87e2484-46c0-4136-aeed-c6d4bfefa012/content
# Loading triplas: agroindustria_canavieira_no_interior_de_sao_paulo_o_caso_de_lencois_paulista
# Total time: 0 days 00:32:00.885340
# Partial time: 0 days 00:00:49.866890
# 38 - Downloading and extracting: analise_das_internacoes_por_condicoes_sensiveis_a_atencao_primaria_em_hospital_de_referencia_regional_spbrasil from https://repositorio.unesp.br/server/api/core/bitstreams/f8d53d0b-f3df-4139-beb0-6e9b7648c440/content
# Loading triplas: analise_das_internacoes_por_condicoes_sensiveis_a_atencao_primaria_em_hospital_de_referencia_regional_spbrasil
# Total time: 0 days 00:32:31.114038
# Partial time: 0 days 00:00:30.229617
# 39 - Downloading and extracting: conectividade_e_variabilidade_genetica_do_tubarao_galhabranca_oceanico_carcharhinus_longimanus_usando_dna_mitocondrial from https://repositorio.unesp.br/server/api/core/bitstreams/ccc91a89-01ba-458b-b077-ebe89bcdef87/content
# Loading triplas: conectividade_e_variabilidade_genetica_do_tubarao_galhabranca_oceanico_carcharhinus_longimanus_usando_dna_mitocondrial
# Total time: 0 days 00:32:59.075909
# Partial time: 0 days 00:00:27.961932
# 40 - Downloading and extracting: marcadores_de_tempo_apyawa_a_solidariedade_entre_os_povos_e_o_ambiente_que_habitam from https://repositorio.unesp.br/server/api/core/bitstreams/7875ffac-bed3-40c1-a695-5268d736103f/content
# Loading triplas: marcadores_de_tempo_apyawa_a_solidariedade_entre_os_povos_e_o_ambiente_que_habitam
# Total time: 0 days 00:33:53.099743
# Partial time: 0 days 00:00:54.022854
# 41 - Downloading and extracting: equipamentos_cineteatrais_usos_e_simbolizacoes_de_espacos_culturais_nas_capitais_centrooestinas_no_estado_novo from https://repositorio.unesp.br/server/api/core/bitstreams/4689e265-9a0e-449f-80d5-f873610fe59e/content
# Loading triplas: equipamentos_cineteatrais_usos_e_simbolizacoes_de_espacos_culturais_nas_capitais_centrooestinas_no_estado_novo
# Total time: 0 days 00:34:42.405219
# Partial time: 0 days 00:00:49.305476
# 42 - Downloading and extracting: diversidade_e_estrutura_populacional_do_tubaraoraposa_nos_oceanos_atlantico_e_indico_utilizando_marcadores_geneticos_moleculares from https://repositorio.unesp.br/server/api/core/bitstreams/1dcb5363-f7a1-4bc1-87af-11a1121b75a5/content
# Loading triplas: diversidade_e_estrutura_populacional_do_tubaraoraposa_nos_oceanos_atlantico_e_indico_utilizando_marcadores_geneticos_moleculares
# Total time: 0 days 00:35:03.145958
# Partial time: 0 days 00:00:20.740739
# 43 - Downloading and extracting: selecao_avaliacao_e_utilizacao_de_uma_levedura_personalizada_para_a_producao_de_etanol from https://repositorio.unesp.br/server/api/core/bitstreams/ffcab98e-01f6-4cd7-b20a-edd61e31ec89/content
# Loading triplas: selecao_avaliacao_e_utilizacao_de_uma_levedura_personalizada_para_a_producao_de_etanol
# Total time: 0 days 00:35:32.600024
# Partial time: 0 days 00:00:29.454066
# 44 - Downloading and extracting: estudo_etnobotanico_de_plantas_medicinais_na_terra_indigena_kaxinawa_de_nova_olinda_municipio_de_feijo_acre from https://repositorio.unesp.br/server/api/core/bitstreams/b9d6585d-4f50-4006-9efe-69c963e557f0/content
# Loading triplas: estudo_etnobotanico_de_plantas_medicinais_na_terra_indigena_kaxinawa_de_nova_olinda_municipio_de_feijo_acre
# Total time: 0 days 00:36:25.644607
# Partial time: 0 days 00:00:53.044583
# 45 - Downloading and extracting: estudo_de_flutuacoes_de_potenciais_em_pocos_quanticos_de_ingaasn from https://repositorio.unesp.br/server/api/core/bitstreams/43585bf1-0bd3-46c8-adc5-0c0179d9ea3c/content
# Loading triplas: estudo_de_flutuacoes_de_potenciais_em_pocos_quanticos_de_ingaasn
# Total time: 0 days 00:37:00.592894
# Partial time: 0 days 00:00:34.948287
# 46 - Downloading and extracting: a_formacao_de_professores_indigenas_na_universidade_do_estado_do_amazonas_avancos_e_desafios from https://repositorio.unesp.br/server/api/core/bitstreams/a726b604-9af5-42ea-8b3c-9d928655ff1f/content
# Loading triplas: a_formacao_de_professores_indigenas_na_universidade_do_estado_do_amazonas_avancos_e_desafios
# Total time: 0 days 00:37:58.866115
# Partial time: 0 days 00:00:58.273221
# 47 - Downloading and extracting: politica_nacional_de_saude_indigena_e_educacao_escolar_indigena_uma_analise_de_contingencias from https://repositorio.unesp.br/server/api/core/bitstreams/a5e490e2-438d-43f7-835e-306f4457a369/content
# Loading triplas: politica_nacional_de_saude_indigena_e_educacao_escolar_indigena_uma_analise_de_contingencias
# Total time: 0 days 00:38:43.799402
# Partial time: 0 days 00:00:44.933287
# 48 - Downloading and extracting: propriedades_estruturais_e_eletronicas_de_filmes_finos_de_pbo2_filmes_finos_de_tio2_e_filmes_finos_de_tio2_dopados_com_chumbo from https://repositorio.unesp.br/server/api/core/bitstreams/c601fd65-90aa-410d-b0f0-917ffd0d1554/content
# Loading triplas: propriedades_estruturais_e_eletronicas_de_filmes_finos_de_pbo2_filmes_finos_de_tio2_e_filmes_finos_de_tio2_dopados_com_chumbo
# Total time: 0 days 00:39:25.798326
# Partial time: 0 days 00:00:41.998924
# 49 - Downloading and extracting: central_hidroelectrica_chadin_2_luchas_por_el_territorio_en_el_peru from https://repositorio.unesp.br/server/api/core/bitstreams/a557002b-26b3-479f-8b04-b3b67c767549/content
# Loading triplas: central_hidroelectrica_chadin_2_luchas_por_el_territorio_en_el_peru
# Total time: 0 days 00:39:56.975027
# Partial time: 0 days 00:00:31.175714
# 50 - Downloading and extracting: frederico_carlos_hoehne_18821959_e_a_flora_medicinal_brasileira_a_pesquisa_botanica_na_cidade_de_sao_paulo_no_inicio_do_seculo_xx from https://repositorio.unesp.br/server/api/core/bitstreams/09210e57-6bd9-4046-9f64-7ab3870a358a/content
# Loading triplas: frederico_carlos_hoehne_18821959_e_a_flora_medicinal_brasileira_a_pesquisa_botanica_na_cidade_de_sao_paulo_no_inicio_do_seculo_xx
# Total time: 0 days 00:40:36.006055
# Partial time: 0 days 00:00:39.031028
# 51 - Downloading and extracting: impactos_e_resistencias_no_processo_de_estrangeirizacao_de_terras_em_rio_brilhante_ms_o_caso_dos_projetos_de_assentamentos_federais_sao_judas_margarida_alves_silvio_rodrigues_e_do_territorio_indigena_laranjeira_nanderu from https://repositorio.unesp.br/server/api/core/bitstreams/117fc7d7-9834-4324-ba67-86a632638e1a/content
# Loading triplas: impactos_e_resistencias_no_processo_de_estrangeirizacao_de_terras_em_rio_brilhante_ms_o_caso_dos_projetos_de_assentamentos_federais_sao_judas_margarida_alves_silvio_rodrigues_e_do_territorio_indigena_laranjeira_nanderu
# Total time: 0 days 00:41:56.261868
# Partial time: 0 days 00:01:20.255813
# 52 - Downloading and extracting: a_ceramica_dos_tapajo_e_o_desejo_de_formas_estudo_de_pecas_ceramicas_arqueologicas_mirando_potencias_criativas from https://repositorio.unesp.br/server/api/core/bitstreams/c62a9254-b7c1-4e62-b652-71f7385d0505/content
# Loading triplas: a_ceramica_dos_tapajo_e_o_desejo_de_formas_estudo_de_pecas_ceramicas_arqueologicas_mirando_potencias_criativas
# Total time: 0 days 00:43:03.554824
# Partial time: 0 days 00:01:07.292956
# 53 - Downloading and extracting: entre_a_literatura_e_a_politica_cultura_e_poder_na_representacao_do_indio_em_jose_de_alencar from https://repositorio.unesp.br/server/api/core/bitstreams/92f9eef0-2b97-475f-afa6-d1d454772533/content
# Loading triplas: entre_a_literatura_e_a_politica_cultura_e_poder_na_representacao_do_indio_em_jose_de_alencar
# Total time: 0 days 00:44:01.001932
# Partial time: 0 days 00:00:57.447108
# 54 - Downloading and extracting: papel_de_cepas_de_streptococcus_mutans_e_bifidobacterium_spp_na_etiologia_ou_protecao_contra_doencas_bucais from https://repositorio.unesp.br/server/api/core/bitstreams/b71c884a-ef02-429d-9770-1a559b536cd6/content
# Loading triplas: papel_de_cepas_de_streptococcus_mutans_e_bifidobacterium_spp_na_etiologia_ou_protecao_contra_doencas_bucais
# Total time: 0 days 00:44:32.306932
# Partial time: 0 days 00:00:31.305000
# 54 - Downloading and extracting: papel_de_cepas_de_streptococcus_mutans_e_bifidobacterium_spp_na_etiologia_ou_protecao_contra_doencas_bucais from https://repositorio.unesp.br/server/api/core/bitstreams/1f50af17-7f48-4b72-8c7d-aaf882f69523/content
# Loading triplas: papel_de_cepas_de_streptococcus_mutans_e_bifidobacterium_spp_na_etiologia_ou_protecao_contra_doencas_bucais
# Total time: 0 days 00:44:37.193256
# Partial time: 0 days 00:00:04.886324
# 55 - Downloading and extracting: produtividade_e_caracteristicas_fisicoquimicas_de_orapronobis_sob_adubacao_organica from https://repositorio.unesp.br/server/api/core/bitstreams/28cf1901-d9da-4b80-b21b-7f8afb148bd1/content
# Loading triplas: produtividade_e_caracteristicas_fisicoquimicas_de_orapronobis_sob_adubacao_organica
# Total time: 0 days 00:44:58.830837
# Partial time: 0 days 00:00:21.637581
# 56 - Downloading and extracting: estudo_da_viabilidade_de_sedimentos_formulados_para_a_aplicacao_em_estudos_ecotoxicologicos_e_quimicos_enfase_para_os_interferentes_endocrinos_17alfaetinilestradiol_e_17betaestradiol from https://repositorio.unesp.br/server/api/core/bitstreams/c12e9974-8e7c-42a0-a9eb-da693aa32d89/content
# Loading triplas: estudo_da_viabilidade_de_sedimentos_formulados_para_a_aplicacao_em_estudos_ecotoxicologicos_e_quimicos_enfase_para_os_interferentes_endocrinos_17alfaetinilestradiol_e_17betaestradiol
# Total time: 0 days 00:45:35.246592
# Partial time: 0 days 00:00:36.415755
# 57 - Downloading and extracting: shenipabu_miyui_literatura_e_mito from https://repositorio.unesp.br/server/api/core/bitstreams/785bf425-812d-4dc5-9298-040c2adaa60c/content
# Loading triplas: shenipabu_miyui_literatura_e_mito
# Total time: 0 days 00:46:34.341098
# Partial time: 0 days 00:00:59.095504
# 58 - Downloading and extracting: valorizacao_dos_saberes_astronomicos_de_uma_aldeia_indigena_terena_no_estado_de_sao_paulo from https://repositorio.unesp.br/server/api/core/bitstreams/b3c9e73f-4668-46bc-b0b3-271b7f73ffe4/content
# Loading triplas: valorizacao_dos_saberes_astronomicos_de_uma_aldeia_indigena_terena_no_estado_de_sao_paulo
# Total time: 0 days 00:46:58.210549
# Partial time: 0 days 00:00:23.869452
# 59 - Downloading and extracting: dinamica_populacional_de_zaprionus_indianus_gupta_1970_diptera_drosophilidae_e_caracterizacao_de_alguns_aspectos_biologicos from https://repositorio.unesp.br/server/api/core/bitstreams/a8ee66ab-2dab-4b1b-93c2-7085775e477f/content
# Loading triplas: dinamica_populacional_de_zaprionus_indianus_gupta_1970_diptera_drosophilidae_e_caracterizacao_de_alguns_aspectos_biologicos
# Total time: 0 days 00:47:35.108573
# Partial time: 0 days 00:00:36.897025
# 60 - Downloading and extracting: relato_e_realidade_nas_cartas_brasileiras_do_padre_antonio_vieira_uma_visao_cognitivista_e_cultural from https://repositorio.unesp.br/server/api/core/bitstreams/f21ba300-3e56-4853-82d6-fd3c752d2888/content
# Loading triplas: relato_e_realidade_nas_cartas_brasileiras_do_padre_antonio_vieira_uma_visao_cognitivista_e_cultural
# Total time: 0 days 00:48:01.781110
# Partial time: 0 days 00:00:26.672537
# 61 - Downloading and extracting: o_papel_da_comunicacao_no_processo_de_transferencia_de_tecnologia_da_embrapa_para_a_comunidade_indigena_campo_alegre_de_boa_vista_rr from https://repositorio.unesp.br/server/api/core/bitstreams/43b17fad-46f7-4e60-9990-5d1a863660c7/content
# Loading triplas: o_papel_da_comunicacao_no_processo_de_transferencia_de_tecnologia_da_embrapa_para_a_comunidade_indigena_campo_alegre_de_boa_vista_rr
# Total time: 0 days 00:48:31.206009
# Partial time: 0 days 00:00:29.424899
# 62 - Downloading and extracting: sinalizando_com_os_terena_um_estudo_do_uso_da_libras_e_de_sinais_nativos_por_indigenas_surdos from https://repositorio.unesp.br/server/api/core/bitstreams/19fb98ff-cd30-412a-a450-5771e55f33db/content
# Loading triplas: sinalizando_com_os_terena_um_estudo_do_uso_da_libras_e_de_sinais_nativos_por_indigenas_surdos
# Total time: 0 days 00:49:07.748679
# Partial time: 0 days 00:00:36.542670
# 63 - Downloading and extracting: traducao_comentada_de_peregrinaciones_de_una_alma_triste_de_juana_manuela_gorriti from https://repositorio.unesp.br/server/api/core/bitstreams/10c6120a-92c3-49b3-aa2b-85f7dfd01059/content
# Loading triplas: traducao_comentada_de_peregrinaciones_de_una_alma_triste_de_juana_manuela_gorriti
# Total time: 0 days 00:49:43.796198
# Partial time: 0 days 00:00:36.047519
# 64 - Downloading and extracting: influencia_das_propriedades_petrograficas_na_qualidade_do_polimento_de_rochas_ornamentais from https://repositorio.unesp.br/server/api/core/bitstreams/882b16ed-88c0-4676-b393-21ba0e70f567/content
# Loading triplas: influencia_das_propriedades_petrograficas_na_qualidade_do_polimento_de_rochas_ornamentais
# Total time: 0 days 00:50:35.699348
# Partial time: 0 days 00:00:51.903150
# 65 - Downloading and extracting: interferencia_de_sistemas_de_manejo_na_floresta_nacional_de_caxiuana_pa_nos_atributos_fisicos_e_quimicos_na_composicao_isotopica_de_solo_antropizado from https://repositorio.unesp.br/server/api/core/bitstreams/0ca66896-4843-4f59-b28c-18305990c514/content
# Loading triplas: interferencia_de_sistemas_de_manejo_na_floresta_nacional_de_caxiuana_pa_nos_atributos_fisicos_e_quimicos_na_composicao_isotopica_de_solo_antropizado
# Total time: 0 days 00:51:05.929337
# Partial time: 0 days 00:00:30.229989
# 66 - Downloading and extracting: fatores_de_risco_para_melasma_facial_em_mulheres_um_estudo_casocontrole from https://repositorio.unesp.br/server/api/core/bitstreams/fff0eaa7-d892-40f2-84a7-4bd73c9273fa/content
# Loading triplas: fatores_de_risco_para_melasma_facial_em_mulheres_um_estudo_casocontrole
# Total time: 0 days 00:51:30.109644
# Partial time: 0 days 00:00:24.180307
# 67 - Downloading and extracting: yudja_utaha_a_culinaria_juruna_no_parque_indigena_xingu__uma_contribuicao_ao_dicionario_bilingue_jurunaportugues from https://repositorio.unesp.br/server/api/core/bitstreams/1faa47de-67e6-4de8-be5f-f0e7ab822249/content
# Loading triplas: yudja_utaha_a_culinaria_juruna_no_parque_indigena_xingu__uma_contribuicao_ao_dicionario_bilingue_jurunaportugues
# Total time: 0 days 00:52:16.216360
# Partial time: 0 days 00:00:46.106716
# 68 - Downloading and extracting: efeitos_biologicos_do_laser_de_baixa_potencia_sobre_o_cultivo_de_celulastronco_mesenquimais_provenientes_do_tecido_adiposo_e_da_medula_ossea_de_caes from https://repositorio.unesp.br/server/api/core/bitstreams/3ef54edd-5fc4-433f-8f1b-7aa893997bb7/content
# Loading triplas: efeitos_biologicos_do_laser_de_baixa_potencia_sobre_o_cultivo_de_celulastronco_mesenquimais_provenientes_do_tecido_adiposo_e_da_medula_ossea_de_caes
# Total time: 0 days 00:52:42.070266
# Partial time: 0 days 00:00:25.853906
# 69 - Downloading and extracting: as_acoes_do_agrohidronegocio_o_papel_do_estado_e_as_formas_de_controle_do_trabalho_no_mato_grosso_do_sul from https://repositorio.unesp.br/server/api/core/bitstreams/bc8d3ba4-0e06-4d91-be3a-5849386ab7b1/content
# Loading triplas: as_acoes_do_agrohidronegocio_o_papel_do_estado_e_as_formas_de_controle_do_trabalho_no_mato_grosso_do_sul
# Total time: 0 days 00:53:43.610666
# Partial time: 0 days 00:01:01.540400
# 70 - Downloading and extracting: identificacao_de_padroes_da_dengue_em_municipios_paulistas_entre_os_anos_de_2003_a_2011 from https://repositorio.unesp.br/server/api/core/bitstreams/836e9fc8-4f9b-4560-801a-ace3a5af98ab/content
# Loading triplas: identificacao_de_padroes_da_dengue_em_municipios_paulistas_entre_os_anos_de_2003_a_2011
# Total time: 0 days 00:54:14.186749
# Partial time: 0 days 00:00:30.576083
# 71 - Downloading and extracting: relacoes_entre_tempo_e_evidencialidade_nas_linguas_indigenas_do_brasil_um_estudo_tipologicofuncional from https://repositorio.unesp.br/server/api/core/bitstreams/9ace0ab1-733f-418b-a4d5-3e9a015dccbb/content
# Loading triplas: relacoes_entre_tempo_e_evidencialidade_nas_linguas_indigenas_do_brasil_um_estudo_tipologicofuncional
# Total time: 0 days 00:54:43.078982
# Partial time: 0 days 00:00:28.892233
# 72 - Downloading and extracting: ensino_da_reanimacao_neonatal_para_parteiras_tradicionais__do_aprendizado_a_pratica_nas_regioes_norte_e_nordeste_do_brasil from https://repositorio.unesp.br/server/api/core/bitstreams/ae64f93a-d80b-4f3d-b1eb-98d2cd0d741a/content
# Loading triplas: ensino_da_reanimacao_neonatal_para_parteiras_tradicionais__do_aprendizado_a_pratica_nas_regioes_norte_e_nordeste_do_brasil
# Total time: 0 days 00:55:08.075560
# Partial time: 0 days 00:00:24.996578
# 73 - Downloading and extracting: concepcoes_sobre_a_questao_indigena_provincia_de_sao_paulo_18221834 from https://repositorio.unesp.br/server/api/core/bitstreams/1f1a8bdd-a7f1-462f-bf81-ceab4b0e3b12/content
# Loading triplas: concepcoes_sobre_a_questao_indigena_provincia_de_sao_paulo_18221834
# Total time: 0 days 00:56:00.562303
# Partial time: 0 days 00:00:52.486743
