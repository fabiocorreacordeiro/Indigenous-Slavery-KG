# %%
#%pip install beautifulsoup4
#%pip install pip-system-certs

# %%
import requests
from bs4 import BeautifulSoup as bs
import pandas as pd
import os
from langchain_community.graphs import Neo4jGraph
from PyPDF2 import PdfReader
from langdetect import detect
import spacy
import re
from unidecode import unidecode
import time

# %% [markdown]
# Conectando ao Neo4j

# %%
from neo4j import GraphDatabase

# Neo4j variables
NEO4J_URL = os.getenv("NEO4J_URL")
NEO4J_USERNAME =os.getenv("NEO4J_USERNAME")
NEO4J_PASSWORD = os.getenv("NEO4J_PASSWORD")


graph = GraphDatabase.driver(NEO4J_URL, auth=(NEO4J_USERNAME, NEO4J_PASSWORD))

# %% [markdown]
# - Buscar os links para a tese no Neo4j
# - Buscar o link do PDF no repositório da universidade
# - Baixar o PDF
# - Extrair o texto do PDF

# %% [markdown]
# Buscar links para a tese no Neo4j

# %%
# Query to get theses and their repositories from the Neo4j database
# This query retrieves theses that are published by the Federal University of Brasília (UNB) and have not been processed yet.
query1 = """
MATCH (t:Thesis)-[:publisher]-(uni:University{uri:'tag:stardog:api:UNB'})
WHERE NOT EXISTS {(t{processed:true})}
RETURN distinct(t["uri"]) as Thesis, t["repository"] as repository 
"""

# Alternative query to get theses that do not have excerpts and have been processed.
query2 = """ 
match (t:Thesis)-[:publisher]-(uni:University{uri:'tag:stardog:api:UNB'})
where (not (t:Thesis)-[:BFO_0000050]-(:Exerpt)) and  exists {(t{processed:true})}
return distinct(t["uri"]) as Thesis, t["repository"] as repository
"""

# Query to retrive theses with few pages and their repositories.
query3 = """
MATCH (t:Thesis)-[:publisher]-(uni:University{uri:'tag:stardog:api:UNB'})
Match (t:Thesis)-[:BFO_0000050]-(e:Exerpt)
RETURN count(e) as pages, t["uri"] as Thesis, t["repository"] as repository
 order by (pages) limit 40
"""

query4 = """
MATCH (t:Thesis)-[:publisher]-(uni:University{uri:'tag:stardog:api:UNB'})
WHERE NOT EXISTS {(t{processed:true})}
RETURN distinct(t["uri"]) as Thesis, t["title"] as title 
"""

graph = GraphDatabase.driver(NEO4J_URL, auth=(NEO4J_USERNAME, NEO4J_PASSWORD))
results = graph.execute_query(query4).records
graph.close()

#results = graph.query(query2)
# Convert the results to a DataFrame
#thesis_repository = pd.DataFrame(results, columns=["pages", "Thesis", "repository"])
thesis_repository = pd.DataFrame(results, columns=["Thesis", "title"])
thesis_repository = thesis_repository.reset_index(drop=True) 
thesis_repository
# Out:
#                                                  Thesis  \
# 0     tag:stardog:api:entre_monitoramento_terrestre_...
# 1     tag:stardog:api:psicologias_da_terra_narrativa...
# 2     tag:stardog:api:viver_a_terra_outramente__um_e...
# 3     tag:stardog:api:analise_sobre_a_presenca_da_te...
# 4     tag:stardog:api:fogo_e_movimento__uma_abordage...
# ...                                                 ...
# 1143  tag:stardog:api:meninas_negras_na_literatura_i...
# 1144  tag:stardog:api:conselhos_escolares_do_paranoa...
# 1145  tag:stardog:api:as_lutas_das_mulheres_negras__...
# 1146      tag:stardog:api:kehinde_simbolo_da_raca_negra
# 1147  tag:stardog:api:vozes_femininas_no_quilombo_da...
#
#                                                   title
# 0     Entre monitoramento terrestre e metodologias g...
# 1     Psicologias da terra narrativas indígenas para...
# 2     Viver a terra outramente : um estudo de caso s...
# 3     Análise sobre a presença da temática étnico-ra...
# 4     Fogo e movimento : uma abordagem tecnológica s...
# ...                                                 ...
# 1143  Meninas negras na literatura infantojuvenil : ...
# 1144  Conselhos escolares do Paranoá/DF : a particip...
# 1145  As lutas das mulheres negras : identidade e mi...
# 1146                     Kehinde, símbolo da raça negra
# 1147  Vozes femininas no "quilombo da literatura" : ...
#
# [1148 rows x 2 columns]

# %% [markdown]
# Criando as utils functions

# %%
# Funcao para coletar link do repositorio na página da BDTD

def get_repository_link(title):

    bdtd_url = 'https://bdtd.ibict.br/vufind/Search/Results?lookfor=' + title.replace(' ', '+') + '&type=Title&limit=1'
    #Fazer requisição e parsear o arquivo html
    try:
        f = requests.get(bdtd_url, verify=True).text#, verify=False) 
    except:
        print("Sleeping for 5 seconds before retrying...")
        time.sleep(5)
        try:
            f = requests.get(bdtd_url, verify=True).text#, verify=False) 
        except:
            print("Sleeping for 30 seconds before retrying...")
            time.sleep(30)
            f = requests.get(bdtd_url, verify=True).text#, verify=False)    
    soup = bs(f, "html.parser")

    #Coletando link para o repositório
    link_list = []
    for doc in soup.find_all('a', href=True):

        if (doc['href'].startswith('http://repositorio.unb.br') |
            doc['href'].startswith('http://repositorio2.unb.br') |
            doc['href'].startswith('https://repositorio.unb.br') |
            doc['href'].startswith('https://repositorio2.unb.br')):
            path = doc['href']
            link_list.append(path)
    if link_list != []:
        return list(set(link_list))[0]
    else:
        return None



# Funcao para coletar link do pdf

def get_pdf_link(url):
    
    #Fazer requisição e parsear o arquivo html
    try:
        f = requests.get(url, verify=True).text#, verify=False) 
    except:
        print("Sleeping for 5 seconds before retrying...")
        time.sleep(5)
        try:
            f = requests.get(url, verify=True).text#, verify=False) 
        except:
            print("Sleeping for 30 seconds before retrying...")
            time.sleep(30)
            f = requests.get(url, verify=True).text#, verify=False)    
    soup = bs(f, "html.parser")
    
    #Coletando link para as teses
    link_list = []
    for doc in soup.find_all('a', href=True):
        if doc['href'].startswith('/bitstream'):     # (doc['href'].endswith('.pdf')):# & doc['href'].startswith('/bitstream')):
            path = doc['href']
            prefix_uni = 'https://repositorio.unb.br'
            link = prefix_uni + path
            link_list.append(link)
    if link_list != []:
        return list(set(link_list))
    else:
        return None
    
    #return None

#fazer download do arquivo
def download_file(pdf_link, thesis_uri):


    # NOTE the stream=True parameter below
    try:
        r = requests.get(pdf_link, verify=True, stream=True)
    except:
        print("Sleeping for 5 seconds before retrying...")
        time.sleep(5)
        try:
            r = requests.get(pdf_link, verify=True, stream=True)
        except:
            print("Sleeping for 30 seconds before retrying...")
            time.sleep(30)
            r = requests.get(pdf_link, verify=True, stream=True)
    # raise_for_status() is not needed with stream=True
    # r.raise_for_status()
    with open('tese UNB.pdf', 'wb') as f:
        for chunk in r.iter_content(chunk_size=8192):
            f.write(chunk)
    return 

#Carregando os modelos SpaCy para inglês e português 
nlp_en = spacy.load("en_core_web_lg")
nlp_pt = spacy.load("pt_core_news_lg")

# Funcão que recebe uma string e a limpar para ficar no formato aceitável para uma URI
def process_uri(x):
    return (re.sub('[^a-zA-Z0-9_ ]', '',
            unidecode(x.strip())
                        .replace(" ", "_")
                        .replace("[","")
                        .replace("]","")
                        .replace("?","")
                        .replace("'","")
                        .lower()))


# Função para extrair texto de uma tese em PDF e identificar entidades
def extratc_text(tese_path):
    
    # Processando o arquivo em PDF
    try:
        reader = PdfReader(tese_path)
    except:
        print(f"Erro ao ler o arquivo {tese_path}. ")
        excerpt = {}
        return excerpt
    number_of_pages = len(reader.pages)
    excerpt = {}
    

    # Iterando por cada página
    for page_number in range(number_of_pages):
        
        
        
        # Extraindo o texto da página
        try:
            if page_number == 0:
                try:
                    page_text = (reader.pages[page_number].extract_text() + '\n ' 
                                + reader.pages[page_number+1].extract_text()[:400])
                except:
                    page_text = reader.pages[page_number].extract_text()
            else:
                
                if page_number == number_of_pages -1:
                    try:
                        page_text = (reader.pages[page_number-1].extract_text()[-400:] + '\n ' 
                                    + reader.pages[page_number].extract_text())
                    except:
                        page_text = reader.pages[page_number].extract_text()
                
                else:
                    try:
                        page_text = (reader.pages[page_number-1].extract_text()[-400:] + '\n ' 
                                    + reader.pages[page_number].extract_text() + '\n ' 
                                    + reader.pages[page_number+1].extract_text()[:400])  
                    except:
                        page_text = reader.pages[page_number].extract_text()
        except:
            page_text = ''
        
        # Limpando page text         
        page_text = page_text.replace("'", "").replace('"', '')
        # Verifica se o último caractere é uma barra invertida
        if page_text != '':
            if page_text[-1] == '\\': 
                page_text = page_text[:-1]
        page_text = re.sub(r"[\ud800-\udfff]", " ", page_text)
        page_text = page_text.encode('utf-8').decode('utf-8')
        
        
        # Detectando o idioma do texto
        try:
            lang = detect(page_text)
            
        except:
            lang = 'Não_detectado'
        
        
        # Extraindo as entidades
        page_extracted = False
        if lang == 'pt':
            doc = nlp_pt(page_text)
            page_extracted = True
        if lang == 'en':
            doc = nlp_en(page_text)
            page_extracted = True
        

        if page_extracted:

            persons = []
            gpes = []
            #orgs = []
            for ent in doc.ents:
                if ent.label_ == "PER": #"PERSON":
                    persons.append(process_uri(ent.text))
                if ent.label_ == "LOC": #"GPE":
                    gpes.append(process_uri(ent.text))
                #if ent.label_ == "ORG":
                #    orgs.append(process_uri(ent.text))
                    
            excerpt[page_number] = {'text': page_text, 
                                    'lang': lang, 
                                    'persons': list(set(persons)), 
                                    'gpes': list(set(gpes)),
                                #'orgs': list(set(orgs))
                                }

    return excerpt

# %% [markdown]
# Iterando por todas as URI para extrair o texto e gravar no grafo NEO4j

# %%
# Gravar hora de início do processamento
start_time = pd.Timestamp.now()
parcial_time = pd.Timestamp.now()

for i in range(0,len(thesis_repository)):

    title = thesis_repository['title'][i].replace("?","")
    repo = get_repository_link(title)

    # Coletando o link do PDF
    #url = thesis_repository['repository'][i]
    thesis_uri = thesis_repository['Thesis'][i][16:]
    pdf_link = get_pdf_link(repo)
    if pdf_link is not None:
        # Itereando pelos links de PDF encontrados (em alguns casos há outros materiais além da tese)
        for pdf_num in range(len(pdf_link)):
            print(f"{i} - Downloading and extracting: {thesis_uri} from {pdf_link[pdf_num]}")
            download_file(pdf_link[pdf_num], thesis_uri)

            # Extraindo o texto e entidades
            tese_path = 'tese UNB.pdf'
            excerpt = extratc_text(tese_path)

            excerpts = []
            persons = []
            gpes = []

            # Salvando as triplas em CSV
            for n in excerpt.keys():

                excerpt_uri = thesis_repository['Thesis'][i] + '_pdf_' + str(pdf_num) + '_p_' + str(n)
                excerpt_text = excerpt[n]['text']
                # Verifica se o último caractere é uma barra invertida
                #if excerpt_text[-1] == '\\': 
                #    excerpt_text = excerpt_text[:-1]
                

                excerpt_page = 'pdf_' + str(pdf_num) + '_p_' + str(n)
                excerpt_lang = excerpt[n]['lang']
                
                excerpts.append([thesis_repository['Thesis'][i], excerpt_uri, excerpt_text, excerpt_page, excerpt_lang])
                    
                #Criando as relações com as entidades
                for person in excerpt[n]['persons']:
                    persons.append([excerpt_uri, 'tag:stardog:api:' + person])
                
                for gpe in excerpt[n]['gpes']:
                    gpes.append([excerpt_uri, 'tag:stardog:api:' + gpe])
            
            # Salvando os dados em CSV no diretório de importação do Neo4j
            pd.DataFrame(excerpts).to_csv('C:\\Users\\facordei\\.Neo4jDesktop\\relate-data\\dbmss\\dbms-792eabfc-5517-4220-ab29-30ef6ec3236e\\import\\excerptsUNB.csv', index=False, header=False)
            pd.DataFrame(persons).to_csv('C:\\Users\\facordei\\.Neo4jDesktop\\relate-data\\dbmss\\dbms-792eabfc-5517-4220-ab29-30ef6ec3236e\\import\\personsUNB.csv', index=False, header=False)
            pd.DataFrame(gpes).to_csv('C:\\Users\\facordei\\.Neo4jDesktop\\relate-data\\dbmss\\dbms-792eabfc-5517-4220-ab29-30ef6ec3236e\\import\\gpesUNB.csv', index=False, header=False)

            #Deletando o arquivo PDF após o processamento
            os.remove('tese UNB.pdf')

            print(f"Loading triplas: {thesis_uri}")

            # Importanto os dados para o Neo4j
            #Excerpts
            query = """
            LOAD CSV FROM 'file:///excerptsUNB.csv'
            AS row
            MATCH  (t:Thesis{uri: row[0]})
            MERGE  (e:Exerpt{
                    uri: row[1],
                    text: row[2],
                    page: row[3],
                    lang: row[4]
                    })-[r:BFO_0000050]-(t);
            """
            graph = GraphDatabase.driver(NEO4J_URL, auth=(NEO4J_USERNAME, NEO4J_PASSWORD))
            results = graph.execute_query(query)
            graph.close()

            #Persons
            query = """
            LOAD CSV FROM 'file:///personsUNB.csv'
            AS row
            MATCH  (e:Exerpt{uri: row[0]})
            MERGE  (p:Person{uri: row[1]})
            MERGE  (e)-[r:mentions]-(p);
            """
            graph = GraphDatabase.driver(NEO4J_URL, auth=(NEO4J_USERNAME, NEO4J_PASSWORD))
            results = graph.execute_query(query)
            graph.close()

            #GPEs
            query = """
            LOAD CSV FROM 'file:///gpesUNB.csv'
            AS row
            MATCH  (e:Exerpt{uri: row[0]})
            MERGE  (p:Place{uri: row[1]})
            MERGE  (e)-[r:mentions]-(p);
            """
            graph = GraphDatabase.driver(NEO4J_URL, auth=(NEO4J_USERNAME, NEO4J_PASSWORD))
            results = graph.execute_query(query)
            graph.close()

            # Removendo os arquivos CSV após a importação
            os.remove('C:\\Users\\facordei\\.Neo4jDesktop\\relate-data\\dbmss\\dbms-792eabfc-5517-4220-ab29-30ef6ec3236e\\import\\excerptsUNB.csv')
            os.remove('C:\\Users\\facordei\\.Neo4jDesktop\\relate-data\\dbmss\\dbms-792eabfc-5517-4220-ab29-30ef6ec3236e\\import\\personsUNB.csv')
            os.remove('C:\\Users\\facordei\\.Neo4jDesktop\\relate-data\\dbmss\\dbms-792eabfc-5517-4220-ab29-30ef6ec3236e\\import\\gpesUNB.csv')

            print(f"Total time: {pd.Timestamp.now() - start_time}")
            print(f"Partial time: {pd.Timestamp.now() - parcial_time}")
            # Atualizando a hora parcial
            parcial_time = pd.Timestamp.now()
    else:
        print(f"No PDF link found for {thesis_uri}")

    # gravando no grafo que a tese foi processada
    query = """
    MATCH  (t:Thesis{uri: \'""" + thesis_repository['Thesis'][i] +  """\'})
    SET t.processed = true
    SET t.repository = \'""" + str(repo) +  """\'
    """
    graph = GraphDatabase.driver(NEO4J_URL, auth=(NEO4J_USERNAME, NEO4J_PASSWORD))
    results = graph.execute_query(query)
    graph.close()
# Out:
# No PDF link found for entre_monitoramento_terrestre_e_metodologias_geoespaciais__perspectivas_complementares_para_a_protecao_dos_povos_indigenas_autonomos
# 1 - Downloading and extracting: psicologias_da_terra_narrativas_indigenas_para_uma_psicologia_brasileira from https://repositorio.unb.br/bitstream/10482/49311/1/BrunaLedoTasso_DISSERT.pdf
# Loading triplas: psicologias_da_terra_narrativas_indigenas_para_uma_psicologia_brasileira
# Total time: 0 days 00:00:41.464422
# Partial time: 0 days 00:00:41.464422
# 2 - Downloading and extracting: viver_a_terra_outramente__um_estudo_de_caso_sobre_o_coletivo_indigena_caianas_e_a_etnoagroecologia_terena from https://repositorio.unb.br/bitstream/10482/46903/1/2023_J%c3%baliaSalom%c3%a3oDias.pdf
# Loading triplas: viver_a_terra_outramente__um_estudo_de_caso_sobre_o_coletivo_indigena_caianas_e_a_etnoagroecologia_terena
# Total time: 0 days 00:01:16.004236
# Partial time: 0 days 00:00:34.539814
# 3 - Downloading and extracting: analise_sobre_a_presenca_da_tematica_etnicoracial_em_materiais_didaticos_dos_anos_iniciais_do_ensino_fundamental_da_educacao_basica_do_distrito_federal from https://repositorio.unb.br/bitstream/10482/46550/1/2023_AnaPauladaSilvaPinheiro.pdf
# Loading triplas: analise_sobre_a_presenca_da_tematica_etnicoracial_em_materiais_didaticos_dos_anos_iniciais_do_ensino_fundamental_da_educacao_basica_do_distrito_federal
# Total time: 0 days 00:01:52.231330
# Partial time: 0 days 00:00:36.228092
# 4 - Downloading and extracting: fogo_e_movimento__uma_abordagem_tecnologica_sobre_a_agricultura_indigena_na_amazonia from https://repositorio.unb.br/bitstream/10482/46521/1/2023_LarissaMattosdaFonseca.pdf
# Loading triplas: fogo_e_movimento__uma_abordagem_tecnologica_sobre_a_agricultura_indigena_na_amazonia
# Total time: 0 days 00:02:24.411931
# Partial time: 0 days 00:00:32.179603
# 5 - Downloading and extracting: do_higienismo_ao_direito__analise_da_organizacao_do_sistema_publico_de_saude_para_o_povo_cigano_romani_no_brasil from https://repositorio.unb.br/bitstream/10482/44492/1/2022_MariaClaraRamosdaFonsecaSilva.pdf
# Loading triplas: do_higienismo_ao_direito__analise_da_organizacao_do_sistema_publico_de_saude_para_o_povo_cigano_romani_no_brasil
# Total time: 0 days 00:02:53.405404
# Partial time: 0 days 00:00:28.993473
# 6 - Downloading and extracting: o_golpe_e_de_estado__o_caso_do_golpe_de_2019_na_bolivia from https://repositorio.unb.br/bitstream/10482/44266/1/2022_LuizaCalvetteCosta.pdf
# Loading triplas: o_golpe_e_de_estado__o_caso_do_golpe_de_2019_na_bolivia
# Total time: 0 days 00:03:32.968224
# Partial time: 0 days 00:00:39.562820
# Total time: 0 days 00:21:38.621731
# Partial time: 0 days 00:00:33.587269
# 29 - Downloading and extracting: embates_entre_a_fronteira_extrativa_agraria_e_a_fronteira_socioambiental_no_sudoeste_paraense from https://repositorio.unb.br/bitstream/10482/44974/1/2022_GabrieldeMendon%c3%a7aDomingues.pdf
# Loading triplas: embates_entre_a_fronteira_extrativa_agraria_e_a_fronteira_socioambiental_no_sudoeste_paraense
# Total time: 0 days 00:22:35.127447
# Partial time: 0 days 00:00:56.505732
# 30 - Downloading and extracting: uma_nova_esperanca__reconstrucao_de_imaginarios_com_indigenas_mulheres_da_comunidade_indigena_nova_esperanca from https://repositorio.unb.br/bitstream/10482/48972/1/SthefaneFelipaDaCostaPereira_DISSERT.pdf
# Loading triplas: uma_nova_esperanca__reconstrucao_de_imaginarios_com_indigenas_mulheres_da_comunidade_indigena_nova_esperanca
# Total time: 0 days 00:23:20.792025
# Partial time: 0 days 00:00:45.663562
# 31 - Downloading and extracting: nanoemulsoes_de_oleo_de_copaiba__desenvolvimento_e_analise_de_sua_atividade_antiinflamatoria from https://repositorio.unb.br/bitstream/10482/44962/1/2022_MarinaCarvalhoSampaio.pdf
# Loading triplas: nanoemulsoes_de_oleo_de_copaiba__desenvolvimento_e_analise_de_sua_atividade_antiinflamatoria
# Total time: 0 days 00:24:03.433211
# Partial time: 0 days 00:00:42.641186
# 32 - Downloading and extracting: autodemarcacao_territorial_indigena__uma_analise_da_via_acionada_pelos_munduruku_face_o_abandono_das_demarcacoes from https://repositorio.unb.br/bitstream/10482/46874/1/2023_Lu%c3%adsdeCam%c3%b5esLimaBoaventura.pdf
# Loading triplas: autodemarcacao_territorial_indigena__uma_analise_da_via_acionada_pelos_munduruku_face_o_abandono_das_demarcacoes
# Total time: 0 days 00:24:30.804625
# Partial time: 0 days 00:00:27.371414
# 33 - Downloading and extracting: extracao_seletiva_de_madeiras_nativas_no_estado_do_para from https://repositorio.unb.br/bitstream/10482/45363/1/2022_JocemaraVianadeSouza.pdf
# Loading triplas: extracao_seletiva_de_madeiras_nativas_no_estado_do_para
# Total time: 0 days 00:24:54.563297
# Partial time: 0 days 00:00:23.758672
# 34 - Downloading and extracting: a_expansao_do_agronegocio_no_sudoeste_do_piaui_e_as_lutas_do_povo_gamela_na_rexistencia_no_territorio_indigena_de_laranjeiras from https://repositorio.unb.br/bitstream/10482/49618/1/JoseWylkBraunaDaSilva_DISSERT.pdf
# Loading triplas: a_expansao_do_agronegocio_no_sudoeste_do_piaui_e_as_lutas_do_povo_gamela_na_rexistencia_no_territorio_indigena_de_laranjeiras
# Total time: 0 days 00:25:25.593419
# Partial time: 0 days 00:00:31.029122
# 35 - Downloading and extracting: ouca_um_bom_conselho__povosfloresta_o_caso_da_uhe_belo_monte_monstro_e_praticas_reconstituintes_de_direitos_na_amazonia_brasileira from https://repositorio.unb.br/bitstream/10482/50660/1/2023_MatheusDeAndradeBueno_DISSERT.pdf
# Loading triplas: ouca_um_bom_conselho__povosfloresta_o_caso_da_uhe_belo_monte_monstro_e_praticas_reconstituintes_de_direitos_na_amazonia_brasileira
# Total time: 0 days 00:26:38.600700
# Partial time: 0 days 00:01:13.007281
# 36 - Downloading and extracting: a_tipografia_das_linguas_indigenas_brasileiras from https://repositorio.unb.br/bitstream/10482/42450/1/2021_RafaelDietzsch.pdf
# Loading triplas: a_tipografia_das_linguas_indigenas_brasileiras
# Total time: 0 days 00:28:01.355964
# Partial time: 0 days 00:01:22.755264
# 37 - Downloading and extracting: educacao_matematica_critica_na_perspectiva_de_educar_em_direitos_humanos__conexoes_entre_politicas_publicas_e_formacao_de_professores from https://repositorio.unb.br/bitstream/10482/38682/1/2020_LygianneBatistaVieira.pdf
# Loading triplas: educacao_matematica_critica_na_perspectiva_de_educar_em_direitos_humanos__conexoes_entre_politicas_publicas_e_formacao_de_professores
# Total time: 0 days 00:28:56.817035
# Partial time: 0 days 00:00:55.461071
# 38 - Downloading and extracting: de_prenda_a_resistencia__a_tradicao_cultural_da_arte_textil_como_praxis_transformadora_no_brasil_e_no_mexico from https://repositorio.unb.br/bitstream/10482/42833/1/2021_SylviaMariadaFonseca.pdf
# Loading triplas: de_prenda_a_resistencia__a_tradicao_cultural_da_arte_textil_como_praxis_transformadora_no_brasil_e_no_mexico
# Total time: 0 days 00:29:55.577547
# Partial time: 0 days 00:00:58.760512
# 39 - Downloading and extracting: estrategias_bioclimaticas_pasivas_para_el_confort_termico_de_viviendas_de_interes_social_mesoandinas__caso_ciudad_de_puno from https://repositorio.unb.br/bitstream/10482/42030/1/2021_DianaKarenPariQuispe.pdf
# Loading triplas: estrategias_bioclimaticas_pasivas_para_el_confort_termico_de_viviendas_de_interes_social_mesoandinas__caso_ciudad_de_puno
# Total time: 0 days 00:31:04.451681
# Partial time: 0 days 00:01:08.874134
# 40 - Downloading and extracting: fronteiras_improvaveis_entre_tempos_e_direitos__constitucionalismo_compartilhado_entre_os_sistemas_de_justica_estatal_e_mebengokre_kayapo_no_acidente_do_gol_1907 from https://repositorio.unb.br/bitstream/10482/39079/1/2020_LucasCravodeOliveira.pdf
# Loading triplas: fronteiras_improvaveis_entre_tempos_e_direitos__constitucionalismo_compartilhado_entre_os_sistemas_de_justica_estatal_e_mebengokre_kayapo_no_acidente_do_gol_1907
# Total time: 0 days 00:31:38.229998
# Partial time: 0 days 00:00:33.778317
# 41 - Downloading and extracting: a_evasao_universitaria_na_unb__uma_pesquisa_nos_cursos_de_licenciatura_em_ciencias_naturais_diurno_e_noturno_da_faculdade_unb_de_planaltina__fup_no_periodo_de_2013_a_2017 from https://repositorio.unb.br/bitstream/10482/38232/1/2019_ArilthonRomuloCavalcanteCasimiro.pdf
# Loading triplas: a_evasao_universitaria_na_unb__uma_pesquisa_nos_cursos_de_licenciatura_em_ciencias_naturais_diurno_e_noturno_da_faculdade_unb_de_planaltina__fup_no_periodo_de_2013_a_2017
# Total time: 0 days 00:32:15.013547
# Partial time: 0 days 00:00:36.783549
# 42 - Downloading and extracting: legislacao_para_imaginaria_sacra_na_america_portuguesa__analise_a_partir_das_constituicoes_primeiras_do_arcebispado_da_bahia_sec_xviii from https://repositorio.unb.br/bitstream/10482/40856/1/2020_DaniloPintodosSantos.pdf
# Loading triplas: legislacao_para_imaginaria_sacra_na_america_portuguesa__analise_a_partir_das_constituicoes_primeiras_do_arcebispado_da_bahia_sec_xviii
# Total time: 0 days 00:32:49.492913
# Partial time: 0 days 00:00:34.479366
# 43 - Downloading and extracting: liberdade_terra_e_uniao_na_almofala_dos_tremembe__um_diptico_etnograficoficcional from https://repositorio.unb.br/bitstream/10482/39012/1/2020_JanainaFerreiraFernandes.pdf
# Loading triplas: liberdade_terra_e_uniao_na_almofala_dos_tremembe__um_diptico_etnograficoficcional
# Total time: 0 days 00:34:25.300277
# Partial time: 0 days 00:01:35.807364
# 44 - Downloading and extracting: o_mundo_de_justiniano_sawrepte__sonhos_espiritos_e_mortos_no_brasil_central from https://repositorio.unb.br/bitstream/10482/39114/1/2020_OdilonRodriguesdeMoraisNeto.pdf
# Loading triplas: o_mundo_de_justiniano_sawrepte__sonhos_espiritos_e_mortos_no_brasil_central
# Total time: 0 days 00:35:25.561863
# Partial time: 0 days 00:01:00.261586
# 45 - Downloading and extracting: realidades_miticas_e_doencas_historicas__experiencias_de_adoecimento_cura_e_morte_nas_narrativas_de_indigenas_fulnio_no_brasil_e_purhepecha_no_mexico from https://repositorio.unb.br/bitstream/10482/43297/1/2021_LilianeCunhadeSouza.pdf
# Loading triplas: realidades_miticas_e_doencas_historicas__experiencias_de_adoecimento_cura_e_morte_nas_narrativas_de_indigenas_fulnio_no_brasil_e_purhepecha_no_mexico
# Total time: 0 days 00:37:32.685946
# Partial time: 0 days 00:02:07.124083
# 46 - Downloading and extracting: quatrocentos_anos_de_civilizacao_outras_racas_outros_costumes__o_sentido_do_realismo_historico_em_caetes_de_graciliano_ramos from https://repositorio.unb.br/bitstream/10482/42445/3/2021_LucianaCarvalhodeAguiarSimoes.pdf
# Loading triplas: quatrocentos_anos_de_civilizacao_outras_racas_outros_costumes__o_sentido_do_realismo_historico_em_caetes_de_graciliano_ramos
# Total time: 0 days 00:38:19.924097
# Partial time: 0 days 00:00:47.238151
# 47 - Downloading and extracting: urnas_funerarias__os_marajoaras_e_suas_representacoes_visuais from https://repositorio.unb.br/bitstream/10482/40268/1/2020_WanderMarcelBarrosChaves.pdf
# Loading triplas: urnas_funerarias__os_marajoaras_e_suas_representacoes_visuais
# Total time: 0 days 00:38:54.222301
# Partial time: 0 days 00:00:34.298204
# 48 - Downloading and extracting: retomando_o_que_e_nosso__uma_analise_das_retomadas_de_terra_dos_terena_de_buriti from https://repositorio.unb.br/bitstream/10482/41871/1/2021_MarinadeBarrosFonseca.pdf
# Loading triplas: retomando_o_que_e_nosso__uma_analise_das_retomadas_de_terra_dos_terena_de_buriti
# Total time: 0 days 00:39:31.767294
# Partial time: 0 days 00:00:37.544993
# 49 - Downloading and extracting: a_estrategia_de_inovacao_social_realizada_pela_embrapa_e_a_transferencia_de_tecnologia_em_redes_de_colaboracao_por_meio_das_unidades_mistas_de_pesquisa_e_inovacao__umipi from https://repositorio.unb.br/bitstream/10482/42194/1/2021_L%c3%adbiaCristinaXavierSantos.pdf

# %%
title = thesis_repository['title'][0].replace("?","")
print(title)
repo = get_repository_link(title)
print(repo)
# Out:
# Entre monitoramento terrestre e metodologias geoespaciais : perspectivas complementares para a proteção dos povos indígenas autônomos
# None
