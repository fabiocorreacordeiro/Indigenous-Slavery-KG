# %%
#%pip install beautifulsoup4
#%pip install pip-system-certs
#% -m pip install ipykernel -U --force-reinstall

# %%
import requests
from bs4 import BeautifulSoup as bs
import pandas as pd
import os
from langchain_community.graphs import Neo4jGraph
from PyPDF2 import PdfReader
import fitz
from langdetect import detect
import spacy
import re
from unidecode import unidecode
import time

# %% [markdown]
# Conectando ao Neo4j

# %%
from neo4j import GraphDatabase

# Neo4j variables
NEO4J_URL = os.getenv("NEO4J_URL")
NEO4J_USERNAME =os.getenv("NEO4J_USERNAME")
NEO4J_PASSWORD = os.getenv("NEO4J_PASSWORD")


graph = GraphDatabase.driver(NEO4J_URL, auth=(NEO4J_USERNAME, NEO4J_PASSWORD))

# %% [markdown]
# - Buscar os links para a tese no Neo4j
# - Buscar o link do PDF no repositório da universidade
# - Baixar o PDF
# - Extrair o texto do PDF

# %% [markdown]
# Buscar links para a tese no Neo4j

# %%
# Query to get theses and their repositories from the Neo4j database
# This query retrieves theses that are published by the Federal University of Paraná (UFPR) and have not been processed yet.
query1 = """
MATCH (t:Thesis)-[:publisher]-(uni:University{uri:'tag:stardog:api:UFPR'})
WHERE NOT EXISTS {(t{processed:true})}
RETURN distinct(t["uri"]) as Thesis, t["repository"] as repository 
"""

# Alternative query to get theses that do not have excerpts and have been processed.
query2 = """ 
match (t:Thesis)-[:publisher]-(uni:University{uri:'tag:stardog:api:UFPR'})
where (not (t:Thesis)-[:BFO_0000050]-(:Exerpt)) and  exists {(t{processed:true})}
return distinct(t["uri"]) as Thesis, t["repository"] as repository
"""

# Query to retrive theses with few pages and their repositories.
query3 = """
MATCH (t:Thesis)-[:publisher]-(uni:University{uri:'tag:stardog:api:UFPR'})
Match (t:Thesis)-[:BFO_0000050]-(e:Exerpt)
RETURN count(e) as pages, t["uri"] as Thesis, t["repository"] as repository
 order by (pages) limit 40
"""

query4 = """
MATCH (t:Thesis)-[:publisher]-(uni:University{uri:'tag:stardog:api:UFPR'})
WHERE NOT EXISTS {(t{processed:true})}
RETURN distinct(t["uri"]) as Thesis, t["title"] as title 
"""

query5 = """
MATCH (t:Thesis {processed: true})-[:publisher]-(uni:University {uri: 'tag:stardog:api:UFPR'})
WHERE NOT (t)--(:Exerpt)
RETURN distinct(t["uri"]) as Thesis, t["title"] as title 
"""

graph = GraphDatabase.driver(NEO4J_URL, auth=(NEO4J_USERNAME, NEO4J_PASSWORD))
results = graph.execute_query(query1).records
graph.close()

#results = graph.query(query2)
# Convert the results to a DataFrame
#thesis_repository = pd.DataFrame(results, columns=["pages", "Thesis", "repository"])
thesis_repository = pd.DataFrame(results, columns=["Thesis", "repository"])
thesis_repository = thesis_repository.reset_index(drop=True) 
thesis_repository
# Out:
#                                                 Thesis  \
# 0    tag:stardog:api:armas_polvora_e_chumbo_a_expan...
# 1    tag:stardog:api:entre_a_liberdade_e_a_administ...
# 2    tag:stardog:api:a_dinamica_agricola_do_norte_d...
# 3    tag:stardog:api:usos_cotidianos_do_parentesco_...
# 4    tag:stardog:api:a_educacao_escolar_no_processo...
# ..                                                 ...
# 345  tag:stardog:api:biologia_de_aegla_parana_schmi...
# 346  tag:stardog:api:a_construcao_do_20_de_novembro...
# 347  tag:stardog:api:relacoes_entre_historia_e_ficc...
# 348  tag:stardog:api:a_construcao_de_identidades_na...
# 349  tag:stardog:api:memoria_e_identidade_na_litera...
#
#                                             repository
# 0    http://repositorio.ufsc.br/xmlui/handle/123456...
# 1                    https://hdl.handle.net/1884/35350
# 2                    https://hdl.handle.net/1884/28953
# 3                    https://hdl.handle.net/1884/27741
# 4                    https://hdl.handle.net/1884/32303
# ..                                                 ...
# 345                  https://hdl.handle.net/1884/63797
# 346                  https://hdl.handle.net/1884/61949
# 347                  https://hdl.handle.net/1884/48876
# 348                  https://hdl.handle.net/1884/58007
# 349                  https://hdl.handle.net/1884/52800
#
# [350 rows x 2 columns]

# %% [markdown]
# Criando as utils functions

# %%
# Funcao para coletar link do repositorio na página da BDTD

#def get_repository_link(title):

#    bdtd_url = 'https://bdtd.ibict.br/vufind/Search/Results?lookfor=' + title.replace(' ', '+') + '&type=Title' #&limit=1'
    #Fazer requisição e parsear o arquivo html
#    try:
#        f = requests.get(bdtd_url, verify=True).text#, verify=False) 
#    except:
#        print("Sleeping for 5 seconds before retrying... (get_repository_link)")
#        time.sleep(5)
#        try:
#            f = requests.get(bdtd_url, verify=True).text#, verify=False) 
#        except:
#            print("Sleeping for 30 seconds before retrying... (get_repository_link)")
#            time.sleep(30)
#            f = requests.get(bdtd_url, verify=True).text#, verify=False)    
#    soup = bs(f, "html.parser")

    #Coletando link para o repositório
#    link_list = []
#    for doc in soup.find_all('a', href=True):

#        if (doc['href'].startswith('https://repositorio.ufsc.br/') |
#            doc['href'].startswith('http://repositorio.ufsc.br/')):
#            path = doc['href']
#            link_list.append(path)
#    if link_list != []:
#        return list(set(link_list))[0]
#    else:
#        return None



# Funcao para coletar link do pdf

def get_pdf_link(url):
    
    headers = {
    'User-Agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/58.0.3029.110 Safari/537.3'
                }

    #Fazer requisição e parsear o arquivo html
    try:
        f = requests.get(url, headers=headers, verify=True).text#, verify=False) 
        
    except:
        print("Sleeping for 5 seconds before retrying... (get_pdf_link)")
        time.sleep(5)
        try:
            f = requests.get(url, headers=headers, verify=True).text#, verify=False) 
        except:
            print("Sleeping for 30 seconds before retrying... (get_pdf_link)")
            time.sleep(30)
            f = requests.get(url, headers=headers, verify=True).text#, verify=False)    
    soup = bs(f, "html.parser")
    
    #Coletando link para as teses
    link_list = []
    for doc in soup.find_all('a', href=True):
        if doc['href'].startswith('/xmlui/bitstream/'):     # (doc['href'].endswith('.pdf')):# & doc['href'].startswith('/bitstream')):
            path = doc['href']
            prefix_uni = 'https://acervodigital.ufpr.br'
            link = prefix_uni + path
            link_list.append(link)
    if link_list != []:
        return list(set(link_list))
    else:
        return None
    
    #return None

#fazer download do arquivo
def download_file(pdf_link, thesis_uri):

    headers = {
    'User-Agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/58.0.3029.110 Safari/537.3'
                }
    
    # NOTE the stream=True parameter below
    try:
        r = requests.get(pdf_link, headers=headers, verify=True, stream=True)
    except:
        print("Sleeping for 5 seconds before retrying... (download_file)")
        time.sleep(5)
        try:
            r = requests.get(pdf_link, headers=headers, verify=True, stream=True)
        except:
            print("Sleeping for 30 seconds before retrying... (download_file)")
            time.sleep(30)
            r = requests.get(pdf_link, headers=headers, verify=True, stream=True)
    # raise_for_status() is not needed with stream=True
    # r.raise_for_status()
    with open('tese UFPR.pdf', 'wb') as f:
        for chunk in r.iter_content(chunk_size=8192):
            f.write(chunk)
    return 

#Carregando os modelos SpaCy para inglês e português 
nlp_en = spacy.load("en_core_web_lg")
nlp_pt = spacy.load("pt_core_news_lg")

# Funcão que recebe uma string e a limpar para ficar no formato aceitável para uma URI
def process_uri(x):
    return (re.sub('[^a-zA-Z0-9_ ]', '',
            unidecode(x.strip())
                        .replace(" ", "_")
                        .replace("[","")
                        .replace("]","")
                        .replace("?","")
                        .replace("'","")
                        .lower()))


# Função para extrair texto de uma tese em PDF e identificar entidades
def extratc_text(tese_path):
    
    # Processando o arquivo em PDF
    try:
        reader = PdfReader(tese_path)
        number_of_pages = len(reader.pages)
    
        excerpt = {}

        extractor = 'PdfReader'

    except:
        reader = fitz.open(tese_path)
        number_of_pages = len(reader)
    
        excerpt = {}
        
        extractor = 'PyMuPDF'

    # Iterando por cada página
    for page_number in range(number_of_pages):

        # Verificando qual extrator de pdf foi utilizado    
        if extractor == 'PdfReader':

            # Extraindo o texto da página
            try:
                if page_number == 0:
                    try:
                        page_text = (reader.pages[page_number].extract_text() + '\n ' 
                                    + reader.pages[page_number+1].extract_text()[:400])
                    except:
                        page_text = reader.pages[page_number].extract_text()
                else:
                    
                    if page_number == number_of_pages -1:
                        try:
                            page_text = (reader.pages[page_number-1].extract_text()[-400:] + '\n ' 
                                        + reader.pages[page_number].extract_text())
                        except:
                            page_text = reader.pages[page_number].extract_text()
                    
                    else:
                        try:
                            page_text = (reader.pages[page_number-1].extract_text()[-400:] + '\n ' 
                                        + reader.pages[page_number].extract_text() + '\n ' 
                                        + reader.pages[page_number+1].extract_text()[:400])  
                        except:
                            page_text = reader.pages[page_number].extract_text()
            except:
                page_text = ''
            
        else:
                
            # Extraindo o texto da página
            try:
                if page_number == 0:
                    try:
                        page_text = (reader[page_number].get_text() + '\n ' 
                                    + reader[page_number+1].get_text()[:400])
                    except:
                        page_text = reader[page_number].get_text()
                else:
                    
                    if page_number == number_of_pages -1:
                        try:
                            page_text = (reader[page_number-1].get_text()[-400:] + '\n ' 
                                        + reader[page_number].get_text())
                        except:
                            page_text = reader[page_number].get_text()
                    
                    else:
                        try:
                            page_text = (reader[page_number-1].get_text()[-400:] + '\n ' 
                                        + reader[page_number].get_text() + '\n ' 
                                        + reader[page_number+1].get_text()[:400])  
                        except:
                            page_text = reader[page_number].get_text()

            except:
                page_text = ''

        # Limpando page text         
        page_text = page_text.replace("'", "").replace('"', '')
        # Verifica se o último caractere é uma barra invertida
        if page_text != '':
            if page_text[-1] == '\\': 
                page_text = page_text[:-2]
        page_text = re.sub(r"[\ud800-\udfff]", " ", page_text)
        page_text = page_text.encode('utf-8').decode('utf-8')
        
        
        # Detectando o idioma do texto
        try:
            lang = detect(page_text)
            
        except:
            lang = 'Não_detectado'
        
        
        # Extraindo as entidades
        page_extracted = False
        if lang == 'pt':
            doc = nlp_pt(page_text)
            page_extracted = True
        if lang == 'en':
            doc = nlp_en(page_text)
            page_extracted = True
        

        if page_extracted:

            persons = []
            gpes = []
            #orgs = []
            for ent in doc.ents:
                if ent.label_ == "PER": #"PERSON":
                    persons.append(process_uri(ent.text))
                if ent.label_ == "LOC": #"GPE":
                    gpes.append(process_uri(ent.text))
                #if ent.label_ == "ORG":
                #    orgs.append(process_uri(ent.text))
                    
            excerpt[page_number] = {'text': page_text, 
                                    'lang': lang, 
                                    'persons': list(set(persons)), 
                                    'gpes': list(set(gpes)),
                                #'orgs': list(set(orgs))
                                }

    return excerpt

# %% [markdown]
# Iterando por todas as URI para extrair o texto e gravar no grafo NEO4j

# %%
# Gravar hora de início do processamento
start_time = pd.Timestamp.now()
parcial_time = pd.Timestamp.now()

for i in range(0,len(thesis_repository)):

    #title ='The problem of identity as it relates to the american black\'s vision of Africa'
    #title = thesis_repository['title'][i].replace("?","").replace('-', ' ').replace('&', ' ').replace('/', ' ').replace('\\', ' ')  
    #repo = get_repository_link(title)

    # Coletando o link do PDF
    url = thesis_repository['repository'][i]
    thesis_uri = thesis_repository['Thesis'][i][16:]
    pdf_link = get_pdf_link(url)
    if pdf_link is not None:
        # Itereando pelos links de PDF encontrados (em alguns casos há outros materiais além da tese)
        for pdf_num in range(len(pdf_link)):
            print(f"{i} - Downloading and extracting: {thesis_uri} from {pdf_link[pdf_num]}")
            download_file(pdf_link[pdf_num], thesis_uri)

            # Extraindo o texto e entidades
            tese_path = 'tese UFPR.pdf'
            excerpt = extratc_text(tese_path)

            excerpts = []
            persons = []
            gpes = []

            # Salvando as triplas em CSV
            for n in excerpt.keys():

                excerpt_uri = thesis_repository['Thesis'][i] + '_pdf_' + str(pdf_num) + '_p_' + str(n)
                excerpt_text = excerpt[n]['text']
                # Verifica se o último caractere é uma barra invertida
                #if excerpt_text[-1] == '\\': 
                #    excerpt_text = excerpt_text[:-1]
                

                excerpt_page = 'pdf_' + str(pdf_num) + '_p_' + str(n)
                excerpt_lang = excerpt[n]['lang']
                
                excerpts.append([thesis_repository['Thesis'][i], excerpt_uri, excerpt_text, excerpt_page, excerpt_lang])
                    
                #Criando as relações com as entidades
                for person in excerpt[n]['persons']:
                    persons.append([excerpt_uri, 'tag:stardog:api:' + person])
                
                for gpe in excerpt[n]['gpes']:
                    gpes.append([excerpt_uri, 'tag:stardog:api:' + gpe])
            
            # Salvando os dados em CSV no diretório de importação do Neo4j
            pd.DataFrame(excerpts).to_csv('C:\\Users\\facordei\\.Neo4jDesktop\\relate-data\\dbmss\\dbms-792eabfc-5517-4220-ab29-30ef6ec3236e\\import\\excerptsUFPR.csv', index=False, header=False)
            pd.DataFrame(persons).to_csv('C:\\Users\\facordei\\.Neo4jDesktop\\relate-data\\dbmss\\dbms-792eabfc-5517-4220-ab29-30ef6ec3236e\\import\\personsUFPR.csv', index=False, header=False)
            pd.DataFrame(gpes).to_csv('C:\\Users\\facordei\\.Neo4jDesktop\\relate-data\\dbmss\\dbms-792eabfc-5517-4220-ab29-30ef6ec3236e\\import\\gpesUFPR.csv', index=False, header=False)

            #Deletando o arquivo PDF após o processamento
            os.remove('tese UFPR.pdf')

            print(f"Loading triplas: {thesis_uri}")

            # Importanto os dados para o Neo4j
            #Excerpts
            query = """
            LOAD CSV FROM 'file:///excerptsUFPR.csv'
            AS row
            MATCH  (t:Thesis{uri: row[0]})
            MERGE  (e:Exerpt{
                    uri: row[1],
                    text: row[2],
                    page: row[3],
                    lang: row[4]
                    })-[r:BFO_0000050]-(t);
            """
            graph = GraphDatabase.driver(NEO4J_URL, auth=(NEO4J_USERNAME, NEO4J_PASSWORD))
            results = graph.execute_query(query)
            graph.close()

            #Persons
            query = """
            LOAD CSV FROM 'file:///personsUFPR.csv'
            AS row
            MATCH  (e:Exerpt{uri: row[0]})
            MERGE  (p:Person{uri: row[1]})
            MERGE  (e)-[r:mentions]-(p);
            """
            graph = GraphDatabase.driver(NEO4J_URL, auth=(NEO4J_USERNAME, NEO4J_PASSWORD))
            results = graph.execute_query(query)
            graph.close()

            #GPEs
            query = """
            LOAD CSV FROM 'file:///gpesUFPR.csv'
            AS row
            MATCH  (e:Exerpt{uri: row[0]})
            MERGE  (p:Place{uri: row[1]})
            MERGE  (e)-[r:mentions]-(p);
            """
            graph = GraphDatabase.driver(NEO4J_URL, auth=(NEO4J_USERNAME, NEO4J_PASSWORD))
            results = graph.execute_query(query)
            graph.close()

            # Removendo os arquivos CSV após a importação
            os.remove('C:\\Users\\facordei\\.Neo4jDesktop\\relate-data\\dbmss\\dbms-792eabfc-5517-4220-ab29-30ef6ec3236e\\import\\excerptsUFPR.csv')
            os.remove('C:\\Users\\facordei\\.Neo4jDesktop\\relate-data\\dbmss\\dbms-792eabfc-5517-4220-ab29-30ef6ec3236e\\import\\personsUFPR.csv')
            os.remove('C:\\Users\\facordei\\.Neo4jDesktop\\relate-data\\dbmss\\dbms-792eabfc-5517-4220-ab29-30ef6ec3236e\\import\\gpesUFPR.csv')

            print(f"Total time: {pd.Timestamp.now() - start_time}")
            print(f"Partial time: {pd.Timestamp.now() - parcial_time}")
            # Atualizando a hora parcial
            parcial_time = pd.Timestamp.now()
    else:
        print(f"No PDF link found for {thesis_uri}")

    # gravando no grafo que a tese foi processada
    query = """
    MATCH  (t:Thesis{uri: \'""" + thesis_repository['Thesis'][i] +  """\'})
    SET t.processed = true
    """
    graph = GraphDatabase.driver(NEO4J_URL, auth=(NEO4J_USERNAME, NEO4J_PASSWORD))
    results = graph.execute_query(query)
    graph.close()
    #break
# Out:
# 0 - Downloading and extracting: armas_polvora_e_chumbo_a_expansao_lusobrasileira_e_os_indigenas_do_planalto_meridional_na_primeira_metade_do_seculo_xix from https://acervodigital.ufpr.br/xmlui/bitstream/handle/123456789/96216/304966.pdf?sequence=1&isAllowed=y
# Loading triplas: armas_polvora_e_chumbo_a_expansao_lusobrasileira_e_os_indigenas_do_planalto_meridional_na_primeira_metade_do_seculo_xix
# Total time: 0 days 00:00:04.252466
# Partial time: 0 days 00:00:04.252466
# 1 - Downloading and extracting: entre_a_liberdade_e_a_administracao_particular__a_condicao_juridica_do_indigena_na_vila_de_curitiba_17001750 from https://acervodigital.ufpr.br/xmlui/bitstream/handle/1884/35350/R%20-%20D%20-%20LILIAM%20FERRARESI%20BRIGHENTE.pdf?sequence=1&isAllowed=y
# Loading triplas: entre_a_liberdade_e_a_administracao_particular__a_condicao_juridica_do_indigena_na_vila_de_curitiba_17001750
# Total time: 0 days 00:00:38.736276
# Partial time: 0 days 00:00:34.483810
# 2 - Downloading and extracting: a_dinamica_agricola_do_norte_do_estado_do_parana_compreendida_a_partir_dos_cultivares_cafeeiro_e_canavieiro from https://acervodigital.ufpr.br/xmlui/bitstream/handle/1884/28953/R%20-%20D%20-%20ALEX%20FERREIRA%20GARCIA.pdf?sequence=1&isAllowed=y
# Loading triplas: a_dinamica_agricola_do_norte_do_estado_do_parana_compreendida_a_partir_dos_cultivares_cafeeiro_e_canavieiro
# Total time: 0 days 00:01:07.668055
# Partial time: 0 days 00:00:28.931779
# 3 - Downloading and extracting: usos_cotidianos_do_parentesco_espiritual__curitiba_na_transicao_do_seculo_xvii_para_o_xviii from https://acervodigital.ufpr.br/xmlui/bitstream/handle/1884/27741/R%20-%20D%20-%20CHAGAS%2c%20PAULA%20ROBERTA.pdf?sequence=1&isAllowed=y
# Loading triplas: usos_cotidianos_do_parentesco_espiritual__curitiba_na_transicao_do_seculo_xvii_para_o_xviii
# Total time: 0 days 00:01:25.819402
# Partial time: 0 days 00:00:18.152346
# 4 - Downloading and extracting: a_educacao_escolar_no_processo_de_subjetivacao_de_universitarios_indigenas_da_ufpr from https://acervodigital.ufpr.br/xmlui/bitstream/handle/1884/32303/R%20-%20D%20-%20FRANCINE%20ROCHA.pdf?sequence=1&isAllowed=y
# Loading triplas: a_educacao_escolar_no_processo_de_subjetivacao_de_universitarios_indigenas_da_ufpr
# Total time: 0 days 00:02:06.884080
# Partial time: 0 days 00:00:41.063679
# 5 - Downloading and extracting: ceramica_tupiguarani_e_os_processos_de_interacao_cultural_no_alto_rio_iguacu_pr from https://acervodigital.ufpr.br/xmlui/bitstream/handle/1884/27058/R%20-%20D%20-%20JONAS%20ELIAS%20VOLCOV.pdf?sequence=1&isAllowed=y
# Loading triplas: ceramica_tupiguarani_e_os_processos_de_interacao_cultural_no_alto_rio_iguacu_pr
# Total time: 0 days 00:02:49.517037
# Partial time: 0 days 00:00:42.632957
# 6 - Downloading and extracting: composicao_da_fauna_de_anopheles_diptera__culicidae_da_reserva_indigena_do_ocoy from https://acervodigital.ufpr.br/xmlui/bitstream/handle/1884/26703/Mestrado%2012%202011%20RODERLEI.pdf?sequence=1&isAllowed=y
# Loading triplas: composicao_da_fauna_de_anopheles_diptera__culicidae_da_reserva_indigena_do_ocoy
# Total time: 0 days 00:03:07.476584
# Partial time: 0 days 00:00:17.959547
# 7 - Downloading and extracting: genetica_de_populacoes_e_microevolucao_do_gene_kir3dl1s1_na_especie_humana from https://acervodigital.ufpr.br/xmlui/bitstream/handle/1884/25692/Dissertacao_RicardoDallaCosta.pdf?sequence=1&isAllowed=y
# Loading triplas: genetica_de_populacoes_e_microevolucao_do_gene_kir3dl1s1_na_especie_humana
# Total time: 0 days 00:03:38.792059
# Partial time: 0 days 00:00:31.315475
# Loading triplas: a_retradicionalizacao_dos_territorios_indigenas_pelo_turismo__um_estudo_comparativo_entre_os_kadiweu_mato_grosso_do_sulbr_e_maori_ilha_norte__nz
# Total time: 0 days 00:12:56.651049
# Partial time: 0 days 00:00:56.447122
# 20 - Downloading and extracting: o_corpo_falante__as_inscricoes_discursivas_do_corpo_na_pintura_academica_brasileira_do_seculo_xix from https://acervodigital.ufpr.br/xmlui/bitstream/handle/1884/26204/Stephanie%20Dahn%20Batista_Tese%20de%20Doutorado.pdf?sequence=1&isAllowed=y
# Loading triplas: o_corpo_falante__as_inscricoes_discursivas_do_corpo_na_pintura_academica_brasileira_do_seculo_xix
# Total time: 0 days 00:14:02.236033
# Partial time: 0 days 00:01:05.584984
# 21 - Downloading and extracting: comunidades_rurais_de_guaratubaparana__os_limites_e_as_possibilidades_da_opcao_extrativista_como_meio_de_vida_no_contexto_do_desenvolvimento_rural_sustentavel from https://acervodigital.ufpr.br/xmlui/bitstream/handle/1884/24153/TESE%20CORRIGIDA%202.pdf?sequence=1&isAllowed=y
# Loading triplas: comunidades_rurais_de_guaratubaparana__os_limites_e_as_possibilidades_da_opcao_extrativista_como_meio_de_vida_no_contexto_do_desenvolvimento_rural_sustentavel
# Total time: 0 days 00:15:07.245843
# Partial time: 0 days 00:01:05.009810
# 22 - Downloading and extracting: francisco_das_chagas_lima__a_atuacao_de_um_padre_secular_no_povoamento_dos_campos_de_guarapuava_18081828 from https://acervodigital.ufpr.br/xmlui/bitstream/handle/1884/28233/R%20-%20D%20-%20LUIZANGELA%20%20PADILHA%20PONTAROLO.pdf?sequence=1&isAllowed=y
# Loading triplas: francisco_das_chagas_lima__a_atuacao_de_um_padre_secular_no_povoamento_dos_campos_de_guarapuava_18081828
# Total time: 0 days 00:15:37.121415
# Partial time: 0 days 00:00:29.875572
# 23 - Downloading and extracting: nem_brabo_nem_manso__homens_animais_e_plantas_no_assentamento_vale_da_serra_pitanga__pr from https://acervodigital.ufpr.br/xmlui/bitstream/handle/1884/28316/R%20-%20D%20-%20RICARDO%20DE%20CAMPOS%20LEINIG.pdf?sequence=1&isAllowed=y
# Loading triplas: nem_brabo_nem_manso__homens_animais_e_plantas_no_assentamento_vale_da_serra_pitanga__pr
# Total time: 0 days 00:16:07.152058
# Partial time: 0 days 00:00:30.030643
# 24 - Downloading and extracting: a_personificacao_do_mal_em_jose_de_anchieta__imaginario_e_recepcao from https://acervodigital.ufpr.br/xmlui/bitstream/handle/1884/30017/R%20-%20D%20-%20ANGELITA%20MARTENS.pdf?sequence=1&isAllowed=y
# Loading triplas: a_personificacao_do_mal_em_jose_de_anchieta__imaginario_e_recepcao
# Total time: 0 days 00:17:04.603335
# Partial time: 0 days 00:00:57.451277
# 25 - Downloading and extracting: il_guarany_de_antonio_carlos_gomes__a_historia_de_uma_opera_nacional from https://acervodigital.ufpr.br/xmlui/bitstream/handle/1884/34996/R%20-%20D%20-%20OLGA%20SOFIA%20FREITAS%20SILVA.pdf?sequence=1&isAllowed=y
# Loading triplas: il_guarany_de_antonio_carlos_gomes__a_historia_de_uma_opera_nacional
# Partial time: 0 days 00:00:26.929358
# 33 - Downloading and extracting: estatisticas_de_incendios_florestais_em_areas_protegidas_no_periodo_de_1998_a_2002 from https://acervodigital.ufpr.br/xmlui/bitstream/handle/1884/1193/JULIANAFERREIRASANTOS.pdf?sequence=1&isAllowed=y
# Loading triplas: estatisticas_de_incendios_florestais_em_areas_protegidas_no_periodo_de_1998_a_2002
# Total time: 0 days 00:22:10.905426
# Partial time: 0 days 00:00:17.540369
# 34 - Downloading and extracting: analise_de_microssatelites_da_regiao_mhc_em_uma_amostra_de_doadores_voluntarios_de_medula_ossea from https://acervodigital.ufpr.br/xmlui/bitstream/handle/1884/15099/DF%20carol.pdf?sequence=1&isAllowed=y
# Loading triplas: analise_de_microssatelites_da_regiao_mhc_em_uma_amostra_de_doadores_voluntarios_de_medula_ossea
# Total time: 0 days 00:22:30.605057
# Partial time: 0 days 00:00:19.699631
# 35 - Downloading and extracting: influencia_do_emprego_de_variedades_de_saccharomyces_cerevisiae_na_elaboracao_de_vinho_tinto_de_uva_terci_oriunda_do_municipio_de_colombo__pr from https://acervodigital.ufpr.br/xmlui/bitstream/handle/1884/28841/D%20-%20DANIELA%20DORNELES.pdf?sequence=1&isAllowed=y
# Loading triplas: influencia_do_emprego_de_variedades_de_saccharomyces_cerevisiae_na_elaboracao_de_vinho_tinto_de_uva_terci_oriunda_do_municipio_de_colombo__pr
# Total time: 0 days 00:22:54.591413
# Partial time: 0 days 00:00:23.986356
# 36 - Downloading and extracting: o_trabalho_da_pessoa_com_deficiencia_e_a_lapidacao_dos_direitos_humanos__o_direito_do_trabalho_uma_acao_afirmativa from https://acervodigital.ufpr.br/xmlui/bitstream/handle/1884/2423/PR__TEXTUAIS_TESE.PDF?sequence=1&isAllowed=y
# Loading triplas: o_trabalho_da_pessoa_com_deficiencia_e_a_lapidacao_dos_direitos_humanos__o_direito_do_trabalho_uma_acao_afirmativa
# Total time: 0 days 00:22:58.902972
# Partial time: 0 days 00:00:04.311559
# 36 - Downloading and extracting: o_trabalho_da_pessoa_com_deficiencia_e_a_lapidacao_dos_direitos_humanos__o_direito_do_trabalho_uma_acao_afirmativa from https://acervodigital.ufpr.br/xmlui/bitstream/handle/1884/2423/TESE_PRONTA_E_REVISADA.PDF?sequence=2&isAllowed=y
# Loading triplas: o_trabalho_da_pessoa_com_deficiencia_e_a_lapidacao_dos_direitos_humanos__o_direito_do_trabalho_uma_acao_afirmativa
# Total time: 0 days 00:24:42.041941
# Partial time: 0 days 00:01:43.138969
# 37 - Downloading and extracting: prevalencia_do_alelo_tp53_r337h_no_estado_do_parana from https://acervodigital.ufpr.br/xmlui/bitstream/handle/1884/30439/R%20-%20D%20-%20GISLAINE%20CUSTODIO%20PIOVEZAN.pdf?sequence=1&isAllowed=y
# Loading triplas: prevalencia_do_alelo_tp53_r337h_no_estado_do_parana
# Total time: 0 days 00:25:22.606013
# Partial time: 0 days 00:00:40.564072
# 38 - Downloading and extracting: utilizando_fotografias_digitais_de_alta_qualidade_na_geracao_de_textura_para_modelos_3d__uma_abordagem_pratica_na_preservacao_digital_de_acervos_culturais_e_naturais from https://acervodigital.ufpr.br/xmlui/bitstream/handle/1884/23730/Dissertacao%20-%20Beatriz%20Trinchao%20Andrade.pdf?sequence=1&isAllowed=y
# Loading triplas: utilizando_fotografias_digitais_de_alta_qualidade_na_geracao_de_textura_para_modelos_3d__uma_abordagem_pratica_na_preservacao_digital_de_acervos_culturais_e_naturais
# Total time: 0 days 00:25:55.985098
# Partial time: 0 days 00:00:33.379085
# 39 - Downloading and extracting: degredo_interno_e_incorporacao_no_brasil_meridional__trajetorias_de_degredados_em_guarapuava_seculo_xix from https://acervodigital.ufpr.br/xmlui/bitstream/handle/1884/10686/DEGREDO%20INTERNO%20E%20INCORPORA%c3%87%c3%83O%20NO%20BRASIL%20MERIDIONAL_%20FABIO%20PONTAROLO.pdf?sequence=1&isAllowed=y
# Loading triplas: degredo_interno_e_incorporacao_no_brasil_meridional__trajetorias_de_degredados_em_guarapuava_seculo_xix
# Total time: 0 days 00:26:33.925424
# Partial time: 0 days 00:00:37.940326
# 40 - Downloading and extracting: estudo_de_populacoes_de_diferentes_ancestralidades_e_evolucao_de_polimorfismos_dos_genes_cd80_e_cd86 from https://acervodigital.ufpr.br/xmlui/bitstream/handle/1884/23508/MarciaHolsbachBeltrame_dissertacao.pdf?sequence=1&isAllowed=y
# Loading triplas: estudo_de_populacoes_de_diferentes_ancestralidades_e_evolucao_de_polimorfismos_dos_genes_cd80_e_cd86
# Total time: 0 days 00:26:54.547565
# Partial time: 0 days 00:00:20.622141
# 41 - Downloading and extracting: investigacao_de_fatores_geneticos_na_patogenese_do_penfigo_foliaceo_endemico__analise_de_associacao_com_genes_de_citocinas_e_microssatelites_do_complexo_principal_de_histocompatibilidade from https://acervodigital.ufpr.br/xmlui/bitstream/handle/1884/82941/D%20-%20T%20-%20NOEMI%20FARAH%20PEREIRA.pdf?sequence=1&isAllowed=y
# Loading triplas: investigacao_de_fatores_geneticos_na_patogenese_do_penfigo_foliaceo_endemico__analise_de_associacao_com_genes_de_citocinas_e_microssatelites_do_complexo_principal_de_histocompatibilidade
# Total time: 0 days 00:27:44.155883
# Partial time: 0 days 00:00:49.607326
# 42 - Downloading and extracting: o_direito_das_minorias__passagem_do_invisivel_real_para_o_visivel_formal from https://acervodigital.ufpr.br/xmlui/bitstream/handle/1884/82944/D%20-%20T%20-%20JOAQUIM%20SHIRAISHI%20NETO.pdf?sequence=1&isAllowed=y
# Loading triplas: o_direito_das_minorias__passagem_do_invisivel_real_para_o_visivel_formal
# Total time: 0 days 00:28:33.960911
# Partial time: 0 days 00:00:49.805028
# 43 - Downloading and extracting: contribuicao_as_possibilidades_de_um_ensino_de_botanica_critico_e_contextualizado from https://acervodigital.ufpr.br/xmlui/bitstream/handle/1884/26566/T%20-%20SILVA%2c%20LENIR%20MARISTELA.pdf?sequence=1&isAllowed=y
# Loading triplas: contribuicao_as_possibilidades_de_um_ensino_de_botanica_critico_e_contextualizado
# Total time: 0 days 00:29:06.749282
# Partial time: 0 days 00:00:32.788371
# 44 - Downloading and extracting: a_analise_polifasica_na_reclassificacao_genetica_de_rhizobium_etli_e_o_estudo_da_diversidade_genetica_de_isolados_dos_cerrados_brasileiros from https://acervodigital.ufpr.br/xmlui/bitstream/handle/1884/27927/LUCIANA%20GRANGE.pdf?sequence=1&isAllowed=y
# Loading triplas: a_analise_polifasica_na_reclassificacao_genetica_de_rhizobium_etli_e_o_estudo_da_diversidade_genetica_de_isolados_dos_cerrados_brasileiros
# Total time: 0 days 00:30:31.698718
# Partial time: 0 days 00:01:24.949436
# 45 - Downloading and extracting: moradores_e_veranistas__as_diferentes_ralacoes_e_percepcoes_com_o_ambiente_na_praia_de_armacao_do_itapocoroi_penha__sc from https://acervodigital.ufpr.br/xmlui/bitstream/handle/1884/6587/DISSERTA%c3%87%c3%83O%20M%c3%94NICA%20K%20GOULART.pdf?sequence=1&isAllowed=y
# Loading triplas: moradores_e_veranistas__as_diferentes_ralacoes_e_percepcoes_com_o_ambiente_na_praia_de_armacao_do_itapocoroi_penha__sc
# Total time: 0 days 00:31:33.433490
# Partial time: 0 days 00:01:01.734772
# 46 - Downloading and extracting: o_ensino_superior_para_os_povos_indigenas__ingressopermanencia_desistencia_conclusao_dos_estudantes_indigenas_da_universidade_estadual_do_centro_oeste_unicentro_parana from https://acervodigital.ufpr.br/xmlui/bitstream/handle/1884/26067/Tese%20Juliane%20Sachser%20Angnes%201-%20Versao%20final.pdf?sequence=1&isAllowed=y
# Loading triplas: o_ensino_superior_para_os_povos_indigenas__ingressopermanencia_desistencia_conclusao_dos_estudantes_indigenas_da_universidade_estadual_do_centro_oeste_unicentro_parana
# Total time: 0 days 00:32:43.665724
# Partial time: 0 days 00:01:10.232234
# 47 - Downloading and extracting: avaliacao_da_variabilidade_genetica_em_tayassu_tacaju_cateto_e_tayassu_pecari_queixada_por_meio_da_utilizacao_de_marcadores_microssatelites from https://acervodigital.ufpr.br/xmlui/bitstream/handle/1884/24267/Dissertacao%20completa.pdf?sequence=1&isAllowed=y
# Loading triplas: avaliacao_da_variabilidade_genetica_em_tayassu_tacaju_cateto_e_tayassu_pecari_queixada_por_meio_da_utilizacao_de_marcadores_microssatelites
# Total time: 0 days 00:33:01.263051
# Partial time: 0 days 00:00:17.597327
# 48 - Downloading and extracting: tecnicas_de_agrupamento_e_de_hierarquizacao_no_contexto_de_kdd__aplicacao_a_dados_temporais_de_instrumentacao_geotecnicaestrutural_da_usina_hidreletrica_de_itaipu from https://acervodigital.ufpr.br/xmlui/bitstream/handle/1884/20898/Tese_R_Villwock.pdf?sequence=1&isAllowed=y
# Loading triplas: tecnicas_de_agrupamento_e_de_hierarquizacao_no_contexto_de_kdd__aplicacao_a_dados_temporais_de_instrumentacao_geotecnicaestrutural_da_usina_hidreletrica_de_itaipu
# Total time: 0 days 00:33:23.755572
# Partial time: 0 days 00:00:22.492521
# 49 - Downloading and extracting: do_poder_do_sangue_e_da_chicha__os_wajuru_do_guapore_rondonia from https://acervodigital.ufpr.br/xmlui/bitstream/handle/1884/22323/Do%20poder%20do%20sangue%20e%20da%20chicha_%20os%20Wajuru%20do%20Guapore%20%28Rondonia%29.pdf?sequence=1&isAllowed=y
# Loading triplas: do_poder_do_sangue_e_da_chicha__os_wajuru_do_guapore_rondonia
# Total time: 0 days 00:34:11.529568
# Partial time: 0 days 00:00:47.773996
# 50 - Downloading and extracting: o_universo_de_feiticaria_em_aura__entre_o_aprisionamento_e_a_libertacao from https://acervodigital.ufpr.br/xmlui/bitstream/handle/1884/24463/D%20-%20GONCALVES%2c%20VALDENIR%20DA%20FONSECA.pdf?sequence=1&isAllowed=y
# Loading triplas: o_universo_de_feiticaria_em_aura__entre_o_aprisionamento_e_a_libertacao
# Total time: 0 days 00:34:46.635768
# Partial time: 0 days 00:00:35.106200
# 51 - Downloading and extracting: na_remenda_do_ceu_com_a_terra_escolas_diferenciadas_nao_sao_huni_kui from https://acervodigital.ufpr.br/xmlui/bitstream/handle/1884/26471/Paulo%20Roberto.pdf?sequence=1&isAllowed=y
# Loading triplas: na_remenda_do_ceu_com_a_terra_escolas_diferenciadas_nao_sao_huni_kui
# Total time: 0 days 00:35:51.393875
# Partial time: 0 days 00:01:04.758107
# 52 - Downloading and extracting: aplicativos_para_o_ensinoaprendizagem_de_linguas_indigenas_de_povos_do_brasil__um_estudo_de_caso_sobre_o_nheengatu_app from https://acervodigital.ufpr.br/xmlui/bitstream/handle/1884/87429/R%20-%20D%20-%20SUELLEN%20TOBLER%20ALMEIDA.pdf?sequence=1&isAllowed=y
# Loading triplas: aplicativos_para_o_ensinoaprendizagem_de_linguas_indigenas_de_povos_do_brasil__um_estudo_de_caso_sobre_o_nheengatu_app
# Total time: 0 days 00:36:04.879140
# Partial time: 0 days 00:00:13.485267
# 53 - Downloading and extracting: eu_nao_acho_do_meu_ponto_de_vista__uma_etnografia_sobre_os_guarani_mbya_de_guaviraty_em_contexto_de_obras_no_litoral_paranaense from https://acervodigital.ufpr.br/xmlui/bitstream/handle/1884/75101/R%20-%20D%20-%20CARLOS%20HENRIQUE%20EMILIANO%20DE%20SOUZA.pdf?sequence=1&isAllowed=y
# Loading triplas: eu_nao_acho_do_meu_ponto_de_vista__uma_etnografia_sobre_os_guarani_mbya_de_guaviraty_em_contexto_de_obras_no_litoral_paranaense
# Total time: 0 days 00:36:33.984144
# Partial time: 0 days 00:00:29.104008
# 54 - Downloading and extracting: cinema_de_indio__uma_realizacao_dos_povos_da_floresta from https://acervodigital.ufpr.br/xmlui/bitstream/handle/1884/22638/Cinema%20de%20indio.pdf?sequence=1&isAllowed=y
# Loading triplas: cinema_de_indio__uma_realizacao_dos_povos_da_floresta
# Total time: 0 days 00:36:51.949797
# Partial time: 0 days 00:00:17.965653
# 55 - Downloading and extracting: as_dadivas_que_vem_da_mata__espaco_historias_e_trajetorias_na_sobreposicao_socioambiental_entre_a_tekoa_kuaray_haxa_e_a_reserva_biologica_bom_jesus_guaraquecaba__pr from https://acervodigital.ufpr.br/xmlui/bitstream/handle/1884/85224/R%20-%20D%20-%20TAMARA%20BACETTI%20BARBOSA.pdf?sequence=1&isAllowed=y
# Sleeping for 5 seconds before retrying... (download_file)
