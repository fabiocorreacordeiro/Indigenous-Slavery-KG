# %%
#%pip install beautifulsoup4
#%pip install pip-system-certs
#% -m pip install ipykernel -U --force-reinstall

# %%
import requests
from bs4 import BeautifulSoup as bs
import pandas as pd
import os
from langchain_community.graphs import Neo4jGraph
from PyPDF2 import PdfReader
import fitz
from langdetect import detect
import spacy
import re
from unidecode import unidecode
import time

# %% [markdown]
# Conectando ao Neo4j

# %%
from neo4j import GraphDatabase

# Neo4j variables
NEO4J_URL = os.getenv("NEO4J_URL")
NEO4J_USERNAME =os.getenv("NEO4J_USERNAME")
NEO4J_PASSWORD = os.getenv("NEO4J_PASSWORD")


graph = GraphDatabase.driver(NEO4J_URL, auth=(NEO4J_USERNAME, NEO4J_PASSWORD))

# %% [markdown]
# - Buscar os links para a tese no Neo4j
# - Buscar o link do PDF no repositório da universidade
# - Baixar o PDF
# - Extrair o texto do PDF

# %% [markdown]
# Buscar links para a tese no Neo4j

# %%
# Query to get theses and their repositories from the Neo4j database
# This query retrieves theses that are published by the Pontifical Catholic University of Rio de Janeiro (PUC-Rio) and have not been processed yet.
query1 = """
MATCH (t:Thesis)-[:publisher]-(uni:University{uri:'tag:stardog:api:PUC_RIO'})
WHERE NOT EXISTS {(t{processed:true})}
RETURN distinct(t["uri"]) as Thesis, t["repository"] as repository 
"""

# Alternative query to get theses that do not have excerpts and have been processed.
query2 = """ 
match (t:Thesis)-[:publisher]-(uni:University{uri:'tag:stardog:api:PUC_RIO'})
where (not (t:Thesis)-[:BFO_0000050]-(:Excerpt)) and  exists {(t{processed:true})}
return distinct(t["uri"]) as Thesis, t["repository"] as repository
"""

# Query to retrive theses with few pages and their repositories.
query3 = """
MATCH (t:Thesis)-[:publisher]-(uni:University{uri:'tag:stardog:api:PUC_RIO'})
Match (t:Thesis)-[:BFO_0000050]-(e:Excerpt)
RETURN count(e) as pages, t["uri"] as Thesis, t["repository"] as repository
 order by (pages) limit 40
"""

query4 = """
MATCH (t:Thesis)-[:publisher]-(uni:University{uri:'tag:stardog:api:PUC_RIO'})
WHERE NOT EXISTS {(t{processed:true})}
RETURN distinct(t["uri"]) as Thesis, t["title"] as title 
"""

query5 = """
MATCH (t:Thesis {processed: true})-[:publisher]-(uni:University {uri: 'tag:stardog:api:PUC_RIO'})
WHERE NOT (t)--(:Excerpt)
RETURN distinct(t["uri"]) as Thesis, t["title"] as title 
"""

graph = GraphDatabase.driver(NEO4J_URL, auth=(NEO4J_USERNAME, NEO4J_PASSWORD))
results = graph.execute_query(query1).records
graph.close()

#results = graph.query(query2)
# Convert the results to a DataFrame
#thesis_repository = pd.DataFrame(results, columns=["pages", "Thesis", "repository"])
thesis_repository = pd.DataFrame(results, columns=["Thesis", "repository"])
thesis_repository = thesis_repository.reset_index(drop=True) 
thesis_repository
# Out:
#                                                 Thesis  \
# 0    tag:stardog:api:en_affirmative_actions_regardi...
# 1    tag:stardog:api:pt_geografias_xamanicas_a_cons...
# 2    tag:stardog:api:en_indigenous_knowledge_in_the...
# 3    tag:stardog:api:en_reantropofagia_vexoa_moquem...
# 4    tag:stardog:api:en_building_foundations_for_su...
# ..                                                 ...
# 313  tag:stardog:api:en_born_and_growing_black_in_t...
# 314  tag:stardog:api:pt_o_teu_cabelo_nao_nega_const...
# 315  tag:stardog:api:en_visualization_of_complex_na...
# 316  tag:stardog:api:en_institutional_racism_and_mi...
# 317  tag:stardog:api:pt_extracao_de_isosuperficies_...
#
#                                             repository
# 0    https://www.maxwell.vrac.puc-rio.br/colecao.ph...
# 1    https://www.maxwell.vrac.puc-rio.br/colecao.ph...
# 2    https://www.maxwell.vrac.puc-rio.br/colecao.ph...
# 3    https://www.maxwell.vrac.puc-rio.br/colecao.ph...
# 4    https://www.maxwell.vrac.puc-rio.br/colecao.ph...
# ..                                                 ...
# 313  https://www.maxwell.vrac.puc-rio.br/colecao.ph...
# 314  https://www.maxwell.vrac.puc-rio.br/colecao.ph...
# 315  https://www.maxwell.vrac.puc-rio.br/colecao.ph...
# 316  https://www.maxwell.vrac.puc-rio.br/colecao.ph...
# 317  https://www.maxwell.vrac.puc-rio.br/colecao.ph...
#
# [318 rows x 2 columns]

# %%
repo = thesis_repository['repository'][3].split('||')[0]
#print(repo)
#print(get_pdf_link(repo))
#headers = {
#    'User-Agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/58.0.3029.110 Safari/537.3'
#                }

    #Fazer requisição e parsear o arquivo html

f = requests.get(repo, headers=headers, verify=True).text#, verify=False) 
f
# Out:
# '<!doctype html>\n<html lang="pt-br">\n\t<head>\n\t\t<meta name="viewport" content="width=device-width, initial-scale=1">\n\t\t<meta http-equiv="Content-Type" content="text/html; charset=utf-8">\n\t\t<meta name="theme-color" content="#4E4E7B" />\n\t\t<meta name="GENERATOR" content="MAX\'s HTML Beauty++ ME">\n\t\t\n\t\t<title>Maxwell</title>\n\t\t<style>\n\t\t\t#main{\n\t\t\t\tbackground-color:#F3EFE3;\n\t\t\t}\n\t\t\t:root{\n\t\t\t\t--main-bg-color : #D0CABC;\n\t\t\t}\n\t\t</style>\n\n<style>\n  /* Estilos para a janela */\n  .janela {\n    display: none;\n    position: absolute;\n    top: 10px;\n    right: 10px;\n    border: 1px solid #ccc;\n    background-color: #fff;\n    padding: 10px;\n    z-index: 1000;\n  }\n\n  /* Estilos para o botão de fechar */\n  .fechar {\n    position: absolute;\n    top: 5px;\n    right: 5px;\n    cursor: pointer;\n  }\n</style>\n\n\t\t\n\t\t<link href="https://www.maxwell.vrac.puc-rio.br/css/novocss.css" rel="stylesheet" type="text/css">\n\t\t<link href="https://www.maxwell.vrac.puc-rio.br/css/novocss_interno.css" rel="stylesheet" type="text/css">\n\t\t<link href="https://www.maxwell.vrac.puc-rio.br/css/nouislider.min.css" rel="stylesheet" type="text/css">\n\t\t<link rel="shortcut icon" href="favicon.ico" />\n\t\t<script tpye=text/javascript>\n\t\t\tvar cor = \'Normal\';\n\t\t\tvar tam = \'2\';\n\t\t</script>\n\t\t<script type="text/javascript" async src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.7/MathJax.js?config=TeX-MML-AM_CHTML"></script>\n\t\t<script src="https://kit.fontawesome.com/f3aeb5b50f.js" crossorigin="anonymous"></script>\n\t\t<SCRIPT TYPE="text/javascript" SRC="JS/function.js"></SCRIPT>\n\t\t<SCRIPT TYPE="text/javascript" SRC="JS/graficopizza.js"></SCRIPT>\n\t\t<SCRIPT TYPE="text/javascript" SRC="JS/grafico.js"></SCRIPT>\n\t\t<SCRIPT TYPE="text/javascript" SRC="JS/ajax_daniel.js"></SCRIPT>\n\t\t<SCRIPT TYPE="text/javascript" SRC="JS/nouislider.min.js"></SCRIPT>\n\t\n\t\n\n\t\t<script tpye=text/javascript>\n\t\t\tcorTexto = "txtNormal txtbaseFont1";\n\t\t\tcorLinha = "linhaNormal";\t\t\n\t\t\n\t\t\n\t\t\tvar segundo=48;\n\t\t\tvar minuto=45;\n\t\t\tvar hora=05;\t\n\t\t\tfunction tempo(){\n\t\t\t\tif(segundo < 59){\n\t\t\t\t\tsegundo=segundo + 1;\n\t\t\t\t\tif(segundo == 59){\n\t\t\t\t\t\tminuto=minuto+1;\n\t\t\t\t\t\tif(minuto == 59){\n\t\t\t\t\t\t\tminuto=0;\n\t\t\t\t\t\t\thora=hora+1;\n\t\t\t\t\t\t}\n\t\t\t\t\t\tsegundo=0; \n\t\t\t\t\t\tif(hora == 24){\n\t\t\t\t\t\t\thora=0;\n\t\t\t\t\t\t\tminuto=0;\n\t\t\t\t\t\t\tsegundo=0;\n\t\t\t\t\t\t}\n\t\t\t\t\t}\n\t\t\t\t}\n\t\n\t\t\tdocument.getElementById("relogio").innerHTML=(hora+":"+ minuto+":"+segundo);\n\t\t}\n\t\t</script>\n\t\t\n<script>\nfunction abrirJanela() {\n  var janela = document.getElementById(\'direitos\');\n  janela.style.display = \'block\';\n}\n\nfunction fecharJanela() {\n  var janela = document.getElementById(\'direitos\');\n  janela.style.display = \'none\';\n}\n</script>\n\n  \t</head>\n  \t<body style="margin-top: 0px; overflow:auto; background-color:#4E4E7B; margin-left:0px ;" onload="setInterval(\'tempo();\',1000)"  >\n\t\t<div name="command_latex_braket" style="display: none;">$$\\newcommand{\\bra}[1]{\\left<#1\\right|}\\newcommand{\\ket}[1]{\\left|#1\\right>}\\newcommand{\\bk}[2]{\\left<#1\\middle|#2\\right>}\\newcommand{\\bke}[3]{\\left<#1\\middle|#2\\middle|#3\\right>}$$</div>\n\t\t<script>\n\t\t  (function(i,s,o,g,r,a,m){i[\'GoogleAnalyticsObject\']=r;i[r]=i[r]||function(){\n\t\t  (i[r].q=i[r].q||[]).push(arguments)},i[r].l=1*new Date();a=s.createElement(o),\n\t\t  m=s.getElementsByTagName(o)[0];a.async=1;a.src=g;m.parentNode.insertBefore(a,m)\n\t\t  })(window,document,\'script\',\'//www.google-analytics.com/analytics.js\',\'ga\');\n\n\t\t  ga(\'create\', \'UA-39957327-1\', \'puc-rio.br\');\n\t\t  ga(\'send\', \'pageview\');\n\n\t\t</script>\t\n\t\n  \t\t<div id="main">\n\t\t\t\n\t\t\t<div class="navbar">\n\t\t\t\t<!--<img height="90" title="Logo da PUC-Rio" src="./img/logo_puc.png" border="0" s ...

# %%
<a href="https://www.maxwell.vrac.puc-rio.br/68056/68056.PDF" class="linkNormal linkFont2" target="_Blank">
									<!--<a href="acessoConteudo.php?nrseqoco=167479" class="linkNormal linkFont2" target="_Blank">-->
										<span title="">PDF   </span>
									</a>

# %%
soup = bs(f, "html.parser")
for doc in soup.find_all(href=True):
    print(doc['href'])
# Out:
# https://www.maxwell.vrac.puc-rio.br/css/novocss.css
# https://www.maxwell.vrac.puc-rio.br/css/novocss_interno.css
# https://www.maxwell.vrac.puc-rio.br/css/nouislider.min.css
# favicon.ico
# https://www.puc-rio.br
# colecao.php
# #
# https://www.maxwell.vrac.puc-rio.br/index.php
# https://www.maxwell.vrac.puc-rio.br/colecao.php
# #
# #
# https://www.maxwell.vrac.puc-rio.br/estatisticas.php
# https://www.maxwell.vrac.puc-rio.br/sobre.php
# index.php
# estatisticas.php
# sobre.php
# prog.php?bot=contraste&tam=2&cor=Normal&strSecao=resultado&nrSeq=68056&idi=1
# prog.php?bot=normal&tam=2&cor=Normal&strSecao=resultado&nrSeq=68056&idi=1
# prog.php?bot=menor&tam=2&cor=Normal&strSecao=resultado&nrSeq=68056&idi=1
# prog.php?bot=maior&tam=2&cor=Normal&strSecao=resultado&nrSeq=68056&idi=1

# %% [markdown]
# Criando as utils functions

# %%
# Funcao para coletar link do repositorio na página da BDTD

#def get_repository_link(title):

#    bdtd_url = 'https://bdtd.ibict.br/vufind/Search/Results?lookfor=' + title.replace(' ', '+') + '&type=Title' #&limit=1'
   #Fazer requisição e parsear o arquivo html
#    try:
#        f = requests.get(bdtd_url, verify=True).text#, verify=False) 
#    except:
#        print("Sleeping for 5 seconds before retrying... (get_repository_link)")
#        time.sleep(5)
#        try:
#            f = requests.get(bdtd_url, verify=True).text#, verify=False) 
#        except:
#            print("Sleeping for 30 seconds before retrying... (get_repository_link)")
#            time.sleep(30)
#            f = requests.get(bdtd_url, verify=True).text#, verify=False)    
#    soup = bs(f, "html.parser")

    #Coletando link para o repositório
#    link_list = []
#    for doc in soup.find_all('a', href=True):
#        if (doc['href'].startswith('https://app.uff.br/') |
#            doc['href'].startswith('http://app.uff.br/')):
#            path = doc['href']
#            link_list.append(path)
#    if link_list != []:
#        return list(set(link_list))[0]
#    else:
#        return None



# Funcao para coletar link do pdf

def get_pdf_link(url):
    
    url = url.split('||')[0]
    url = url.replace('http:', 'https:')
    headers = {
    'User-Agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/58.0.3029.110 Safari/537.3'
                }

    #Fazer requisição e parsear o arquivo html
    try:
        f = requests.get(url, headers=headers, verify=True).text#, verify=False) 
        
    except:
        print("Sleeping for 5 seconds before retrying... (get_pdf_link)")
        time.sleep(5)
        try:
            f = requests.get(url, headers=headers, verify=True).text#, verify=False) 
        except:
            print("Sleeping for 30 seconds before retrying... (get_pdf_link)")
            time.sleep(30)
            f = requests.get(url, headers=headers, verify=True).text#, verify=False)    
    soup = bs(f, "html.parser")
    
    #Coletando link para as teses
    link_list = []
    for doc in soup.find_all('a', href=True):
        if True: # doc['href'].endswith('.PDF'): # & doc['href'].startswith('/bitstream')):
            path = doc['href']
            prefix_uni = ''
            link = prefix_uni + path #.replace('download', 'content')
            link_list.append(link)
    if link_list != []:
        return list(set(link_list))
    else:
        return None
    

#fazer download do arquivo
def download_file(pdf_link, thesis_uri):

    headers = {
    'User-Agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/58.0.3029.110 Safari/537.3'
                }
    
    # NOTE the stream=True parameter below
    try:
        r = requests.get(pdf_link, headers=headers, verify=True, stream=True)
    except:
        print("Sleeping for 5 seconds before retrying... (download_file)")
        time.sleep(5)
        try:
            r = requests.get(pdf_link, headers=headers, verify=True, stream=True)
        except:
            print("Sleeping for 30 seconds before retrying... (download_file)")
            time.sleep(30)
            r = requests.get(pdf_link, headers=headers, verify=True, stream=True)
    # raise_for_status() is not needed with stream=True
    # r.raise_for_status()
    with open('tese UFPA.pdf', 'wb') as f:
        for chunk in r.iter_content(chunk_size=8192):
            f.write(chunk)
    return 

#Carregando os modelos SpaCy para inglês e português 
nlp_en = spacy.load("en_core_web_lg")
nlp_pt = spacy.load("pt_core_news_lg")

# Funcão que recebe uma string e a limpar para ficar no formato aceitável para uma URI
def process_uri(x):
    return (re.sub('[^a-zA-Z0-9_ ]', '',
            unidecode(x.strip())
                        .replace(" ", "_")
                        .replace("[","")
                        .replace("]","")
                        .replace("?","")
                        .replace("'","")
                        .lower()))


# Função para extrair texto de uma tese em PDF e identificar entidades
def extratc_text(tese_path):
    
    # Processando o arquivo em PDF
    try:
        reader = PdfReader(tese_path)
        number_of_pages = len(reader.pages)
    
        excerpt = {}

        extractor = 'PdfReader'

    except:
        reader = fitz.open(tese_path)
        number_of_pages = len(reader)
    
        excerpt = {}
        
        extractor = 'PyMuPDF'

    # Iterando por cada página
    for page_number in range(number_of_pages):

        # Verificando qual extrator de pdf foi utilizado    
        if extractor == 'PdfReader':

            # Extraindo o texto da página
            try:
                if page_number == 0:
                    try:
                        page_text = (reader.pages[page_number].extract_text() + '\n ' 
                                    + reader.pages[page_number+1].extract_text()[:400])
                    except:
                        page_text = reader.pages[page_number].extract_text()
                else:
                    
                    if page_number == number_of_pages -1:
                        try:
                            page_text = (reader.pages[page_number-1].extract_text()[-400:] + '\n ' 
                                        + reader.pages[page_number].extract_text())
                        except:
                            page_text = reader.pages[page_number].extract_text()
                    
                    else:
                        try:
                            page_text = (reader.pages[page_number-1].extract_text()[-400:] + '\n ' 
                                        + reader.pages[page_number].extract_text() + '\n ' 
                                        + reader.pages[page_number+1].extract_text()[:400])  
                        except:
                            page_text = reader.pages[page_number].extract_text()
            except:
                page_text = ''
            
        else:
                
            # Extraindo o texto da página
            try:
                if page_number == 0:
                    try:
                        page_text = (reader[page_number].get_text() + '\n ' 
                                    + reader[page_number+1].get_text()[:400])
                    except:
                        page_text = reader[page_number].get_text()
                else:
                    
                    if page_number == number_of_pages -1:
                        try:
                            page_text = (reader[page_number-1].get_text()[-400:] + '\n ' 
                                        + reader[page_number].get_text())
                        except:
                            page_text = reader[page_number].get_text()
                    
                    else:
                        try:
                            page_text = (reader[page_number-1].get_text()[-400:] + '\n ' 
                                        + reader[page_number].get_text() + '\n ' 
                                        + reader[page_number+1].get_text()[:400])  
                        except:
                            page_text = reader[page_number].get_text()

            except:
                page_text = ''

        # Limpando page text         
        page_text = page_text.replace("'", "").replace('"', '')
        # Verifica se o último caractere é uma barra invertida
        if page_text != '':
            if page_text[-1] == '\\': 
                page_text = page_text[:-2]
        page_text = re.sub(r"[\ud800-\udfff]", " ", page_text)
        page_text = page_text.encode('utf-8').decode('utf-8')
        
        
        # Detectando o idioma do texto
        try:
            lang = detect(page_text)
            
        except:
            lang = 'Não_detectado'
        
        
        # Extraindo as entidades
        page_extracted = False
        if lang == 'pt':
            doc = nlp_pt(page_text)
            page_extracted = True
        if lang == 'en':
            doc = nlp_en(page_text)
            page_extracted = True
        

        if page_extracted:

            persons = []
            gpes = []
            #orgs = []
            for ent in doc.ents:
                if ent.label_ == "PER": #"PERSON":
                    persons.append(process_uri(ent.text))
                if ent.label_ == "LOC": #"GPE":
                    gpes.append(process_uri(ent.text))
                #if ent.label_ == "ORG":
                #    orgs.append(process_uri(ent.text))
                    
            excerpt[page_number] = {'text': page_text, 
                                    'lang': lang, 
                                    'persons': list(set(persons)), 
                                    'gpes': list(set(gpes)),
                                #'orgs': list(set(orgs))
                                }

    return excerpt

# %% [markdown]
# Iterando por todas as URI para extrair o texto e gravar no grafo NEO4j

# %%
# Gravar hora de início do processamento
start_time = pd.Timestamp.now()
parcial_time = pd.Timestamp.now()

for i in range(0,len(thesis_repository)):

    #title ='The problem of identity as it relates to the american black\'s vision of Africa'
    #title = thesis_repository['title'][i].replace("?","").replace('-', ' ').replace('&', ' ').replace('/', ' ').replace('\\', ' ')  
    #repo = get_repository_link(title)
    # Coletando o link do PDF
    repo = thesis_repository['repository'][i]
    
    if repo is None:
        print(f"No repository link found for title: {title}")
        pass
    
    else:
        thesis_uri = thesis_repository['Thesis'][i][16:]
        pdf_link = get_pdf_link(repo)
        if pdf_link is not None:
            # Itereando pelos links de PDF encontrados (em alguns casos há outros materiais além da tese)
            for pdf_num in range(len(pdf_link)):
                print(f"{i} - Downloading and extracting: {thesis_uri} from {pdf_link[pdf_num]}")
                download_file(pdf_link[pdf_num], thesis_uri)

                # Extraindo o texto e entidades
                tese_path = 'tese UFPA.pdf'
                excerpt = extratc_text(tese_path)

                excerpts = []
                persons = []
                gpes = []

                # Salvando as triplas em CSV
                for n in excerpt.keys():

                    excerpt_uri = thesis_repository['Thesis'][i] + '_pdf_' + str(pdf_num) + '_p_' + str(n)
                    excerpt_text = excerpt[n]['text']
                    # Verifica se o último caractere é uma barra invertida
                    #if excerpt_text[-1] == '\\': 
                    #    excerpt_text = excerpt_text[:-1]
                    

                    excerpt_page = 'pdf_' + str(pdf_num) + '_p_' + str(n)
                    excerpt_lang = excerpt[n]['lang']
                    
                    excerpts.append([thesis_repository['Thesis'][i], excerpt_uri, excerpt_text, excerpt_page, excerpt_lang])
                        
                    #Criando as relações com as entidades
                    for person in excerpt[n]['persons']:
                        persons.append([excerpt_uri, 'tag:stardog:api:' + person])
                    
                    for gpe in excerpt[n]['gpes']:
                        gpes.append([excerpt_uri, 'tag:stardog:api:' + gpe])
                
                # Salvando os dados em CSV no diretório de importação do Neo4j
                pd.DataFrame(excerpts).to_csv('C:\\Users\\facordei\\.Neo4jDesktop\\relate-data\\dbmss\\dbms-792eabfc-5517-4220-ab29-30ef6ec3236e\\import\\excerptsUFPA.csv', index=False, header=False)
                pd.DataFrame(persons).to_csv('C:\\Users\\facordei\\.Neo4jDesktop\\relate-data\\dbmss\\dbms-792eabfc-5517-4220-ab29-30ef6ec3236e\\import\\personsUFPA.csv', index=False, header=False)
                pd.DataFrame(gpes).to_csv('C:\\Users\\facordei\\.Neo4jDesktop\\relate-data\\dbmss\\dbms-792eabfc-5517-4220-ab29-30ef6ec3236e\\import\\gpesUFPA.csv', index=False, header=False)

                #Deletando o arquivo PDF após o processamento
                os.remove('tese UFPA.pdf')

                print(f"Loading triplas: {thesis_uri}")

                # Importanto os dados para o Neo4j
                #Excerpts
                query = """
                LOAD CSV FROM 'file:///excerptsUFPA.csv'
                AS row
                MATCH  (t:Thesis{uri: row[0]})
                MERGE  (e:Excerpt{
                        uri: row[1],
                        text: row[2],
                        page: row[3],
                        lang: row[4]
                        })-[r:BFO_0000050]-(t);
                """
                graph = GraphDatabase.driver(NEO4J_URL, auth=(NEO4J_USERNAME, NEO4J_PASSWORD))
                results = graph.execute_query(query)
                graph.close()

                #Persons
                query = """
                LOAD CSV FROM 'file:///personsUFPA.csv'
                AS row
                MATCH  (e:Excerpt{uri: row[0]})
                MERGE  (p:Person{uri: row[1]})
                MERGE  (e)-[r:mentions]-(p);
                """
                graph = GraphDatabase.driver(NEO4J_URL, auth=(NEO4J_USERNAME, NEO4J_PASSWORD))
                results = graph.execute_query(query)
                graph.close()

                #GPEs
                query = """
                LOAD CSV FROM 'file:///gpesUFPA.csv'
                AS row
                MATCH  (e:Excerpt{uri: row[0]})
                MERGE  (p:Place{uri: row[1]})
                MERGE  (e)-[r:mentions]-(p);
                """
                graph = GraphDatabase.driver(NEO4J_URL, auth=(NEO4J_USERNAME, NEO4J_PASSWORD))
                results = graph.execute_query(query)
                graph.close()

                # Removendo os arquivos CSV após a importação
                os.remove('C:\\Users\\facordei\\.Neo4jDesktop\\relate-data\\dbmss\\dbms-792eabfc-5517-4220-ab29-30ef6ec3236e\\import\\excerptsUFPA.csv')
                os.remove('C:\\Users\\facordei\\.Neo4jDesktop\\relate-data\\dbmss\\dbms-792eabfc-5517-4220-ab29-30ef6ec3236e\\import\\personsUFPA.csv')
                os.remove('C:\\Users\\facordei\\.Neo4jDesktop\\relate-data\\dbmss\\dbms-792eabfc-5517-4220-ab29-30ef6ec3236e\\import\\gpesUFPA.csv')

                print(f"Total time: {pd.Timestamp.now() - start_time}")
                print(f"Partial time: {pd.Timestamp.now() - parcial_time}")
                # Atualizando a hora parcial
                parcial_time = pd.Timestamp.now()
        else:
            print(f"No PDF link found for {thesis_uri}")

        # gravando no grafo que a tese foi processada
        query = """
        MATCH  (t:Thesis{uri: \'""" + thesis_repository['Thesis'][i] +  """\'})
        SET t.processed = true
        """
        #SET t.repository = \'""" + str(repo) +  """\'
        
        graph = GraphDatabase.driver(NEO4J_URL, auth=(NEO4J_USERNAME, NEO4J_PASSWORD))
        results = graph.execute_query(query)
        graph.close()
        #break
# Out:
# 0 - Downloading and extracting: educacao_e_tradicao_de_criancas_e_adolescentes_praticantes_de_candomble_ketu_os_ewe_do_ofa_kare from https://repositorio.ufpa.br/server/api/core/bitstreams/838dae09-bbb0-4b9e-8c6b-a0304f25c326/content
# Loading triplas: educacao_e_tradicao_de_criancas_e_adolescentes_praticantes_de_candomble_ketu_os_ewe_do_ofa_kare
# Total time: 0 days 00:00:30.298277
# Partial time: 0 days 00:00:30.298277
# 1 - Downloading and extracting: estrategias_de_permanencia_de_indigenas_estudantes_na_universidade_federal_do_para_desafios_e_resistencia from https://repositorio.ufpa.br/server/api/core/bitstreams/ed9f6553-f4a6-431f-8b9b-899b4db3cb24/content
# Loading triplas: estrategias_de_permanencia_de_indigenas_estudantes_na_universidade_federal_do_para_desafios_e_resistencia
# Total time: 0 days 00:01:04.173220
# Partial time: 0 days 00:00:33.875942
# 2 - Downloading and extracting: a_ameaca_aos_habitats_avaliacao_da_cobertura_e_uso_da_terra_na_area_do_municipio_de_tailandia_pa_pela_monocultura_da_palma_de_oleo from https://repositorio.ufpa.br/server/api/core/bitstreams/410b37ff-678e-46df-80e4-5a125610755c/content
# Loading triplas: a_ameaca_aos_habitats_avaliacao_da_cobertura_e_uso_da_terra_na_area_do_municipio_de_tailandia_pa_pela_monocultura_da_palma_de_oleo
# Total time: 0 days 00:01:33.000463
# Partial time: 0 days 00:00:28.826244
# 3 - Downloading and extracting: aqui_a_cura_e_de_verdade_reflexoes_em_torno_da_cura_em_sao_caetano_de_odivelaspa from https://repositorio.ufpa.br/server/api/core/bitstreams/b404437d-411b-4fcf-8b11-1f2acef5160f/content
# Loading triplas: aqui_a_cura_e_de_verdade_reflexoes_em_torno_da_cura_em_sao_caetano_de_odivelaspa
# Total time: 0 days 00:02:02.882787
# Partial time: 0 days 00:00:29.882324
# 4 - Downloading and extracting: entre_maracas_curimbas_e_tambores_pajelancas_nas_religioes_afrobrasileiras from https://repositorio.ufpa.br/server/api/core/bitstreams/8266b534-e0b1-47a6-8954-37581ecdda2d/content
# Loading triplas: entre_maracas_curimbas_e_tambores_pajelancas_nas_religioes_afrobrasileiras
# Total time: 0 days 00:02:39.714397
# Partial time: 0 days 00:00:36.831610
# 5 - Downloading and extracting: impactos_das_mudancas_climaticas_na_biomassa_florestal_amazonica_previsao_de_perda_e_estrategias_de_conservacao_prioritarias_para_o_potencial_de_biomassa_sob_as_mudancas_climaticas from https://repositorio.ufpa.br/server/api/core/bitstreams/cbaca8e2-8249-4d95-a02d-0e744a4a7f41/content
# Sleeping for 5 seconds before retrying... (download_file)
# Loading triplas: impactos_das_mudancas_climaticas_na_biomassa_florestal_amazonica_previsao_de_perda_e_estrategias_de_conservacao_prioritarias_para_o_potencial_de_biomassa_sob_as_mudancas_climaticas
# Total time: 0 days 00:03:11.663303
# Partial time: 0 days 00:00:31.947917
# 6 - Downloading and extracting: bilreiras_ancestres_alumbramentos_para_rendilhar_uma_poetica_artistica from https://repositorio.ufpa.br/server/api/core/bitstreams/eef9edd5-63d1-403a-b414-4afc1d1cca5d/content
# Loading triplas: bilreiras_ancestres_alumbramentos_para_rendilhar_uma_poetica_artistica
# Total time: 0 days 00:04:49.247381
# Partial time: 0 days 00:01:37.584078
# 7 - Downloading and extracting: entre_as_terras_do_rio_branco_e_a_guiana_inglesa_relatos_de_viajantes_sobre_povos_indigenas_18351899 from https://repositorio.ufpa.br/server/api/core/bitstreams/1e1b7502-fd40-43b3-86e8-ff2e44c78600/content
# Loading triplas: entre_as_terras_do_rio_branco_e_a_guiana_inglesa_relatos_de_viajantes_sobre_povos_indigenas_18351899
# Total time: 0 days 00:05:44.499443
# Partial time: 0 days 00:00:55.252062
# 8 - Downloading and extracting: aviamento_e_redistribuicao_na_amazonia_uma_analise_evolucionaria_do_periodo_colonial from https://repositorio.ufpa.br/server/api/core/bitstreams/373b759d-2928-4947-88e6-16603f19a12a/content
# Loading triplas: aviamento_e_redistribuicao_na_amazonia_uma_analise_evolucionaria_do_periodo_colonial
# Total time: 0 days 00:06:43.766313
# Partial time: 0 days 00:00:59.266870
# 9 - Downloading and extracting: propriedades_e_padroes_de_qualidade_na_comercializacao_de_produtos_vegetais_amazonicos_com_alegacoes_funcionais from https://repositorio.ufpa.br/server/api/core/bitstreams/60d1287b-c01f-4220-b084-55eb21643956/content
# Loading triplas: propriedades_e_padroes_de_qualidade_na_comercializacao_de_produtos_vegetais_amazonicos_com_alegacoes_funcionais
# Total time: 0 days 00:07:40.350849
# Partial time: 0 days 00:00:56.584536
# 10 - Downloading and extracting: de_nascenca_ou_de_simpatia_iniciacao_hierarquia_e_atribuicoes_dos_mestres_na_pajelanca_marajoara from https://repositorio.ufpa.br/server/api/core/bitstreams/c48bad2d-dc61-45cb-ae7f-751e0f8d4b8c/content
# Loading triplas: de_nascenca_ou_de_simpatia_iniciacao_hierarquia_e_atribuicoes_dos_mestres_na_pajelanca_marajoara
# Total time: 0 days 00:08:01.706326
# Partial time: 0 days 00:00:21.355477
# 11 - Downloading and extracting: saude_indigena_no_para_e_sua_interface_com_o_covid19_planejamento_implementacao_e_governanca from https://repositorio.ufpa.br/server/api/core/bitstreams/de1923f5-f86a-49f9-b6a7-b25f0a17635b/content
# Loading triplas: saude_indigena_no_para_e_sua_interface_com_o_covid19_planejamento_implementacao_e_governanca
# Total time: 0 days 00:08:56.412378
# Partial time: 0 days 00:00:54.706052
# 12 - Downloading and extracting: melhores_mestres_saberes_indigenas_e_ciencia_colonial_no_vale_amazonico_seculo_xviii from https://repositorio.ufpa.br/server/api/core/bitstreams/1fbc3474-95d9-4591-8bd1-aad43b4cf825/content
# Loading triplas: melhores_mestres_saberes_indigenas_e_ciencia_colonial_no_vale_amazonico_seculo_xviii
# Total time: 0 days 00:09:52.520177
# Partial time: 0 days 00:00:56.107799
# 13 - Downloading and extracting: historias_contracoloniais_em_abaetetuba_e_barcarena_grafias_de_vida_e_resistencia_do_seremcomum_na_amazonia from https://repositorio.ufpa.br/server/api/core/bitstreams/647092ad-f0d6-4f7b-8031-f42567509482/content
# Loading triplas: historias_contracoloniais_em_abaetetuba_e_barcarena_grafias_de_vida_e_resistencia_do_seremcomum_na_amazonia
# Total time: 0 days 00:11:47.464818
# Partial time: 0 days 00:01:54.944970
# 14 - Downloading and extracting: desmatamento_em_territorios_tradicionalmente_ocupados_disputas_conflitos_e_significados_do_reflorestamento_e_da_restauracao_florestal_no_bico_do_papagaio_tocantinense from https://repositorio.ufpa.br/server/api/core/bitstreams/c0056b43-2f3c-4b13-99c6-591331f502c1/content
# Loading triplas: desmatamento_em_territorios_tradicionalmente_ocupados_disputas_conflitos_e_significados_do_reflorestamento_e_da_restauracao_florestal_no_bico_do_papagaio_tocantinense
# Total time: 0 days 00:12:16.532010
# Partial time: 0 days 00:00:29.066863
# 15 - Downloading and extracting: formacao_inicial_de_professoresas_indigenas_em_dialogos_integradores_de_aprendizagem_na_objetivacao_cultural from https://repositorio.ufpa.br/server/api/core/bitstreams/ab086f4d-d9e4-4031-92d1-74b20e3f04f4/content
# Loading triplas: formacao_inicial_de_professoresas_indigenas_em_dialogos_integradores_de_aprendizagem_na_objetivacao_cultural
# Total time: 0 days 00:12:55.162788
# Partial time: 0 days 00:00:38.630778
# 16 - Downloading and extracting: o_quadrilatero_cabano_e_as_cabanagens_nos_sertoes_da_amazonia_guerra_indios_rios_e_matas_17901841 from https://repositorio.ufpa.br/server/api/core/bitstreams/d327f586-0b14-4c2c-ad01-671b4f950f9f/content
# Loading triplas: o_quadrilatero_cabano_e_as_cabanagens_nos_sertoes_da_amazonia_guerra_indios_rios_e_matas_17901841
# Total time: 0 days 00:14:11.684262
# Partial time: 0 days 00:01:16.521474
# 17 - Downloading and extracting: a_exploracao_de_recursos_faunisticos_na_amazonia_historia_economia_e_meio_ambiente_do_brasil_colonia_ao_imperio from https://repositorio.ufpa.br/server/api/core/bitstreams/6ac29479-7c63-473b-a08d-732648f5bfa1/content

# %%
i
# Out:
# 269
