# %%
import requests

# %%
pessoas_unicas = {'tag:stardog:api:deus': {'uris':['tag:stardog:api:deus', 'tag:stardog:api:god'], 
                                           'wiki_uri': 'Deus'},
                  'tag:stardog:api:karl_marx': {'uris':['tag:stardog:api:karl_marx', 'tag:stardog:api:marx', 'tag:stardog:api:karlmarx'], 
                                           'wiki_uri': 'Karl_Marx'},
                  'tag:stardog:api:viveiros_de_castro': {'uris':['tag:stardog:api:viveiros_de_castro', 'tag:stardog:api:viveiros_decastro'], 
                                           'wiki_uri': 'Eduardo_Viveiros_de_Castro'},
                  'tag:stardog:api:michel_foucault': {'uris':['tag:stardog:api:foucault', 'tag:stardog:api:michael_foucault', 'tag:stardog:api:michel_foucault'], 
                                           'wiki_uri': 'Michel_Foucault'},
                  'tag:stardog:api:exu': {'uris':['tag:stardog:api:exu'], 
                                           'wiki_uri': 'Exu_(orixá)'},
                  'tag:stardog:api:gilberto_freyre': {'uris':['tag:stardog:api:gilberto_freyre', 'tag:stardog:api:gilberto_freire', 'tag:stardog:api:gilbertofreyre'], 
                                           'wiki_uri': 'Gilberto_Freire'},
                  'tag:stardog:api:jesus_cristo': {'uris':['tag:stardog:api:jesus_cristo', 'tag:stardog:api:cristo'], 
                                           'wiki_uri': 'Jesus'},
                  'tag:stardog:api:pierre_bourdieu': {'uris':['tag:stardog:api:pierre_bourdieu', 'tag:stardog:api:bourdieu', 'tag:stardog:api:pierrebourdieu'], 
                                           'wiki_uri': 'Pierre_Bourdieu'},
                  'tag:stardog:api:xango': {'uris':['tag:stardog:api:xango'], 
                                           'wiki_uri': 'Xangô'},
                  'tag:stardog:api:levi_strauss': {'uris':['tag:stardog:api:levi_strauss', 'tag:stardog:api:levistrauss', 'tag:stardog:api:claudelevistrauss', 'tag:stardog:api:claude_levistrauss', 'tag:stardog:api:claude_levi_strauss'], 
                                           'wiki_uri': 'Claude_Lévi-Strauss'},
                  'tag:stardog:api:paulo_freire': {'uris':['tag:stardog:api:paulo_freire', 'tag:stardog:api:paulofreire'], 
                                           'wiki_uri': 'Paulo_Freire'},
                  'tag:stardog:api:ailton_krenak': {'uris':['tag:stardog:api:ailton_krenak', 'tag:stardog:api:airton_krenak', 'tag:stardog:api:ailtonkrenak', 'tag:stardog:api:ailton_alves_lacerda_krenak', 'tag:stardog:api:ailton_lacerda_krenak'], 
                                           'wiki_uri': 'Ailton_Krenak'},
                  'tag:stardog:api:daniel_munduruku': {'uris':['tag:stardog:api:munduruku', 'tag:stardog:api:daniel_munduruku', 'tag:stardog:api:danielmunduruku'], 
                                           'wiki_uri': 'Daniel_Munduruku'},
                  'tag:stardog:api:luis_inacio_lula_da_silva': {'uris':['tag:stardog:api:lula', 'tag:stardog:api:lula_da_silva', 'tag:stardog:api:luis_inacio_lula_da_silva', 'tag:stardog:api:luis_inacio_da_silva'], 
                                           'wiki_uri': 'Luiz_Inácio_Lula_da_Silva'},                                                            
                  'tag:stardog:api:florestan_fernandes': {'uris':['tag:stardog:api:florestan_fernandes', 'tag:stardog:api:florestanfernandes', 'tag:stardog:api:florestan'], 
                                           'wiki_uri': 'Florestan_Fernandes'},
                  'tag:stardog:api:lelia_gonzalez': {'uris':['tag:stardog:api:lelia_gonzalez', 'tag:stardog:api:lelia_de_almeida_gonzalez', 'tag:stardog:api:leliagonzalez'], 
                                           'wiki_uri': 'Lélia_Gonzalez'},
                  'tag:stardog:api:oxum': {'uris':['tag:stardog:api:oxum'], 
                                           'wiki_uri': 'Oxum'},
                  'tag:stardog:api:machado_de_assis': {'uris':['tag:stardog:api:machado_de_assis', 'tag:stardog:api:joaquim_maria_machado_de_assis', 'tag:stardog:api:joaquim_machado_de_assis', 'tag:stardog:api:machadodeassis', 'tag:stardog:api:machado_deassis', 'tag:stardog:api:machadode_assis'], 
                                           'wiki_uri': 'Machado_de_Assis'},
                  'tag:stardog:api:aristoteles': {'uris':['tag:stardog:api:aristoteles'], 
                                           'wiki_uri': 'Aristóteles'},
                  'tag:stardog:api:darcy_ribeiro': {'uris':['tag:stardog:api:darcy_ribeiro', 'tag:stardog:api:darcyribeiro'], 
                                           'wiki_uri': 'Darcy_Ribeiro'},                    
                  'tag:stardog:api:conceicao_evaristo': {'uris':['tag:stardog:api:conceicao_evaristo', 'tag:stardog:api:conceicaoevaristo', 'tag:stardog:api:conceicao_evaristo_de_brito', 'tag:stardog:api:maria_da_conceicao_evaristo_de_brito', 'tag:stardog:api:maria_da_conceicao_evaristo', 'tag:stardog:api:maria_conceicao_evaristo'], 
                                           'wiki_uri': 'Conceição_Evaristo'}, 
                  'tag:stardog:api:nina_rodrigues': {'uris':['tag:stardog:api:nina_rodrigues', 'tag:stardog:api:ninarodrigues', 'tag:stardog:api:raymundo_nina_rodrigues', 'tag:stardog:api:raymundo_rodrigues'], 
                                           'wiki_uri': 'Nina_Rodrigues'}, 
                  'tag:stardog:api:getulio_vargas': {'uris':['tag:stardog:api:getulio_vargas', 'tag:stardog:api:getuliovargas', 'tag:stardog:api:getulio_dorneles_vargas', 'tag:stardog:api:vargas'], 
                                           'wiki_uri': 'Getúlio_Vargas'}, 
                  'tag:stardog:api:zumbi_dos_palmares': {'uris':['tag:stardog:api:zumbi', 'tag:stardog:api:zumbi_dos_palmares', 'tag:stardog:api:zumbi_palmares'], 
                                           'wiki_uri': 'Zumbi_dos_Palmares'},
                  'tag:stardog:api:sigmund_freud': {'uris':['tag:stardog:api:freud', 'tag:stardog:api:sigmund_freud', 'tag:stardog:api:sigmundfreud'], 
                                           'wiki_uri': 'Sigmund_Freud'},
                  'tag:stardog:api:gilles_deleuze': {'uris':['tag:stardog:api:deleuze', 'tag:stardog:api:gilles_deleuze', 'tag:stardog:api:gillesdeleuze'], 
                                           'wiki_uri': 'Gilles_Deleuze'},
                  'tag:stardog:api:jose_de_alencar': {'uris':['tag:stardog:api:jose_de_alencar', 'tag:stardog:api:jose_martiniano_de_alencar',], 
                                           'wiki_uri': 'José_de_Alencar'},
                  'tag:stardog:api:abdias_do_nascimento': {'uris':['tag:stardog:api:abdias_do_nascimento', 'tag:stardog:api:abdias_nascimento', 'tag:stardog:api:abdias', 'tag:stardog:api:abdiasdonascimento', 'tag:stardog:api:abdiasnascimento'], 
                                           'wiki_uri': 'Abdias_do_Nascimento'},
                  'tag:stardog:api:iemanja': {'uris':['tag:stardog:api:iemanja'], 
                                           'wiki_uri': 'Iemanjá'},
                  'tag:stardog:api:fernando_henrique_cardoso': {'uris':['tag:stardog:api:fernando_henrique_cardoso', 'tag:stardog:api:fernando_henrique', 'tag:stardog:api:fhc', 'tag:stardog:api:fernandohenriquecardoso', 'tag:stardog:api:fernandohenrique'], 
                                           'wiki_uri': 'Fernando_Henrique_Cardoso'},
                  'tag:stardog:api:sueli_carneiro': {'uris':['tag:stardog:api:sueli_carneiro', 'tag:stardog:api:suelicarneiro', 'tag:stardog:api:aparecida_sueli_carneiro'], 
                                           'wiki_uri': 'Sueli_Carneiro'},
                  'tag:stardog:api:mario_de_andrade': {'uris':['tag:stardog:api:mario_de_andrade', 'tag:stardog:api:mario_raul_de_morais_andrade',], 
                                           'wiki_uri': 'Mário_de_Andrade'},
                  'tag:stardog:api:stuart_hall': {'uris':['tag:stardog:api:stuart_hall', 'tag:stardog:api:stuarthall'], 
                                           'wiki_uri': 'Stuart_Hall'},
                  'tag:stardog:api:friedrich_engels': {'uris':['tag:stardog:api:engels', 'tag:stardog:api:friedrich_engels', 'tag:stardog:api:friedrichengels'], 
                                           'wiki_uri': 'Friedrich_Engels'},
                  'tag:stardog:api:joaquim_nabuco': {'uris':['tag:stardog:api:joaquim_nabuco', 'tag:stardog:api:joaquimnabuco', 'tag:stardog:api:joaquim_aurelio_barreto_nabuco_de_araujo', 'tag:stardog:api:joaquim_nabuco_de_araujo', 'tag:stardog:api:joaquim_aurelio_nabuco_de_araujo', 'tag:stardog:api:joaquim_nabuco_araujo',], 
                                           'wiki_uri': 'Joaquim_Nabuco'},
                  'tag:stardog:api:manuela_carneiro_da_cunha': {'uris':['tag:stardog:api:manuela_carneiro', 'tag:stardog:api:manuelacarneiro', 'tag:stardog:api:manuela_carneiroda_cunha', 'tag:stardog:api:manuela_carneiro_da_cunha', 'tag:stardog:api:manuela_carneiro_cunha',], 
                                           'wiki_uri': 'Manuela_Carneiro_da_Cunha'},
                  'tag:stardog:api:jair_bolsonaro': {'uris':['tag:stardog:api:bolsonaro', 'tag:stardog:api:jair_bolsonaro', 'tag:stardog:api:jair_messias_bolsonaro', 'tag:stardog:api:jairbolsonaro'], 
                                           'wiki_uri': 'Jair_Bolsonaro'},
                  'tag:stardog:api:ogum': {'uris':['tag:stardog:api:ogum'], 
                                           'wiki_uri': 'Ogum'},
                  'tag:stardog:api:carlos_hasenbalg': {'uris':['tag:stardog:api:hasenbalg', 'tag:stardog:api:carlos_hasenbalg', 'tag:stardog:api:carloshasenbalg'], 
                                           'wiki_uri': 'Carlos_Hasenbalg'},
                  'tag:stardog:api:pedro_ii': {'uris':['tag:stardog:api:d_pedro_ii', 'tag:stardog:api:pedro_ii', 'tag:stardog:api:dom_pedro_ii', 'tag:stardog:api:imperador_pedro_ii'], 
                                           'wiki_uri': 'Pedro_II_do_Brasil'},
                  'tag:stardog:api:oxossi': {'uris':['tag:stardog:api:oxossi'], 
                                           'wiki_uri': 'Oxóssi'},
                  'tag:stardog:api:marshall_sahlins': {'uris':['tag:stardog:api:sahlins', 'tag:stardog:api:marshall_david_sahlins', 'tag:stardog:api:marshall_sahlins',], 
                                           'wiki_uri': 'Marshall_Sahlins'},
                  'tag:stardog:api:georg_wilhelm_friedrich_hegel': {'uris':['tag:stardog:api:hegel', 'tag:stardog:api:georg_wilhelm_friedrich_hegel', 'tag:stardog:api:friedrich_hegel', 'tag:stardog:api:georg_hegel',], 
                                           'wiki_uri': 'Georg_Wilhelm_Friedrich_Hegel'},
                  'tag:stardog:api:clifford_geertz': {'uris':['tag:stardog:api:geertz', 'tag:stardog:api:clifford_geertz', 'tag:stardog:api:cliffordgeertz', 'tag:stardog:api:james_geertz'], 
                                           'wiki_uri': 'Clifford_Geertz'},
                  'tag:stardog:api:frantz_fanon': {'uris':[ 'tag:stardog:api:frantz_fanon', 'tag:stardog:api:frantzfanon', 'tag:stardog:api:frantz_omar_fanon', 'tag:stardog:api:omar_fanon', 'tag:stardog:api:omarfanon', 'tag:stardog:api:franz_fanon',], 
                                           'wiki_uri': 'Frantz_Fanon'},
                  'tag:stardog:api:beatriz_nascimento': {'uris':['tag:stardog:api:beatriz_nascimento', 'tag:stardog:api:beatriznascimento', 'tag:stardog:api:maria_beatriz_nascimento',], 
                                           'wiki_uri': 'Beatriz_Nascimento'},
                  'tag:stardog:api:platao': {'uris':['tag:stardog:api:platao'], 
                                           'wiki_uri': 'Platão'},
                  'tag:stardog:api:curt_nimuendaju': {'uris':['tag:stardog:api:nimuendaju', 'tag:stardog:api:curt_nimuendaju', 'tag:stardog:api:curt_unckel', 'tag:stardog:api:curtnimuendaju'], 
                                           'wiki_uri': 'Curt_Nimuendajú'},
                  'tag:stardog:api:luiz_gama': {'uris':['tag:stardog:api:luiz_gama', 'tag:stardog:api:luizgama', 'tag:stardog:api:luis_gama', 'tag:stardog:api:luisgama', 'tag:stardog:api:luis_gonzaga_pinto_gama', 'tag:stardog:api:luis_gonzaga_pinto_da_gama'], 
                                           'wiki_uri': 'Luís_Gama'},
                  'tag:stardog:api:milton_santos': {'uris':['tag:stardog:api:milton_santos', 'tag:stardog:api:miltonsantos', 'tag:stardog:api:milton_almeida_santos', 'tag:stardog:api:milton_almeida_dos_santos',], 
                                           'wiki_uri': 'Milton_Santos'},
                  'tag:stardog:api:kabengele_munanga': {'uris':['tag:stardog:api:kabengele', 'tag:stardog:api:kabengele_munanga', 'tag:stardog:api:munanga', 'tag:stardog:api:kabengelemunanga'], 
                                           'wiki_uri': 'Kabengele_Munanga'},
                  'tag:stardog:api:lilia_schwarcz': {'uris':['tag:stardog:api:lilia_schwarcz', , 'tag:stardog:api:liliaschwarcz', 'tag:stardog:api:lilia_moritz', 'tag:stardog:api:liliamoritz', 'tag:stardog:api:lilia_moritz_schwarcz', 'tag:stardog:api:liliamoritzschwarcz'], 
                                           'wiki_uri': 'Lilia_Schwarcz'},
                  'tag:stardog:api:emile_durkheim': {'uris':['tag:stardog:api:durkheim', 'tag:stardog:api:emile_durkheim', 'tag:stardog:api:emiledurkheim', 'tag:stardog:api:david_emile_durkheim'], 
                                           'wiki_uri': 'Émile_Durkheim'}, 
                  'tag:stardog:api:achille_mbembe': {'uris':['tag:stardog:api:achille_mbembe', 'tag:stardog:api:achillembembe', 'tag:stardog:api:joseph_achille_mbembe'], 
                                           'wiki_uri': 'Achille_Mbembe'}, 
                  'tag:stardog:api:flavio_dos_santos_gomes': {'uris':['tag:stardog:api:flavio_dos_santos_gomes', 'tag:stardog:api:flavio_dos_santos', ], 
                                           'wiki_uri': 'Flávio_dos_Santos_Gomes'}, 
                  'tag:stardog:api:felix_guattari': {'uris':['tag:stardog:api:felix_guattari', 'tag:stardog:api:felixguattari', 'tag:stardog:api:guattari'], 
                                           'wiki_uri': 'Félix_Guattari'}, 
                  'tag:stardog:api:jean_jacques_rousseau': {'uris':['tag:stardog:api:jean_jacques_rousseau', 'tag:stardog:api:jeanjacquesrousseau', 'tag:stardog:api:rousseau', 'tag:stardog:api:jean_rousseau', 'tag:stardog:api:jacques_rousseau'], 
                                           'wiki_uri': 'Jean-Jacques_Rousseau'}, 
                  'tag:stardog:api:clovis_moura': {'uris':['tag:stardog:api:clovis_moura', 'tag:stardog:api:clovismoura', 'tag:stardog:api:clovis_steiger_de_assis_moura', 'tag:stardog:api:clovis_de_assis_moura'], 
                                           'wiki_uri': 'Clóvis_Moura'}, 
                  'tag:stardog:api:immanuel_kant': {'uris':['tag:stardog:api:immanuel_kant', 'tag:stardog:api:immanuelkant', 'tag:stardog:api:kant'], 
                                           'wiki_uri': 'Immanuel_Kant'}, 
                  'tag:stardog:api:roger_bastide': {'uris':['tag:stardog:api:roger_bastide', 'tag:stardog:api:rogerbastide'], 
                                           'wiki_uri': 'Roger_Bastide'}, 
                  'tag:stardog:api:nossa_senhora': {'uris':['tag:stardog:api:nossa_senhora', 'tag:stardog:api:nossasenhora'], 
                                           'wiki_uri': 'Maria_(mãe_de_Jesus)'},
                  'tag:stardog:api:candido_rondon': {'uris':['tag:stardog:api:candido_rondon', 'tag:stardog:api:candidorondon', 'tag:stardog:api:rondon', 'tag:stardog:api:marechal_rondon', 'tag:stardog:api:candido_mariano_da_silva_rondon', 'tag:stardog:api:candido_da_silva_rondon', 'tag:stardog:api:candido_mariano_rondon'], 
                                           'wiki_uri': 'Cândido_Rondon'},
                  'tag:stardog:api:nossa_senhora_do_rosario': {'uris':['tag:stardog:api:nossa_senhora_do_rosario'], 
                                           'wiki_uri': 'Nossa_Senhora_do_Rosário'},
                  'tag:stardog:api:friedrich_nietzsche': {'uris':['tag:stardog:api:friedrich_nietzsche', 'tag:stardog:api:nietzsche', 'tag:stardog:api:friedrichnietzsche', 'tag:stardog:api:friedrich_wilhelm_nietzsche'], 
                                           'wiki_uri': 'Friedrich_Nietzsche'},
                  'tag:stardog:api:bell_hooks': {'uris':['tag:stardog:api:bell_hooks', 'tag:stardog:api:bellhooks', 'tag:stardog:api:gloria_jean_watkins', 'tag:stardog:api:gloria_watkins'], 
                                           'wiki_uri': 'Bell_hooks'},
                  'tag:stardog:api:marques_de_pombal': {'uris':['tag:stardog:api:marques_de_pombal', 'tag:stardog:api:marques_pombal', 'tag:stardog:api:marquesdepombal', 'tag:stardog:api:marques_depombal', 'tag:stardog:api:marquesde_pombal'], 
                                           'wiki_uri': 'Sebastião_José_de_Carvalho_e_Melo'},
                  'tag:stardog:api:hanna_arendt': {'uris':['tag:stardog:api:hanna_arendt', 'tag:stardog:api:arendt'], 
                                           'wiki_uri': 'Hannah_Arendt'},
                  'tag:stardog:api:carolina_maria_de_jesus': {'uris':['tag:stardog:api:carolina_maria_de_jesus', 'tag:stardog:api:carolina_maria_de_jesus'], 
                                           'wiki_uri': 'Carolina_Maria_de_Jesus'},
                  'tag:stardog:api:orixa': {'uris':['tag:stardog:api:orixa'], 
                                           'wiki_uri': 'Orixá'},
                  'tag:stardog:api:silvio_romero': {'uris':['tag:stardog:api:silvio_romero', 'tag:stardog:api:silvioromero', 'tag:stardog:api:silvio_vasconcelos_da_silveira_ramos_romero', 'tag:stardog:api:silvio_ramos_romero'], 
                                           'wiki_uri': 'Sílvio_Romero'},
                  'tag:stardog:api:sergio_buarque_de_holanda': {'uris':['tag:stardog:api:sergio_buarque', 'tag:stardog:api:sergiobuarque', 'tag:stardog:api:sergio_buarque_de_holanda', 'tag:stardog:api:sergiobuarquedeholanda', 'tag:stardog:api:sergio_buarquedeholanda'], 
                                           'wiki_uri': 'Sérgio_Buarque_de_Holanda'},
                  'tag:stardog:api:jorge_amado': {'uris':['tag:stardog:api:jorge_amado', 'tag:stardog:api:jorgeamado', 'tag:stardog:api:jorge_leal_amado_de_faria'], 
                                           'wiki_uri': 'Jorge_Amado'},
                  'tag:stardog:api:eric_hobsbawm': {'uris':['tag:stardog:api:eric_hobsbawm', 'tag:stardog:api:erichobsbawm', 'tag:stardog:api:hobsbawm', 'tag:stardog:api:eric_john_ernest_hobsbawm'], 
                                           'wiki_uri': 'Eric_Hobsbawm'},
                  'tag:stardog:api:lima_barreto': {'uris':['tag:stardog:api:lima_barreto', 'tag:stardog:api:limabarreto', 'tag:stardog:api:afonso_henriques_de_lima_barreto'], 
                                           'wiki_uri': 'Lima_Barreto_(escritor)'},
                  'tag:stardog:api:jurgen_habermas': {'uris':['tag:stardog:api:jurgen_habermas', 'tag:stardog:api:jurgenhabermas', 'tag:stardog:api:habermas'], 
                                           'wiki_uri': 'Jürgen_Habermas'},
                  'tag:stardog:api:d_joao_v': {'uris':[ 'tag:stardog:api:d_joao_v', 'tag:stardog:api:d_joao_v', 'tag:stardog:api:joao_v'], 
                                           'wiki_uri': 'João_V_de_Portugal'},
                  'tag:stardog:api:joao_pacheco_de_oliveira': {'uris':['tag:stardog:api:joao_pacheco', 'tag:stardog:api:joao_pacheco_de_oliveira', 'tag:stardog:api:joaopacheco_de_oliveira'], 
                                           'wiki_uri': 'João_Pacheco_de_Oliveira_(antropólogo)'}
}                                           
                                           
                                           #'wikipedia_abstract': {'en':'abstract in english',
                                           #                     'pt':'resumo em português'}}}

# %%
pessoas_unicas.keys()
# Out:
# dict_keys(['tag:stardog:api:deus', 'tag:stardog:api:karl_marx', 'tag:stardog:api:viveiros_de_castro', 'tag:stardog:api:michel_foucault', 'tag:stardog:api:exu', 'tag:stardog:api:gilberto_freyre', 'tag:stardog:api:jesus_cristo', 'tag:stardog:api:pierre_bourdieu', 'tag:stardog:api:xango', 'tag:stardog:api:levi_strauss', 'tag:stardog:api:paulo_freire', 'tag:stardog:api:ailton_krenak', 'tag:stardog:api:daniel_munduruku', 'tag:stardog:api:luis_inacio_lula_da_silva', 'tag:stardog:api:florestan_fernandes', 'tag:stardog:api:lelia_gonzalez', 'tag:stardog:api:oxum', 'tag:stardog:api:machado_de_assis', 'tag:stardog:api:aristoteles', 'tag:stardog:api:darcy_ribeiro', 'tag:stardog:api:conceicao_evaristo', 'tag:stardog:api:nina_rodrigues', 'tag:stardog:api:getulio_vargas', 'tag:stardog:api:zumbi_dos_palmares', 'tag:stardog:api:sigmund_freud', 'tag:stardog:api:gilles_deleuze', 'tag:stardog:api:jose_de_alencar', 'tag:stardog:api:abdias_do_nascimento', 'tag:stardog:api:iemanja', 'tag:stardog:api:fernan
# ...

# %%
    'tag:stardog:api:hegel',
    'tag:stardog:api:georg_wilhelm_friedrich_hegel',
    'tag:stardog:api:friedrich_hegel',
    'tag:stardog:api:georg_hegel',
    'tag:stardog:api:geertz',
    'tag:stardog:api:clifford_geertz',
    'tag:stardog:api:james_geertz',
    'tag:stardog:api:frantz_fanon',
    'tag:stardog:api:frantz_omar_fanon',
    'tag:stardog:api:omar_fanon',
    'tag:stardog:api:franz_fanon',
    'tag:stardog:api:beatriz_nascimento',
    'tag:stardog:api:maria_beatriz_nascimento',
    'tag:stardog:api:platao',
    'tag:stardog:api:nimuendaju',
    'tag:stardog:api:curt_nimuendaju',
    'tag:stardog:api:curt_unckel',
    'tag:stardog:api:luiz_gama',
    'tag:stardog:api:luis_gama',
    'tag:stardog:api:luis_gonzaga_pinto_gama',
    'tag:stardog:api:luis_gonzaga_pinto_da_gama',
    'tag:stardog:api:milton_santos',
    'tag:stardog:api:milton_almeida_santos',
    'tag:stardog:api:milton_almeida_dos_santos',
    'tag:stardog:api:kabengele',
    'tag:stardog:api:kabengele_munanga',
    'tag:stardog:api:munanga',
]

# %%
import requests

def get_wiki_summary(title, lang='pt'):
    # Define o endpoint da REST API
    url = f"https://{lang}.wikipedia.org/api/rest_v1/page/summary/{title}"
    
    # É uma boa prática definir um User-Agent para identificar sua aplicação
    headers = {
        'User-Agent': 'MeuScriptDeResumo/1.0 (contato@exemplo.com)'
    }
    
    try:
        response = requests.get(url, headers=headers)
        response.raise_for_status() # Verifica se houve erro na requisição
        
        data = response.json()
        
        # Extrai os campos principais
        resumo = {
            'description': data.get('description'),
            'abstract': data.get('extract')
        }
        return resumo
        
    except requests.exceptions.RequestException as e:
        return f"Erro ao acessar a API: {e}"

# %%
get_wiki_summary('Karl_Marx', 'en')
# Out:
# {'description': 'German philosopher and socialist theorist (1818–1883)',
#  'abstract': "Karl Marx was a German philosopher, social and political theorist, economist, journalist, and revolutionary socialist. He is best-known for the 1848 pamphlet The Communist Manifesto, and his three-volume Das Kapital (1867–1894), a critique of classical political economy which employs his theory of historical materialism in an analysis of capitalism, in the culmination of his life's work. Marx's ideas and their subsequent development, collectively known as Marxism, have had enormous influence."}

# %%
for uri in pessoas_unicas.keys():
    pessoas_unicas[uri]['wiki_pt'] = get_wiki_summary(pessoas_unicas[uri]['wiki_uri'], 'pt')
    pessoas_unicas[uri]['wiki_en'] = get_wiki_summary(pessoas_unicas[uri]['wiki_uri'], 'en')
    
pessoas_unicas
# Out:
# {'tag:stardog:api:deus': {'uris': ['tag:stardog:api:deus',
#    'tag:stardog:api:god'],
#   'wiki_uri': 'Deus',
#   'wiki_pt': {'description': 'entidade concebida como onipotente, onipresente e onisciente',
#    'abstract': 'Nos sistemas de crenças monoteístas, Deus é geralmente visto como o ser supremo, criador e principal objeto da fé. Nos sistemas de crenças politeístas, um deus é "um espírito ou ser que se acredita ter criado, ou que controla alguma parte do universo ou da vida, motivo pelo qual tal divindade é frequentemente adorada". A crença na existência de pelo menos um deus é chamada de teísmo.'},
#   'wiki_en': {'description': 'Latin for "god" or "deity"',
#    'abstract': "Deus is the Latin word for 'god' or 'deity'.\nLatin deus and dīvus ('divine') are in turn descended from Proto-Indo-European *deiwos, 'celestial' or 'shining', from the same root as *Dyēus, the reconstructed chief god of the Proto-Indo-European pantheon."}},
# ...
